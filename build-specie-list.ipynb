# %% [markdown]
# This notebook uses the existing Wyoming Landscape Conservation Initiative (WLIC) literature database and the eXtract Dark Data database (xDD, also known as GeoDeepDive: https://geodeepdive.org/) to build a list of unique specie names that have been published on in WLCI efforts.

# %%
#Import Needed packages
import requests
import pandas as pd

# %%
#The WLCI literature database was exported as CSL JSON and posted to this ScienceBase Item: https://www.sciencebase.gov/catalog/item/4f4e476fe4b07f02db47e19f 
#as file wlci_lit_20190702.json.  The file can be accessed via 

#File download url
lit_json_file = "https://www.sciencebase.gov/catalog/file/get/4f4e476fe4b07f02db47e19f?f=__disk__ad%2F2e%2Fcc%2Fad2ecc69ef3957ef9cd23d4cba1c7c68b983acad"
#Request and return JSON of literature data
lit_json = requests.get(lit_json_file).json()

# %%
#Set function for accessing xDD database
def xdd_api(route, params):
    """Create list of docs mentioning a term of interest
    Parameters : see https://geodeepdive.org/api for more detail
    ----------
    routes : str of available api routes for xDD 
    params : str of key value pairs of paramaters:values separated by &
    """
    base_url = 'https://geodeepdive.org/api'
    search = (base_url + '/' + route + '?' + str(params))
    #print (search)
    try:
        r=requests.get(search)
        if r.status_code == 200 and 'success' in r.json():
            json_r = r.json()
            data = json_r['success']['data']
            return data
        elif r.status_code == 200:
            data = []
            return data
        else:
            raise Exception('xDD API returning: {}'.format(r.status_code))
    except Exception as e:
        raise Exception(e)

# %%
#Create list of relationship information between WLCI database and xDD database
wlci_xdd = []
for ref in lit_json:
    wlci_id = ref['id']
    if 'DOI' in ref:
        doi = ref['DOI']
    elif 'note' in ref and 'OCLC' not in ref['note']:
        doi = ref['note']
    route = 'articles'
    param = 'max=1&doi='+str(doi)
    xdd_data = xdd_api(route, param)
    if xdd_data:
        xdd_id = xdd_data[0]['_gddid']
        wlci_xdd.append({'wlci_id': wlci_id, 'relation': 'doi_match', 'xdd_id':xdd_id, 'param':param, 'title': ref['title']})

# %%
#Turn list of matched articles into Pandas dataframe for visual
wlci_xdd_df = pd.DataFrame(wlci_xdd)
wlci_xdd_df
# Out:
#                                          param   relation  \
# 0                 max=1&doi=10.1002/jwmg.21386  doi_match
# 1      max=1&doi=10.1016/j.ecolind.2015.03.002  doi_match
# 2                   max=1&doi=10.1002/jwmg.155  doi_match
# 3                   max=1&doi=10.1002/eap.1512  doi_match
# 4                 max=1&doi=10.1002/jwmg.21179  doi_match
# 5      max=1&doi=10.1080/2150704X.2015.1072289  doi_match
# 6      max=1&doi=10.1016/j.ecolind.2017.12.033  doi_match
# 7       max=1&doi=10.1080/15420353.2014.885925  doi_match
# 8       max=1&doi=10.1080/15420353.2014.885925  doi_match
# 9       max=1&doi=10.1080/15420353.2014.885925  doi_match
# 10                  max=1&doi=10.1002/jwmg.337  doi_match
# 11     max=1&doi=10.1016/j.jhydrol.2015.02.020  doi_match
# 12      max=1&doi=10.1080/01431161.2011.605085  doi_match
# 13                 max=1&doi=10.1002/ecs2.2113  doi_match
# 14                 max=1&doi=10.1002/ieam.4118  doi_match
# 15                 max=1&doi=10.1890/08-2034.1  doi_match
# 16                  max=1&doi=10.2193/2008-478  doi_match
# 17           max=1&doi=10.1111/1365-2664.12013  doi_match
# 18  max=1&doi=10.1111/j.1365-2656.2011.01845.x  doi_match
# 19      max=1&doi=10.1016/j.biocon.2018.10.020  doi_match
# 20                 max=1&doi=10.1002/ece3.3607  doi_match
# 21         max=1&doi=10.1016/j.jag.2014.01.008  doi_match
# 22         max=1&doi=10.1016/j.jag.2011.09.012  doi_match
# 23           max=1&doi=10.1111/1365-2664.12513  doi_match
# 24      max=1&doi=10.1016/j.biocon.2015.02.009  doi_match
# 25   max=1&doi=10.1016/j.ecolmodel.2017.05.017  doi_match
# 26                 max=1&doi=10.1111/ele.12772  doi_match
# 27      max=1&doi=10.1016/j.foreco.2016.01.017  doi_match
# 28      max=1&doi=10.1016/j.foreco.2016.01.017  doi_match
# 29                 max=1&doi=10.1111/gcb.12852  doi_match
# 30                 max=1&doi=10.1111/gcb.12852  doi_match
# 31                 max=1&doi=10.1111/gcb.12852  doi_match
# 32                 max=1&doi=10.1002/wmon.1014  doi_match
# 33                 max=1&doi=10.1002/wmon.1014  doi_match
# 34                 max=1&doi=10.1002/wmon.1014  doi_match
# 35                 max=1&doi=10.1002/wmon.1014  doi_match
#
#                                                 title  \
# 0   Greater Sage-Grouse Population Trends Across W...
# 1   Forecasting Sagebrush Ecosystem Components and...
# 2   The Importance of Within-Year Repeated Counts ...
# 3   Patterns in Greater Sage-grouse population dyn...
# 4   Investigating Impacts of Oil and Gas Developme...
# 5   Mapping Forest Functional Type in a Forest-Shr...
# 6   Vegetation Responses to Sagebrush-reduction Tr...
# 7   Geospatial Considerations for a Multiorganizat...
# 8   Map Service: Historical Oil and Gas Exploratio...
# 9   Interactive Mapping Application of Oil and Gas...
# 10  Interseasonal Movements of Greater Sage-Grouse...
# 11  Soil Disturbance as a Driver of Increased Stre...
# 12  Assessing Long-Term Variations in Sagebrush Ha...
# 13  Evaluating the Influence of Energy and Residen...
# 14  Multiple Approaches to Surface Water Quality A...
# 15  Identifying and Prioritizing Ungulate Migratio...
# 16  Influence of Well Pad Activity on Winter Habit...
# 17  A Framework for Understanding Semi-Permeable B...
# 18           Stopover Ecology of a Migratory Ungulate
# 19  Novel Landscape Elements within Natural Gas Fi...
# 20  Salinity Tolerance of Three Competing Rangelan...
# 21  Performance and Effects of Land Cover Type on ...
# 22  Multi-Scale Remote Sensing Sagebrush Character...
# 23  Towards a Mechanistic Understanding of Human-i...
# 24  Energy Development and Avian Nest Survival in ...
# 25  Using Dynamic Population Simulations to Extend...
# 26  The Greenscape Shapes Surfing of Resource Wave...
# 27  Spatial and Temporal Trends of Drought Effects...
# 28  Video: Exploration and Production Through Time...
# 29  Greater Deciduous Shrub Abundance Extends Tund...
# 30  Habitat Use and Migration Ecology of Mule Deer...
# 31  Demographic Responses of Sagebrush-Obligate So...
# 32  Habitat Prioritization Across Large Landscapes...
# 33  Evaluating the Influence of Development on Mul...
# 34  Evaluating Natural Gas Development Impacts on ...
# 35  Retrospective Approaches to Evaluate Resilienc...
#
#                                             wlci_id                    xdd_id
# 0   http://zotero.org/groups/2341914/items/R3NSCC9R  5c2c30a41faed655488b299b
# 1   http://zotero.org/groups/2341914/items/Z7TMPV6Q  579f4458cf58f123c56623f8
# 2   http://zotero.org/groups/2341914/items/JFV5GDKM  5c2c1b8a1faed655488b27d9
# 3   http://zotero.org/groups/2341914/items/Q5TCVPYX  58e2c641cf58f1697d39b86b
# 4   http://zotero.org/groups/2341914/items/W5K4UAZ8  5c2c22901faed655488b289b
# 5   http://zotero.org/groups/2341914/items/X3I66DJ8  594407d1cf58f1b3059ba5a4
# 6   http://zotero.org/groups/2341914/items/822S7HY8  5ad055c3cf58f1a9152a8fd5
# 7   http://zotero.org/groups/2341914/items/9N87KUPL  5c7442c01faed65548974980
# 8   http://zotero.org/groups/2341914/items/RUFHZ2GV  5c7442c01faed65548974980
# 9   http://zotero.org/groups/2341914/items/I7C83EUR  5c7442c01faed65548974980
# 10  http://zotero.org/groups/2341914/items/4TCBL9S3  5c2c30a41faed655488b29a1
# 11  http://zotero.org/groups/2341914/items/HJ28LVB4  54fefadfe13823a766aa719f
# 12  http://zotero.org/groups/2341914/items/TRECRZAA  5904c6c6cf58f152d18be8bf
# 13  http://zotero.org/groups/2341914/items/5GTCJ27A  5c4977e21faed6554893aeb0
# 14  http://zotero.org/groups/2341914/items/D78REKE6  5ce31ce50b45c76caf8ae883
# 15  http://zotero.org/groups/2341914/items/K7EW3YQE  5839f904cf58f149de664120
# 16  http://zotero.org/groups/2341914/items/F4N9CWU6  572c8f7ccf58f1127a9809f7
# 17  http://zotero.org/groups/2341914/items/7243RZFL  58976134cf58f1a1de231c7a
# 18  http://zotero.org/groups/2341914/items/Q9VEKFZX  583da612cf58f107cb09840d
# 19  http://zotero.org/groups/2341914/items/K4YNMGZX  5c1cc81f1faed65548897433
# 20  http://zotero.org/groups/2341914/items/JK87YUFS  5a49f8becf58f132c3775c3a
# 21  http://zotero.org/groups/2341914/items/4W5FVZZM  551d04b9e138236e51a9956a
# 22  http://zotero.org/groups/2341914/items/5PXF3TPC  551d6881e138236e51a9970e
# 23  http://zotero.org/groups/2341914/items/NNI3PJ5Z  5897848bcf58f1ac5aa42563
# 24  http://zotero.org/groups/2341914/items/88PSMFIC  57a84443cf58f17046db1a8a
# 25  http://zotero.org/groups/2341914/items/G9L9FU5W  5acfde1ecf58f17c7517b27d
# 26  http://zotero.org/groups/2341914/items/BH3VH7QL  5900f56ccf58f172049f469a
# 27  http://zotero.org/groups/2341914/items/RUATTVSK  577bdf78cf58f1585217325f
# 28  http://zotero.org/groups/2341914/items/SEWHB8JW  577bdf78cf58f1585217325f
# 29  http://zotero.org/groups/2341914/items/LSJ875PV  585b52f3cf58f1a722da9ab5
# 30  http://zotero.org/groups/2341914/items/UWBWSZ6T  585b52f3cf58f1a722da9ab5
# 31  http://zotero.org/groups/2341914/items/CFZY53Q2  585b52f3cf58f1a722da9ab5
# 32  http://zotero.org/groups/2341914/items/A2WG577D  5c4e3f571faed655489408c3
# 33  http://zotero.org/groups/2341914/items/5Z6EBWBP  5c4e3f571faed655489408c3
# 34  http://zotero.org/groups/2341914/items/2XW76EW7  5c4e3f571faed655489408c3
# 35  http://zotero.org/groups/2341914/items/KP3R7Q33  5c4e3f571faed655489408c3

# %%
# Save csv documenting xdd and wlci literature relationship
wlci_xdd_df.to_csv('sources/wlci_xdd_lit.csv', sep=',')

# %%
#Create list of species that are mentioned in the WLCI efforts
specie_mentions = []
for xdd_record in wlci_xdd:
    wlci_id = xdd_record['wlci_id']
    xdd_id = xdd_record['xdd_id']
    route = 'terms'
    param = f"docid={xdd_id}&dictionary=ITIS"
    xdd_data = xdd_api(route, param)
    for x in xdd_data:
        if len(x['term'].split()) >1:
            specie = x['term']
            hits = str(x['n_hits'])
            #specie_mentions.append({'specie':specie, 'xdd_id':xdd_id, 'wlci_id':wlci_id, 'n_hits':hits}) 
            specie_mentions.append(specie)

# %%
with open('sources/wlci_xdd_specie_list.txt', 'w') as file_handler:
    file_handler.write("\n".join(str(item) for item in specie_mentions))
