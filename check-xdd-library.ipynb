# %% [markdown]
# To keep up with current literature on species of interest this notebook accesses eXtract Dark Data (xDD), formaly known as GeoDeepDive.  The xDD database is continuously being updated with published scientific literature from many of the large publishers including Elsiver, Taylor & Francis, GSA, and USGS.  We are currently working with the xDD team  on a number of tools and techniques for a) identifying literature potentially applicable to species-based research and b) using natural language processing tools to pull specific data from those sources for use. This is an ongoing effort that will result in improved production capabilities over time.
#
# In the near term, we take advantage of some basic and enhanced search functionality to identify potential articles of interested in the xDD library of millions of documents that are increasing daily. The xdd module in the bispy package contains some search and packaging functionality that interfaces with the xDD REST API.

# %%
import requests
import json
import bispy
from IPython.display import display
from joblib import Parallel, delayed
import random

xdd = bispy.xdd.Xdd()

import warnings
warnings.filterwarnings('ignore')

# %%
# Open source WLCI list created from build-specie-list.ipynb
with open("sources/wlci_xdd_specie_list.txt", "r") as f:
    sp_list =f.readlines()
sp_list= [x.strip() for x in sp_list]

# %%
# Use joblib to run multiple requests to xDD in parallel via scientific names
xdd_results = Parallel(n_jobs=8)(delayed(xdd.snippets)(name) for name in [r for r in sp_list])

# %%
# Dump the records we discovered and packaged to a cache file
# I need to revisit this once I get some things cleared up with taxonomic matching to hopefully find more records
with open("cache/xdd.json", "w") as f:
    f.write(json.dumps([x for x in xdd_results if "Number Documents" in x["Processing Metadata"].keys() and x["Processing Metadata"]["Number Documents"] > 0], indent=4))

# %%
# Open the file back up and verify
with open("cache/xdd.json", "r") as f:
    xdd_cache = json.loads(f.read())

print(len(xdd_cache))
display(xdd_cache[random.randint(0,len(xdd_cache)-1)])
# Out:
# 58
# {'Processing Metadata': {'Status': 'Success',
#   'Date Processed': '2019-07-03T15:28:49.990156',
#   'Search URL': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Centrocercus minimus',
#   'Search Term': 'Centrocercus minimus',
#   'Number Documents': 41},
#  'Data': [{'pubname': 'Biological Conservation',
#    'publisher': 'Elsevier',
#    '_gddid': '57a9de64cf58f138b8812975',
#    'title': 'Polygyny and female breeding failure reduce effective population size in the lekking Gunnison sage-grouse',
#    'doi': '10.1016/j.biocon.2007.10.018',
#    'coverDate': 'February 2008',
#    'URL': 'http://www.sciencedirect.com/science/article/pii/S0006320707004223',
#    'authors': 'Stiver, Julie R.; Apa, Anthony D.; Remington, Thomas E.; Gibson, Robert M.',
#    'highlight': ['of a small population of the Gunnison sage-grouse (Centrocercus minimus), a ground',
#     'Gunnison sage-grouse (Centrocercus minimus), a ground nesting bird with a lek mating',
#     'al., 1999; Kelly, 2001). The Gunnison sage-grouse (Centrocercus minimus) is a recently',
#     'Gunnison sage-grouse (Centrocercus minimus) is a recently described bird species existing',
#     'inbreeding depression occurs  Bonasa sewerzowi a 6 Centrocercus minimus b  5  C.',
#     'occurs  Bonasa sewerzowi a 6 Centrocercus minimus b  5  C. urophasianus c Lagopus lagopus']},
#   {'pubname': 'Conservation Biology',
#    'publisher': 'Wiley',
#    '_gddid': '583cc508cf58f178fb628706',
#    'title': 'Population Bottlenecks and Increased Hatching Failure in Endangered Birds',
#    'doi': '10.1111/j.1523-1739.2010.01553.x',
#    'coverDate': '2010 12',
#    'URL': 'http://doi.wiley.com/10.1111/j.1523-1739.2010.01553.x',
#    'authors': 'HEBER, SOL; BRISKIE, JAMES V.',
#    'highlight': ['Himantopus mexicanus knudseni; 27, Myadestes palmeri; 28, Centrocercus minimus; 29, Foudia',
#     'Myadestes palmeri; 28, Centrocercus minimus; 29, Foudia rubra; 30, Otus insularis; 31,']},
#   {'pubname': 'The Journal of Wildlife Management',
#    'publisher': 'Wiley',
#    '_gddid': '5c2c37a71faed655488b2ace',
#    'title': 'Habitat selection and use by sympatric, translocated greater sage-grouse and Columbian sharp-tailed grouse',
#    'doi': '10.1002/jwmg.990',
#    'coverDate': '2015 11',
#    'URL': 'http://doi.wiley.com/10.1002/jwmg.990',
#    'authors': 'Stonehouse, Kourtney F.; Shipley, Lisa A.; Lowe, Jason; Atamian, Michael T.; Swanson, Mark E.; Schroeder, Michael A.',
#    'highlight': ['2010, Aldridge et al. 2012), Gunnison sage-grouse (Centrocercus minimus; Lyon and',
#     'Gunnison sage-grouse (Centrocercus minimus; Lyon and Anderson 2003), greater prairie-chickens']},
#   {'pubname': 'Forest Ecology and Management',
#    'publisher': 'Elsevier',
#    '_gddid': '577bddbfcf58f15852172d7f',
#    'title': 'Synthesis of the conservation value of the early-successional stage in forests of eastern North America',
#    'doi': '10.1016/j.foreco.2013.12.001',
#    'coverDate': '15 July 2014',
#    'URL': 'http://www.sciencedirect.com/science/article/pii/S0378112713007949',
#    'authors': 'King, David I.; Schlossberg, Scott',
#    'highlight': ['species are shrubland species (Gunnison sage-grouse [Centrocercus minimus], Florida',
#     '(Gunnison sage-grouse [Centrocercus minimus], Florida scrub-jay [Aphelocoma coerulescens],']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '57c0ef84cf58f1331a56f583',
#    'title': 'Evaluation of the lek-count index for greater sage-grouse',
#    'doi': '10.2193/0091-7648(2004)32[56:EOTLIF]2.0.CO;2',
#    'coverDate': 'March 2004',
#    'URL': 'http://www.bioone.org/doi/abs/10.2193/0091-7648%282004%2932%5B56%3AEOTLIF%5D2.0.CO%3B2',
#    'authors': 'Walsh, Daniel P.; White, Gary C.; Remington, Thomas E.; Bowden, David C.',
#    'highlight': ['GROUSE WORKING GROUP. 2000. Gunnison sage grouse (Centrocercus minimus) conservation',
#     '2000. Gunnison sage grouse (Centrocercus minimus) conservation plan. San Juan County Gunnison']},
#   {'pubname': 'Journal of Wildlife Management',
#    'publisher': 'Wiley',
#    '_gddid': '572c8f81cf58f1127a980a05',
#    'title': 'Raptor and Corvid Response to Power Distribution Line Perch Deterrents in Utah',
#    'doi': '10.2193/2009-204',
#    'coverDate': 'May 2010',
#    'URL': 'http://www.bioone.org/doi/abs/10.2193/2009-204',
#    'authors': 'Prather, Phoebe R.; Messmer, Terry A.',
#    'highlight': ['line that bisected occupied Gunnison sage-grouse (Centrocercus minimus) habitat',
#     'Gunnison sage-grouse (Centrocercus minimus) habitat in southeastern Utah, USA. Perch',
#     'man-made vertical structures. KEY WORDS avian predators, Centrocercus minimus, corvids,',
#     'avian predators, Centrocercus minimus, corvids, Gunnison sage-grouse, mitigation,',
#     'G. 2005. Summer ecology of Gunnison sage-grouse (Centrocercus minimus) in San',
#     'Gunnison sage-grouse (Centrocercus minimus) in San Juan County, Utah. Thesis, Utah']},
#   {'pubname': 'Animal Conservation',
#    'publisher': 'Wiley',
#    '_gddid': '583b75eccf58f109b4b3aeee',
#    'title': 'A pedigree gone bad: increased offspring survival after using DNA-based relatedness to minimize inbreeding in\xa0a\xa0captive population',
#    'doi': '10.1111/acv.12247',
#    'coverDate': '2016 06',
#    'URL': 'http://doi.wiley.com/10.1111/acv.12247',
#    'authors': 'Hammerly, S. C.; de la Cerda, D. A.; Bailey, H.; Johnson, J. A.',
#    'highlight': ['noninvasive sampling studies of Gunnison Sage-Grouse (Centrocercus minimus). Conserv.',
#     'Gunnison Sage-Grouse (Centrocercus minimus). Conserv. Genet. Resour. 2, 17–20. Piertney,']},
#   {'pubname': 'Wildlife Monographs',
#    'publisher': 'Wiley',
#    '_gddid': '5c4e3f571faed655489408c3',
#    'title': 'Habitat prioritization across large landscapes, multiple seasons, and novel areas: An example using greater sage-grouse in Wyoming',
#    'doi': '10.1002/wmon.1014',
#    'coverDate': '2014 09',
#    'URL': 'http://doi.wiley.com/10.1002/wmon.1014',
#    'authors': "Fedy, Bradley C.; Doherty, Kevin E.; Aldridge, Cameron L.; O'Donnell, Micheal; Beck, Jeffrey L.; Bedrosian, Bryan; Gummer, David; Holloran, Matthew J.; Johnson, Gregory D.; Kaczor, Nicholas W.; Kirol, Christopher P.; Mandich, Cheryl A.; Marshall, David; Mckee, Gwyn; Olson, Chad; Pratt, Aaron C.; Swanson, Christopher C.; Walker, Brett L.",
#    'highlight': ['Doherty et al. 2008). Similarly, Gunnison sage-grouse (Centrocercus minimus) avoided',
#     'Gunnison sage-grouse (Centrocercus minimus) avoided nesting in habitats in proximity']},
#   {'pubname': 'Advances in Climate Change Research',
#    'publisher': 'Elsevier',
#    '_gddid': '55fc544ecf58f1b3a35acd51',
#    'title': 'Climate Change Adaptation for People and Nature: A Case Study from the U.S. Southwest',
#    'doi': '10.3724/SP.J.1248.2012.00022',
#    'coverDate': '25 March 2012',
#    'URL': 'http://www.sciencedirect.com/science/article/pii/S1674927812500031',
#    'authors': 'Mccarthy, Patrick D.',
#    'highlight': ['to build resilience of the Gunnison sage-grouse (Centrocercus minimus) and sustain',
#     'Gunnison sage-grouse (Centrocercus minimus) and sustain surface water and groundwater']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '572028dccf58f17baa18bf5d',
#    'title': 'Managing nesting by Chihuahuan ravens on H-frame electric transmission structures',
#    'doi': '10.1002/wsb.129',
#    'coverDate': 'June 2012',
#    'URL': 'http://doi.wiley.com/10.1002/wsb.129',
#    'authors': 'Dwyer, James F.; Leiker, Diana L.',
#    'highlight': ['ravens; Coates et al. 2008) and Gunnison sage-grouse (Centrocercus minimus) are species',
#     'Gunnison sage-grouse (Centrocercus minimus) are species of special concern (Colorado']},
#   {'pubname': 'Ibis',
#    'publisher': 'Wiley',
#    '_gddid': '58b1e970cf58f198f55331c6',
#    'title': 'Book reviews',
#    'doi': '10.1111/ibi.12301',
#    'coverDate': '2015 10',
#    'URL': 'http://doi.wiley.com/10.1111/ibi.12301',
#    'authors': '',
#    'highlight': ['that new species of kiwi (Apteryx rowi),  grouse (Centrocercus minimus), albatross',
#     'rowi),  grouse (Centrocercus minimus), albatross (Diomedea antipodensis), hawk-eagle']},
#   {'pubname': 'Molecular Ecology',
#    'publisher': 'Wiley',
#    '_gddid': '570cb3a1cf58f1717f0196a1',
#    'title': 'A multilocus population genetic survey of the greater sage-grouse across their range',
#    'doi': '10.1111/j.1365-294X.2005.02491.x',
#    'coverDate': 'April 2005',
#    'URL': 'http://doi.wiley.com/10.1111/j.1365-294X.2005.02491.x',
#    'authors': 'OYLER-MCCANCE, S. J.; TAYLOR, S. E.; QUINN, T. W.',
#    'highlight': ['sage-grouse (Young et al. 2000), the Gunnison sage-grouse (Centrocercus minimus). Benedict',
#     'Gunnison sage-grouse (Centrocercus minimus). Benedict et al. (2003) investigated whether']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '57c0fb31cf58f136e6f0031b',
#    'title': "Federal listing of prairie grouse: lessons from the Attwater's prairie-chicken",
#    'doi': '10.2193/0091-7648(2004)32[112:FLOPGL]2.0.CO;2',
#    'coverDate': 'March 2004',
#    'URL': 'http://www.bioone.org/doi/abs/10.2193/0091-7648%282004%2932%5B112%3AFLOPGL%5D2.0.CO%3B2',
#    'authors': 'Morrow, Michael E.; Rossignol, Terry A.; Silvy, Nova J.',
#    'highlight': ['state or provincial level. The Gunnison sage grouse (Centrocercus minimus), the western',
#     'Gunnison sage grouse (Centrocercus minimus), the western sage grouse (C. urophasianus']},
#   {'pubname': 'Conservation Letters',
#    'publisher': 'Wiley',
#    '_gddid': '5713bc59cf58f1b3cec396a6',
#    'title': 'Conserving imperiled species: a comparison of the IUCN Red List and U.S. Endangered Species Act',
#    'doi': '10.1111/j.1755-263X.2011.00205.x',
#    'coverDate': 'January 2012',
#    'URL': 'http://doi.wiley.com/10.1111/j.1755-263X.2011.00205.x',
#    'authors': 'Harris, J. Berton C.; Reid, J. Leighton; Scheffers, Brett R.; Wanger, Thomas C.; Sodhi, Navjot S.; Fordham, Damien A.; Brook, Barry W.',
#    'highlight': ['(Vermivora bachmanii)a,b Endangered Gunnison sage-grouse (Centrocercus minimus) Hawaiian',
#     'Gunnison sage-grouse (Centrocercus minimus) Hawaiian duck (Anas wyvilliana) black-footed']},
#   {'pubname': 'Journal of Evolutionary Biology',
#    'publisher': 'Wiley',
#    '_gddid': '57172db5cf58f14f932de5da',
#    'title': 'Role of sexual and natural selection in evolution of body size and shape: a phylogenetic study of morphological radiation in grouse',
#    'doi': '10.1111/j.1420-9101.2006.01097.x',
#    'coverDate': 'July 2006',
#    'URL': 'http://doi.wiley.com/10.1111/j.1420-9101.2006.01097.x',
#    'authors': 'DROVETSKI, S. V.; ROHWER, S.; MODE, N. A.',
#    'highlight': ['bonasia – hazel grouse B. umbellus – ruffed grouse Centrocercus minimus – Gunnison',
#     '– ruffed grouse Centrocercus minimus – Gunnison grouse C. urophasianus – sage']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '571ffc54cf58f16a1c4d0f82',
#    'title': 'Age and sex identification from wings of sage-grouse',
#    'doi': '10.1002/wsb.517',
#    'coverDate': 'March 2015',
#    'URL': 'http://doi.wiley.com/10.1002/wsb.517',
#    'authors': 'Braun, Clait E.; Schroeder, Michael A.',
#    'highlight': ['The Wildlife Society. KEY WORDS age determination, Centrocercus minimus, Centrocercus',
#     'age determination, Centrocercus minimus, Centrocercus urophasianus, greater sage-grouse,']},
#   {'pubname': 'Ecology and Evolution',
#    'publisher': 'Wiley',
#    '_gddid': '5712acc0cf58f158378f2c9b',
#    'title': 'An integrated modeling approach to estimating Gunnison sage-grouse population dynamics: combining index and demographic data',
#    'doi': '10.1002/ece3.1290',
#    'coverDate': 'October 2014',
#    'URL': 'http://doi.wiley.com/10.1002/ece3.1290',
#    'authors': 'Davis, Amy J.; Hooten, Mevin B.; Phillips, Michael L.; Doherty, Paul F.',
#    'highlight': ['Fort Collins, Colorado 80526  Keywords Bayesian, Centrocercus minimus, growth',
#     '80526  Keywords Bayesian, Centrocercus minimus, growth rate, integrated population model,',
#     'population growth rate (k) for Gunnison sage-grouse (Centrocercus minimus). The long-term',
#     'Gunnison sage-grouse (Centrocercus minimus). The long-term population index data available',
#     'integrated population modeling to Gunnison sage-grouse (Centrocercus minimus, GUSG)',
#     'Gunnison sage-grouse (Centrocercus minimus, GUSG) data. GUSG have declined substantially']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '57c0e4eccf58f12f97221139',
#    'title': 'Private-land habitat opportunities for prairie grouse through federal conservation programs',
#    'doi': '10.2193/0091-7648(2004)32[83:PHOFPG]2.0.CO;2',
#    'coverDate': 'March 2004',
#    'URL': 'http://www.bioone.org/doi/abs/10.2193/0091-7648%282004%2932%5B83%3APHOFPG%5D2.0.CO%3B2',
#    'authors': 'Riley, Terry Z.',
#    'highlight': ['significant declines in the populations of prairie grouse (Centrocercus minimus, C. urophasianus,',
#     'prairie grouse (Centrocercus minimus, C. urophasianus, Tympanuchus cupido, T.',
#     '(Centrocercus urophasianus), Gunnison sage-grouse (Centrocercus minimus), and sharp-tailed',
#     'Gunnison sage-grouse (Centrocercus minimus), and sharp-tailed grouse (Tympanuchus phasianellus)']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '57c0fb30cf58f136e6f00319',
#    'title': 'Assuring the future of prairie grouse: dogmas, demagogues, and getting outside the box',
#    'doi': '10.2193/0091-7648(2004)32[104:ATFOPG]2.0.CO;2',
#    'coverDate': 'March 2004',
#    'URL': 'http://www.bioone.org/doi/abs/10.2193/0091-7648%282004%2932%5B104%3AATFOPG%5D2.0.CO%3B2',
#    'authors': 'Applegate, Roger D.; Williams, Christopher K.; Manes, Robert R.',
#    'highlight': ['to Young et al. (2000), the Gunnison sage-grouse (Centrocercus minimus) was unlikely',
#     'Gunnison sage-grouse (Centrocercus minimus) was unlikely to have occurred in Kansas']},
#   {'pubname': 'Zoo Biology',
#    'publisher': 'Wiley',
#    '_gddid': '57e1b3cbcf58f17e03469378',
#    'title': 'Captive-breeding of captive and wild-reared Gunnison sage-grouse',
#    'doi': '10.1002/zoo.21253',
#    'coverDate': '2016 01',
#    'URL': 'http://doi.wiley.com/10.1002/zoo.21253',
#    'authors': 'Apa, Anthony D.; Wiechman, Lief A.',
#    'highlight': ['University, Fort Collins, CO Gunnison sage-grouse (Centrocercus minimus) distribution',
#     'CO Gunnison sage-grouse (Centrocercus minimus) distribution in North America has decreased',
#     'Wiley Periodicals, Inc. Keywords: captive flock; Centrocercus minimus; conservation-reliant;',
#     'Inc. Keywords: captive flock; Centrocercus minimus; conservation-reliant; founder flock  INTRODUCTION Gunnison',
#     'founder flock  INTRODUCTION Gunnison sage-grouse (Centrocercus minimus; GUSG)',
#     'flock  INTRODUCTION Gunnison sage-grouse (Centrocercus minimus; GUSG) distribution in North America has']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '57c0f553cf58f1351467c314',
#    'title': 'West Nile virus and sage-grouse: What more have we learned?',
#    'doi': '10.2193/0091-7648(2005)33[616:WNVASW]2.0.CO;2',
#    'coverDate': 'June 2005',
#    'URL': 'http://doi.wiley.com/10.2193/0091-7648(2005)33[616:WNVASW]2.0.CO;2',
#    'authors': 'Naugle, David E.; Aldridge, Cameron L.; Walker, Brett L.; Doherty, Kevin E.; Matchett, Marc R.; McIntosh, Jock; Cornish, Todd E.; Boyce, Mark S.',
#    'highlight': ['(Centrocercus urophasianus) and Gunnison sage-grouse (Centrocercus minimus). Previously',
#     'Gunnison sage-grouse (Centrocercus minimus). Previously widespread, sage-grouse have']},
#   {'pubname': 'Biodiversity',
#    'publisher': 'Taylor and Francis',
#    '_gddid': '594e1508cf58f18aab773a91',
#    'title': 'Effects of invasive alien plants on birds: some examples from North America',
#    'doi': '10.1080/14888386.2005.9712772',
#    'coverDate': '2005 11',
#    'URL': 'http://www.tandfonline.com/doi/abs/10.1080/14888386.2005.9712772',
#    'authors': 'Catling, Paul M.',
#    'highlight': ['the affected birds are the Gunnison Sage Grouse (Centrocercus minimus) and the',
#     'Gunnison Sage Grouse (Centrocercus minimus) and the Greater Sage Grouse (Centrocercus']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '57c0ffdecf58f138733ec8a7',
#    'title': 'Gunnison Sage-Grouse Use of Conservation Reserve Program Fields in Utah and Response to Emergency Grazing: A Preliminary Evaluation',
#    'doi': '10.2193/0091-7648(2006)34[957:GSUOCR]2.0.CO;2',
#    'coverDate': 'November 2006',
#    'URL': 'http://doi.wiley.com/10.2193/0091-7648(2006)34[957:GSUOCR]2.0.CO;2',
#    'authors': 'LUPIS, SARAH G.; MESSMER, TERRY A.; BLACK, TODD',
#    'highlight': ['Conservation Reserve Program (CRP) by Gunnison sage-grouse (Centrocercus minimus) or the',
#     'Gunnison sage-grouse (Centrocercus minimus) or the impacts of grazing on their habitat',
#     'SOCIETY BULLETIN 34(4):957–962; 2006)  Key words Centrocercus minimus, Conservation',
#     '2006)  Key words Centrocercus minimus, Conservation Reserve Program, emergency',
#     'sage-grouse, habitat use, Utah.  Gunnison sage-grouse (Centrocercus minimus) once inhabited',
#     'Utah.  Gunnison sage-grouse (Centrocercus minimus) once inhabited the Gunnison Basin of Colorado,',
#     'Movement and habitat use by Gunnison sage grouse (Centrocercus minimus) in southwestern',
#     'Gunnison sage grouse (Centrocercus minimus) in southwestern Colorado. Thesis, University',
#     'L. 2005. Summer ecology of Gunnison sage-grouse (Centrocercus minimus) in San',
#     'Gunnison sage-grouse (Centrocercus minimus) in San Juan County, Utah. Thesis, Utah']},
#   {'pubname': 'Ecosphere',
#    'publisher': 'Wiley',
#    '_gddid': '571a7b89cf58f1a73337b6df',
#    'title': 'Combined effects of heat waves and droughts on avian communities across the conterminous United States',
#    'doi': '10.1890/ES10-00057.1',
#    'coverDate': 'November 2010',
#    'URL': 'http://doi.wiley.com/10.1890/ES10-00057.1',
#    'authors': 'Albright, Thomas P.; Pidgeon, Anna M.; Rittenhouse, Chadwick D.; Clayton, Murray K.; Wardlow, Brian D.; Flather, Curtis H.; Culbert, Patrick D.; Radeloff, Volker C.',
#    'highlight': ['vetula Bonasa umbellus Centrocercus urophasianus Centrocercus minimus Falcipennis',
#     'Centrocercus urophasianus Centrocercus minimus Falcipennis canadensis Lagopus lagopus Lagopus']},
#   {'pubname': 'The Journal of Wildlife Management',
#    'publisher': 'Wiley',
#    '_gddid': '5c866a291faed65548992b00',
#    'title': 'Population Estimation Techniques for Lekking Species',
#    'doi': '10.1111/j.1937-2817.2010.tb01291.x',
#    'coverDate': '2010 09',
#    'URL': 'http://doi.wiley.com/10.1111/j.1937-2817.2010.tb01291.x',
#    'authors': 'WALSH, DANIEL P.; STIVER, JULIE R.; WHITE, GARY C.; REMINGTON, THOMAS E.; APA, ANTHONY D.',
#    'highlight': ['(Centrocercus urophasianus) and Gunnison sage-grouse (Centrocercus minimus). We evaluated',
#     'Gunnison sage-grouse (Centrocercus minimus). We evaluated 2 different estimators: Bowden’s',
#     '(Tympanuchus pallidicinctus), Gunnison sage-grouse (Centrocercus minimus), and greater',
#     'Gunnison sage-grouse (Centrocercus minimus), and greater sagegrouse (Centrocercus urophasianus;']},
#   {'pubname': 'Molecular Ecology Resources',
#    'publisher': 'Wiley',
#    '_gddid': '5721130dcf58f11df339e445',
#    'title': 'Countering criticisms of single mitochondrial DNA gene barcoding in birds',
#    'doi': '10.1111/j.1755-0998.2009.02650.x',
#    'coverDate': 'May 2009',
#    'URL': 'http://doi.wiley.com/10.1111/j.1755-0998.2009.02650.x',
#    'authors': 'BAKER, ALLAN J.; TAVARES, ERIKA SENDRA; ELBOURNE, REBECCA F.',
#    'highlight': ['nuchalis, S. ruber Empidonax difficilis, E. occidentalis Centrocercus minimus, C. urophasianus',
#     'E. occidentalis Centrocercus minimus, C. urophasianus Catharus minimus, C. bicknelli  50']},
#   {'pubname': 'Zoo Biology',
#    'publisher': 'Wiley',
#    '_gddid': '57e1a6dccf58f1798b946043',
#    'title': 'Captive-rearing of Gunnison sage-grouse from egg collection to adulthood to foster proactive conservation and recovery of a conservation-reliant species',
#    'doi': '10.1002/zoo.21228',
#    'coverDate': '2015 09',
#    'URL': 'http://doi.wiley.com/10.1002/zoo.21228',
#    'authors': 'Apa, Anthony D.; Wiechman, Lief A.',
#    'highlight': ['State University, Colorado  Gunnison sage-grouse (Centrocercus minimus) are distributed',
#     'Colorado  Gunnison sage-grouse (Centrocercus minimus) are distributed across southwestern Colorado',
#     'incubation; bacterial infection; captive population; Centrocercus minimus; Galliformes',
#     'captive population; Centrocercus minimus; Galliformes husbandry; wild and captive',
#     'and hatch  INTRODUCTION  The Gunnison sage-grouse (Centrocercus minimus; GUSG)',
#     'Gunnison sage-grouse (Centrocercus minimus; GUSG) is a recently described species [Young']},
#   {'pubname': 'Journal of Arid Environments',
#    'publisher': 'Elsevier',
#    '_gddid': '58b98c32cf58f17ab6772d2f',
#    'title': 'Nutritional analysis of sagebrush by near-infrared reflectance spectroscopy',
#    'doi': '10.1016/j.jaridenv.2016.07.003',
#    'coverDate': 'November 2016',
#    'URL': 'http://www.sciencedirect.com/science/article/pii/S014019631630129X',
#    'authors': 'Olsoy, Peter J.; Griggs, Thomas C.; Ulappa, Amy C.; Gehlken, Kristina; Shipley, Lisa A.; Shewmaker, Glenn E.; Forbey, Jennifer Sorensen',
#    'highlight': ['conservation concern (e.g., Gunnison sage-grouse [Centrocercus minimus], greater',
#     'Gunnison sage-grouse [Centrocercus minimus], greater sage-grouse [Centrocercus urophasianus],']},
#   {'pubname': 'Wildlife Society Bulletin',
#    'publisher': 'Wiley',
#    '_gddid': '57c0ef81cf58f1331a56f57c',
#    'title': 'Contributions of the Farm Bill on Fish and Wildlife',
#    'doi': '10.2193/0091-7648(2006)34[905:COTFBO]2.0.CO;2',
#    'coverDate': 'November 2006',
#    'URL': 'http://doi.wiley.com/10.2193/0091-7648(2006)34[905:COTFBO]2.0.CO;2',
#    'authors': 'GRAY, RANDALL L.; TEELS, BILLY M.',
#    'highlight': ['County for conservation of the Gunnison sage-grouse (Centrocercus minimus), previously',
#     'Gunnison sage-grouse (Centrocercus minimus), previously a candidate species for listing']},
#   {'pubname': 'Conservation Biology',
#    'publisher': 'Wiley',
#    '_gddid': '583cda1ecf58f18039c552d0',
#    'title': 'Accelerating Adaptation of Natural Resource Management to Address Climate Change',
#    'doi': '10.1111/j.1523-1739.2012.01954.x',
#    'coverDate': '2013 02',
#    'URL': 'http://doi.wiley.com/10.1111/j.1523-1739.2012.01954.x',
#    'authors': 'Cross, Molly S.; McCarthy, Patrick D.; Garfin, Gregg; Gori, David; Enquist, Carolyn A.F.',
#    'highlight': ['losses  Gunnison River basin, Colorado  Gunnison Sage-Grouse (Centrocercus minimus)  increase',
#     'Colorado  Gunnison Sage-Grouse (Centrocercus minimus)  increase and maintain the Gunnison population',
#     'via fencing and planting” for Gunnison Sage-Grouse (Centrocercus minimus) (Neely',
#     'Gunnison Sage-Grouse (Centrocercus minimus) (Neely et al. 2010). Other actions, however,']},
#   {'pubname': 'Journal of Biogeography',
#    'publisher': 'Wiley',
#    '_gddid': '5c3017301faed655488b70cf',
#    'title': 'What makes the Sino-Himalayan mountains the major diversity hotspots for pheasants?',
#    'doi': '10.1111/jbi.13156',
#    'coverDate': '2018 03',
#    'URL': 'http://doi.wiley.com/10.1111/jbi.13156',
#    'authors': 'Cai, Tianlong; Fjeldså, Jon; Wu, Yongjie; Shao, Shimiao; Chen, Youhua; Quan, Qing; Li, Xinhai; Song, Gang; Qu, Yanhua; Qiao, Gexia; Lei, Fumin',
#    'highlight': ['sewerzowi Tetrastes bonasia Centrocercus urophasianus Centrocercus minimus Dendragapus',
#     'Centrocercus urophasianus Centrocercus minimus Dendragapus obscurus Dendragapus fuliginosus']},
#   {'pubname': 'Ecology and Evolution',
#    'publisher': 'Wiley',
#    '_gddid': '5712e761cf58f16c1d00bb97',
#    'title': 'Genetic variation in nuclear and mitochondrial markers supports a large sex difference in lifetime reproductive skew in a lekking species',
#    'doi': '10.1002/ece3.1188',
#    'coverDate': 'September 2014',
#    'URL': 'http://doi.wiley.com/10.1002/ece3.1188',
#    'authors': 'Verkuil, Yvonne I.; Juillet, Cedric; Lank, David B.; Widemo, Fredrik; Piersma, Theunis',
#    'highlight': ['lekking species. In the lekking Gunnison sagegrouse (Centrocercus minimus), the simulated',
#     'Gunnison sagegrouse (Centrocercus minimus), the simulated reduction in effective population']},
#   {'pubname': 'Biological Conservation',
#    'publisher': 'Elsevier',
#    '_gddid': '5ad2651acf58f1ac17934225',
#    'title': 'Synthesizing multiple data types for biological conservation using integrated population models',
#    'doi': '10.1016/j.biocon.2017.10.017',
#    'coverDate': 'January 2018',
#    'URL': 'https://www.sciencedirect.com/science/article/pii/S0006320717305141',
#    'authors': 'Zipkin, Elise F.; Saunders, Sarah P.',
#    'highlight': ['extensive information available for sage-grouse (Centrocercus minimus, C. urophasianus),',
#     'for sage-grouse (Centrocercus minimus, C. urophasianus), a threatened species']},
#   {'pubname': 'Ecology and Evolution',
#    'publisher': 'Wiley',
#    '_gddid': '57502b7dcf58f16f8bcffb96',
#    'title': 'Evaluating vegetation effects on animal demographics: the role of plant phenology and sampling bias',
#    'doi': '10.1002/ece3.2148',
#    'coverDate': 'April 2016',
#    'URL': 'http://doi.wiley.com/10.1002/ece3.2148',
#    'authors': 'Gibson, Daniel; Blomberg, Erik J.; Sedinger, James S.',
#    'highlight': ['(Centrocercus urophasianus) Gunnison Sage-grouse (Centrocercus minimus) Lesser',
#     'Gunnison Sage-grouse (Centrocercus minimus) Lesser Prairie Chicken (Tympanuchus pallidicinctus)',
#     'Daily nest survival rates of Gunnison sage-grouse (Centrocercus minimus): assessing',
#     'Gunnison sage-grouse (Centrocercus minimus): assessing local- and landscape-scale drivers.']},
#   {'pubname': 'PLOS ONE',
#    'publisher': 'Public Library of Science',
#    '_gddid': '577349bf642f88249251630b',
#    'title': 'PLOS ONE: Nest Success of Gunnison Sage-Grouse in Colorado, USA',
#    'doi': '10.1371/journal.pone.0136310',
#    'coverDate': 'Aug 19, 2015',
#    'URL': 'http://journals.plos.org/plosone/article?id=10.1371%2Fjournal.pone.0136310',
#    'authors': 'Amy J. Davis ;  Michael L. Phillips ;  Paul F. Doherty Jr.',
#    'highlight': ['University, UNITED STATES  Gunnison Sage-Grouse (Centrocercus minimus) is a species',
#     'STATES  Gunnison Sage-Grouse (Centrocercus minimus) is a species of concern for which little demographic',
#     'species [1,2]. The range of Gunnison Sage-Grouse (Centrocercus minimus, GUSG)',
#     'Gunnison Sage-Grouse (Centrocercus minimus, GUSG) has contracted to 10% of the possible']},
#   {'pubname': 'Ibis',
#    'publisher': 'Wiley',
#    '_gddid': '58b16ac3cf58f168c838f199',
#    'title': 'Book reviews',
#    'doi': '10.1111/j.1474-919X.2011.01202.x',
#    'coverDate': '2012 01',
#    'URL': 'http://doi.wiley.com/10.1111/j.1474-919X.2011.01202.x',
#    'authors': '',
#    'highlight': ['more urgent priorities. The Gunnison Sage Grouse Centrocercus minimus was already',
#     'Gunnison Sage Grouse Centrocercus minimus was already listed, having lost almost 90%']},
#   {'pubname': 'Ecology and Evolution',
#    'publisher': 'Wiley',
#    '_gddid': '5a2db5e1cf58f12162d47c8d',
#    'title': 'Effects of livestock grazing on rangeland biodiversity: A meta-analysis of grouse populations',
#    'doi': '10.1002/ece3.3287',
#    'coverDate': '2017 10',
#    'URL': 'http://doi.wiley.com/10.1002/ece3.3287',
#    'authors': 'Dettenmaier, Seth J.; Messmer, Terry A.; Hovick, Torre J.; Dahlgren, David K.',
#    'highlight': ['(Silvy & Hagen, 2004). The Gunnison sage-\xadgrouse (Centrocercus minimus) in North',
#     'Gunnison sage-\xadgrouse (Centrocercus minimus) in North America (NA) was listed as a threatened',
#     'urophasianus  <150,000  Near threatened Decreasing  Gunnison Sage-\xadGrousec  Centrocercus minimus <2,500  Endangered  Decreasing  White-\xadtailed',
#     'Decreasing  Gunnison Sage-\xadGrousec  Centrocercus minimus <2,500  Endangered  Decreasing  White-\xadtailed']},
#   {'pubname': 'Journal of Arid Environments',
#    'publisher': 'Elsevier',
#    '_gddid': '552240d1e138236e51a9ab64',
#    'title': 'Historical fire in sagebrush landscapes of the Gunnison sage-grouse range from land-survey records',
#    'doi': '10.1016/j.jaridenv.2013.07.005',
#    'coverDate': 'November 2013',
#    'URL': 'http://www.sciencedirect.com/science/article/pii/S0140196313001250',
#    'authors': 'Bukowski, Beth E.; Baker, William L.',
#    'highlight': ['current range of the Gunnison sage-grouse (GUSG; Centrocercus minimus), which',
#     'sage-grouse (GUSG; Centrocercus minimus), which is proposed for listing under the',
#     'populations, such as the Gunnison sage-grouse (GUSG; Centrocercus minimus). Few studies,',
#     'sage-grouse (GUSG; Centrocercus minimus). Few studies, using data derived directly']},
#   {'pubname': 'The Journal of Wildlife Management',
#    'publisher': 'Wiley',
#    '_gddid': '5c2c3eaf1faed655488b2b30',
#    'title': 'Crucial nesting habitat for gunnison sage-grouse: A spatially explicit hierarchical approach',
#    'doi': '10.1002/jwmg.268',
#    'coverDate': '2012 02',
#    'URL': 'http://doi.wiley.com/10.1002/jwmg.268',
#    'authors': 'Aldridge, Cameron L.; Saher, D. Joanne; Childers, Theresa M.; Stahlnecker, Kenneth E.; Bowen, Zachary H.',
#    'highlight': ['CO 80526-8118, USA ABSTRACT Gunnison sage-grouse (Centrocercus minimus) is a species',
#     'Gunnison sage-grouse (Centrocercus minimus) is a species of special concern and is',
#     'scenarios. ß 2011 The Wildlife Society. KEY WORDS Centrocercus minimus, Colorado,',
#     'Society. KEY WORDS Centrocercus minimus, Colorado, extrapolation, Gunnison sage-grouse,',
#     'Messier 2000, Mayor et al. 2009). Gunnison sage-grouse (Centrocercus minimus) is considered',
#     '2009). Gunnison sage-grouse (Centrocercus minimus) is considered a species of special concern']},
#   {'pubname': 'Diversity and Distributions',
#    'publisher': 'Wiley',
#    '_gddid': '5711fc37cf58f119dff02d4d',
#    'title': 'Range-wide patterns of greater sage-grouse persistence',
#    'doi': '10.1111/j.1472-4642.2008.00502.x',
#    'coverDate': 'November 2008',
#    'URL': 'http://doi.wiley.com/10.1111/j.1472-4642.2008.00502.x',
#    'authors': 'Aldridge, Cameron L.; Nielsen, Scott E.; Beyer, Hawthorne L.; Boyce, Mark S.; Connelly, John W.; Knick, Steven T.; Schroeder, Michael A.',
#    'highlight': ['(Centrocercus urophasianus) and Gunnison sage-grouse (Centrocercus minimus) in North',
#     'Gunnison sage-grouse (Centrocercus minimus) in North America. Adapted from Schroeder']},
#   {'pubname': 'Journal of Avian Biology',
#    'publisher': 'Wiley',
#    '_gddid': '5c7d61011faed655489847e0',
#    'title': 'Survival of Gunnison sage-grouse Centrocercus minimus in Colorado, USA',
#    'doi': '10.1111/jav.00473',
#    'coverDate': '2015 03',
#    'URL': 'http://doi.wiley.com/10.1111/jav.00473',
#    'authors': 'Davis, Amy J.; Phillips, Michael L.; Doherty, Paul F.',
#    'highlight': ['September 2014  Survival of Gunnison sage-grouse Centrocercus minimus in Colorado,',
#     'Gunnison sage-grouse Centrocercus minimus in Colorado, USA  Amy J.\xa0Davis, Michael',
#     'Fort Collins, CO 80526, USA.\xad  Gunnison sage-grouse Centrocercus minimus has declined',
#     'USA.\xad  Gunnison sage-grouse Centrocercus minimus has declined from their historic range and',
#     'changes in adult survival.  Gunnison sage-grouse Centrocercus minimus (hereafter',
#     'survival.  Gunnison sage-grouse Centrocercus minimus (hereafter GUSG) have declined considerably']}]}
