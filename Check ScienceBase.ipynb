# %% [markdown]
# Understanding what data products are released about a species is important in understanding what we know about the species and what gaps may exist in current knowledge.  This notebook leverages USGS SB to return official data release items that mention species of interest.

# %%
#Import needed packages
import requests
import json
import bispy
from IPython.display import display
from joblib import Parallel, delayed
import random
from bispy import bis 
from sciencebasepy import SbSession

sb = SbSession()
bis_utils = bispy.bis.Utils()

# %%
# Open up the cached updated ITIS list with valid/accepted species names from ITIS Exploration.ipynb
with open("cache/valid_itis.json", "r") as f:
    valid_itis = json.loads(f.read())

# %% [markdown]
# This function finds items in ScienceBase containing a given WLCI species name within the item

# %%
# Use joblib to run multiple requests for ScienceBase records in parallel via the valid/accepted ITIS scientific names
sb_results = Parallel(n_jobs=8)(delayed(sb.find_items_by_any_text)(name) for name in [r["scientific_name"] for r in valid_itis])
sb_results
# Out:
# [{'total': 8,
#   'took': '1.9s',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Festuca+idahoensis&max=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e49dce4b07f02db5e1737'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e49dce4b07f02db5e1737',
#       'rel': 'related'}},
#     'id': '4f4e49dce4b07f02db5e1737',
#     'title': 'Mycorrhizae transfer carbon from a native grass to an invasive weed: evidence from stable isotopes and physiology',
#     'summary': "Invasive exotic weeds pose one of the earth's most pressing environmental problems. Although many invaders completely eliminate native plant species from some communities, ecologists know little about the mechanisms by which these exotics competitively exclude other species. Mycorrhizal fungi radically alter competitive interactions between plants within natural communities, and a recent study has shown that arbuscular mycorrhizal (AM) fungi provide a substantial competitive advantage to spotted knapweed, Centaurea maculosa, a noxious perennial plant that has spread throughout much of the native prairie in the northwestern U.S. Here we present evidence that this advantage is potentially due to mycorrhizally mediated transfer of carbon [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 172.1092}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505376a9e4b097cd4fcdd3b9'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505376a9e4b097cd4fcdd3b9',
#       'rel': 'related'}},
#     'id': '505376a9e4b097cd4fcdd3b9',
#     'title': 'Responses of bluebunch wheatgrass, Idaho fescue, and nematodes to ungulate grazing in Yellowstone National Park',
#     'hasChildren': False,
#     '_searchHit': {'_score': 150.0055}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50576cd2e4b01ad7e027a7a1'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50576cd2e4b01ad7e027a7a1',
#       'rel': 'related'}},
#     'id': '50576cd2e4b01ad7e027a7a1',
#     'title': 'Relationships between Centaurea maculosa and indigenous plant assemblages',
#     'hasChildren': False,
#     '_searchHit': {'_score': 144.72763}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50576b1ee4b01ad7e027a1bb'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50576b1ee4b01ad7e027a1bb',
#       'rel': 'related'}},
#     'id': '50576b1ee4b01ad7e027a1bb',
#     'title': 'Relative importance of allelopathy in interference: the effects of an invasive weed on a native bunchgrass',
#     'hasChildren': False,
#     '_searchHit': {'_score': 142.12584}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b54fe4b097cd4fced02f'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b54fe4b097cd4fced02f',
#       'rel': 'related'}},
#     'id': '5053b54fe4b097cd4fced02f',
#     'title': 'Biodiversity among Festuca (Poaceae) in North America: Diagnostic evidence from DELTA and clustering programs, and an INTKEY package for interactive, illustrated identification and information retrieval',
#     'hasChildren': False,
#     '_searchHit': {'_score': 141.36359}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053f675e4b097cd4fcf8693'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053f675e4b097cd4fcf8693',
#       'rel': 'related'}},
#     'id': '5053f675e4b097cd4fcf8693',
#     'title': 'Mycorrhizae and Fine Root Dynamics of Centaurea maculosa and Native Bunchgrasses in Western Montana',
#     'hasChildren': False,
#     '_searchHit': {'_score': 129.0821}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e48c1e4b07f02db53c357'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e48c1e4b07f02db53c357',
#       'rel': 'related'}},
#     'id': '4f4e48c1e4b07f02db53c357',
#     'title': 'Germination and seed water status of four grasses on moss-dominated biological soil crusts from arid lands',
#     'summary': 'Biological soil crusts dominated by drought-tolerant mosses are commonly found through arid and semiarid steppe communities of the northern Great Basin of North America. We conducted growth chamber experiments to investigate the effects of these crusts on the germination of four grasses: Festuca idahoensis, Festuca ovina, Elymus wawawaiensis and Bromus tectorum. For each of these species, we recorded germination time courses on bare soil and two types of biological soil crusts; one composed predominantly of the tall moss Tortula ruralis and the other dominated by the short moss Bryum argenteum. On the short-moss crust, the final germination percentage was about half of that on bare soil. Also, the mean germination time was 4 days longer [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 125.72884}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505bd0d4e4b08c986b32f0a6'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505bd0d4e4b08c986b32f0a6',
#       'rel': 'related'}},
#     'id': '505bd0d4e4b08c986b32f0a6',
#     'title': 'Wildfire-resistant biological soil crusts and fire-induced loss of soil stability in Palouse prairies, USA',
#     'summary': "Frequent low-intensity fires are a natural component of the ecology of the Palouse prairies of northwestern North America. To study the effects of fire upon biological soil crusts (BSCs) occurring in these grasslands, we sampled three burned (in 2000) sites and three unburned sites in the Hell's Canyon area (OR, USA) ???1 year post-fire. We measured vascular plant and BSC cover, soil microbe pigmentation, texture and chemistry, and soil surface physical properties (stability and rugosity). Festuca idahoensis was two times more abundant in unburned plots (P=0.0006), and vascular plant and litter cover were generally higher in unburned plots. At the community scale, there was no difference in the lichen and moss species composition, [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 122.157196}}]},
#  {'total': 218,
#   'took': '1.9s',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Ursus+americanus&max=20'},
#   'nextlink': {'rel': 'next',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Ursus+americanus&max=20&offset=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505373ade4b097cd4fcdc7ee'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505373ade4b097cd4fcdc7ee',
#       'rel': 'related'}},
#     'id': '505373ade4b097cd4fcdc7ee',
#     'title': 'Demodicosis in black bears (Ursus americanus ) from Florida.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 622.76056}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50537687e4b097cd4fcdd231'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50537687e4b097cd4fcdd231',
#       'rel': 'related'}},
#     'id': '50537687e4b097cd4fcdd231',
#     'title': 'Winter recreation and hibernating black bears Ursus americanus',
#     'hasChildren': False,
#     '_searchHit': {'_score': 607.4029}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5054140ee4b097cd4fcfcde3'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5054140ee4b097cd4fcfcde3',
#       'rel': 'related'}},
#     'id': '5054140ee4b097cd4fcfcde3',
#     'title': 'Phylogeography of black bears (Ursus americanus) of the Pacific Northwest',
#     'hasChildren': False,
#     '_searchHit': {'_score': 607.4029}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e217e4b063d5d307dc91'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e217e4b063d5d307dc91',
#       'rel': 'related'}},
#     'id': '59f5e217e4b063d5d307dc91',
#     'title': 'Louisiana Black Bear (Ursus americanus luteolus) mABBEl_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Louisiana Black Bear (Ursus americanus luteolus) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 569.9373}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e250e4b063d5d307dde5'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e250e4b063d5d307dde5',
#       'rel': 'related'}},
#     'id': '59f5e250e4b063d5d307dde5',
#     'title': 'American Black Bear (Ursus americanus) mABBEx_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for American Black Bear (Ursus americanus) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 569.77454}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5f64e4b0b7ea5452569a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5f64e4b0b7ea5452569a',
#       'rel': 'related'}},
#     'id': '58fa5f64e4b0b7ea5452569a',
#     'title': 'Florida Black Bear (Ursus americanus floridanus) mABBEf_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Florida Black Bear (Ursus americanus floridanus) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 559.8839}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505371c1e4b097cd4fcdbc6e'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505371c1e4b097cd4fcdbc6e',
#       'rel': 'related'}},
#     'id': '505371c1e4b097cd4fcdbc6e',
#     'title': 'Black Bear, Ursus americanus , food habits in southwestern Alberta.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 557.4398}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5ebbde4b063d5d307e121'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5ebbde4b063d5d307e121',
#       'rel': 'related'}},
#     'id': '59f5ebbde4b063d5d307e121',
#     'title': 'Florida Black Bear (Ursus americanus floridanus) mABBEf_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Florida Black Bear (Ursus americanus floridanus) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 555.3683}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5ba29320e4b08583a5c6180f'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5ba29320e4b08583a5c6180f',
#       'rel': 'related'}},
#     'id': '5ba29320e4b08583a5c6180f',
#     'title': 'American Black Bear (Ursus americanus) mABBEx_CONUS_2001v1 Web Service',
#     'hasChildren': False,
#     '_searchHit': {'_score': 549.3672}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505ba5f1e4b08c986b320dab'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505ba5f1e4b08c986b320dab',
#       'rel': 'related'}},
#     'id': '505ba5f1e4b08c986b320dab',
#     'title': 'Tetranucleotide microsatellite loci from the black bear (Ursus americanus)',
#     'summary': 'We describe primers and polymerase chain reaction conditions to amplify 21 tetranucleotide microsatellite DNA loci in black bears (Ursus americanus). We tested primers using individuals from two populations, one each in Georgia and Florida. Among individuals from Georgia (n = 29), primer pairs yielded an average of 2.9 alleles (range, one to four) and an average observed heterozygosity (HO) of 0.50 (range, 0.00 to 0.79). Among individuals from Florida (n = 19), primer pairs yielded an average of 5.7 alleles (range, one to 14) and an HO of 0.55 (range, 0.00 to 1.00). A comparison of previously developed markers with individuals from Georgia suggests that bear populations in Georgia and Florida have reduced allelic diversity relative [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 548.7256}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5f75e4b0b7ea5452569f'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5f75e4b0b7ea5452569f',
#       'rel': 'related'}},
#     'id': '58fa5f75e4b0b7ea5452569f',
#     'title': 'Louisiana Black Bear (Ursus americanus luteolus) mABBEl_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Louisiana Black Bear (Ursus americanus luteolus) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 547.0806}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5f8be4b0b7ea545256a2'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5f8be4b0b7ea545256a2',
#       'rel': 'related'}},
#     'id': '58fa5f8be4b0b7ea545256a2',
#     'title': 'American Black Bear (Ursus americanus) mABBEx_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for American Black Bear (Ursus americanus) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 545.62317}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50538876e4b097cd4fce23a6'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50538876e4b097cd4fce23a6',
#       'rel': 'related'}},
#     'id': '50538876e4b097cd4fce23a6',
#     'title': 'Serologic survey of Toxoplasma gondii in grizzly bears (Ursus arctos) and black bears (Ursus americanus) from Alaska, 1988 to 1991',
#     'hasChildren': False,
#     '_searchHit': {'_score': 534.9109}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e4adde4b07f02db686d25'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4adde4b07f02db686d25',
#       'rel': 'related'}},
#     'id': '4f4e4adde4b07f02db686d25',
#     'title': 'Taxonomic assessment of the black bear (Ursus americanus) in the eastern United States',
#     'summary': 'The subspecific status of the Louisiana black bear (Ursus americanus luteolus) and Florida black bear (U. a. floridanus) were assessed using morphologic features to determine their distinctness in relation to one another and to the black bear (U. a. americanus). Forty-four dimensions were recorded from skulls of 125 male and 127 female adult (4.5 years or older) bears. Results showed skulls of U. a. luteolus, U. a. floridanus, and U. a. americanus to be similar in morphology. However, features of U. a. luteolus, and U. a. floridanus tended, in general, to be larger and shaped differently than those of U. a. americanus. Differences between measurements of U. a. luteolus and U. a. floridanus were less apparent than those between either [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 533.77563}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5059f1fce4b0c8380cd4af3d'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5059f1fce4b0c8380cd4af3d',
#       'rel': 'related'}},
#     'id': '5059f1fce4b0c8380cd4af3d',
#     'title': 'Bone formation is not impaired by hibernation (disuse) in black bears Ursus americanus',
#     'summary': 'Disuse by bed rest, limb immobilization or space flight causes rapid bone loss by arresting bone formation and accelerating bone resorption. This net bone loss increases the risk of fracture upon remobilization. Bone loss also occurs in hibernating ground squirrels, golden hamsters, and little brown bats by arresting bone formation and accelerating bone resorption. There is some histological evidence to suggest that black bears Ursus americanus do not lose bone mass during hibernation (i.e. disuse). There is also evidence suggesting that muscle mass and strength are preserved in black bears during hibernation. The question of whether bears can prevent bone loss during hibernation has not been conclusively answered. The goal of the [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 533.3491}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e4b1be4b07f02db6a8ff3'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4b1be4b07f02db6a8ff3',
#       'rel': 'related'}},
#     'id': '4f4e4b1be4b07f02db6a8ff3',
#     'title': 'Geographic variation in the black bear (Ursus americanus) in the eastern United States and Canada',
#     'summary': 'The pattern of geographic variation in morphologic characters of the black bear (Ursus americanus) was assessed at 13 sites in the eastern United States and Canada. Thirty measurements from 206 males and 207 females were recorded to the nearest 0.01 mm using digital calipers and subjected to principal components analysis. A matrix of correlations among skull characters was computed, and the first 3 principal components were extracted. These accounted for 90.5% of the variation in the character set for males and 87.1% for females. Three-dimensional projection of localities onto principal components showed that, for males and females, largest individuals occurred in the more southern localities (e.g., males--Louisiana-Mississippi, eastern [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 527.78485}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50537226e4b097cd4fcdc15a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50537226e4b097cd4fcdc15a',
#       'rel': 'related'}},
#     'id': '50537226e4b097cd4fcdc15a',
#     'title': 'Prevalence of Trichinella spiralis in black bears (Ursus americanus ) from Newfoundland and Labrador, Canada.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 486.6769}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505369e4e4b097cd4fcd99b3'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505369e4e4b097cd4fcd99b3',
#       'rel': 'related'}},
#     'id': '505369e4e4b097cd4fcd99b3',
#     'title': 'Trichinella spiralis in the black bear (Ursus americanus ) of Pennsylvania: Distribution, prevalence and intensity of infection.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 473.80496}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053e7d5e4b097cd4fcf5d92'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053e7d5e4b097cd4fcf5d92',
#       'rel': 'related'}},
#     'id': '5053e7d5e4b097cd4fcf5d92',
#     'title': 'Effects of Collection Method on Sex and Age Composition of Black Bear (Ursus americanus) Harvest in Oregon',
#     'hasChildren': False,
#     '_searchHit': {'_score': 473.1536}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5057983fe4b01ad7e0284f33'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5057983fe4b01ad7e0284f33',
#       'rel': 'related'}},
#     'id': '5057983fe4b01ad7e0284f33',
#     'title': 'Rapid ecological and behavioural changes in carnivores: the responses of black bears (Ursus americanus) to altered food',
#     'hasChildren': False,
#     '_searchHit': {'_score': 473.12054}}]},
#  {'total': 209,
#   'took': '4.6s',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Pseudotsuga+menziesii&max=20'},
#   'nextlink': {'rel': 'next',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Pseudotsuga+menziesii&max=20&offset=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/537f6c63e4b021317a8725e0'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=537f6c63e4b021317a8725e0',
#       'rel': 'related'}},
#     'id': '537f6c63e4b021317a8725e0',
#     'title': 'Douglas fir (Pseudotsuga menziesii) extent, North America',
#     'summary': 'These maps are a digital representation of the individual tree species range maps of the Atlas of the United States Trees by Elbert L. Little, Jr. The atlas shows the natural distribution or range of the native tree species of North America. These coverages represent 3 volumes of the atlas.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 704.7533}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053a657e4b097cd4fce9acc'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053a657e4b097cd4fce9acc',
#       'rel': 'related'}},
#     'id': '5053a657e4b097cd4fce9acc',
#     'title': 'Nutrient dynamics during the development of a Douglas-fir (Pseudotsuga menziesii Mirb.) stand',
#     'hasChildren': False,
#     '_searchHit': {'_score': 654.2863}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505774d8e4b01ad7e027ca36'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505774d8e4b01ad7e027ca36',
#       'rel': 'related'}},
#     'id': '505774d8e4b01ad7e027ca36',
#     'title': 'Production capacity of Douglas fir (Pseudotsuga menziesii [Mirb.] Franco) in a mixed stand',
#     'hasChildren': False,
#     '_searchHit': {'_score': 613.6983}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b502e4b097cd4fcece43'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b502e4b097cd4fcece43',
#       'rel': 'related'}},
#     'id': '5053b502e4b097cd4fcece43',
#     'title': 'Composition of terpenes in the needles of Douglas fir (Pseudotsuga menziesii (Mirbel) Franco) growing in the urban environment',
#     'hasChildren': False,
#     '_searchHit': {'_score': 577.20184}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053738be4b097cd4fcdc654'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053738be4b097cd4fcdc654',
#       'rel': 'related'}},
#     'id': '5053738be4b097cd4fcdc654',
#     'title': 'Genetic differentiation in carbon isotope discrimination and gas exchange in Pseudotsuga menziesii : A common-garden experiment.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 539.1689}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50539fafe4b097cd4fce80ff'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50539fafe4b097cd4fce80ff',
#       'rel': 'related'}},
#     'id': '50539fafe4b097cd4fce80ff',
#     'title': 'Invasion of northern oak woodlands by Pseudotsuga menziesii (Mirb.) Franco in the Sonoma Mountains of California',
#     'hasChildren': False,
#     '_searchHit': {'_score': 539.1689}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50537225e4b097cd4fcdc154'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50537225e4b097cd4fcdc154',
#       'rel': 'related'}},
#     'id': '50537225e4b097cd4fcdc154',
#     'title': 'Dynamics of mixed stands of Alnus rubra and Pseudotsuga menziesii : Extension of size - density analysis to species mixture.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 530.8681}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b2e9e4b097cd4fcec75d'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b2e9e4b097cd4fcec75d',
#       'rel': 'related'}},
#     'id': '5053b2e9e4b097cd4fcec75d',
#     'title': 'Dynamics of a broadleaved (Castanea sativa) conifer (Pseudotsuga menziesii) mixed stands in Northern Portugal',
#     'hasChildren': False,
#     '_searchHit': {'_score': 530.68866}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50575c74e4b01ad7e0274209'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50575c74e4b01ad7e0274209',
#       'rel': 'related'}},
#     'id': '50575c74e4b01ad7e0274209',
#     'title': 'Carbon and nitrogen allocation to male and female reproduction in Rocky Mountain Douglas-fir (Pseudotsuga menziesii var. glauca, Pinaceae)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 530.68866}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505418a2e4b097cd4fcfdb59'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505418a2e4b097cd4fcfdb59',
#       'rel': 'related'}},
#     'id': '505418a2e4b097cd4fcfdb59',
#     'title': 'Morphotype community structure of ectomycorrhizas on Douglas fir (Pseudotsuga menziesii Mirb. Franco) seedlings grown under elevated atmospheric CO2 and temperature',
#     'hasChildren': False,
#     '_searchHit': {'_score': 476.57147}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505aaa43e4b0c8380cd86231'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505aaa43e4b0c8380cd86231',
#       'rel': 'related'}},
#     'id': '505aaa43e4b0c8380cd86231',
#     'title': 'Response of douglas fir (Pseudotsuga menziesii) to uraniferous groundwater in a small glaciated drainage, Northeastern Washington State',
#     'summary': 'Douglas fir trees and associated soils were sampled from the slopes of a small (??? 4 km2) drainage basin in northeastern Washington to investigate the biogeochemical response to locally uraniferous groundwater. Uranium is preferentially incorporated in needles and twigs compared to larger branches or the trunk. The U concentration in needle ash ranges from 0.2 to 5.8 ??g g-1 (ppm) and shows no correlation with the U concentration in associated soils. Rather, the distribution of anomalously uraniferous douglas fir (>1.0??g g-1 U in needle ash) appears to be controlled by observed or readily inferred pathways of near-surface groundwater movement in the drainage. These pathways include: (1) general downslope movement of subsurface runoff; [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 474.1377}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e4a13e4b07f02db602068'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4a13e4b07f02db602068',
#       'rel': 'related'}},
#     'id': '4f4e4a13e4b07f02db602068',
#     'title': 'Forest floor bryophytes of Pseudotsuga menziesii-Tsuga heterophylla stand in Oregon: Influences of substrate and overstory',
#     'summary': 'Species richness and abundance of bryophytes inhabiting forest floor substrates were assessed at two sites in western Oregon. Bryophyte diversity, abundance, and community composition were compared between sites, and between young forest stands (~55 yrs) and old-growth stands (400 + yrs) within each site. Relationships of stand structural features to diversity and community composition were assessed by stratifying sampling between "diversity" plots placed in areas of greater structural diversity, such as hardwood openings and remnant old-growth trees, and "matrix" plots situated within the remaining more homogeneous conifer-dominated forest matrix. Richness, particularly for liverworts, was significantly higher in old-growth than young [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 454.39948}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505aaa42e4b0c8380cd8622b'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505aaa42e4b0c8380cd8622b',
#       'rel': 'related'}},
#     'id': '505aaa42e4b0c8380cd8622b',
#     'title': 'Response of douglas fir (Pseudotsuga menziesii) to uraniferous groundwater in a small glaciated drainage, Northeastern Washington State',
#     'summary': 'Douglas fir trees and associated soils were sampled from the slopes of a small (???4 km2) drainage basin in northeastern Washington to investigate the biogeochemical response to locally uraniferous groundwater. Uranium is preferentially incorporated in needles and twigs compared to larger branches or the trunk. The U concentration in needle ash ranges from 0.2 to 5.8??g g-1 (ppm) and shows no correlation with the U concentration in associated soils. Rather, the distribution of anomalously uraniferous douglas fir (> 1.0??g g-1 U in needle ash) appears to be controlled by observed or readily inferred pathways of near-surface groundwater movement in the drainage. These pathways include: (1) general downslope movement of subsurface runoff; [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 454.39948}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e49d6e4b07f02db5de0d1'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e49d6e4b07f02db5de0d1',
#       'rel': 'related'}},
#     'id': '4f4e49d6e4b07f02db5de0d1',
#     'title': 'Clonal expansion and seedling recruitment of Oregon grape (Berberis nervosa) in Douglas-fir (Pseudotsuga menziesii) forests: Comparisons with salal (Gaultheria shallon)',
#     'summary': 'Seedling regeneration and morphology of Oregon grape (Berberis nervosa Pursh) and salal (Gaultheria shallon Pursh) were studied in thinned and unthinned Douglas-fir (Pseudotsuga menziesii (Mirb.) Franco) stands in the central Coast Range, Oregon. Above- and below-ground growth of both species were significantly and negatively correlated with stand density. Oregon grape appears to have less potential for vegetative spread than does salal. It produced two to three times fewer rhizome extensions, and rhizome extensions were only half as long as those of salal. Oregon grape seedlings were common in areas of moss ground cover among patches of the two species. Salal seedlings were restricted to decaying logs. Seedling densities of Oregon [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 443.30664}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053bcbde4b097cd4fceea48'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053bcbde4b097cd4fceea48',
#       'rel': 'related'}},
#     'id': '5053bcbde4b097cd4fceea48',
#     'title': 'Distribution of Larval Colonies of Lophocampa argentata Packard, the Silver Spotted Tiger Moth (Lepidoptera: Arctiidae), in an Old Growth Douglas-fir, Pseudotsuga menziesii/Western Hemlock, Tsuga heterophylla, Forest Canopy, Cascade Mountains, Washington State',
#     'hasChildren': False,
#     '_searchHit': {'_score': 383.13586}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/537f6c57e4b021317a8724f0'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=537f6c57e4b021317a8724f0',
#       'rel': 'related'}},
#     'id': '537f6c57e4b021317a8724f0',
#     'title': 'Ensemble forecast of climate suitability for Douglas-fir (Pseudotsuga menziesii) in the southern Sierra Nevada and Tehachapi Mountains (California, USA) based upon multiple (n=11) downscaled 2045-2065 A2 GCM projections',
#     'summary': "The Nature Conservancy (TNC) has derived climate suitability forecasts for most species of trees and shrubs considered to be ecological dominants of terrestrial Californian habitat types. Our plant projections are compiled as decision support tools to help Conservancy project staff, as well as our external partners, develop the necessary plans, priorities and strategies to successfully adapt to uncertain changes in future climate. In the recently completed Southern Sierra Partnership's 2010 Climate-Adapted Conservation Plan for the Southern Sierra Nevada and Tehachapi Mountains, species and habitat forecasts shown here informed the development of a regional conservation design that explicitly incorporates long-term conservation values [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 305.0694}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/537f6c57e4b021317a8724ee'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=537f6c57e4b021317a8724ee',
#       'rel': 'related'}},
#     'id': '537f6c57e4b021317a8724ee',
#     'title': 'Hot, wet scenario forecast of climate suitability for Douglas-fir (Pseudotsuga menziesii) in the southern Sierra Nevada and Tehachapi Mountains (California, USA) based upon downscaled 2045-2065 IPSL-CM4 A2 projections',
#     'summary': "The Nature Conservancy (TNC) has derived climate suitability forecasts for most species of trees and shrubs considered to be ecological dominants of terrestrial Californian habitat types. Our plant projections are compiled as decision support tools to help Conservancy project staff, as well as our external partners, develop the necessary plans, priorities and strategies to successfully adapt to uncertain changes in future climate. In the recently completed Southern Sierra Partnership's 2010 Climate-Adapted Conservation Plan for the Southern Sierra Nevada and Tehachapi Mountains, species and habitat forecasts shown here informed the development of a regional conservation design that explicitly incorporates long-term conservation values [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 304.33566}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/537f6c57e4b021317a8724ea'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=537f6c57e4b021317a8724ea',
#       'rel': 'related'}},
#     'id': '537f6c57e4b021317a8724ea',
#     'title': 'Hot, dry scenario forecast of climate suitability for Douglas-fir (Pseudotsuga menziesii) in the southern Sierra Nevada and Tehachapi Mountains (California, USA) based upon downscaled 2045-2065 MIROC3.2 A2  projections',
#     'summary': "The Nature Conservancy (TNC) has derived climate suitability forecasts for most species of trees and shrubs considered to be ecological dominants of terrestrial Californian habitat types. Our plant projections are compiled as decision support tools to help Conservancy project staff, as well as our external partners, develop the necessary plans, priorities and strategies to successfully adapt to uncertain changes in future climate. In the recently completed Southern Sierra Partnership's 2010 Climate-Adapted Conservation Plan for the Southern Sierra Nevada and Tehachapi Mountains, species and habitat forecasts shown here informed the development of a regional conservation design that explicitly incorporates long-term conservation values [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 303.44635}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/537f6c57e4b021317a8724ec'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=537f6c57e4b021317a8724ec',
#       'rel': 'related'}},
#     'id': '537f6c57e4b021317a8724ec',
#     'title': 'Warm, dry scenario forecast of climate suitability for Douglas-fir (Pseudotsuga menziesii) in the southern Sierra Nevada and Tehachapi Mountains (California, USA) based upon downscaled 2045-2065 MRI-CGCM2.3.2 A2  projections',
#     'summary': "The Nature Conservancy (TNC) has derived climate suitability forecasts for most species of trees and shrubs considered to be ecological dominants of terrestrial Californian habitat types. Our plant projections are compiled as decision support tools to help Conservancy project staff, as well as our external partners, develop the necessary plans, priorities and strategies to successfully adapt to uncertain changes in future climate. In the recently completed Southern Sierra Partnership's 2010 Climate-Adapted Conservation Plan for the Southern Sierra Nevada and Tehachapi Mountains, species and habitat forecasts shown here informed the development of a regional conservation design that explicitly incorporates long-term conservation values [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 295.36578}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e4ae1e4b07f02db6885ff'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4ae1e4b07f02db6885ff',
#       'rel': 'related'}},
#     'id': '4f4e4ae1e4b07f02db6885ff',
#     'title': 'Patterns of lichen diversity in Yellowstone National Park',
#     'summary': 'We here report 359 species in 103 genera from Yellowstone National Park. We found 71.3% of the total number of species in Picea engelmannii forests and 57.4% of the total number in Pseudotsuga menziesii stands. This compares to 42.3% of the species in Pinus contorta and 37.0% of the species in Pinus contorta/Pinus albicaulis stands. The presence of old Pseudotsuga menziesii and mature Picea engelmannii indicates that the forests have not burned for at least 300 yr, contributing to higher lichen diversity. The drier lodgepole pine and whitebark pine forests burn more frequently than every 300 yr and have fewer microhabitats for lichen growth. Species with thalli large enough to identify are beginning to recolonize substrates burned [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 174.34462}}]},
#  {'total': 53,
#   'took': '2.2s',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Tamiasciurus+hudsonicus&max=20'},
#   'nextlink': {'rel': 'next',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Tamiasciurus+hudsonicus&max=20&offset=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e21ce4b063d5d307dcad'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e21ce4b063d5d307dcad',
#       'rel': 'related'}},
#     'id': '59f5e21ce4b063d5d307dcad',
#     'title': 'Red Squirrel (Tamiasciurus hudsonicus) mRESQx_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Red Squirrel (Tamiasciurus hudsonicus) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 704.0969}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa76aee4b0b7ea54525ab8'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa76aee4b0b7ea54525ab8',
#       'rel': 'related'}},
#     'id': '58fa76aee4b0b7ea54525ab8',
#     'title': 'Red Squirrel (Tamiasciurus hudsonicus) mRESQx_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Red Squirrel (Tamiasciurus hudsonicus) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 679.8338}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e21ae4b063d5d307dca5'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e21ae4b063d5d307dca5',
#       'rel': 'related'}},
#     'id': '59f5e21ae4b063d5d307dca5',
#     'title': 'Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) mRESQg_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 666.4644}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505772bbe4b01ad7e027c12a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505772bbe4b01ad7e027c12a',
#       'rel': 'related'}},
#     'id': '505772bbe4b01ad7e027c12a',
#     'title': 'Evidence of Autumn Breeding in Red Squirrels, Tamiasciurus hudsonicus, in Western Montana',
#     'hasChildren': False,
#     '_searchHit': {'_score': 641.06824}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505391d2e4b097cd4fce4a82'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505391d2e4b097cd4fce4a82',
#       'rel': 'related'}},
#     'id': '505391d2e4b097cd4fce4a82',
#     'title': 'Indicators of red squirrel (Tamiasciurus hudsonicus) abundance in the whitebark pine zone',
#     'hasChildren': False,
#     '_searchHit': {'_score': 623.6086}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b725e4b097cd4fced56a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b725e4b097cd4fced56a',
#       'rel': 'related'}},
#     'id': '5053b725e4b097cd4fced56a',
#     'title': 'Red squirrels, Tamiasciurus hudsonicus, produce predator-class specific alarm calls',
#     'hasChildren': False,
#     '_searchHit': {'_score': 623.6086}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50540687e4b097cd4fcfb607'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50540687e4b097cd4fcfb607',
#       'rel': 'related'}},
#     'id': '50540687e4b097cd4fcfb607',
#     'title': 'Red Squirrel, Tamiasciurus hudsonicus, Population Density in the Southern Appalachian Mountains',
#     'hasChildren': False,
#     '_searchHit': {'_score': 617.3956}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa769be4b0b7ea54525ab5'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa769be4b0b7ea54525ab5',
#       'rel': 'related'}},
#     'id': '58fa769be4b0b7ea54525ab5',
#     'title': 'Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) mRESQg_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 609.2311}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5057919ae4b01ad7e02838ad'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5057919ae4b01ad7e02838ad',
#       'rel': 'related'}},
#     'id': '5057919ae4b01ad7e02838ad',
#     'title': 'Interactions between predators and Mt. Graham red squirrels (Tamiasciurus hudsonicus grahamensis)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 605.8958}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b874e4b07657d1a6c2d6'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b874e4b07657d1a6c2d6',
#       'rel': 'related'}},
#     'id': '5771b874e4b07657d1a6c2d6',
#     'title': 'Intraspecific cache pilferage by larder-hoarding red squirrels (Tamiasciurus hudsonicus)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 600.7753}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e48bfe4b07f02db53ae76'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e48bfe4b07f02db53ae76',
#       'rel': 'related'}},
#     'id': '4f4e48bfe4b07f02db53ae76',
#     'title': 'Intraspecific phylogeography of red squirrels (Tamiasciurus hudsonicus) in the central Rocky Mountain region of North America.',
# ...
#     'hasChildren': False,
#     '_searchHit': {'_score': 89.74826}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b428e'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4b32e4b07f02db6b428e',
#       'rel': 'related'}},
#     'id': '4f4e4b32e4b07f02db6b428e',
#     'title': 'A 40,000-year woodrat-midden record of vegetational and biogeographical dynamics in north-eastern Utah',
#     'summary': 'Aim A conspicuous climatic and biogeographical transition occurs at 40-45° N in western North America. This pivot point marks a north–south opposition of wet and dry conditions at interannual and decadal time-scales, as well as the northern and southern limits of many dominant western plant species. Palaeoecologists have yet to focus on past climatic and biotic shifts along this transition, in part because it requires comparisons across dissimilar records [i.e. pollen from lacustrine sediments to the north and plant macrofossils from woodrat (Neotoma) middens to the south]. To overcome these limitations, we are extending the woodrat-midden record northward into the lowlands of the central Rocky Mountains.Location Woodrat middens were [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 79.38806}}]},
#  {'total': 178,
#   'took': '497ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Populus+tremuloides&max=20'},
#   'nextlink': {'rel': 'next',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Populus+tremuloides&max=20&offset=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505414e3e4b097cd4fcfd12f'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505414e3e4b097cd4fcfd12f',
#       'rel': 'related'}},
#     'id': '505414e3e4b097cd4fcfd12f',
#     'title': 'Microsatellite DNA markers in Populus tremuloides',
#     'hasChildren': False,
#     '_searchHit': {'_score': 698.8849}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053bc81e4b097cd4fcee8ce'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053bc81e4b097cd4fcee8ce',
#       'rel': 'related'}},
#     'id': '5053bc81e4b097cd4fcee8ce',
#     'title': 'Isolation and characterization of microsatellites in trembling aspen (Populus tremuloides)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 633.8116}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/537f6c59e4b021317a87254a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=537f6c59e4b021317a87254a',
#       'rel': 'related'}},
#     'id': '537f6c59e4b021317a87254a',
#     'title': 'Quaking aspen (Populus tremuloides) extent, North America',
#     'summary': 'These maps are a digital representation of the individual tree species range maps of the Atlas of the United States Trees by Elbert L. Little, Jr. The atlas shows the natural distribution or range of the native tree species of North America. These coverages represent 3 volumes of the atlas.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 613.9095}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5aafd716e4b081f61ab0d76c'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5aafd716e4b081f61ab0d76c',
#       'rel': 'related'}},
#     'id': '5aafd716e4b081f61ab0d76c',
#     'title': 'Simulating the dependence of aspen (Populus tremuloides) on redistributed snow in a semi‐arid watershed',
#     'summary': 'Abstract (from Ecosphere): In semi‐arid mountainous regions across the western United States, the distribution of upland aspen (Populus tremuloides) is often related to heterogeneous soil moisture subsidies resulting from redistributed snow. As temperatures increase, interactions between decreasing snowpack and future trends in the net primary productivity (NPP) of aspen forests remain uncertain. This study characterizes the importance of heterogeneously distributed snow water to aspen communities in the Reynolds Creek Critical Zone Observatory located in southwestern Idaho, USA. Net primary productivity of three aspen stands was simulated at sites spanning elevational and precipitation gradients using the biogeochemical process model [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 549.8521}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b862e4b07657d1a6bfa8'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b862e4b07657d1a6bfa8',
#       'rel': 'related'}},
#     'id': '5771b862e4b07657d1a6bfa8',
#     'title': 'Understorey vegetation in boreal Picea mariana and Populus tremuloides stands in British Columbia',
#     'summary': 'Abstract. We compared the species composition and species density of vascular plants in the understorey vegetation of boreal forest between Picea mariana (Black spruce) and Populus tremuloides (Trembling aspen) stands in British Columbia, Canada, and related differences in species composition and species density between the two forest types to dominant canopy tree species as well as a wide variety of environmental factors. We analysed 231 stands, distributed in three different climatic regions representing drier, wetter, and milder variations of montane boreal climate. Of these stands 118 were dominated by P. mariana and 113 by P. tremuloides. P. tremuloides stands had higher species density than P. mariana stands in all climatic regions, [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 545.9371}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5cbf8de5e4b09b8c0b700fb2'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5cbf8de5e4b09b8c0b700fb2',
#       'rel': 'related'}},
#     'id': '5cbf8de5e4b09b8c0b700fb2',
#     'title': 'Northern Nevada aspen (Populus tremuloides) data (2010-2011)',
#     'summary': 'The dataset includes several variables that were sampled across aspen stands in the Santa Rosa, Ruby, and Jarbidge mountain ranges (Great Basin, Northern Nevada, USA) in 2010 and 2011. Across 101 aspen sites, several plot-level attributes were collected (e.g. elevation, slope, aspen stand type). For each plot, data describing live trees (both those less than 7.5 cm diameter and those greater than/equal to 7.5 cm) are included, such as species, diameter, and age. The data set also includes information for dead trees greater than/equal to 7.5 cm diameter (e.g. species, location, diameter).',
#     'hasChildren': False,
#     '_searchHit': {'_score': 531.8611}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50576e7ce4b01ad7e027ad92'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50576e7ce4b01ad7e027ad92',
#       'rel': 'related'}},
#     'id': '50576e7ce4b01ad7e027ad92',
#     'title': 'Simulation of 1-year-old Populus tremuloides response to ozone stress at Ithaca, USA, and Suwon, Republic of Korea',
#     'hasChildren': False,
#     '_searchHit': {'_score': 499.57306}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50578b0ae4b01ad7e02820db'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50578b0ae4b01ad7e02820db',
#       'rel': 'related'}},
#     'id': '50578b0ae4b01ad7e02820db',
#     'title': 'Interactive effects of human activities, herbivory and fire on quaking aspen (Populus tremuloides) age structures in western Wyoming',
#     'hasChildren': False,
#     '_searchHit': {'_score': 498.33658}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e49dce4b07f02db5e18b9'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e49dce4b07f02db5e18b9',
#       'rel': 'related'}},
#     'id': '4f4e49dce4b07f02db5e18b9',
#     'title': 'The persistence of quaking aspen (Populus tremuloides) in the Grand Mesa Area, Colorado',
#     'summary': 'Human activities have caused the decline of numerous species and ecosystems. To promote ecosystem resilience, recent management efforts aim to maintain ecosystem patterns and processes within their historical range of variability. There has been substantial concern that quaking aspen, the most widely distributed tree in North America and the most important deciduous tree in the subalpine forests of the Rocky Mountains, has declined significantly in the western landscape during the 20th century. This reported decline has been attributed to conifer encroachment associated with fire exclusion, as well as other causes. To assess long-term changes in the extent of quaking aspen in a 175000-ha study area in western Colorado, we used a Geographic [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 496.96756}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50577083e4b01ad7e027b68a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50577083e4b01ad7e027b68a',
#       'rel': 'related'}},
#     'id': '50577083e4b01ad7e027b68a',
#     'title': 'Secondary Plant Compounds in Seedling and Mature Aspen (Populus tremuloides) in Yellowstone National Park, Wyoming',
#     'hasChildren': False,
#     '_searchHit': {'_score': 490.48676}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5057aa77e4b01ad7e0288a3d'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5057aa77e4b01ad7e0288a3d',
#       'rel': 'related'}},
#     'id': '5057aa77e4b01ad7e0288a3d',
#     'title': 'The impact of vessel size on vulnerability curves: Data and models for within-species variability in saplings of aspen, Populus tremuloides Michx',
#     'hasChildren': False,
#     '_searchHit': {'_score': 490.48676}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b2f6e4b097cd4fcec7b9'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b2f6e4b097cd4fcec7b9',
#       'rel': 'related'}},
#     'id': '5053b2f6e4b097cd4fcec7b9',
#     'title': 'Condition and trend of aspen, Populus tremuloides, in Kootenay and Yoho National Parks: Implications for ecological integrity',
#     'hasChildren': False,
#     '_searchHit': {'_score': 490.37704}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505399cfe4b097cd4fce6b31'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505399cfe4b097cd4fce6b31',
#       'rel': 'related'}},
#     'id': '505399cfe4b097cd4fce6b31',
#     'title': 'Rare episode of sexual reproduction in aspen (Populus tremuloides Michx.) following the 1988 Yellowstone fires',
#     'hasChildren': False,
#     '_searchHit': {'_score': 486.5951}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053ae8ee4b097cd4fceb779'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053ae8ee4b097cd4fceb779',
#       'rel': 'related'}},
#     'id': '5053ae8ee4b097cd4fceb779',
#     'title': 'Height growth and site index models for trembling aspen (Populus tremuloides Michx.) in northern British Columbia',
#     'hasChildren': False,
#     '_searchHit': {'_score': 483.81754}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50578a82e4b01ad7e0281ceb'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50578a82e4b01ad7e0281ceb',
#       'rel': 'related'}},
#     'id': '50578a82e4b01ad7e0281ceb',
#     'title': 'Changes in landscape patterns associated with the persistence of aspen (Populus tremuloides Michx.) on the western slope of the Rocky Mountains, Colorado',
#     'hasChildren': False,
#     '_searchHit': {'_score': 471.42975}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/545d07a5e4b0ba8303f720dc'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=545d07a5e4b0ba8303f720dc',
#       'rel': 'related'}},
#     'id': '545d07a5e4b0ba8303f720dc',
#     'title': 'Decay of aspen (Populus tremuloides Michx.) wood in moist and dry boreal, temperate, and tropical forest fragments',
#     'hasChildren': False,
#     '_searchHit': {'_score': 469.2359}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/545d0796e4b0ba8303f71f10'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=545d0796e4b0ba8303f71f10',
#       'rel': 'related'}},
#     'id': '545d0796e4b0ba8303f71f10',
#     'title': 'Assessing Quaking Aspen (Populus tremuloides) Decline on Cedar Mountain in Southern Utah Using Remote Sensing and Geographic Information Systems',
#     'hasChildren': False,
#     '_searchHit': {'_score': 468.24664}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50536099e4b097cd4fcd6893'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50536099e4b097cd4fcd6893',
#       'rel': 'related'}},
#     'id': '50536099e4b097cd4fcd6893',
#     'title': 'Biological control of blue stain fungi on Populus tremuloides using selected Ophiostoma isolates',
#     'hasChildren': False,
#     '_searchHit': {'_score': 467.27194}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/542fbaa6e4b092f17df61d6e'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=542fbaa6e4b092f17df61d6e',
#       'rel': 'related'}},
#     'id': '542fbaa6e4b092f17df61d6e',
#     'title': 'Phenology and climate relationships in aspen (<i>Populus tremuloides</i> Michx.) forest and woodland communities of southwestern Colorado',
#     'summary': 'Trembling aspen (Populus tremuloides Michx.) occurs over wide geographical, latitudinal, elevational, and environmental gradients, making it a favorable candidate for a study of phenology and climate relationships. Aspen forests and woodlands provide numerous ecosystem services, such as high primary productivity and biodiversity, retention and storage of environmental variables (precipitation, temperature, snow–water equivalent) that affect the spring and fall phenology of the aspen woodland communities of southwestern Colorado. We assessed the land surface phenology of aspen woodlands using two phenology indices, start of season time (SOST) and end of season time (EOST), from the U.S. Geological Survey (USGS) database of conterminous [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 466.68445}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b8c7e4b07657d1a6d28c'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b8c7e4b07657d1a6d28c',
#       'rel': 'related'}},
#     'id': '5771b8c7e4b07657d1a6d28c',
#     'title': 'Populus tremuloides Michx. postfire stand dynamics in the northern boreal-cordilleran ecoclimatic region of central Yukon Territory, Canada',
#     'hasChildren': False,
#     '_searchHit': {'_score': 465.0116}}]}]

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("cache/sciencebase.json", sb_results))
# Out:
# {'Doc Cache File': 'cache/sciencebase.json',
#  'Number of Documents in Cache': 116,
#  'Document Number 3': {'total': 53,
#   'took': '2.2s',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Tamiasciurus+hudsonicus&max=20'},
#   'nextlink': {'rel': 'next',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Tamiasciurus+hudsonicus&max=20&offset=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e21ce4b063d5d307dcad'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e21ce4b063d5d307dcad',
#       'rel': 'related'}},
#     'id': '59f5e21ce4b063d5d307dcad',
#     'title': 'Red Squirrel (Tamiasciurus hudsonicus) mRESQx_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Red Squirrel (Tamiasciurus hudsonicus) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 704.0969}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa76aee4b0b7ea54525ab8'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa76aee4b0b7ea54525ab8',
#       'rel': 'related'}},
#     'id': '58fa76aee4b0b7ea54525ab8',
#     'title': 'Red Squirrel (Tamiasciurus hudsonicus) mRESQx_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Red Squirrel (Tamiasciurus hudsonicus) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 679.8338}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e21ae4b063d5d307dca5'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e21ae4b063d5d307dca5',
#       'rel': 'related'}},
#     'id': '59f5e21ae4b063d5d307dca5',
#     'title': 'Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) mRESQg_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 666.4644}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505772bbe4b01ad7e027c12a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505772bbe4b01ad7e027c12a',
#       'rel': 'related'}},
#     'id': '505772bbe4b01ad7e027c12a',
#     'title': 'Evidence of Autumn Breeding in Red Squirrels, Tamiasciurus hudsonicus, in Western Montana',
#     'hasChildren': False,
#     '_searchHit': {'_score': 641.06824}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505391d2e4b097cd4fce4a82'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505391d2e4b097cd4fce4a82',
#       'rel': 'related'}},
#     'id': '505391d2e4b097cd4fce4a82',
#     'title': 'Indicators of red squirrel (Tamiasciurus hudsonicus) abundance in the whitebark pine zone',
#     'hasChildren': False,
#     '_searchHit': {'_score': 623.6086}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b725e4b097cd4fced56a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b725e4b097cd4fced56a',
#       'rel': 'related'}},
#     'id': '5053b725e4b097cd4fced56a',
#     'title': 'Red squirrels, Tamiasciurus hudsonicus, produce predator-class specific alarm calls',
#     'hasChildren': False,
#     '_searchHit': {'_score': 623.6086}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50540687e4b097cd4fcfb607'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50540687e4b097cd4fcfb607',
#       'rel': 'related'}},
#     'id': '50540687e4b097cd4fcfb607',
#     'title': 'Red Squirrel, Tamiasciurus hudsonicus, Population Density in the Southern Appalachian Mountains',
#     'hasChildren': False,
#     '_searchHit': {'_score': 617.3956}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa769be4b0b7ea54525ab5'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa769be4b0b7ea54525ab5',
#       'rel': 'related'}},
#     'id': '58fa769be4b0b7ea54525ab5',
#     'title': 'Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) mRESQg_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Mt. Graham Red Squirrel (Tamiasciurus hudsonicus grahamensis) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 609.2311}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5057919ae4b01ad7e02838ad'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5057919ae4b01ad7e02838ad',
#       'rel': 'related'}},
#     'id': '5057919ae4b01ad7e02838ad',
#     'title': 'Interactions between predators and Mt. Graham red squirrels (Tamiasciurus hudsonicus grahamensis)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 605.8958}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b874e4b07657d1a6c2d6'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b874e4b07657d1a6c2d6',
#       'rel': 'related'}},
#     'id': '5771b874e4b07657d1a6c2d6',
#     'title': 'Intraspecific cache pilferage by larder-hoarding red squirrels (Tamiasciurus hudsonicus)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 600.7753}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e48bfe4b07f02db53ae76'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e48bfe4b07f02db53ae76',
#       'rel': 'related'}},
#     'id': '4f4e48bfe4b07f02db53ae76',
#     'title': 'Intraspecific phylogeography of red squirrels (Tamiasciurus hudsonicus) in the central Rocky Mountain region of North America.',
#     'summary': 'We used variation in a portion of the mitochondrial DNA control region to examine phylogeography of Tamiasciurus hudsonicus, a boreal-adapted small mammal in the central Rocky Mountain region. AMOVA revealed that 65.66% of genetic diversity was attributable to variation within populations, 16.93% to variation among populations on different mountain ranges, and 17.41% to variation among populations within mountain ranges. Nested clade analysis revealed two major clades that likely diverged in allopatry during the Pleistocene: a southern clade from southern Colorado and a northern clade comprising northern Colorado, Wyoming, eastern Utah, and eastern Idaho. Historically restricted gene flow as a result of geographic barriers was indicated [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 527.532}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50540686e4b097cd4fcfb5ff'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50540686e4b097cd4fcfb5ff',
#       'rel': 'related'}},
#     'id': '50540686e4b097cd4fcfb5ff',
#     'title': 'Dispersal of Fruits and Seeds of Poison-ivy, Toxicodendron radicans, by Ruffed Grouse, Bonasa umbellus, and Squirrels, Tamiasciurus hudsonicus and Sciurus carolinensis',
#     'hasChildren': False,
#     '_searchHit': {'_score': 520.3439}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58b884e2e4b01ccd5500c09a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58b884e2e4b01ccd5500c09a',
#       'rel': 'related'}},
#     'id': '58b884e2e4b01ccd5500c09a',
#     'title': 'Personality, habitat use, and their consequences for survival in North American red squirrels Tamiasciurus hudsonicus',
#     'hasChildren': False,
#     '_searchHit': {'_score': 514.50116}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b871e4b07657d1a6c220'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b871e4b07657d1a6c220',
#       'rel': 'related'}},
#     'id': '5771b871e4b07657d1a6c220',
#     'title': 'The hormonal regulation of non-breeding territorial aggression in North American red squirrels (Tamiasciurus hudsonicus)',
#     'summary': 'Classically, testosterone (T) was considered the principal regulator of aggression. However, recent studies in birds have found aggression and T uncoupled during the non-breeding season. Circulating testosterone comes with costs such as immunosuppression and energy expenditure. Instead, the pro-hormone, dehydroepiandrosterone (DHEA), is circulated and activated within the brain via conversion into oestradiol (E 2 ), avoiding the costs associated with T. At present the site of DHEA synthesis is unknown. My thesis investigated the existence of an analogous pathway in non-breeding red squirrels (Tamiasciurus hudsonicus ) with two studies: (a) a field study investigating the effects of E2 on aggression and (b) a laboratory study that attempted [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 502.2834}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59ae663ae4b0e9bde133c7c1'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59ae663ae4b0e9bde133c7c1',
#       'rel': 'related'}},
#     'id': '59ae663ae4b0e9bde133c7c1',
#     'title': 'Severe reduction in genetic variation in a montane isolate: The endangered Mount Graham red squirrel (Tamiasciurus hudsonicus grahamensis)',
#     'summary': 'The Mount Graham red squirrel (Tamiasciurus hudsonicus grahamensis; MGRS) is endemic to the Pinaleño Mountains of Arizona at the southernmost extent of the species’ range. The MGRS was listed as federally endangered in 1987, and is currently at high risk of extinction due to declining population size and increasing threats. Here we present a genetic assessment of the MGRS using eight nuclear DNA microsatellite markers and a 472 bp fragment of the mitochondrial cytochrome b gene. We analyzed 34 MGRS individuals and an additional 66 red squirrels from the nearby White Mountains, Arizona (T. h. mogollonensis). Both nuclear and mitochondrial DNA analyses revealed an extreme reduction in measures of genetic diversity relative to conspecifics [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 485.58847}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b8e6e4b07657d1a6d904'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b8e6e4b07657d1a6d904',
#       'rel': 'related'}},
#     'id': '5771b8e6e4b07657d1a6d904',
#     'title': 'The relationship between adult hippocampal neurogenesis and spatial learning and memory in natural populations of food-storing red squirrels (Tamiasciurus hudsonicus)',
#     'summary': 'Previous research on the relationship between spatial memory and adult hippocampal neurogenesis has been controversial. In the present study, neurogenesis was compared between two natural populations of the same species that differ in their reliance on spatial memory to cache and retrieve stored food. Western red squirrels store food in a single site whereas eastern red squirrels store food in multiple sites. Neurogenesis was assessed using endogenous markers of the number of proliferating cells (Ki-67) and the number of immature neurons (DCX), and neuronal recruitment was determined by measuring the area of the dentate gyrus of the hippocampus. The number of proliferating cells, immature neurons and neuronal recruitment were enhanced [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 467.13745}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/596fcba7e4b0d1f9f0646226'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=596fcba7e4b0d1f9f0646226',
#       'rel': 'related'}},
#     'id': '596fcba7e4b0d1f9f0646226',
#     'title': 'Evaluating camera traps as an alternative to live trapping for estimating the density of snowshoe hares (Lepus americanus) and red squirrels (Tamiasciurus hudsonicus)',
#     'summary': 'Live trapping is one of the methods typically used to estimate population densities of small mammals, but this is labor-intensive and can be stressful to individuals. We assess the use of camera trap hit (detection) rates as a noninvasive alternative to live trapping for estimating population densities of snowshoe hares (Lepus americanus (Erxleben, 1777)) and red squirrels (Tamiasciurus hudsonicus (Erxleben, 1777))—two common small (≤1.5 kg) mammal species in the boreal forests of northern North America. We compared hit rates from camera trapping to live trapping mark-recapture density estimates and asked if the hit window—the length of time used to group consecutive videos together as single detections or “hits”—has an effect on the [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 466.0333}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b86ee4b07657d1a6c174'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b86ee4b07657d1a6c174',
#       'rel': 'related'}},
#     'id': '5771b86ee4b07657d1a6c174',
#     'title': 'Intraspecific cache pilferage by larder-hoarding red squirrels (Tamiasciurus hudsonicus) in Kluane, Yukon',
#     'summary': 'Pilfering is thought to play a role in the evolution of scatter-hoarding strategies; but is not well understood in larder-hoarding animals. I studied intraspecific pilfering in red squirrels in Kluane, YT, Canada. The purpose of this project was to estimate the natural rate of cache pilferage, and to examine variation in pilfering behaviour. Results from experimental removal of territory owners, suggested that younger squirrels with smaller food caches were more likely to pilfer when given the opportunity. Survival over-winter was dependent on the number of cones cached and pilfering squirrels were less likely to survive. Using a mark-recapture study of marked cones I found that few individuals (14%) did any pilfering and stolen cones [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 463.51523}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/572a2b00e4b0b13d391a2bb0'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=572a2b00e4b0b13d391a2bb0',
#       'rel': 'related'}},
#     'id': '572a2b00e4b0b13d391a2bb0',
#     'title': 'Estimating population densities of Peromyscus maniculatus, Clethrionomys rutilus, Lepus americanus, and Tamiasciurus hudsonicus using remote cameras in the boreal forest of Yukon Territory, Canada',
#     'hasChildren': False,
#     '_searchHit': {'_score': 453.2565}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5771b894e4b07657d1a6c846'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5771b894e4b07657d1a6c846',
#       'rel': 'related'}},
#     'id': '5771b894e4b07657d1a6c846',
#     'title': 'Spatial and temporal variability in white spruce (Picea glauca) cone production: individual and population responses of North American red squirrels (Tamiasciurus hudsonicus)',
#     'summary': 'Habitat quality is largely heterogeneous over space and time, although common simplifying assumptions in ecological research include homogeneity of areas occupied by a population and equal resource availability among individuals. These assumptions are made due to difficulties in quantifying the food available to individuals and following the effects of food on individual performance under natural conditions. My objectives were to document temporal and spatial variability in food availability, and its effects on seed predator individual performance and population dynamics in a white spruce-red squirrel system near Kluane Lake, Yukon. This system was ideal for my study because white spruce is the only conifer present, their seeds are [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 371.5573}}]}}

# %% [markdown]
# Check to see if any invalid/not accepted ITIS specie names matched with ScienceBase records

# %%
# Open up the cached updated ITIS list with invalid/not accepted species names from ITIS Exploration.ipynb
with open("cache/invalid_itis.json", "r") as f:
    invalid_itis = json.loads(f.read())

# %%
# Use joblib to run multiple requests for ScienceBase documents in parallel via the invalid/not accepted ITIS scientific names
invalid_sb_result = Parallel(n_jobs=8)(delayed(sb.find_items_by_any_text)(name) for name in [r["scientific_name"] for r in invalid_itis])
invalid_sb_result
# Out:
# [{'total': 29,
#   'took': '5ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Amphispiza+belli&max=20'},
#   'nextlink': {'rel': 'next',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Amphispiza+belli&max=20&offset=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50576d3de4b01ad7e027ab8b'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50576d3de4b01ad7e027ab8b',
#       'rel': 'related'}},
#     'id': '50576d3de4b01ad7e027ab8b',
#     'title': 'Sage Sparrow (Amphispiza belli)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 847.0132}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b4a4d'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4b32e4b07f02db6b4a4d',
#       'rel': 'related'}},
#     'id': '4f4e4b32e4b07f02db6b4a4d',
#     'title': 'Species Assessment for Sage Sparrow (Amphispiza Belli) in Wyoming',
#     'summary': '  The Sage Sparrow (Amphispiza belli) is a common breeding bird in landscapes dominated by  big sagebrush (Artemisia spp.) in western North America.  The species prefers large, undisturbed  tracts of tall and dense sagebrush.  Such habitat is declining across large areas, and many  sagebrush obligates such as the Sage Sparrow are showing corresponding declines in distribution  and abundance.  For example, in Washington over half the native shrubsteppe has been converted  to agriculture in the last 150 years (Vander Haegen et al. 2000).  In this report, shrubsteppe is  defined as an environment with a “…co-dominance of sagebrush and native bunch grass and  moderate shrub cover” (B. Walker, personal communication).  Shrubsteppe habitat [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 769.07355}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e296e4b063d5d307df75'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e296e4b063d5d307df75',
#       'rel': 'related'}},
#     'id': '59f5e296e4b063d5d307df75',
#     'title': "Bell's Sage Sparrow (Amphispiza belli belli) bSAGSb_CONUS_2001v1 Range Map",
#     'summary': "This dataset represents a species known range extent for Bell's Sage Sparrow (Amphispiza belli belli) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 746.6998}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5693e4b0b7ea545253c9'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5693e4b0b7ea545253c9',
#       'rel': 'related'}},
#     'id': '58fa5693e4b0b7ea545253c9',
#     'title': 'Sage Sparrow (Amphispiza belli) bSAGSx_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Sage Sparrow (Amphispiza belli) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 741.0935}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5667e4b0b7ea545253bb'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5667e4b0b7ea545253bb',
#       'rel': 'related'}},
#     'id': '58fa5667e4b0b7ea545253bb',
#     'title': "Bell's Sage Sparrow (Amphispiza belli belli) bSAGSb_CONUS_2001v1 Habitat Map",
#     'summary': "This dataset represents a species habitat distribution map for Bell's Sage Sparrow (Amphispiza belli belli) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 740.5627}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5ec3ae4b063d5d307e52f'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5ec3ae4b063d5d307e52f',
#       'rel': 'related'}},
#     'id': '59f5ec3ae4b063d5d307e52f',
#     'title': 'Sage Sparrow (Amphispiza belli) bSAGSx_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Sage Sparrow (Amphispiza belli) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 703.7288}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5ec6ee4b063d5d307e705'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5ec6ee4b063d5d307e705',
#       'rel': 'related'}},
#     'id': '59f5ec6ee4b063d5d307e705',
#     'title': 'Saltbush Sparrow (Amphispiza belli canescens) bSAGSa_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Saltbush Sparrow (Amphispiza belli canescens) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 656.83716}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e1f0e4b063d5d307dbad'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e1f0e4b063d5d307dbad',
#       'rel': 'related'}},
#     'id': '59f5e1f0e4b063d5d307dbad',
#     'title': 'Great Basin Sage Sparrow (Amphispiza belli nevadensis) bSAGSn_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for Great Basin Sage Sparrow (Amphispiza belli nevadensis) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 650.8702}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/59f5e1b5e4b063d5d307da7b'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=59f5e1b5e4b063d5d307da7b',
#       'rel': 'related'}},
#     'id': '59f5e1b5e4b063d5d307da7b',
#     'title': 'San Clemente Sage Sparrow (Amphispiza belli clementeae) bSAGSc_CONUS_2001v1 Range Map',
#     'summary': "This dataset represents a species known range extent for San Clemente Sage Sparrow (Amphispiza belli clementeae) within the conterminous United States (CONUS) based on 2001 ground conditions. This range map was created by attributing sub-watershed polygons with information of a species' presence, origin, seasonal and reproductive use. See Gap Analysis Project Species Range Maps for more information regarding data creation and user constraints. For species specific range information, see the attached Range data.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 648.7645}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5658e4b0b7ea545253b6'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5658e4b0b7ea545253b6',
#       'rel': 'related'}},
#     'id': '58fa5658e4b0b7ea545253b6',
#     'title': 'Saltbush Sparrow (Amphispiza belli canescens) bSAGSa_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Saltbush Sparrow (Amphispiza belli canescens) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 638.7857}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5675e4b0b7ea545253c0'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5675e4b0b7ea545253c0',
#       'rel': 'related'}},
#     'id': '58fa5675e4b0b7ea545253c0',
#     'title': 'San Clemente Sage Sparrow (Amphispiza belli clementeae) bSAGSc_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for San Clemente Sage Sparrow (Amphispiza belli clementeae) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 637.3944}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/58fa5685e4b0b7ea545253c5'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5685e4b0b7ea545253c5',
#       'rel': 'related'}},
#     'id': '58fa5685e4b0b7ea545253c5',
#     'title': 'Great Basin Sage Sparrow (Amphispiza belli nevadensis) bSAGSn_CONUS_2001v1 Habitat Map',
#     'summary': "This dataset represents a species habitat distribution map for Great Basin Sage Sparrow (Amphispiza belli nevadensis) within the conterminous United States (CONUS) based on 2001 ground conditions. This habitat map was created by applying a deductive habitat model to remotely-sensed data layers within the species' known range. See Gap Analysis Project Species Habitat Maps for more information regarding model process and user constraints. For species specific model information, see the attached Species Habitat Model Report.",
#     'hasChildren': False,
#     '_searchHit': {'_score': 619.51685}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50538a31e4b097cd4fce2a7a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50538a31e4b097cd4fce2a7a',
#       'rel': 'related'}},
#     'id': '50538a31e4b097cd4fce2a7a',
#     'title': 'Habitat distributions of wintering sparrows: Foraging success in a transplant experiment',
#     'hasChildren': False,
#     '_searchHit': {'_score': 150.29231}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b7e4e4b097cd4fceda28'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b7e4e4b097cd4fceda28',
#       'rel': 'related'}},
#     'id': '5053b7e4e4b097cd4fceda28',
#     'title': 'Foraging patch selection by shrubsteppe sparrows',
#     'hasChildren': False,
#     '_searchHit': {'_score': 148.5546}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5a61292fe4b06e28e9c25d65'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5a61292fe4b06e28e9c25d65',
#       'rel': 'related'}},
#     'id': '5a61292fe4b06e28e9c25d65',
#     'title': 'Characteristics of nesting areas used by San Clemente Island Sage Sparrows',
#     'summary': 'I examined the nest habitat used by Sage Sparrows (Amphispiza belli clementeae) on San Clemente Island, one of the California Channel Islands, during March through June 1986. All nests were found in boxthorn shrubs in coastal scrub habitat. The cover of vegetation was greater and more evenly distributed at nest sites than in surrounding habitat. Nests were placed most often on the leeward side of live boxthorn shrubs interspersed by cactus.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 147.31499}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505b88c1e4b08c986b316b52'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505b88c1e4b08c986b316b52',
#       'rel': 'related'}},
#     'id': '505b88c1e4b08c986b316b52',
#     'title': 'Seasonal movements and environmental triggers to fall migration of Sage Sparrows',
#     'summary': 'Post-breeding ecology of shrubland passerines prior to onset of migration is unknown relative to dynamics of breeding areas. We radiomarked and monitored 38 Sage Sparrows (Amphispiza belli ssp. nevadensis) at one site in Oregon and two in Nevada from September to mid-November 2007 to track local movements, estimate seasonal range sizes, and characterize weather patterns triggering onset of migration. Median area used by Sage Sparrows monitored between 3 and 18 days during or prior to migration was 14 ha; maximum daily movement was 15 km. Radio-marked Sage Sparrows at each location departed individually, rather than en masse, corresponding with passage of cold front weather systems. Conventional telemetry techniques limited our ability [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 145.64082}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50539774e4b097cd4fce6053'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50539774e4b097cd4fce6053',
#       'rel': 'related'}},
#     'id': '50539774e4b097cd4fce6053',
#     'title': 'Using vigilance behavior to test whether predation promotes habitat partitioning',
#     'hasChildren': False,
#     '_searchHit': {'_score': 145.44771}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50541b0ae4b097cd4fcfe019'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50541b0ae4b097cd4fcfe019',
#       'rel': 'related'}},
#     'id': '50541b0ae4b097cd4fcfe019',
#     'title': 'Choices and consequences of habitat occupancy and nest site selection in sage sparrows',
#     'hasChildren': False,
#     '_searchHit': {'_score': 143.77713}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e4b20e4b07f02db6abb18'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4b20e4b07f02db6abb18',
#       'rel': 'related'}},
#     'id': '4f4e4b20e4b07f02db6abb18',
#     'title': 'Landscape characteristics of fragmented shrubsteppe habitats and breeding passerine birds',
#     'summary': "We examined the influence of local and landscape-level attributes of fragmented habitats in shrubsteppe habitats on the breeding distributions of Sage (Amphispiza belli) and Brewer's (Spizella breweri) Sparrows, Sage Thrashers (Oreoscoptes montanus), Horned Larks (Eremophila alpestris), and Western Meadowlarks (Sturnella neglecta) in the Snake River Plains of southwestern Idaho. We developed habitat (resource) selection models for each species by combining bird counts conducted from 1991 through 1933 with local vegetation characteristics and landscape attributes derived from satellite imagery. Site selection by shrubsteppe species (Sage and Brewer's Sparrows, and Sage Thrashers) depended on local vegetation cover and landscape features, [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 143.32037}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5059ef71e4b0c8380cd4a247'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5059ef71e4b0c8380cd4a247',
#       'rel': 'related'}},
#     'id': '5059ef71e4b0c8380cd4a247',
#     'title': 'Avian response to wildfire in interior Columbia basin shrubsteppe',
#     'summary': "Wildfire and conversion of sagebrush (Artemisia spp.) shrublands to cheatgrass (Bromus tectorum) grasslands is a serious threat to the shrubsteppe ecosystem, but few studies have documented wildfire's effects on birds with multiple years of pre- and post-fire data. Using data from avian point counts recorded 4 years before and 7 years after a large-scale, severe wildfire in the Columbia Basin of south-central Washington, we found significant effects of fire on population trends or mean abundance of nearly all species investigated. The Sage Sparrow (Amphispiza belli), a sagebrush obligate, was decreasing at a high rate both pre- and post-fire. Among species inhabiting more open shrubsteppe or grasslands, the mean abundance of three [...]",
#     'hasChildren': False,
#     '_searchHit': {'_score': 141.4123}}]},
#  {'total': 76,
#   'took': '401ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Brucella+abortus&max=20'},
#   'nextlink': {'rel': 'next',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Brucella+abortus&max=20&offset=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50541852e4b097cd4fcfda43'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50541852e4b097cd4fcfda43',
#       'rel': 'related'}},
#     'id': '50541852e4b097cd4fcfda43',
#     'title': 'Safety of Brucella abortus strain RB51 in bull elk',
#     'hasChildren': False,
#     '_searchHit': {'_score': 726.6112}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50538c68e4b097cd4fce35b7'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50538c68e4b097cd4fce35b7',
#       'rel': 'related'}},
#     'id': '50538c68e4b097cd4fce35b7',
#     'title': 'Experimental studies on Brucella abortus in moose (Alces alces)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 695.87445}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505780a3e4b01ad7e027f819'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505780a3e4b01ad7e027f819',
#       'rel': 'related'}},
#     'id': '505780a3e4b01ad7e027f819',
#     'title': 'Safety of Brucella abortus strain RB51 in deer mice',
#     'hasChildren': False,
#     '_searchHit': {'_score': 683.1524}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053fcf9e4b097cd4fcf9911'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053fcf9e4b097cd4fcf9911',
#       'rel': 'related'}},
#     'id': '5053fcf9e4b097cd4fcf9911',
#     'title': 'Biosafety of parenteral Brucella abortus RB51 vaccine in bison calves',
#     'hasChildren': False,
#     '_searchHit': {'_score': 678.205}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505797c2e4b01ad7e0284bf3'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505797c2e4b01ad7e0284bf3',
#       'rel': 'related'}},
#     'id': '505797c2e4b01ad7e0284bf3',
#     'title': 'Immune responses of elk to vaccination with Brucella abortus strain RB51',
#     'hasChildren': False,
#     '_searchHit': {'_score': 651.74}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505797c2e4b01ad7e0284bf1'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505797c2e4b01ad7e0284bf1',
#       'rel': 'related'}},
#     'id': '505797c2e4b01ad7e0284bf1',
#     'title': 'Immune responses of bison to ballistic or hand vaccination with Brucella abortus strain RB51',
#     'hasChildren': False,
#     '_searchHit': {'_score': 643.2815}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50536973e4b097cd4fcd934b'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50536973e4b097cd4fcd934b',
#       'rel': 'related'}},
#     'id': '50536973e4b097cd4fcd934b',
#     'title': 'Experimental infection of gray foxes (Urocyon cinereoargenteus ) with Brucella abortus .',
#     'hasChildren': False,
#     '_searchHit': {'_score': 641.66003}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50578ea3e4b01ad7e0282b6d'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50578ea3e4b01ad7e0282b6d',
#       'rel': 'related'}},
#     'id': '50578ea3e4b01ad7e0282b6d',
#     'title': 'Brucella abortus strain RB51 vaccination in elk I. Efficacy of reduced dosage',
#     'hasChildren': False,
#     '_searchHit': {'_score': 638.89294}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50541852e4b097cd4fcfda41'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50541852e4b097cd4fcfda41',
#       'rel': 'related'}},
#     'id': '50541852e4b097cd4fcfda41',
#     'title': 'Safety and efficacy of Brucella abortus strain RB51 vaccine in captive pregnant elk',
#     'hasChildren': False,
#     '_searchHit': {'_score': 630.9541}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/55c333a9e4b033ef52106a7c'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=55c333a9e4b033ef52106a7c',
#       'rel': 'related'}},
#     'id': '55c333a9e4b033ef52106a7c',
#     'title': 'An ecological perspective on the changing face of Brucella abortus in the western United States',
#     'summary': 'After a hiatus during the 1990s, outbreaks of Brucella abortus in cattle are occurring more frequently in some of the western states of the United States, namely, Montana, Wyoming and Idaho. This increase is coincident with increasing brucellosis seroprevalence in elk (Cervus elaphus), which is correlated with elk density. Vaccines are a seductive solution, but their use in wildlife systems remains limited by logistical, financial, and scientific constraints. Cattle vaccination is ongoing in the region. Livestock regulations, however, tend to be based on serological tests that test for previous exposure and available vaccines do not protect against seroconversion. The authors review recent ecological studies of brucellosis, with particular [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 628.09937}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50578f0fe4b01ad7e0282e63'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50578f0fe4b01ad7e0282e63',
#       'rel': 'related'}},
#     'id': '50578f0fe4b01ad7e0282e63',
#     'title': 'Safety of Brucella abortus strain RB51 vaccine in non-target ungulates and coyotes',
#     'hasChildren': False,
#     '_searchHit': {'_score': 624.9261}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505a0c10e4b0c8380cd52a09'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505a0c10e4b0c8380cd52a09',
#       'rel': 'related'}},
#     'id': '505a0c10e4b0c8380cd52a09',
#     'title': 'Evaluation of Brucella abortus strain RB51 and strain 19 in pronghorn antelope',
#     'summary': 'Free-roaming elk and bison in the Greater Yellowstone Area remain the only wildlife reservoirs for Brucella abortus in the United States, and the large number of animals and a lack of holding facilities make it unreasonable to individually vaccinate each animal. Therefore, oral delivery is being proposed as a possible option to vaccinate these wild ungulates. One of the main problems associated with oral vaccination is the potential exposure of nontarget species to the vaccines. The purpose of this study was to determine the effects of two Brucella vaccines, strain 19 (S19) and the rough strain RB51 (SRB51), in pregnant pronghorn antelope. We conclude that S19 and SRB51 rarely colonize maternal and fetal tissues of pregnant pronghorn [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 617.29004}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5059f195e4b0c8380cd4ad0b'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5059f195e4b0c8380cd4ad0b',
#       'rel': 'related'}},
#     'id': '5059f195e4b0c8380cd4ad0b',
#     'title': 'Biosafety of parenteral Brucella abortus RB51 vaccine in bison calves',
#     'summary': 'Vaccination is considered among the primary management tools for reducing brucellosis prevalence in Greater Yellowstone Area (GYA) ungulates. Before their use, however, vaccine safety and efficacy must be demonstrated. Twenty-seven female bison (Bison bison) calves (approx 5 months old) were vaccinated with Brucella abortus Strain RB51 (1.5 x 1010 colony forming units [CFU], subcutaneously) as part of routine management. We assessed the persistence, pathology, shedding, and transmission associated with RB51 by serial necropsy, bacteriology, histopathology, and serology of 20 of these 27 vaccinated calves, and RB51 serology of 10 nonvaccinated, commingling adult females. With the exception of 1 calf, RB51 dot-blot titers at necropsy [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 612.4053}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50536ec8e4b097cd4fcdb033'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50536ec8e4b097cd4fcdb033',
#       'rel': 'related'}},
#     'id': '50536ec8e4b097cd4fcdb033',
#     'title': 'Brucella abortus in captive bison. I. Serology, bacteriology, pathogenesis, and transmission to cattle.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 611.8413}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505371d9e4b097cd4fcdbd9c'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505371d9e4b097cd4fcdbd9c',
#       'rel': 'related'}},
#     'id': '505371d9e4b097cd4fcdbd9c',
#     'title': 'Brucella abortus in bison. II. Evaluation of strain 19 vaccination of pregnant cows.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 599.7799}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053c926e4b097cd4fcf0eec'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053c926e4b097cd4fcf0eec',
#       'rel': 'related'}},
#     'id': '5053c926e4b097cd4fcf0eec',
#     'title': 'Conservation of germ plasm from bison infected with Brucella abortus',
#     'hasChildren': False,
#     '_searchHit': {'_score': 599.7799}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50536cece4b097cd4fcda4c8'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50536cece4b097cd4fcda4c8',
#       'rel': 'related'}},
#     'id': '50536cece4b097cd4fcda4c8',
#     'title': 'Interspecific transmission of Brucella abortus from experimentally infected coyotes (Canis latrans ) to parturient cattle.',
#     'hasChildren': False,
#     '_searchHit': {'_score': 551.764}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053f9f3e4b097cd4fcf9011'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053f9f3e4b097cd4fcf9011',
#       'rel': 'related'}},
#     'id': '5053f9f3e4b097cd4fcf9011',
#     'title': 'Serosurvey for antibodies against Brucella abortus and Leptospira interrogans in pampas deer from Brazil',
#     'hasChildren': False,
#     '_searchHit': {'_score': 547.2914}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505a0863e4b0c8380cd51ad1'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505a0863e4b0c8380cd51ad1',
#       'rel': 'related'}},
#     'id': '505a0863e4b0c8380cd51ad1',
#     'title': 'Efficacy of single calfhood vaccination of elk with Brucella abortus strain 19',
#     'summary': 'Brucellosis has been eradicated from cattle in the states of Wyoming, Montana, and Idaho, USA. However, free-ranging elk (Cervus elaphus) that use feedgrounds in the Greater Yellowstone Area (GYA) and bison (Bison bison) in Yellowstone and Grand Teton national parks still have high seroprevalence to the disease and have caused loss of brucellosis-free status in Wyoming. Management tools to control or eliminate the disease are limited; however, wildlife vaccination is among the methods currently used by wildlife managers in Wyoming. We conducted a controlled challenge study of single calfhood vaccination. Elk calves, caught in January and February of 1999 and 2000 and acclimated to captivity for 3 weeks, were randomly assigned to control [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 544.28674}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505780a0e4b01ad7e027f801'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505780a0e4b01ad7e027f801',
#       'rel': 'related'}},
#     'id': '505780a0e4b01ad7e027f801',
#     'title': 'Experimental infection of nontarget species of rodents and birds with Brucella abortus strain RB51 vaccine',
#     'hasChildren': False,
#     '_searchHit': {'_score': 543.55743}}]},
#  {'total': 0,
#   'took': '2ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Thrichomys+fosteri&max=20'},
#   'items': []},
#  {'total': 2,
#   'took': '302ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Equus+burchelli&max=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053a7d8e4b097cd4fce9e2e'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053a7d8e4b097cd4fce9e2e',
#       'rel': 'related'}},
#     'id': '5053a7d8e4b097cd4fce9e2e',
#     'title': 'Migration of zebra and wildebeest between Tarangire National Park and Simanjiro Plains, northern Tanzania, in 1972 and recent trends',
#     'hasChildren': False,
#     '_searchHit': {'_score': 152.34262}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053becee4b097cd4fceef9a'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053becee4b097cd4fceef9a',
#       'rel': 'related'}},
#     'id': '5053becee4b097cd4fceef9a',
#     'title': 'Chromosomal rearrangements in a Somali wild ass pedigree, Equus africanus somaliensis (Perissodactyla, Equidae)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 141.45003}}]},
#  {'total': 16,
#   'took': '363ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Tetrao+tetrix&max=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50541abae4b097cd4fcfdee3'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50541abae4b097cd4fcfdee3',
#       'rel': 'related'}},
#     'id': '50541abae4b097cd4fcfdee3',
#     'title': 'Combs and sexual selection in black grouse (Tetrao tetrix)',
#     'hasChildren': False,
#     '_searchHit': {'_score': 782.08136}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50538aa3e4b097cd4fce2eaa'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50538aa3e4b097cd4fce2eaa',
#       'rel': 'related'}},
#     'id': '50538aa3e4b097cd4fce2eaa',
#     'title': 'Implications of grazing and predator management on the habitats and breeding success of black grouse Tetrao tetrix',
#     'hasChildren': False,
#     '_searchHit': {'_score': 593.53986}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50537ef6e4b097cd4fcdf8d9'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50537ef6e4b097cd4fcdf8d9',
#       'rel': 'related'}},
#     'id': '50537ef6e4b097cd4fcdf8d9',
#     'title': 'Forest fragmentation due to agriculture affects the reproductive success of the ground-nesting black grouse Tetrao tetrix',
#     'hasChildren': False,
#     '_searchHit': {'_score': 590.31885}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b0c9e4b097cd4fcebfb5'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b0c9e4b097cd4fcebfb5',
#       'rel': 'related'}},
#     'id': '5053b0c9e4b097cd4fcebfb5',
#     'title': 'Estimation of the chemical composition of black grouse Tetrao tetrix diets in the eastern Italian Alps',
#     'hasChildren': False,
#     '_searchHit': {'_score': 584.9204}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50542456e4b097cd4fcff7ce'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50542456e4b097cd4fcff7ce',
#       'rel': 'related'}},
#     'id': '50542456e4b097cd4fcff7ce',
#     'title': 'Genetic correlates of spatial population structure in central European capercaillie Tetrao urogallus and black grouse T. tetrix: a project in progress',
#     'hasChildren': False,
#     '_searchHit': {'_score': 540.9799}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/545d078ce4b0ba8303f71da7'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=545d078ce4b0ba8303f71da7',
#       'rel': 'related'}},
#     'id': '545d078ce4b0ba8303f71da7',
#     'title': 'Small-scale habitat use of black grouse (Tetrao tetrix L.) and rock ptarmigan (Lagopus muta helvetica Thienemann) in the Austrian Alps',
#     'hasChildren': False,
#     '_searchHit': {'_score': 483.89307}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50537f2ae4b097cd4fcdfaea'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50537f2ae4b097cd4fcdfaea',
#       'rel': 'related'}},
#     'id': '50537f2ae4b097cd4fcdfaea',
#     'title': 'Decline of black grouse in Scotland and northern England',
#     'hasChildren': False,
#     '_searchHit': {'_score': 167.87924}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50538658e4b097cd4fce1948'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50538658e4b097cd4fce1948',
#       'rel': 'related'}},
#     'id': '50538658e4b097cd4fce1948',
#     'title': 'Synchrony in tetraonid population dynamics',
#     'hasChildren': False,
#     '_searchHit': {'_score': 166.76479}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50575c3ee4b01ad7e0273f33'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50575c3ee4b01ad7e0273f33',
#       'rel': 'related'}},
#     'id': '50575c3ee4b01ad7e0273f33',
#     'title': 'Predator control and the density and reproductive success of grouse populations in Finland',
#     'hasChildren': False,
#     '_searchHit': {'_score': 166.64384}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053ce89e4b097cd4fcf1b70'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053ce89e4b097cd4fcf1b70',
#       'rel': 'related'}},
#     'id': '5053ce89e4b097cd4fcf1b70',
#     'title': 'Predicting autumn population sizes of tetraonid game birds from reproduction data of pied flycatcher Ficedula hypoleuca',
#     'hasChildren': False,
#     '_searchHit': {'_score': 164.92917}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505416abe4b097cd4fcfd423'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505416abe4b097cd4fcfd423',
#       'rel': 'related'}},
#     'id': '505416abe4b097cd4fcfd423',
#     'title': 'Landscape fragmentation and forest composition effects on grouse breeding success in boreal forests',
#     'hasChildren': False,
#     '_searchHit': {'_score': 164.92917}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053a19ce4b097cd4fce8716'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053a19ce4b097cd4fce8716',
#       'rel': 'related'}},
#     'id': '5053a19ce4b097cd4fce8716',
#     'title': 'Breeding success of black grouse and capercaillie in relation to mammalian predator densities on two spatial scales',
#     'hasChildren': False,
#     '_searchHit': {'_score': 164.77464}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/50538130e4b097cd4fce0514'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=50538130e4b097cd4fce0514',
#       'rel': 'related'}},
#     'id': '50538130e4b097cd4fce0514',
#     'title': 'Mate-choice copying in black grouse',
#     'hasChildren': False,
#     '_searchHit': {'_score': 160.3635}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053b0c6e4b097cd4fcebfa1'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053b0c6e4b097cd4fcebfa1',
#       'rel': 'related'}},
#     'id': '5053b0c6e4b097cd4fcebfa1',
#     'title': 'Seasonal mortality of black grouse Tetra tetrix during a year with little snow',
#     'hasChildren': False,
#     '_searchHit': {'_score': 156.56903}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/505399e0e4b097cd4fce6bbd'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=505399e0e4b097cd4fce6bbd',
#       'rel': 'related'}},
#     'id': '505399e0e4b097cd4fce6bbd',
#     'title': 'Paternity, copulation disturbance and female choice in lekking black grouse',
#     'hasChildren': False,
#     '_searchHit': {'_score': 136.05078}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5053f9e4e4b097cd4fcf8fcb'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5053f9e4e4b097cd4fcf8fcb',
#       'rel': 'related'}},
#     'id': '5053f9e4e4b097cd4fcf8fcb',
#     'title': 'Microsatellite markers reveal the potential for kin selection on black grouse leks',
#     'hasChildren': False,
#     '_searchHit': {'_score': 136.05078}}]},
#  {'total': 3,
#   'took': '3ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Bassia+prostrata&max=20'},
#   'items': [{'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/5425208ee4b0e641df8a6dbd'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5425208ee4b0e641df8a6dbd',
#       'rel': 'related'}},
#     'id': '5425208ee4b0e641df8a6dbd',
#     'title': 'Long-term effects of seeding after wildfire on vegetation in Great Basin shrubland ecosystems',
#     'summary': '1. Invasive annual grasses alter fire regimes in shrubland ecosystems of the western USA, threatening ecosystem function and fragmenting habitats necessary for shrub-obligate species such as greater sage-grouse. Post-fire stabilization and rehabilitation treatments have been administered to stabilize soils, reduce invasive species spread and restore or establish sustainable ecosystems in which native species are well represented. Long-term effectiveness of these treatments has rarely been evaluated.  2. We studied vegetation at 88 sites where aerial or drill seeding was implemented following fires between 1990 and 2003 in Great Basin (USA) shrublands. We examined sites on loamy soils that burned only once since 1970 to eliminate confounding [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 93.5233}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/53559437e4b0120853e8bf7e'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=53559437e4b0120853e8bf7e',
#       'rel': 'related'}},
#     'id': '53559437e4b0120853e8bf7e',
#     'title': 'Fire rehabilitation effectiveness: a chronosequence approach for the Great Basin',
#     'summary': 'Federal land management agencies have invested heavily in seeding vegetation for emergency stabilization and rehabilitation (ES&R) of non-forested lands. ES&R projects are implemented to reduce post-fire dominance of non-native annual grasses, minimize probability of recurrent fire, quickly recover lost habitat for sensitive species, and ultimately result in plant communities with desirable characteristics including resistance to invasive species and resilience or ability to recover following disturbance. Land managers lack scientific evidence to verify whether seeding non-forested lands achieves their desired long-term ES&R objectives. The overall objective of our investigation is to determine if ES&R projects increase perennial plant [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 81.62706}},
#    {'link': {'rel': 'self',
#      'url': 'https://www.sciencebase.gov/catalog/item/4f4e49b4e4b07f02db5cb036'},
#     'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e49b4e4b07f02db5cb036',
#       'rel': 'related'}},
#     'id': '4f4e49b4e4b07f02db5cb036',
#     'title': 'Seeding Cool-Season Grasses to Suppress Broom Snakeweed (Gutierrezia sarothrae), Downy Brome (Bromus tectorum), and Weedy Forbs',
#     'summary': 'Broom snakeweed (snakeweed) is an aggressive native range-weed found throughout arid and semiarid areas of the western United States, that increases following disturbances such as overgrazing, drought, or wildfire. Ecologically based strategies that include controlling snakeweed and reestablishing desirable herbaceous species are needed to restore productivity and diversity to invaded areas. The objective of this study was to compare the ability of selected introduced and native grass species and prostrate kochia (kochia) to prevent reinvasion of snakeweed, downy brome, and annual forbs following control. This field study was replicated at two sites (Howell and Nephi, Utah) within the sagebrush-steppe biome. Snakeweed and downy brome [...]',
#     'hasChildren': False,
#     '_searchHit': {'_score': 54.96304}}]}]

# %%
# Cache the retrieved document and return/display a sample for verification
display(bis_utils.doc_cache("cache/Results of Consultations with Invalid ITIS Species Names/invalid_sciencebase.json", invalid_sb_result))
# Out:
# {'Doc Cache File': 'cache/Results of Consultations with Invalid ITIS Species Names/invalid_sciencebase.json',
#  'Number of Documents in Cache': 6,
#  'Document Number 2': {'total': 0,
#   'took': '382ms',
#   'selflink': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/items?q=Thrichomys+fosteri&max=20'},
#   'items': []}}
