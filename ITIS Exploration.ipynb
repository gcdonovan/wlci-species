# %% [markdown]
# This notebook explores the records retrieved from the consultation between the WLCI scientific species name list and the ITIS API. The cached ITIS results are examined and next steps are determined.

# %%
#Import needed packages
import json
import bispy
import requests
from IPython.display import display
from joblib import Parallel, delayed
#import logging
#logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')



bis_utils = bispy.bis.Utils()

# %%
#Open cache ITIS list created from WLCI Species List from Literature.ipynb
with open("cache/itis.json", "r") as f:
    itis_cache = json.loads(f.read())

# %%
#Print ITIS list 
itis_cache
# Out:
# [{'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.612983',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Artemisiospiza\\%20nevadensis'}]},
#   'itis_data': [{'tsn': '997723',
#     'nameWInd': 'Artemisiospiza nevadensis',
#     'nameWOInd': 'Artemisiospiza nevadensis',
#     'unit1': 'Artemisiospiza',
#     'unit2': 'nevadensis',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '997695',
#     'rank': 'Species',
#     'synonyms': ['997723:$Amphispiza belli nevadensis$Artemisiospiza belli nevadensi$'],
#     'synonymTSNs': ['997723:$179403$998356$'],
#     'date_created': '2015-10-28 14:07:42',
#     'date_modified': '2015-10-28 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Emberizidae'},
#      {'rank': 'Genus', 'name': 'Artemisiospiza'},
#      {'rank': 'Species', 'name': 'Artemisiospiza nevadensis'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Emberizidae',
#      'Artemisiospiza',
#      'Artemisiospiza nevadensis'],
#     'commonnames': [{'name': 'Sagebrush Sparrow', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.735333',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Artemisia\\%20cana'}]},
#   'itis_data': [{'tsn': '35454',
#     'nameWInd': 'Artemisia cana',
#     'nameWOInd': 'Artemisia cana',
#     'unit1': 'Artemisia',
#     'unit2': 'cana',
#     'usage': 'accepted',
#     'kingdom': 'Plantae',
#     'parentTSN': '35431',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2010-10-05 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Asteranae'},
#      {'rank': 'Order', 'name': 'Asterales'},
#      {'rank': 'Family', 'name': 'Asteraceae'},
#      {'rank': 'Genus', 'name': 'Artemisia'},
#      {'rank': 'Species', 'name': 'Artemisia cana'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Asteranae',
#      'Asterales',
#      'Asteraceae',
#      'Artemisia',
#      'Artemisia cana'],
#     'commonnames': [{'name': 'silver sagebrush', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.744980',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Bison\\%20bison'}]},
#   'itis_data': [{'tsn': '180706',
#     'nameWInd': 'Bison bison',
#     'nameWOInd': 'Bison bison',
#     'unit1': 'Bison',
#     'unit2': 'bison',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180705',
#     'rank': 'Species',
#     'synonyms': ['180706:$Bison bison bison$Bos bison$Bison americanus$Bison sylvestris$Bison americanus pennsylvanicu$Bison bison septemtrionalis$Bison bison athabasacae$Bison americanus$Bison bison athabascae$'],
#     'synonymTSNs': ['180706:$202412$203618$203619$203620$203621$203622$625194$898267$898933$'],
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2012-12-21 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Artiodactyla'},
#      {'rank': 'Family', 'name': 'Bovidae'},
#      {'rank': 'Subfamily', 'name': 'Bovinae'},
#      {'rank': 'Genus', 'name': 'Bison'},
#      {'rank': 'Species', 'name': 'Bison bison'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Artiodactyla',
#      'Bovidae',
#      'Bovinae',
#      'Bison',
#      'Bison bison'],
#     'commonnames': [{'name': 'American bison', 'language': 'English'},
#      {'name': 'bison', 'language': 'English'},
#      {'name': 'Bisonte americano', 'language': 'Spanish'},
#      {'name': 'American Bison', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.672427',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Procyon\\%20lotor'}]},
#   'itis_data': [{'tsn': '180575',
#     'nameWInd': 'Procyon lotor',
#     'nameWOInd': 'Procyon lotor',
#     'unit1': 'Procyon',
#     'unit2': 'lotor',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180574',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2007-08-15 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Carnivora'},
#      {'rank': 'Suborder', 'name': 'Caniformia'},
#      {'rank': 'Family', 'name': 'Procyonidae'},
#      {'rank': 'Genus', 'name': 'Procyon'},
#      {'rank': 'Species', 'name': 'Procyon lotor'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Carnivora',
#      'Caniformia',
#      'Procyonidae',
#      'Procyon',
#      'Procyon lotor'],
#     'commonnames': [{'name': 'Raccoon', 'language': 'English'},
#      {'name': 'northern raccoon', 'language': 'English'},
#      {'name': 'Mapache común', 'language': 'Spanish'},
#      {'name': 'common raccoon', 'language': 'English'},
#      {'name': 'raton laveur', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.691439',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:926246'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Equus\\%20burchelli'}]},
#   'itis_data': [{'tsn': '926246',
#     'nameWInd': 'Equus quagga burchellii',
#     'nameWOInd': 'Equus quagga burchellii',
#     'unit1': 'Equus',
#     'unit2': 'quagga',
#     'unit3': 'burchellii',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '624996',
#     'rank': 'Subspecies',
#     'synonyms': ['926246:$Equus burchellii$Hippotigris campestris$Equus festivus$Equus zebroides$Hippotigris antiquorum$Equus wardi$Equus burchelli$Asinus burchellii$Hippotigris isabellinus$Equus burchellii burchellii$Equus burchellii antiquorum$Equus burchelli burchelli$Hippotigris chapmanni kaokensi$'],
#     'synonymTSNs': ['926246:$624992$926090$926091$926092$926093$926100$926145$926147$926159$926168$926240$926241$926243$'],
#     'date_created': '2013-11-04 18:34:23',
#     'date_modified': '2013-11-04 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Perissodactyla'},
#      {'rank': 'Family', 'name': 'Equidae'},
#      {'rank': 'Genus', 'name': 'Equus'},
#      {'rank': 'Subgenus', 'name': 'Equus (Hippotigris)'},
#      {'rank': 'Species', 'name': 'Equus quagga'},
#      {'rank': 'Subspecies', 'name': 'Equus quagga burchellii'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Perissodactyla',
#      'Equidae',
#      'Equus',
#      'Equus (Hippotigris)',
#      'Equus quagga',
#      'Equus quagga burchellii'],
#     'commonnames': [{'name': 'Zululand zebra', 'language': 'English'},
#      {'name': 'Damara zebra', 'language': 'English'},
#      {'name': "Burchell's Zebra", 'language': 'English'},
#      {'name': 'Bontequagga', 'language': 'English'}]},
#    {'tsn': '926145',
#     'nameWInd': 'Equus burchelli',
#     'nameWOInd': 'Equus burchelli',
#     'unit1': 'Equus',
#     'unit2': 'burchelli',
#     'usage': 'invalid',
#     'unacceptReason': 'unavailable, literature misspelling',
#     'kingdom': 'Animalia',
#     'rank': 'Species',
#     'synonyms': ['926246:$Equus burchellii$Hippotigris campestris$Equus festivus$Equus zebroides$Hippotigris antiquorum$Equus wardi$Equus burchelli$Asinus burchellii$Hippotigris isabellinus$Equus burchellii burchellii$Equus burchellii antiquorum$Equus burchelli burchelli$Hippotigris chapmanni kaokensi$'],
#     'synonymTSNs': ['926246:$624992$926090$926091$926092$926093$926100$926145$926147$926159$926168$926240$926241$926243$'],
#     'acceptedTSN': ['926246'],
#     'date_created': '2013-11-04 18:34:01',
#     'date_modified': '2013-11-04 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Perissodactyla'},
#      {'rank': 'Family', 'name': 'Equidae'},
#      {'rank': 'Genus', 'name': 'Equus'},
#      {'rank': 'Subgenus', 'name': 'Equus (Hippotigris)'},
#      {'rank': 'Species', 'name': 'Equus quagga'},
#      {'rank': 'Subspecies', 'name': 'Equus quagga burchellii'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Perissodactyla',
#      'Equidae',
#      'Equus',
#      'Equus (Hippotigris)',
#      'Equus quagga',
#      'Equus quagga burchellii']}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.706945',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Prunus\\%20virginiana'}]},
#   'itis_data': [{'tsn': '24806',
#     'nameWInd': 'Prunus virginiana',
#     'nameWOInd': 'Prunus virginiana',
#     'unit1': 'Prunus',
#     'unit2': 'virginiana',
#     'usage': 'accepted',
#     'kingdom': 'Plantae',
#     'parentTSN': '24762',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-12-08 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Rosanae'},
#      {'rank': 'Order', 'name': 'Rosales'},
#      {'rank': 'Family', 'name': 'Rosaceae'},
#      {'rank': 'Genus', 'name': 'Prunus'},
#      {'rank': 'Species', 'name': 'Prunus virginiana'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Rosanae',
#      'Rosales',
#      'Rosaceae',
#      'Prunus',
#      'Prunus virginiana'],
#     'commonnames': [{'name': 'chokecherry', 'language': 'English'},
#      {'name': 'common chokecherry', 'language': 'English'},
#      {'name': 'Virginia chokecherry', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.709045',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Atriplex\\%20gardneri'}]},
#   'itis_data': [{'tsn': '20531',
#     'nameWInd': 'Atriplex gardneri',
#     'nameWOInd': 'Atriplex gardneri',
#     'unit1': 'Atriplex',
#     'unit2': 'gardneri',
#     'usage': 'accepted',
#     'kingdom': 'Plantae',
#     'parentTSN': '20505',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-08-30 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Caryophyllanae'},
#      {'rank': 'Order', 'name': 'Caryophyllales'},
#      {'rank': 'Family', 'name': 'Amaranthaceae'},
#      {'rank': 'Genus', 'name': 'Atriplex'},
#      {'rank': 'Species', 'name': 'Atriplex gardneri'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Caryophyllanae',
#      'Caryophyllales',
#      'Amaranthaceae',
#      'Atriplex',
#      'Atriplex gardneri'],
#     'commonnames': [{'name': "Gardner's saltbush", 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.707885',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Aythya\\%20affinis'}]},
#   'itis_data': [{'tsn': '175134',
#     'nameWInd': 'Aythya affinis',
#     'nameWOInd': 'Aythya affinis',
#     'unit1': 'Aythya',
#     'unit2': 'affinis',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '175124',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2007-01-23 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Anseriformes'},
#      {'rank': 'Family', 'name': 'Anatidae'},
#      {'rank': 'Subfamily', 'name': 'Anatinae'},
#      {'rank': 'Genus', 'name': 'Aythya'},
#      {'rank': 'Species', 'name': 'Aythya affinis'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Anseriformes',
#      'Anatidae',
#      'Anatinae',
#      'Aythya',
#      'Aythya affinis'],
#     'commonnames': [{'name': 'Pato boludo-menor', 'language': 'Spanish'},
#      {'name': 'Lesser Scaup', 'language': 'English'},
#      {'name': 'petit fuligule', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:50.997938',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Ovis\\%20canadensis'}]},
#   'itis_data': [{'tsn': '180711',
#     'nameWInd': 'Ovis canadensis',
#     'nameWOInd': 'Ovis canadensis',
#     'unit1': 'Ovis',
#     'unit2': 'canadensis',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180709',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2012-12-21 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Artiodactyla'},
#      {'rank': 'Family', 'name': 'Bovidae'},
#      {'rank': 'Subfamily', 'name': 'Caprinae'},
#      {'rank': 'Genus', 'name': 'Ovis'},
#      {'rank': 'Species', 'name': 'Ovis canadensis'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Artiodactyla',
#      'Bovidae',
#      'Caprinae',
#      'Ovis',
#      'Ovis canadensis'],
#     'commonnames': [{'name': 'bighorn sheep', 'language': 'English'},
#      {'name': 'Borrego cimarrón', 'language': 'Spanish'},
#      {'name': 'Bighorn Sheep', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.015788',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Lasiurus\\%20cinereus'}]},
#   'itis_data': [{'tsn': '180017',
#     'nameWInd': 'Lasiurus cinereus',
#     'nameWOInd': 'Lasiurus cinereus',
#     'unit1': 'Lasiurus',
#     'unit2': 'cinereus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '945947',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2014-08-27 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Chiroptera'},
#      {'rank': 'Suborder', 'name': 'Yangochiroptera'},
#      {'rank': 'Superfamily', 'name': 'Vespertilionoidea'},
#      {'rank': 'Family', 'name': 'Vespertilionidae'},
#      {'rank': 'Subfamily', 'name': 'Vespertilioninae'},
#      {'rank': 'Tribe', 'name': 'Lasiurini'},
#      {'rank': 'Genus', 'name': 'Lasiurus'},
#      {'rank': 'Subgenus', 'name': 'Lasiurus (Lasiurus)'},
#      {'rank': 'Species', 'name': 'Lasiurus cinereus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Chiroptera',
#      'Yangochiroptera',
#      'Vespertilionoidea',
#      'Vespertilionidae',
#      'Vespertilioninae',
#      'Lasiurini',
#      'Lasiurus',
#      'Lasiurus (Lasiurus)',
#      'Lasiurus cinereus'],
#     'commonnames': [{'name': 'hoary bat', 'language': 'English'},
#      {'name': 'Murciélago-cola peluda canoso', 'language': 'Spanish'},
#      {'name': 'chauve-souris cendrée', 'language': 'French'},
#      {'name': 'Hoary Bat', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.092177',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Grus\\%20americana'}]},
#   'itis_data': [{'tsn': '176176',
#     'nameWInd': 'Grus americana',
#     'nameWOInd': 'Grus americana',
#     'unit1': 'Grus',
#     'unit2': 'americana',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '176175',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2006-11-28 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Gruiformes'},
#      {'rank': 'Family', 'name': 'Gruidae'},
#      {'rank': 'Subfamily', 'name': 'Gruinae'},
#      {'rank': 'Genus', 'name': 'Grus'},
#      {'rank': 'Species', 'name': 'Grus americana'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Gruiformes',
#      'Gruidae',
#      'Gruinae',
#      'Grus',
#      'Grus americana'],
#     'commonnames': [{'name': 'Whooping Crane', 'language': 'English'},
#      {'name': 'Grulla blanca', 'language': 'Spanish'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.095298',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Atriplex\\%20argentea'}]},
#   'itis_data': [{'tsn': '20512',
#     'nameWInd': 'Atriplex argentea',
#     'nameWOInd': 'Atriplex argentea',
#     'unit1': 'Atriplex',
#     'unit2': 'argentea',
#     'usage': 'accepted',
#     'kingdom': 'Plantae',
#     'parentTSN': '20505',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-08-30 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Caryophyllanae'},
#      {'rank': 'Order', 'name': 'Caryophyllales'},
#      {'rank': 'Family', 'name': 'Amaranthaceae'},
#      {'rank': 'Genus', 'name': 'Atriplex'},
#      {'rank': 'Species', 'name': 'Atriplex argentea'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Caryophyllanae',
#      'Caryophyllales',
#      'Amaranthaceae',
#      'Atriplex',
#      'Atriplex argentea'],
#     'commonnames': [{'name': 'silverscale', 'language': 'unspecified'},
#      {'name': 'silverscale saltweed', 'language': 'unspecified'},
#      {'name': 'silverscale saltbush', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.099245',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:997724'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Amphispiza\\%20belli'}]},
#   'itis_data': [{'tsn': '997724',
#     'nameWInd': 'Artemisiospiza belli',
#     'nameWOInd': 'Artemisiospiza belli',
#     'unit1': 'Artemisiospiza',
#     'unit2': 'belli',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '997695',
#     'rank': 'Species',
#     'synonyms': ['997724:$Amphispiza belli$'],
#     'synonymTSNs': ['997724:$179402$'],
#     'date_created': '2015-10-28 14:07:43',
#     'date_modified': '2015-10-28 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Emberizidae'},
#      {'rank': 'Genus', 'name': 'Artemisiospiza'},
#      {'rank': 'Species', 'name': 'Artemisiospiza belli'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Emberizidae',
#      'Artemisiospiza',
#      'Artemisiospiza belli'],
#     'commonnames': [{'name': "Bell's Sparrow", 'language': 'English'},
#      {'name': 'Zacatonero de artemisa', 'language': 'Spanish'},
#      {'name': 'Sage Sparrow', 'language': 'English'}]},
#    {'tsn': '179402',
#     'nameWInd': 'Amphispiza belli',
#     'nameWOInd': 'Amphispiza belli',
#     'unit1': 'Amphispiza',
#     'unit2': 'belli',
#     'usage': 'invalid',
#     'unacceptReason': 'subsequent name/combination',
#     'kingdom': 'Animalia',
#     'rank': 'Species',
#     'synonyms': ['997724:$Amphispiza belli$'],
#     'synonymTSNs': ['997724:$179402$'],
#     'acceptedTSN': ['997724'],
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2015-10-28 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Emberizidae'},
#      {'rank': 'Genus', 'name': 'Artemisiospiza'},
#      {'rank': 'Species', 'name': 'Artemisiospiza belli'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Emberizidae',
#      'Artemisiospiza',
#      'Artemisiospiza belli'],
#     'commonnames': [{'name': 'Sage Sparrow', 'language': 'English'},
#      {'name': 'Zacatonero de artemisa', 'language': 'Spanish'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.108539',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Tympanuchus\\%20pallidicinctus'}]},
#   'itis_data': [{'tsn': '175838',
#     'nameWInd': 'Tympanuchus pallidicinctus',
#     'nameWOInd': 'Tympanuchus pallidicinctus',
#     'unit1': 'Tympanuchus',
#     'unit2': 'pallidicinctus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '175833',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2005-06-08 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Galliformes'},
#      {'rank': 'Family', 'name': 'Phasianidae'},
#      {'rank': 'Subfamily', 'name': 'Tetraoninae'},
#      {'rank': 'Genus', 'name': 'Tympanuchus'},
#      {'rank': 'Species', 'name': 'Tympanuchus pallidicinctus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Galliformes',
#      'Phasianidae',
#      'Tetraoninae',
#      'Tympanuchus',
#      'Tympanuchus pallidicinctus'],
#     'commonnames': [{'name': 'Lesser Prairie-Chicken', 'language': 'English'},
#      {'name': 'Lesser Prairie Chicken', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.113149',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'Multi Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Poa\\%20secunda'},
#     {'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:41223%20AND%20(usage:accepted%20OR%20usage:valid)'}]},
#   'itis_data': [{'tsn': '41223',
#     'nameWInd': 'Puccinellia rupestris',
#     'nameWOInd': 'Puccinellia rupestris',
#     'unit1': 'Puccinellia',
#     'unit2': 'rupestris',
#     'usage': 'accepted',
#     'kingdom': 'Plantae',
#     'parentTSN': '41176',
#     'rank': 'Species',
#     'synonyms': ['41223:$Glyceria rupestris$Atropis procumbens$Festuca procumbens$Glyceria procumbens$Panicularia procumbens$Poa procumbens$Poa rupestris$Poa secunda$Pseudosclerochloa rupestris$Sclerochloa procumbens$Scleropoa procumbens$'],
#     'synonymTSNs': ['41223:$514093$786977$790096$790238$791815$794305$794335$794344$794571$794908$794912$'],
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2010-11-30 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Lilianae'},
#      {'rank': 'Order', 'name': 'Poales'},
#      {'rank': 'Family', 'name': 'Poaceae'},
#      {'rank': 'Genus', 'name': 'Puccinellia'},
#      {'rank': 'Species', 'name': 'Puccinellia rupestris'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Lilianae',
#      'Poales',
#      'Poaceae',
#      'Puccinellia',
#      'Puccinellia rupestris'],
#     'commonnames': [{'name': 'British alkaligrass',
#       'language': 'unspecified'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.316249',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Centrocercus\\%20minimus'}]},
#   'itis_data': [{'tsn': '677540',
#     'nameWInd': 'Centrocercus minimus',
#     'nameWOInd': 'Centrocercus minimus',
#     'unit1': 'Centrocercus',
#     'unit2': 'minimus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '175854',
#     'rank': 'Species',
#     'date_created': '2005-06-08 08:29:33',
#     'date_modified': '2005-06-08 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Galliformes'},
#      {'rank': 'Family', 'name': 'Phasianidae'},
#      {'rank': 'Subfamily', 'name': 'Tetraoninae'},
#      {'rank': 'Genus', 'name': 'Centrocercus'},
#      {'rank': 'Species', 'name': 'Centrocercus minimus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Galliformes',
#      'Phasianidae',
#      'Tetraoninae',
#      'Centrocercus',
#      'Centrocercus minimus'],
#     'commonnames': [{'name': 'Gunnison Sage Grouse', 'language': 'English'},
#      {'name': 'Gunnison Grouse', 'language': 'English'},
#      {'name': 'Gunnison Sage-Grouse', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.338426',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Falco\\%20mexicanus'}]},
#   'itis_data': [{'tsn': '175603',
#     'nameWInd': 'Falco mexicanus',
#     'nameWOInd': 'Falco mexicanus',
#     'unit1': 'Falco',
#     'unit2': 'mexicanus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '175598',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-09-22 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Falconiformes'},
#      {'rank': 'Family', 'name': 'Falconidae'},
#      {'rank': 'Subfamily', 'name': 'Falconinae'},
#      {'rank': 'Genus', 'name': 'Falco'},
#      {'rank': 'Species', 'name': 'Falco mexicanus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Falconiformes',
#      'Falconidae',
#      'Falconinae',
#      'Falco',
#      'Falco mexicanus'],
#     'commonnames': [{'name': 'Prairie Falcon', 'language': 'English'},
#      {'name': 'Halcón mexicano', 'language': 'Spanish'},
#      {'name': 'Faucon des prairies', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.359754',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Falco\\%20sparverius'}]},
#   'itis_data': [{'tsn': '175622',
#     'nameWInd': 'Falco sparverius',
#     'nameWOInd': 'Falco sparverius',
#     'unit1': 'Falco',
#     'unit2': 'sparverius',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '175598',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-09-22 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Falconiformes'},
#      {'rank': 'Family', 'name': 'Falconidae'},
#      {'rank': 'Subfamily', 'name': 'Falconinae'},
#      {'rank': 'Genus', 'name': 'Falco'},
#      {'rank': 'Species', 'name': 'Falco sparverius'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Falconiformes',
#      'Falconidae',
#      'Falconinae',
#      'Falco',
#      'Falco sparverius'],
#     'commonnames': [{'name': 'American Kestrel', 'language': 'English'},
#      {'name': 'Cernícalo americano', 'language': 'Spanish'},
#      {'name': "Crécerelle d'Amérique", 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.366245',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Canis\\%20lupus'}]},
#   'itis_data': [{'tsn': '180596',
#     'nameWInd': 'Canis lupus',
#     'nameWOInd': 'Canis lupus',
#     'unit1': 'Canis',
#     'unit2': 'lupus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180595',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2015-11-20 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Carnivora'},
#      {'rank': 'Suborder', 'name': 'Caniformia'},
#      {'rank': 'Family', 'name': 'Canidae'},
#      {'rank': 'Genus', 'name': 'Canis'},
#      {'rank': 'Species', 'name': 'Canis lupus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Carnivora',
#      'Caniformia',
#      'Canidae',
#      'Canis',
#      'Canis lupus'],
#     'commonnames': [{'name': 'Wolf', 'language': 'English'},
#      {'name': 'Gray Wolf', 'language': 'English'},
#      {'name': 'Lobo gris', 'language': 'Spanish'},
#      {'name': 'loup', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.367199',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Rangifer\\%20tarandus'}]},
#   'itis_data': [{'tsn': '180701',
#     'nameWInd': 'Rangifer tarandus',
#     'nameWOInd': 'Rangifer tarandus',
#     'unit1': 'Rangifer',
#     'unit2': 'tarandus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180700',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2012-12-21 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Artiodactyla'},
#      {'rank': 'Family', 'name': 'Cervidae'},
#      {'rank': 'Subfamily', 'name': 'Capreolinae'},
#      {'rank': 'Genus', 'name': 'Rangifer'},
#      {'rank': 'Species', 'name': 'Rangifer tarandus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Artiodactyla',
#      'Cervidae',
#      'Capreolinae',
#      'Rangifer',
#      'Rangifer tarandus'],
#     'commonnames': [{'name': 'reindeer', 'language': 'English'},
#      {'name': 'caribou', 'language': 'English'},
#      {'name': 'caribou', 'language': 'French'},
#      {'name': 'Reindeer', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.371100',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Aquila\\%20chrysaetos'}]},
#   'itis_data': [{'tsn': '175407',
#     'nameWInd': 'Aquila chrysaetos',
#     'nameWOInd': 'Aquila chrysaetos',
#     'unit1': 'Aquila',
#     'unit2': 'chrysaetos',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '175406',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-09-22 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Accipitriformes'},
#      {'rank': 'Family', 'name': 'Accipitridae'},
#      {'rank': 'Genus', 'name': 'Aquila'},
#      {'rank': 'Species', 'name': 'Aquila chrysaetos'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Accipitriformes',
#      'Accipitridae',
#      'Aquila',
#      'Aquila chrysaetos'],
#     'commonnames': [{'name': 'Águila real', 'language': 'Spanish'},
#      {'name': 'Golden Eagle', 'language': 'English'},
#      {'name': 'Aigle royal', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.560117',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Descurainia\\%20sophia'}]},
#   'itis_data': [{'tsn': '22843',
#     'nameWInd': 'Descurainia sophia',
#     'nameWOInd': 'Descurainia sophia',
#     'unit1': 'Descurainia',
#     'unit2': 'sophia',
#     'usage': 'accepted',
#     'kingdom': 'Plantae',
#     'parentTSN': '22819',
#     'rank': 'Species',
#     'synonyms': ['22843:$Sisymbrium sophia$Sophia sophia$'],
#     'synonymTSNs': ['22843:$521589$521808$'],
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-08-30 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Rosanae'},
#      {'rank': 'Order', 'name': 'Brassicales'},
#      {'rank': 'Family', 'name': 'Brassicaceae'},
#      {'rank': 'Genus', 'name': 'Descurainia'},
#      {'rank': 'Species', 'name': 'Descurainia sophia'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Rosanae',
#      'Brassicales',
#      'Brassicaceae',
#      'Descurainia',
#      'Descurainia sophia'],
#     'commonnames': [{'name': 'flixweed', 'language': 'English'},
#      {'name': 'pinnate tansymustard', 'language': 'English'},
#      {'name': 'flaxweed tansymustard', 'language': 'English'},
#      {'name': 'flixweed tansymustard', 'language': 'English'},
#      {'name': 'herb-sophia', 'language': 'English'},
#      {'name': 'tansymustard', 'language': 'English'},
#      {'name': 'herb sophia', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.569479',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Lepus\\%20townsendii'}]},
#   'itis_data': [{'tsn': '180118',
#     'nameWInd': 'Lepus townsendii',
#     'nameWOInd': 'Lepus townsendii',
#     'unit1': 'Lepus',
#     'unit2': 'townsendii',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180111',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2019-04-27 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Lagomorpha'},
#      {'rank': 'Family', 'name': 'Leporidae'},
#      {'rank': 'Genus', 'name': 'Lepus'},
#      {'rank': 'Species', 'name': 'Lepus townsendii'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Lagomorpha',
#      'Leporidae',
#      'Lepus',
#      'Lepus townsendii'],
#     'commonnames': [{'name': 'White-tailed Jack Rabbit',
#       'language': 'English'},
#      {'name': 'White-tailed Jackrabbit', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.614415',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Otis\\%20tarda'}]},
#   'itis_data': [{'tsn': '176419',
#     'nameWInd': 'Otis tarda',
#     'nameWOInd': 'Otis tarda',
#     'unit1': 'Otis',
#     'unit2': 'tarda',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '176418',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2006-11-28 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Otidiformes'},
#      {'rank': 'Family', 'name': 'Otididae'},
#      {'rank': 'Genus', 'name': 'Otis'},
#      {'rank': 'Species', 'name': 'Otis tarda'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Otidiformes',
#      'Otididae',
#      'Otis',
#      'Otis tarda'],
#     'commonnames': [{'name': 'Great Bustard', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:51.618613',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'Multi Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Arctostaphylos\\%20patula'},
#     {'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:23512%20AND%20(usage:accepted%20OR%20usage:valid)'}]},
#   'itis_data': [{'tsn': '23512',
#     'nameWInd': 'Arctostaphylos patula',
#     'nameWOInd': 'Arctostaphylos patula',
#     'unit1': 'Arctostaphylos',
#     'unit2': 'patula',
#     'usage': 'accepted',
#     'kingdom': 'Plantae',
#     'parentTSN': '23467',
#     'rank': 'Species',
#     'synonyms': ['23512:$Arctostaphylos acutifolia$Arctostaphylos patula$Arctostaphylos patula platyphy$Arctostaphylos acutifolia$Arctostaphylos parryana pineto$Arctostaphylos patula coalesce$'],
#     'synonymTSNs': ['23512:$23471$23513$23514$184524$184525$184526$'],
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2012-05-31 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
# ...
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Accipitriformes'},
#      {'rank': 'Family', 'name': 'Accipitridae'},
#      {'rank': 'Genus', 'name': 'Buteo'},
#      {'rank': 'Species', 'name': 'Buteo swainsoni'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Accipitriformes',
#      'Accipitridae',
#      'Buteo',
#      'Buteo swainsoni'],
#     'commonnames': [{'name': 'Aguililla de Swainson', 'language': 'Spanish'},
#      {'name': "Swainson's Hawk", 'language': 'English'},
#      {'name': 'Buse de Swainson', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:56.829986',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Spizella\\%20breweri'}]},
#   'itis_data': [{'tsn': '179440',
#     'nameWInd': 'Spizella breweri',
#     'nameWOInd': 'Spizella breweri',
#     'unit1': 'Spizella',
#     'unit2': 'breweri',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '179431',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2015-10-28 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Emberizidae'},
#      {'rank': 'Genus', 'name': 'Spizella'},
#      {'rank': 'Species', 'name': 'Spizella breweri'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Emberizidae',
#      'Spizella',
#      'Spizella breweri'],
#     'commonnames': [{'name': "Brewer's Sparrow", 'language': 'English'},
#      {'name': 'Gorrión de Brewer', 'language': 'Spanish'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:56.830271',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Castor\\%20canadensis'}]},
#   'itis_data': [{'tsn': '180212',
#     'nameWInd': 'Castor canadensis',
#     'nameWOInd': 'Castor canadensis',
#     'unit1': 'Castor',
#     'unit2': 'canadensis',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180211',
#     'rank': 'Species',
#     'synonyms': ['180212:$Castor caecator$Castor canadensis phaeus$Castor canadensis acadicus$Castor canadensis baileyi$Castor canadensis belugae$Castor canadensis caecator$Castor canadensis canadensis$Castor canadensis carolinensis$Castor canadensis concisor$Castor canadensis duchesnei$Castor canadensis frondator$Castor canadensis idoneus$Castor canadensis labradorensi$Castor canadensis leucodontus$Castor canadensis mexicanus$Castor canadensis michiganensi$Castor canadensis missouriensi$Castor canadensis pallidus$Castor canadensis repentinus$Castor canadensis rostralis$Castor canadensis sagittatus$Castor subauratus shastensis$Castor subauratus subauratus$Castor canadensis taylori$Castor canadensis texensis$'],
#     'synonymTSNs': ['180212:$900102$900103$900104$900105$900106$900107$900108$900109$900110$900111$900112$900113$900114$900115$900116$900117$900118$900119$900120$900121$900122$900123$900124$900125$900126$'],
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2013-02-25 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Rodentia'},
#      {'rank': 'Suborder', 'name': 'Castorimorpha'},
#      {'rank': 'Family', 'name': 'Castoridae'},
#      {'rank': 'Genus', 'name': 'Castor'},
#      {'rank': 'Species', 'name': 'Castor canadensis'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Rodentia',
#      'Castorimorpha',
#      'Castoridae',
#      'Castor',
#      'Castor canadensis'],
#     'commonnames': [{'name': 'castor', 'language': 'French'},
#      {'name': 'American Beaver', 'language': 'English'},
#      {'name': 'Castor Americano', 'language': 'Spanish'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:56.831280',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Dendroctonus\\%20ponderosae'}]},
#   'itis_data': [{'tsn': '114918',
#     'nameWInd': 'Dendroctonus ponderosae',
#     'nameWOInd': 'Dendroctonus ponderosae',
#     'unit1': 'Dendroctonus',
#     'unit2': 'ponderosae',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '114910',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2018-09-25 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Protostomia'},
#      {'rank': 'Superphylum', 'name': 'Ecdysozoa'},
#      {'rank': 'Phylum', 'name': 'Arthropoda'},
#      {'rank': 'Subphylum', 'name': 'Hexapoda'},
#      {'rank': 'Class', 'name': 'Insecta'},
#      {'rank': 'Subclass', 'name': 'Pterygota'},
#      {'rank': 'Infraclass', 'name': 'Neoptera'},
#      {'rank': 'Superorder', 'name': 'Holometabola'},
#      {'rank': 'Order', 'name': 'Coleoptera'},
#      {'rank': 'Suborder', 'name': 'Polyphaga'},
#      {'rank': 'Infraorder', 'name': 'Cucujiformia'},
#      {'rank': 'Superfamily', 'name': 'Curculionoidea'},
#      {'rank': 'Family', 'name': 'Curculionidae'},
#      {'rank': 'Subfamily', 'name': 'Scolytinae'},
#      {'rank': 'Genus', 'name': 'Dendroctonus'},
#      {'rank': 'Species', 'name': 'Dendroctonus ponderosae'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Protostomia',
#      'Ecdysozoa',
#      'Arthropoda',
#      'Hexapoda',
#      'Insecta',
#      'Pterygota',
#      'Neoptera',
#      'Holometabola',
#      'Coleoptera',
#      'Polyphaga',
#      'Cucujiformia',
#      'Curculionoidea',
#      'Curculionidae',
#      'Scolytinae',
#      'Dendroctonus',
#      'Dendroctonus ponderosae'],
#     'commonnames': [{'name': 'mountain pine beetle', 'language': 'English'},
#      {'name': 'dendroctone du pin ponderosa', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:57.095422',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Pterodroma\\%20sandwichensis'}]},
#   'itis_data': [{'tsn': '562561',
#     'nameWInd': 'Pterodroma sandwichensis',
#     'nameWOInd': 'Pterodroma sandwichensis',
#     'unit1': 'Pterodroma',
#     'unit2': 'sandwichensis',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '174566',
#     'rank': 'Species',
#     'synonyms': ['562561:$Pterodroma phaeopygia sandwich$'],
#     'synonymTSNs': ['562561:$202225$'],
#     'date_created': '1999-08-20 14:32:53',
#     'date_modified': '2011-09-22 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Procellariiformes'},
#      {'rank': 'Family', 'name': 'Procellariidae'},
#      {'rank': 'Genus', 'name': 'Pterodroma'},
#      {'rank': 'Species', 'name': 'Pterodroma sandwichensis'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Procellariiformes',
#      'Procellariidae',
#      'Pterodroma',
#      'Pterodroma sandwichensis'],
#     'commonnames': [{'name': 'Pétrel des Hawaï', 'language': 'French'},
#      {'name': 'Hawaiian Petrel', 'language': 'English'},
#      {'name': 'Hawaiian Dark-rumped Petrel', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:57.095772',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Branta\\%20leucopsis'}]},
#   'itis_data': [{'tsn': '175014',
#     'nameWInd': 'Branta leucopsis',
#     'nameWOInd': 'Branta leucopsis',
#     'unit1': 'Branta',
#     'unit2': 'leucopsis',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '174998',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2007-01-23 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Anseriformes'},
#      {'rank': 'Family', 'name': 'Anatidae'},
#      {'rank': 'Subfamily', 'name': 'Anserinae'},
#      {'rank': 'Genus', 'name': 'Branta'},
#      {'rank': 'Species', 'name': 'Branta leucopsis'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Anseriformes',
#      'Anatidae',
#      'Anserinae',
#      'Branta',
#      'Branta leucopsis'],
#     'commonnames': [{'name': 'Barnacle Goose', 'language': 'English'},
#      {'name': 'bernache nonnette', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:57.096042',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Taxidea\\%20taxus'}]},
#   'itis_data': [{'tsn': '180565',
#     'nameWInd': 'Taxidea taxus',
#     'nameWOInd': 'Taxidea taxus',
#     'unit1': 'Taxidea',
#     'unit2': 'taxus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180564',
#     'rank': 'Species',
#     'synonyms': ['180565:$Ursus taxus$'],
#     'synonymTSNs': ['180565:$1086127$'],
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2018-11-27 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Carnivora'},
#      {'rank': 'Suborder', 'name': 'Caniformia'},
#      {'rank': 'Family', 'name': 'Mustelidae'},
#      {'rank': 'Subfamily', 'name': 'Taxidiinae'},
#      {'rank': 'Genus', 'name': 'Taxidea'},
#      {'rank': 'Species', 'name': 'Taxidea taxus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Carnivora',
#      'Caniformia',
#      'Mustelidae',
#      'Taxidiinae',
#      'Taxidea',
#      'Taxidea taxus'],
#     'commonnames': [{'name': 'American Badger', 'language': 'English'},
#      {'name': 'badger', 'language': 'English'},
#      {'name': 'Tlalcoyote', 'language': 'Spanish'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:57.096658',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Odocoileus\\%20hemionus'}]},
#   'itis_data': [{'tsn': '180698',
#     'nameWInd': 'Odocoileus hemionus',
#     'nameWOInd': 'Odocoileus hemionus',
#     'unit1': 'Odocoileus',
#     'unit2': 'hemionus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '180697',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2012-12-21 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Artiodactyla'},
#      {'rank': 'Family', 'name': 'Cervidae'},
#      {'rank': 'Subfamily', 'name': 'Capreolinae'},
#      {'rank': 'Genus', 'name': 'Odocoileus'},
#      {'rank': 'Species', 'name': 'Odocoileus hemionus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Artiodactyla',
#      'Cervidae',
#      'Capreolinae',
#      'Odocoileus',
#      'Odocoileus hemionus'],
#     'commonnames': [{'name': 'mule deer', 'language': 'English'},
#      {'name': 'Venado bura', 'language': 'Spanish'},
#      {'name': 'Mule Deer', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-15T15:34:57.102011',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Passer\\%20domesticus'}]},
#   'itis_data': [{'tsn': '179628',
#     'nameWInd': 'Passer domesticus',
#     'nameWOInd': 'Passer domesticus',
#     'unit1': 'Passer',
#     'unit2': 'domesticus',
#     'usage': 'valid',
#     'kingdom': 'Animalia',
#     'parentTSN': '179627',
#     'rank': 'Species',
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2013-11-04 00:00:00',
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Passeridae'},
#      {'rank': 'Genus', 'name': 'Passer'},
#      {'rank': 'Species', 'name': 'Passer domesticus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Passeridae',
#      'Passer',
#      'Passer domesticus'],
#     'commonnames': [{'name': 'Gorrión casero', 'language': 'Spanish'},
#      {'name': 'House Sparrow', 'language': 'English'},
#      {'name': 'moineau domestique', 'language': 'French'}]}]}]

# %%
#Filter the ITIS cache to only list the ITIS TSN records
itis_tsn = []
for record in itis_cache:
    for item in record['itis_data']:
        itis_tsn.append(item["tsn"])

# %%
itis_tsn
# Out:
# ['997723',
#  '35454',
#  '180706',
#  '180575',
#  '926246',
#  '926145',
#  '24806',
#  '20531',
#  '175134',
#  '180711',
#  '180017',
#  '176176',
#  '20512',
#  '997724',
#  '179402',
#  '175838',
#  '41223',
#  '677540',
#  '175603',
#  '175622',
#  '180596',
#  '180701',
#  '175407',
#  '22843',
#  '180118',
#  '176419',
#  '23512',
#  '503283',
#  '163909',
#  '625114',
#  '180703',
#  '183343',
#  '167237',
#  '178515',
#  '528646',
#  '173856',
#  '25134',
#  '551209',
#  '180016',
#  '41062',
#  '179725',
#  '183623',
#  '20518',
#  '174474',
#  '180599',
#  '161979',
#  '950052',
#  '503283',
#  '822851',
#  '503290',
#  '40913',
#  '40816',
#  '175855',
#  '175170',
#  '180305',
#  '171677',
#  '114919',
#  '202223',
#  '183311',
#  '554256',
#  '502264',
#  '20707',
#  '182660',
#  '174712',
#  '180001',
#  '40524',
#  '23601',
#  '960160',
#  '968200',
#  '625063',
#  '174479',
#  '175130',
#  '183291',
#  '183327',
#  '21920',
#  '25290',
#  '632855',
#  '174999',
#  '180276',
#  '180195',
#  '785041',
#  '179333',
#  '175420',
#  '503433',
#  '180604',
#  '784287',
#  '180607',
#  '180170',
#  '35498',
#  '20662',
#  '175147',
#  '194820',
#  '552706',
#  '19479',
#  '178654',
#  '930310',
#  '20692',
#  '560894',
#  '677538',
#  '553891',
#  '175165',
#  '175167',
#  '573027',
#  '180695',
#  '180000',
#  '183741',
#  '162035',
#  '161983',
#  '507785',
#  '183424',
#  '175377',
#  '175350',
#  '175274',
#  '162002',
#  '42269',
#  '180543',
#  '27779',
#  '176891',
#  '174469',
#  '714807',
#  '154396',
#  '504637',
#  '175430',
#  '167123',
#  '161975',
#  '175185',
#  '175863',
#  '930314',
#  '161980',
#  '180717',
#  '161989',
#  '202344',
#  '552521',
#  '174685',
#  '939675',
#  '192053',
#  '997873',
#  '507974',
#  '180166',
#  '179167',
#  '507943',
#  '25371',
#  '176177',
#  '180544',
#  '825373',
#  '825422',
#  '25136',
#  '507594',
#  '173840',
#  '625079',
#  '898935',
#  '551209',
#  '646471',
#  '25109',
#  '552497',
#  '930308',
#  '195773',
#  '180343',
#  '181830',
#  '502267',
#  '553429',
#  '175367',
#  '179440',
#  '180212',
#  '114918',
#  '562561',
#  '175014',
#  '180565',
#  '180698',
#  '179628']

# %%
# Set function for accessing the ITIS database using ITIS TSN numbers
def itis_api(itis_tsn):
    base_url = 'http://www.itis.gov/ITISWebService/jsonservice/ITISService/getGeographicDivisionsFromTSN'
    param = '?tsn=' + str(itis_tsn)
    get = (base_url + str(param))
    #logging.debug('This is a log message.'+str(get))
    try:
        r=requests.get(get)
        if r.status_code == 200 and 'success' in r.json():
            json_r = r.json()
            data = json_r['success']['data']
            return data
        elif r.status_code == 200:
            data = []
            return data
        else:
            raise Exception('itis API returning: {0}'.format(r.status_code))
    except Exception as e:
        raise Exception(e)

# %%
#Create list with data and call the ITIS API
itis_data_list= []
for item in itis_tsn:
    itis_data_list.append(itis_api(item))
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
display(itis_data_list)
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# In some cases more than one ITIS record was returned from the function. In every case, the “processing_metadata” structure indicates that the scientific species names used at the point of discovery were accepted. However, the "itis_data" structure indicates that potentially invalid names were provided from the WLCI literature database or xDD source information yet have a valid record in ITIS. The following code block lets us examine what is going on in these cases.
#
# The “processing_metadata” structure provides information about what the function does. It includes the URLs to the ITIS API that resulted in some action. Both the valid/accepted and invalid/unaccepted names from ITIS are recorded. We reach back to the itis_cahce to show that record.

# %%
#Select ITIS records with more than one record 
validate =[i for i in itis_cache if "itis_data" in i.keys() and len(i["itis_data"]) > 1]

# %%
validate

# %% [markdown]
# This list indicates a few things:
# 1. There is one case where a source name was misspelled, Equus burchelli should have been Equus quagga burchellii. In this case, the search used the TSN of the misspelled species name to correctly identify the species. ITIS considers the record containing the misspelled name to be invalid and the other record valid, even though they are for the same name.
# 2. In three cases, the names provided were considered invalid or not accepted because ITIS considered the names to be synonyms or junior synonyms of the correct species names.
# 3. In one case, ITIS considered the name provided to be invalid because it was an  “original name/combination”.
# 4. In one case, ITIS considered the name provided to be invalid because it was a “subsequent name/combination”.
#
# In the case of any disagreement between WLCI scientists and the taxonomic authority, both the invalid/not accepted and valid/accepted ITIS names from the WLCI species names list will be used for further consultations with additional systems. Two seperate lists, invalid_itis and valid_itis, will be used to distinguish the invalid/not accepted and valid/accepted ITIS names in these consultations. Any information that results from consultations using the invalid_itis list will be cached separately and evaluated for their utility.

# %%
#Create list containing sciencitific names and ITIS usage classifications
itis_explore = list()
for itis_doc_set in itis_cache:
    for itis_doc in itis_doc_set["itis_data"]:
        itis_explore.append({"scientific_name": itis_doc["nameWInd"],"itis_usage": itis_doc["usage"]})

# %%
#Display the ITIS list of species names and ITIS usage (valid/invalid and accepted/not accepted)
itis_explore

# %%
#Create list of specie names considered invalid or not accepted by ITIS
invalid_itis=[i for i in itis_explore if i['itis_usage'] == 'invalid']
invalid_itis.extend([i for i in itis_explore if i['itis_usage'] == 'not accepted'])

# %%
#Display list of specie names considered invalid or not accepted by ITIS
invalid_itis

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("cache/invalid_itis.json", invalid_itis))

# %%
#Create an updated list of species names considered valid or accepted by ITIS
updated_itis=[e for e in itis_explore if e['scientific_name'] not in {'Amphispiza belli','Thrichomys fosteri','Tetrao tetrix','Brucella abortus','Equus burchelli','Bassia prostrata'}]
len(updated_itis)

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("cache/valid_itis.json", updated_itis))
