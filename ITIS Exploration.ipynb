# %% [markdown]
# This notebook explores the records retrieved from the consultation between the WLCI scientific species name list and the ITIS API. The cached ITIS results are examined and next steps are determined.

# %%
#Import needed packages
import json
import bispy
import requests
from IPython.display import display
from joblib import Parallel, delayed

bis_utils = bispy.bis.Utils()

# %%
#Open cache ITIS list created from WLCI Species List from Literature.ipynb
with open("cache/itis.json", "r") as f:
    itis_cache = json.loads(f.read())

# %%
#Print ITIS list 
itis_cache
# Out:
# [{'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.784573',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Setophaga\\%20discolor'}]},
#   'parameters': {'Scientific Name': 'Setophaga discolor'},
#   'itis_data': [{'tsn': '950052',
#     'nameWInd': 'Setophaga discolor',
#     'nameWOInd': 'Setophaga discolor',
#     'unit1': 'Setophaga',
#     'unit2': 'discolor',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Vieillot, 1809)',
#     'kingdom': 'Animalia',
#     'parentTSN': '178978',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['950052:$Dendroica discolor$'],
#     'synonymTSNs': ['950052:$178918$'],
#     '_version_': 1641159186509201413,
#     'date_created': '2014-09-17 11:43:16',
#     'date_modified': '2014-09-17 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '2014-09-17 00:00:00'},
#      {'geographic_value': 'Caribbean', 'update_date': '2014-09-17 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Canada',
#       'origin': 'Native',
#       'update_date': '2014-09-17 00:00:00'},
#      {'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2014-09-17 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '1078',
#       'source_type': 'website',
#       'source_name': 'IOC World Bird List (v 4.3)',
#       'version': '4.3',
#       'acquisition_date': '2014-09-11 00:00:00',
#       'source_comment': 'Gill, F., and D. Donsker, eds. 2014. IOC World Bird List (v 4.3). Available at http://www.worldbirdnames.org [Accessed 11 September, 2014]',
#       'create_date': '2014-09-17 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '1079',
#       'source_type': 'website',
#       'source_name': 'AOU Check-List (09-2014)',
#       'version': 'Sep-2014',
#       'acquisition_date': '2014-09-15 00:00:00',
#       'source_comment': 'American Ornithologists\' Union\'s "AOU Checklist of North and Middle American Birds" (AOU Check-list, 7th edition, updated through the 54th supplement), maintained at http://checklist.aou.org/',
#       'create_date': '2014-09-17 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Parulidae'},
#      {'rank': 'Genus', 'name': 'Setophaga'},
#      {'rank': 'Species', 'name': 'Setophaga discolor'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Parulidae',
#      'Setophaga',
#      'Setophaga discolor'],
#     'commonnames': [{'name': 'Prairie Warbler', 'language': 'English'},
#      {'name': 'Paruline des prés', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.865490',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'Multi Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Pascopyrum\\%20smithii'},
#     {'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:784287%20AND%20(usage:accepted%20OR%20usage:valid)'}]},
#   'parameters': {'Scientific Name': 'Pascopyrum smithii'},
#   'itis_data': [{'tsn': '784287',
#     'nameWInd': 'Pascopyrum smithii',
#     'nameWOInd': 'Pascopyrum smithii',
#     'unit1': 'Pascopyrum',
#     'unit2': 'smithii',
#     'usage': 'accepted',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Rydb.) Barkworth & D.R. Dewey',
#     'kingdom': 'Plantae',
#     'parentTSN': '500464',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['784287:$Agropyron smithii$Pascopyrum smithii$Agropyron molle$Elymus smithii$Elytrigia smithii$Agropyron smithii molle$Agropyron smithii palmeri$Elytrigia smithii mollis$Agropyron occidentale$Agropyron palmeri$Elytrigia smithii$Zeia mollis$Zeia occidentalis$Zeia smithii$Agropyron glaucum occidentale$Agropyron occidentale molle$Agropyron occidentale occident$Agropyron occidentale palmeri$Agropyron smithii smithii$Agropyron smithii typica$Agropyron spicatum molle$Agropyron spicatum palmeri$Agropyron spicatum viride$Elytrigia smithii molle$Agropyron smithii molle$'],
#     'synonymTSNs': ['784287:$40385$504124$508461$512844$512859$532028$532029$534893$785326$785327$789559$796563$796564$796569$798708$798720$798721$798722$798754$798755$798756$798757$798761$800399$803201$'],
#     '_version_': 1641159162255638535,
#     'date_created': '2010-11-30 18:39:33',
#     'date_modified': '2010-11-30 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '2010-12-01 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '483',
#       'source_type': 'database',
#       'source_name': 'Catalogue of New World Grasses (Poaceae) - 11/2009',
#       'version': '24/11/2009',
#       'acquisition_date': '2009-11-24 00:00:00',
#       'source_comment': 'Maintained by R. J. Soreng et al., at http://www.tropicos.org/Project/CNWG and formerly at http://mobot.mobot.org/W3T/Search/nwgc.html',
#       'create_date': '2010-12-01 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '485',
#       'source_type': 'database',
#       'source_name': 'Poaceae update',
#       'version': 'Sept. 2010',
#       'acquisition_date': '2010-09-01 00:00:00',
#       'source_comment': 'Poaceae update for ITIS, in cooperation with NatureServe, and based on the Catalogue of New World Grasses database and other sources',
#       'create_date': '2010-12-01 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Lilianae'},
#      {'rank': 'Order', 'name': 'Poales'},
#      {'rank': 'Family', 'name': 'Poaceae'},
#      {'rank': 'Genus', 'name': 'Pascopyrum'},
#      {'rank': 'Species', 'name': 'Pascopyrum smithii'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Lilianae',
#      'Poales',
#      'Poaceae',
#      'Pascopyrum',
#      'Pascopyrum smithii']}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.879340',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Lasiurus\\%20cinereus\\%20semotus'}]},
#   'parameters': {'Scientific Name': 'Lasiurus cinereus semotus'},
#   'itis_data': [{'tsn': '202344',
#     'nameWInd': 'Lasiurus cinereus semotus',
#     'nameWOInd': 'Lasiurus cinereus semotus',
#     'unit1': 'Lasiurus',
#     'unit2': 'cinereus',
#     'unit3': 'semotus',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(H. Allen, 1890)',
#     'kingdom': 'Animalia',
#     'parentTSN': '180017',
#     'rankID': '230',
#     'rank': 'Subspecies',
#     'synonyms': ['202344:$Atalapha semota$'],
#     'synonymTSNs': ['202344:$946824$'],
#     '_version_': 1641159122419187716,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2014-08-27 00:00:00',
#     'geographicDivision': [{'geographic_value': 'Oceania',
#       'update_date': '2004-06-08 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Hawaii',
#       'origin': 'Native',
#       'update_date': '2004-06-08 00:00:00'}],
#     'expert': [{'reference_type': 'EXP',
#       'expert_id': '55',
#       'expert_name': 'Don E. Wilson',
#       'expert_comment': 'Smithsonian Institution, MRC 108 Washington DC 20560-0108',
#       'create_date': '2002-08-06 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'EXP',
#       'expert_id': '103',
#       'expert_name': 'Alfred L. Gardner',
#       'expert_comment': 'Curator of North American mammals and Chief of Mammal Section, National Biological Service, Smithsonian Institution, National Museum of Natural History, Washington, DC, USA',
#       'create_date': '2003-10-28 00:00:00',
#       'update_date': ''}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '1191',
#       'author': 'Hall, E. Raymond',
#       'title': 'The Mammals of North America, vols. I and II, 2nd ed.',
#       'other_variable_0': '1981-04-03 00:00:00',
#       'other_variable_1': '1981-04-03 00:00:00',
#       'other_variable_2': 'John Wiley and Sons, Inc.',
#       'other_variable_3': 'New York, New York, USA',
#       'other_variable_6': '1181',
#       'other_variable_8': 'N',
#       'other_variable_9': '2019-04-27 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1419',
#       'author': 'Wilson, Don E., and F. Russell Cole',
#       'title': 'Common Names of Mammals of the World',
#       'other_variable_0': '2000-01-01 00:00:00',
#       'other_variable_1': '2000-01-01 00:00:00',
#       'other_variable_2': 'Smithsonian Institution Press',
#       'other_variable_3': 'Washington, DC, USA',
#       'other_variable_4': '1-56098-383-3',
#       'other_variable_6': 'xiv + 204',
#       'other_variable_7': 'With contributions by Bernadette N. Graham, Adam P. Potter, and Mariana M. Upmeyer',
#       'other_variable_8': 'N',
#       'other_variable_9': '2019-04-27 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1422',
#       'author': 'Wilson, Don E., and DeeAnn M. Reeder, eds.',
#       'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 2nd ed., 3rd printing',
#       'other_variable_0': '1992-01-01 00:00:00',
#       'other_variable_1': '1993-01-01 00:00:00',
#       'other_variable_2': 'Smithsonian Institution Press',
#       'other_variable_3': 'Washington, DC, USA',
#       'other_variable_4': '1-56098-217-9',
#       'other_variable_6': 'xviii + 1207',
#       'other_variable_7': 'Corrections were made to text at 3rd printing',
#       'other_variable_8': 'N',
#       'other_variable_9': '2019-04-27 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '7504',
#       'author': 'U. S. Fish and Wildlife Service',
#       'title': 'Federal Register, vol. 39, no. 3',
#       'other_variable_0': '1974-01-04 00:00:00',
#       'other_variable_1': '1974-01-04 00:00:00',
#       'other_variable_6': '1158-1185',
#       'other_variable_8': 'N',
#       'other_variable_9': '2013-12-23 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '11204',
#       'author': 'Simmons, Nancy B. / Wilson, Don E., and DeeAnn M. Reeder, eds.',
#       'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 3rd ed., vols. 1 & 2',
#       'other_variable_0': '2005-10-01 00:00:00',
#       'other_variable_1': '2005-10-01 00:00:00',
#       'other_variable_2': 'Johns Hopkins University Press',
#       'other_variable_3': 'Baltimore, Maryland, USA',
#       'other_variable_4': '0-8018-8221-4',
#       'other_variable_6': '312-529',
#       'other_variable_7': 'Corrections were made to text at 3rd printing',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-11-30 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '61',
#       'source_type': 'database',
#       'source_name': 'U. S. Dept. Interior',
#       'version': '1',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2009-09-01 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '225',
#       'source_type': 'website',
#       'source_name': 'U. S. Fish and Wildlife Service Endangered Species Program-05/01',
#       'version': 'undefined',
#       'acquisition_date': '2001-05-01 00:00:00',
#       'source_comment': 'http://www.fws.gov/endangered/',
#       'create_date': '2012-11-21 00:00:00',
#       'update_date': ''}],
#     'comment': [{'comment_id': '25146',
#       'commentator': 'David F. Mitchell, ITIS Data Development Specialist',
#       'comment_text': 'US ESA: Listed Endangered, included in the U.S. List of Endangered Native Fish and Wildlife, as published in Federal Register Volume 39, Number 3, Pages 1158 - 1185, January 04, 1974',
#       'create_date': '2012-12-21 08:37:17',
#       'update_date': '2012-12-21 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Chiroptera'},
#      {'rank': 'Suborder', 'name': 'Yangochiroptera'},
#      {'rank': 'Superfamily', 'name': 'Vespertilionoidea'},
#      {'rank': 'Family', 'name': 'Vespertilionidae'},
#      {'rank': 'Subfamily', 'name': 'Vespertilioninae'},
#      {'rank': 'Tribe', 'name': 'Lasiurini'},
#      {'rank': 'Genus', 'name': 'Lasiurus'},
#      {'rank': 'Subgenus', 'name': 'Lasiurus (Lasiurus)'},
#      {'rank': 'Species', 'name': 'Lasiurus cinereus'},
#      {'rank': 'Subspecies', 'name': 'Lasiurus cinereus semotus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Chiroptera',
#      'Yangochiroptera',
#      'Vespertilionoidea',
#      'Vespertilionidae',
#      'Vespertilioninae',
#      'Lasiurini',
#      'Lasiurus',
#      'Lasiurus (Lasiurus)',
#      'Lasiurus cinereus',
#      'Lasiurus cinereus semotus'],
#     'commonnames': [{'name': 'Hawaiian hoary bat', 'language': 'English'},
#      {'name': 'Hawaiian Hoary bat', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.881356',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Pseudoroegneria\\%20spicata'}]},
#   'parameters': {'Scientific Name': 'Pseudoroegneria spicata'},
#   'itis_data': [{'tsn': '504637',
#     'nameWInd': 'Pseudoroegneria spicata',
#     'nameWOInd': 'Pseudoroegneria spicata',
#     'unit1': 'Pseudoroegneria',
#     'unit2': 'spicata',
#     'usage': 'accepted',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Pursh) Á. Löve',
#     'kingdom': 'Plantae',
#     'parentTSN': '500516',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['504637:$Agropyron spicatum$Elymus spicatus$Elytrigia spicata$Roegneria spicata$Agropyron divergens$Agropyron divergens$Festuca spicata$Schedonorus spicatus$Triticum divergens$Zeia spicata$Agropyron divergens tenue$Agropyron divergens tenuispicu$'],
#     'synonymTSNs': ['504637:$40386$512845$512860$520188$785305$785306$790130$794842$796212$796570$798701$798702$'],
#     '_version_': 1641159123939622914,
#     'date_created': '1996-11-04 17:57:08',
#     'date_modified': '2010-11-30 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '1996-11-05 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2000-03-15 00:00:00'},
#      {'jurisdiction_value': 'Alaska',
#       'origin': 'Native',
#       'update_date': '2000-03-15 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '168',
#       'source_type': 'database',
#       'source_name': 'The PLANTS Database',
#       'version': '4.0.4',
#       'acquisition_date': '1996-07-26 00:00:00',
#       'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#       'create_date': '2004-02-23 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '169',
#       'source_type': 'database',
#       'source_name': 'The PLANTS Database',
#       'version': '5.1.1',
#       'acquisition_date': '2000-01-21 00:00:00',
#       'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#       'create_date': '2004-02-23 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '483',
#       'source_type': 'database',
#       'source_name': 'Catalogue of New World Grasses (Poaceae) - 11/2009',
#       'version': '24/11/2009',
#       'acquisition_date': '2009-11-24 00:00:00',
#       'source_comment': 'Maintained by R. J. Soreng et al., at http://www.tropicos.org/Project/CNWG and formerly at http://mobot.mobot.org/W3T/Search/nwgc.html',
#       'create_date': '2010-12-01 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '485',
#       'source_type': 'database',
#       'source_name': 'Poaceae update',
#       'version': 'Sept. 2010',
#       'acquisition_date': '2010-09-01 00:00:00',
#       'source_comment': 'Poaceae update for ITIS, in cooperation with NatureServe, and based on the Catalogue of New World Grasses database and other sources',
#       'create_date': '2010-12-01 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Lilianae'},
#      {'rank': 'Order', 'name': 'Poales'},
#      {'rank': 'Family', 'name': 'Poaceae'},
#      {'rank': 'Genus', 'name': 'Pseudoroegneria'},
#      {'rank': 'Species', 'name': 'Pseudoroegneria spicata'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Lilianae',
#      'Poales',
#      'Poaceae',
#      'Pseudoroegneria',
#      'Pseudoroegneria spicata'],
#     'commonnames': [{'name': 'bluebunch-wheat grass',
#       'language': 'unspecified'},
#      {'name': 'bluebunch wheatgrass', 'language': 'unspecified'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.910915',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Cronartium\\%20ribicola'}]},
#   'parameters': {'Scientific Name': 'Cronartium ribicola'},
#   'itis_data': [{'tsn': '192053',
#     'nameWInd': 'Cronartium ribicola',
#     'nameWOInd': 'Cronartium ribicola',
#     'unit1': 'Cronartium',
#     'unit2': 'ribicola',
#     'usage': 'accepted',
#     'credibilityRating': 'No review; untreated NODC data',
#     'taxonAuthor': 'A. Dietr.',
#     'kingdom': 'Fungi',
#     'parentTSN': '192052',
#     'rankID': '220',
#     'rank': 'Species',
#     '_version_': 1641159119211593735,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2001-02-27 00:00:00',
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Fungi'},
#      {'rank': 'Subkingdom', 'name': 'Dikarya'},
#      {'rank': 'Division', 'name': 'Basidiomycota'},
#      {'rank': 'Subdivision', 'name': 'Pucciniomycotina'},
#      {'rank': 'Class', 'name': 'Pucciniomycetes'},
#      {'rank': 'Order', 'name': 'Pucciniales'},
#      {'rank': 'Family', 'name': 'Cronartiaceae'},
#      {'rank': 'Genus', 'name': 'Cronartium'},
#      {'rank': 'Species', 'name': 'Cronartium ribicola'}],
#     'hierarchy': ['Fungi',
#      'Dikarya',
#      'Basidiomycota',
#      'Pucciniomycotina',
#      'Pucciniomycetes',
#      'Pucciniales',
#      'Cronartiaceae',
#      'Cronartium',
#      'Cronartium ribicola'],
#     'commonnames': [{'name': 'white-pine blister rust',
#       'language': 'unspecified'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.914568',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Lepidochelys\\%20olivacea'}]},
#   'parameters': {'Scientific Name': 'Lepidochelys olivacea'},
#   'itis_data': [{'tsn': '173840',
#     'nameWInd': 'Lepidochelys olivacea',
#     'nameWOInd': 'Lepidochelys olivacea',
#     'unit1': 'Lepidochelys',
#     'unit2': 'olivacea',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Eschscholtz, 1829)',
#     'kingdom': 'Animalia',
#     'parentTSN': '173838',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['173840:$Chelonia olivacea$Lepidochelys olivacea remivaga$Caretta remivaga$Chelonia multiscutata$Chelonia dussumierii$Cephalochelys oceanica$Thalassiochelys tarapacona$Thalassochelys controversa$'],
#     'synonymTSNs': ['173840:$208668$208669$208670$949193$949194$949195$949196$949197$'],
#     '_version_': 1641159116825034755,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2014-08-27 00:00:00',
#     'geographicDivision': [{'geographic_value': 'Middle America',
#       'update_date': '2001-06-11 00:00:00'},
#      {'geographic_value': 'North America',
#       'update_date': '1997-10-27 00:00:00'},
#      {'geographic_value': 'Oceania', 'update_date': '1997-10-27 00:00:00'},
#      {'geographic_value': 'Africa', 'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'Australia', 'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'Caribbean', 'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'East Pacific',
#       'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'Eastern Atlantic Ocean',
#       'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'Indo-West Pacific',
#       'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'South America',
#       'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'Southern Asia',
#       'update_date': '2005-05-09 00:00:00'},
#      {'geographic_value': 'Western Atlantic Ocean',
#       'update_date': '2005-05-09 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2005-05-09 00:00:00'},
#      {'jurisdiction_value': 'Hawaii',
#       'origin': 'Native',
#       'update_date': '2005-05-09 00:00:00'},
#      {'jurisdiction_value': 'Mexico',
#       'origin': 'Native',
#       'update_date': '2005-05-09 00:00:00'}],
#     'expert': [{'reference_type': 'EXP',
#       'expert_id': '24',
#       'expert_name': 'Roy W. McDiarmid',
#       'expert_comment': 'U.S. Geological Survey, Biological Resources Division, Patuxent Wildlife Research Center',
#       'create_date': '2004-08-16 00:00:00',
#       'update_date': ''}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '103',
#       'author': 'Iverson, John B.',
#       'title': 'A Revised Checklist with Distribution Maps of the Turtles of the World',
#       'other_variable_0': '1992-01-01 00:00:00',
#       'other_variable_1': '1992-01-01 00:00:00',
#       'other_variable_2': 'Privately Printed',
#       'other_variable_3': 'Richmond, Indiana',
#       'other_variable_4': '0-9617431-0-5',
#       'other_variable_6': 'xiii + 363',
#       'other_variable_8': 'N',
#       'other_variable_9': '2016-11-23 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '104',
#       'author': 'Wermuth, H. and R. Mertens',
#       'title': 'Schildkroten, Krokodile Bruckenechsen',
#       'other_variable_0': '1961-01-01 00:00:00',
#       'other_variable_1': '1961-01-01 00:00:00',
#       'other_variable_2': 'VEB Gustav Fischer Verlag, Jena',
#       'other_variable_3': 'Germany',
#       'other_variable_8': 'N',
#       'other_variable_9': '2014-08-27 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '706',
#       'author': 'Banks, R. C., R. W. McDiarmid, and A. L. Gardner',
#       'title': 'Resource Publication, no. 166',
#       'other_variable_0': '1987-01-01 00:00:00',
#       'other_variable_1': '1987-01-01 00:00:00',
#       'other_variable_2': 'United States Department of the Interior Fish and Wildlife Service',
#       'other_variable_3': 'Washington, D.C., USA',
#       'other_variable_6': '79',
#       'other_variable_8': 'N',
#       'other_variable_9': '2019-04-27 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1306',
#       'author': 'Flores-Villela, Oscar / McCoy, C. J., ed.',
#       'title': 'Carnegie Museum of Natural History Special Publication, no. 17',
#       'other_variable_0': '1993-01-29 00:00:00',
#       'other_variable_1': '1993-01-29 00:00:00',
#       'other_variable_2': 'Carnegie Museum of Natural History',
#       'other_variable_3': 'Pittsburgh, Pennsylvania, USA',
#       'other_variable_4': '0-911239-42-1',
#       'other_variable_6': 'iv + 73',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '2899',
#       'author': 'Banks, R. C., R. W. McDiarmid, A. L. Gardner, and W. C. Starnes',
#       'title': 'Checklist of Vertebrates of the United States, the U.S. Territories, and Canada, draft (2004)',
#       'other_variable_0': '2004-12-31 00:00:00',
#       'other_variable_1': '2004-12-31 00:00:00',
#       'other_variable_7': 'As-yet (2004) unpublished manuscript from 1998',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-10-26 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '3096',
#       'author': 'Collins, J. T.',
#       'title': 'Standard Common and Current Scientific Names for North American Amphibians and Reptiles, Third Edition',
#       'other_variable_0': '1990-07-01 00:00:00',
#       'other_variable_1': '1990-07-01 00:00:00',
#       'other_variable_2': 'Society for the Study of Amphibians and Reptiles',
#       'other_variable_3': 'St. Louis, Missouri, USA',
#       'other_variable_4': '0-916984-21-4',
#       'other_variable_6': 'ii + 41',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '10925',
#       'author': 'Crother, Brian I., Jeff Boundy, Frank T. Burbrink, Jonathan A. Campbell, Kevin de Queiroz, et al.',
#       'title': 'Herpetological Circular, no. 39',
#       'other_variable_0': '2012-08-01 00:00:00',
#       'other_variable_1': '2012-08-01 00:00:00',
#       'other_variable_2': 'Society for the Study of Amphibians and Reptiles',
#       'other_variable_3': 'Shoreview, Minnesota, USA',
#       'other_variable_4': '9780916984854',
#       'other_variable_6': '1-92',
#       'other_variable_7': 'Available free as a PDF at http://ssarherps.org/pages/HerpCommNames.php',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-09-25 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '11628',
#       'author': 'Turtle Taxonomy Working Group [van Dijk, P. P., J. Iverson, A. Rhodin, H. Shaffer, and R. Bour]',
#       'title': 'Chelonian Research Monographs, no. 5, v. 7',
#       'other_variable_0': '2014-06-16 00:00:00',
#       'other_variable_1': '2014-06-16 00:00:00',
#       'other_variable_5': '1088-7105',
#       'other_variable_6': '329-479',
#       'other_variable_7': 'doi:10.3854/crm.5.000.checklist.v7.2014 - Available online at http://www.iucn-tftsg.org/cbftt/',
#       'other_variable_8': 'N',
#       'other_variable_9': '2016-11-23 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '61',
#       'source_type': 'database',
#       'source_name': 'U. S. Dept. Interior',
#       'version': '1',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2009-09-01 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '126',
#       'source_type': 'database',
#       'source_name': 'Comisión Nacional para el Conocimiento y Uso de la Biodiversidad',
#       'version': 'undefined',
#       'acquisition_date': '2000-10-07 00:00:00',
#       'source_comment': 'CONABIO: (http://www.conabio.gob.mx/)',
#       'create_date': '2005-05-09 00:00:00',
#       'update_date': ''}],
#     'comment': [{'comment_id': '13348',
#       'commentator': 'Herrick Brown - ITIS Data Development Technician',
#       'comment_text': 'Banks et al. (2003) note: Threatened throughout range',
#       'create_date': '2005-05-09 11:51:32',
#       'update_date': '2014-08-27 00:00:00'},
#      {'comment_id': '29955',
#       'commentator': 'T. R. Kahn ITIS Data Developer',
#       'comment_text': 'IUCN: Vulnerable A2bd (2008). CITES: Appendix I, as Cheloniidae spp.',
#       'create_date': '2014-08-27 23:20:54',
#       'update_date': '2014-08-27 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Reptilia'},
#      {'rank': 'Order', 'name': 'Testudines'},
#      {'rank': 'Suborder', 'name': 'Cryptodira'},
#      {'rank': 'Superfamily', 'name': 'Chelonioidea'},
#      {'rank': 'Family', 'name': 'Cheloniidae'},
#      {'rank': 'Subfamily', 'name': 'Carettinae'},
#      {'rank': 'Genus', 'name': 'Lepidochelys'},
#      {'rank': 'Species', 'name': 'Lepidochelys olivacea'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Reptilia',
#      'Testudines',
#      'Cryptodira',
#      'Chelonioidea',
#      'Cheloniidae',
#      'Carettinae',
#      'Lepidochelys',
#      'Lepidochelys olivacea'],
#     'commonnames': [{'name': 'Pacific ridley', 'language': 'English'},
#      {'name': 'Olive Ridley', 'language': 'English'},
#      {'name': 'Tortuga-marina escamosa-del Pacífico', 'language': 'Spanish'},
#      {'name': 'Olive Ridley Sea Turtle', 'language': 'English'},
#      {'name': 'Pacific Ridley Sea Turtle', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.948631',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Pterodroma\\%20sandwichensis'}]},
#   'parameters': {'Scientific Name': 'Pterodroma sandwichensis'},
#   'itis_data': [{'tsn': '562561',
#     'nameWInd': 'Pterodroma sandwichensis',
#     'nameWOInd': 'Pterodroma sandwichensis',
#     'unit1': 'Pterodroma',
#     'unit2': 'sandwichensis',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Ridgway, 1884)',
#     'kingdom': 'Animalia',
#     'parentTSN': '174566',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['562561:$Pterodroma phaeopygia sandwich$'],
#     'synonymTSNs': ['562561:$202225$'],
#     '_version_': 1641159131770388481,
#     'date_created': '1999-08-20 14:32:53',
#     'date_modified': '2011-09-22 00:00:00',
#     'expert': [{'reference_type': 'EXP',
#       'expert_id': '11',
#       'expert_name': 'Alan P. Peterson, M.D.',
#       'expert_comment': 'PO Box 1999 Walla Walla, Washington 99362-0999',
#       'create_date': '2001-09-28 00:00:00',
#       'update_date': ''}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '5351',
#       'author': 'Gill, Frank, and Minturn Wright',
#       'title': 'Birds of the World: Recommended English Names',
#       'other_variable_0': '2006-01-01 00:00:00',
#       'other_variable_1': '2006-01-01 00:00:00',
#       'other_variable_2': 'Princeton University Press',
#       'other_variable_3': 'Princeton, New Jersey, USA',
#       'other_variable_4': '0-691-12827-8',
#       'other_variable_6': 'ix + 259',
#       'other_variable_7': 'Includes a CD-ROM with the full dataset',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-06-26 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '6101',
#       'author': "American Ornithologists' Union",
#       'title': 'The Auk, vol. 119, no. 3',
#       'other_variable_0': '2002-07-01 00:00:00',
#       'other_variable_1': '2002-07-01 00:00:00',
#       'other_variable_5': '0004-8038',
#       'other_variable_6': '897-906',
#       'other_variable_8': 'N',
#       'other_variable_9': '2015-10-28 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '388',
#       'source_type': 'website',
#       'source_name': 'AOU Check-List (07-2005)',
#       'version': 'Jul-2005',
#       'acquisition_date': '2005-08-29 00:00:00',
#       'source_comment': 'American Ornithologists\' Union\'s "LIST OF THE 2,037 BIRD SPECIES (WITH SCIENTIFIC AND ENGLISH NAMES) KNOWN FROM THE A.O.U. CHECK-LIST AREA" (AOU Check-list, 7th edition, updated with Supplements 42-46), maintained at http://www.aou.org/',
#       'create_date': '2006-11-29 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '413',
#       'source_type': 'website',
#       'source_name': 'FRENCH NAMES OF NORTH AMERICAN BIRDS',
#       'version': 'Jul-2005',
#       'acquisition_date': '2005-08-29 00:00:00',
#       'source_comment': 'American Ornithologists\' Union\'s "FRENCH NAMES OF NORTH AMERICAN BIRDS" (based on AOU Check-list, 7th edition, updated with Supplements 42-46), maintained at http://www.aou.org/',
#       'create_date': '2007-06-13 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '582',
#       'source_type': 'website',
#       'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2011.02.14',
#       'version': '14-Feb-11',
#       'acquisition_date': '2011-05-28 00:00:00',
#       'source_comment': '"Zoonomen - Zoological Nomenclature Resource" maintained by Alan P. Peterson at http://www.zoonomen.net',
#       'create_date': '2011-09-22 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '586',
#       'source_type': 'website',
#       'source_name': 'AOU Check-List (08-2011)',
#       'version': 'Aug-2011',
#       'acquisition_date': '2011-08-26 00:00:00',
#       'source_comment': 'American Ornithologists\' Union\'s "Check-list of North American Birds - List of the 2,078 Bird Species Known From the A.O.U. Check-list Area" (AOU Check-list, 7th edition, updated with Supplements 42-52), maintained at http://www.aou.org/',
#       'create_date': '2011-09-22 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '587',
#       'source_type': 'website',
#       'source_name': 'IOC World Bird List, Master List v2.9',
#       'version': '2.9',
#       'acquisition_date': '2011-08-26 00:00:00',
#       'source_comment': "Master list and sub-lists are maintained at http://www.worldbirdnames.org/names.html, and 'virtually replace' Gill & Wright 2006 (Birds of the World, Recommended English Names)",
#       'create_date': '2011-09-22 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Procellariiformes'},
#      {'rank': 'Family', 'name': 'Procellariidae'},
#      {'rank': 'Genus', 'name': 'Pterodroma'},
#      {'rank': 'Species', 'name': 'Pterodroma sandwichensis'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Procellariiformes',
#      'Procellariidae',
#      'Pterodroma',
#      'Pterodroma sandwichensis'],
#     'commonnames': [{'name': 'Pétrel des Hawaï', 'language': 'French'},
#      {'name': 'Hawaiian Petrel', 'language': 'English'},
#      {'name': 'Hawaiian Dark-rumped Petrel', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:01.937931',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Anoplopoma\\%20fimbria'}]},
#   'parameters': {'Scientific Name': 'Anoplopoma fimbria'},
#   'itis_data': [{'tsn': '167123',
#     'nameWInd': 'Anoplopoma fimbria',
#     'nameWOInd': 'Anoplopoma fimbria',
#     'unit1': 'Anoplopoma',
#     'unit2': 'fimbria',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Pallas, 1814)',
#     'kingdom': 'Animalia',
#     'parentTSN': '167122',
#     'rankID': '220',
#     'rank': 'Species',
#     '_version_': 1641159115859296256,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2005-12-01 00:00:00',
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '1398',
#       'author': 'Eschmeyer, William N., ed.',
#       'title': 'Special Publication of the Center for Biodiversity Research and Information, no. 1, vol 1-3',
#       'other_variable_0': '1998-01-01 00:00:00',
#       'other_variable_1': '1998-01-01 00:00:00',
#       'other_variable_2': 'California Academy of Sciences',
#       'other_variable_3': 'San Francisco, California, USA',
#       'other_variable_4': '0-940228-47-5',
#       'other_variable_6': '2905',
#       'other_variable_7': 'http://www.jstor.org/stable/25622932',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1405',
#       'author': 'Robins, Richard C., Reeve M. Bailey, Carl E. Bond, James R. Brooker, Ernest A. Lachner, et al.',
#       'title': 'American Fisheries Society Special Publication, no. 12',
#       'other_variable_0': '1980-01-01 00:00:00',
#       'other_variable_1': '1980-01-01 00:00:00',
#       'other_variable_2': 'American Fisheries Society',
#       'other_variable_3': 'Bethesda, Maryland, USA',
#       'other_variable_6': '174',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1727',
#       'author': 'Robins, Richard C., Reeve M. Bailey, Carl E. Bond, James R. Brooker, Ernest A. Lachner, et al.',
#       'title': 'American Fisheries Society Special Publication, no. 20',
#       'other_variable_0': '1991-01-01 00:00:00',
#       'other_variable_1': '1991-01-01 00:00:00',
#       'other_variable_2': 'American Fisheries Society',
#       'other_variable_3': 'Bethesda, Maryland, USA',
#       'other_variable_4': '0-913235-70-9',
#       'other_variable_5': '0097-0638',
#       'other_variable_6': '183',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '2861',
#       'author': 'Nelson, Joseph S., Edwin J. Crossman, H. Espinosa-Pérez, L. T. Findley, C. R. Gilbert, et al., eds.',
#       'title': 'American Fisheries Society Special Publication, no. 29',
#       'other_variable_0': '2004-01-01 00:00:00',
#       'other_variable_1': '2004-07-01 00:00:00',
#       'other_variable_2': 'American Fisheries Society',
#       'other_variable_3': 'Bethesda, Maryland, USA',
#       'other_variable_4': '1-888569-61-1',
#       'other_variable_5': '0097-0638',
#       'other_variable_6': 'ix + 386',
#       'other_variable_7': 'Full author list: Nelson, Joseph S., Edwin J. Crossman, Héctor Espinosa-Pérez, Lloyd T. Findley, Carter R. Gilbert, Robert N. Lea, and James D. Williams',
#       'other_variable_9': '2017-08-28 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '345',
#       'source_type': 'website',
#       'source_name': 'Catalog of Fishes, 22-Oct-2005',
#       'version': '17-Oct-05',
#       'acquisition_date': '2005-10-22 00:00:00',
#       'source_comment': 'http://www.calacademy.org/research/ichthyology/catalog/',
#       'create_date': '2005-12-01 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Actinopterygii'},
#      {'rank': 'Class', 'name': 'Teleostei'},
#      {'rank': 'Superorder', 'name': 'Acanthopterygii'},
#      {'rank': 'Order', 'name': 'Scorpaeniformes'},
#      {'rank': 'Suborder', 'name': 'Anoplopomatoidei'},
#      {'rank': 'Family', 'name': 'Anoplopomatidae'},
#      {'rank': 'Genus', 'name': 'Anoplopoma'},
#      {'rank': 'Species', 'name': 'Anoplopoma fimbria'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Actinopterygii',
#      'Teleostei',
#      'Acanthopterygii',
#      'Scorpaeniformes',
#      'Anoplopomatoidei',
#      'Anoplopomatidae',
#      'Anoplopoma',
#      'Anoplopoma fimbria'],
#     'commonnames': [{'name': 'sablefish', 'language': 'English'},
#      {'name': 'bacalao negro', 'language': 'Spanish'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:02.113218',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Gopherus\\%20agassizii'}]},
#   'parameters': {'Scientific Name': 'Gopherus agassizii'},
#   'itis_data': [{'tsn': '173856',
#     'nameWInd': 'Gopherus agassizii',
#     'nameWOInd': 'Gopherus agassizii',
#     'unit1': 'Gopherus',
#     'unit2': 'agassizii',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Cooper, 1861)',
#     'kingdom': 'Animalia',
#     'parentTSN': '173855',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['173856:$Xerobates agassizii$Scaptochelys agassizii$Xerobates lepidocephalus$'],
#     'synonymTSNs': ['173856:$202112$202113$949561$'],
#     '_version_': 1641159116828180481,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2016-11-23 00:00:00',
#     'geographicDivision': [{'geographic_value': 'Middle America',
#       'update_date': '2001-06-11 00:00:00'},
#      {'geographic_value': 'North America',
#       'update_date': '1997-10-27 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2005-05-09 00:00:00'},
#      {'jurisdiction_value': 'Mexico',
#       'origin': 'Native',
#       'update_date': '2005-05-09 00:00:00'}],
#     'expert': [{'reference_type': 'EXP',
#       'expert_id': '24',
#       'expert_name': 'Roy W. McDiarmid',
#       'expert_comment': 'U.S. Geological Survey, Biological Resources Division, Patuxent Wildlife Research Center',
#       'create_date': '2004-08-16 00:00:00',
#       'update_date': ''}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '103',
#       'author': 'Iverson, John B.',
#       'title': 'A Revised Checklist with Distribution Maps of the Turtles of the World',
#       'other_variable_0': '1992-01-01 00:00:00',
#       'other_variable_1': '1992-01-01 00:00:00',
#       'other_variable_2': 'Privately Printed',
#       'other_variable_3': 'Richmond, Indiana',
#       'other_variable_4': '0-9617431-0-5',
#       'other_variable_6': 'xiii + 363',
#       'other_variable_8': 'N',
#       'other_variable_9': '2016-11-23 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '706',
#       'author': 'Banks, R. C., R. W. McDiarmid, and A. L. Gardner',
#       'title': 'Resource Publication, no. 166',
#       'other_variable_0': '1987-01-01 00:00:00',
#       'other_variable_1': '1987-01-01 00:00:00',
#       'other_variable_2': 'United States Department of the Interior Fish and Wildlife Service',
#       'other_variable_3': 'Washington, D.C., USA',
#       'other_variable_6': '79',
#       'other_variable_8': 'N',
#       'other_variable_9': '2019-04-27 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1306',
#       'author': 'Flores-Villela, Oscar / McCoy, C. J., ed.',
#       'title': 'Carnegie Museum of Natural History Special Publication, no. 17',
#       'other_variable_0': '1993-01-29 00:00:00',
#       'other_variable_1': '1993-01-29 00:00:00',
#       'other_variable_2': 'Carnegie Museum of Natural History',
#       'other_variable_3': 'Pittsburgh, Pennsylvania, USA',
#       'other_variable_4': '0-911239-42-1',
#       'other_variable_6': 'iv + 73',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '2899',
#       'author': 'Banks, R. C., R. W. McDiarmid, A. L. Gardner, and W. C. Starnes',
#       'title': 'Checklist of Vertebrates of the United States, the U.S. Territories, and Canada, draft (2004)',
#       'other_variable_0': '2004-12-31 00:00:00',
#       'other_variable_1': '2004-12-31 00:00:00',
#       'other_variable_7': 'As-yet (2004) unpublished manuscript from 1998',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-10-26 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '10925',
#       'author': 'Crother, Brian I., Jeff Boundy, Frank T. Burbrink, Jonathan A. Campbell, Kevin de Queiroz, et al.',
#       'title': 'Herpetological Circular, no. 39',
#       'other_variable_0': '2012-08-01 00:00:00',
#       'other_variable_1': '2012-08-01 00:00:00',
#       'other_variable_2': 'Society for the Study of Amphibians and Reptiles',
#       'other_variable_3': 'Shoreview, Minnesota, USA',
#       'other_variable_4': '9780916984854',
#       'other_variable_6': '1-92',
#       'other_variable_7': 'Available free as a PDF at http://ssarherps.org/pages/HerpCommNames.php',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-09-25 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '11628',
#       'author': 'Turtle Taxonomy Working Group [van Dijk, P. P., J. Iverson, A. Rhodin, H. Shaffer, and R. Bour]',
#       'title': 'Chelonian Research Monographs, no. 5, v. 7',
#       'other_variable_0': '2014-06-16 00:00:00',
#       'other_variable_1': '2014-06-16 00:00:00',
#       'other_variable_5': '1088-7105',
#       'other_variable_6': '329-479',
#       'other_variable_7': 'doi:10.3854/crm.5.000.checklist.v7.2014 - Available online at http://www.iucn-tftsg.org/cbftt/',
#       'other_variable_8': 'N',
#       'other_variable_9': '2016-11-23 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '14662',
# ...
#       'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'Australia', 'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'Caribbean', 'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'Europe & Northern Asia (excluding China)',
#       'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'Middle America',
#       'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'North America',
#       'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'Oceania', 'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'South America',
#       'update_date': '2008-05-20 00:00:00'},
#      {'geographic_value': 'Southern Asia',
#       'update_date': '2008-05-20 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Canada',
#       'origin': 'Introduced',
#       'update_date': '2008-12-05 00:00:00'},
#      {'jurisdiction_value': 'Caribbean Territories',
#       'origin': 'Introduced',
#       'update_date': '2008-12-05 00:00:00'},
#      {'jurisdiction_value': 'Continental US',
#       'origin': 'Introduced',
#       'update_date': '2008-12-05 00:00:00'},
#      {'jurisdiction_value': 'Hawaii',
#       'origin': 'Introduced',
#       'update_date': '2008-12-05 00:00:00'},
#      {'jurisdiction_value': 'Mexico',
#       'origin': 'Native',
#       'update_date': '2008-12-05 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '364',
#       'source_type': 'manuscript',
#       'source_name': 'Checklist of Apoidea of North America... - 18-Nov-2005',
#       'version': '18-Nov-05',
#       'acquisition_date': '2005-11-18 00:00:00',
#       'source_comment': 'Griswold, T., and J. S. Ascher. 2005. Checklist of Apoidea of North America (including Central America and the Caribbean) (as-yet unpublished manuscript from 2004+)',
#       'create_date': '2006-03-09 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '396',
#       'source_type': 'database',
#       'source_name': 'Checklist for Apoidea, Australian Faunal Directory',
#       'version': '2006',
#       'acquisition_date': '2007-01-16 00:00:00',
#       'source_comment': 'Walker, K. L. 2006. Australian Checklist of Apoidea. Australian Biological Resources Study, Canberra (update to 2001 version by J. C. Cardale). http://www.environment.gov.au/cgi-bin/abrs/fauna/tree.pl?pstrVol=APOIDEA',
#       'create_date': '2008-02-13 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '441',
#       'source_type': 'database',
#       'source_name': 'Apoidea Database, Fauna Europaea',
#       'version': '2004',
#       'acquisition_date': '2006-12-12 00:00:00',
#       'source_comment': 'Polaszek, Andrew (compiler). Apoidea Database, Fauna Europaea http://www.faunaeur.org/',
#       'create_date': '2008-02-13 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '446',
#       'source_type': 'manuscript',
#       'source_name': 'World Bee Checklist Project - update 2008-09',
#       'version': '10/09/2008',
#       'acquisition_date': '2008-09-10 00:00:00',
#       'source_comment': 'John Ascher, Connal Eardley, Terry Griswold, Gabriel Melo, Andrew Polaszek, Michael Ruggiero, Paul Williams, Ken Walker, and Natapot Warrit. Additional credits noted at: http://www.discoverlife.org/mp/20q?act=x_guide_credit&guide=Apoidea_species',
#       'create_date': '2008-09-30 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Protostomia'},
#      {'rank': 'Superphylum', 'name': 'Ecdysozoa'},
#      {'rank': 'Phylum', 'name': 'Arthropoda'},
#      {'rank': 'Subphylum', 'name': 'Hexapoda'},
#      {'rank': 'Class', 'name': 'Insecta'},
#      {'rank': 'Subclass', 'name': 'Pterygota'},
#      {'rank': 'Infraclass', 'name': 'Neoptera'},
#      {'rank': 'Superorder', 'name': 'Holometabola'},
#      {'rank': 'Order', 'name': 'Hymenoptera'},
#      {'rank': 'Suborder', 'name': 'Apocrita'},
#      {'rank': 'Infraorder', 'name': 'Aculeata'},
#      {'rank': 'Superfamily', 'name': 'Apoidea'},
#      {'rank': 'Family', 'name': 'Apidae'},
#      {'rank': 'Subfamily', 'name': 'Apinae'},
#      {'rank': 'Tribe', 'name': 'Apini'},
#      {'rank': 'Genus', 'name': 'Apis'},
#      {'rank': 'Species', 'name': 'Apis mellifera'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Protostomia',
#      'Ecdysozoa',
#      'Arthropoda',
#      'Hexapoda',
#      'Insecta',
#      'Pterygota',
#      'Neoptera',
#      'Holometabola',
#      'Hymenoptera',
#      'Apocrita',
#      'Aculeata',
#      'Apoidea',
#      'Apidae',
#      'Apinae',
#      'Apini',
#      'Apis',
#      'Apis mellifera'],
#     'commonnames': [{'name': 'honey bee', 'language': 'English'},
#      {'name': 'abeille domestique', 'language': 'French'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:06.873173',
#    'status_message': 'Exact Match',
#    'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Cercocarpus\\%20ledifolius'}]},
#   'parameters': {'Scientific Name': 'Cercocarpus ledifolius'},
#   'itis_data': [{'tsn': '25134',
#     'nameWInd': 'Cercocarpus ledifolius',
#     'nameWOInd': 'Cercocarpus ledifolius',
#     'unit1': 'Cercocarpus',
#     'unit2': 'ledifolius',
#     'usage': 'accepted',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': 'Nutt.',
#     'kingdom': 'Plantae',
#     'parentTSN': '25131',
#     'rankID': '220',
#     'rank': 'Species',
#     '_version_': 1641159096871682048,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2011-12-08 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '1996-11-05 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2000-03-15 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '168',
#       'source_type': 'database',
#       'source_name': 'The PLANTS Database',
#       'version': '4.0.4',
#       'acquisition_date': '1996-07-26 00:00:00',
#       'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#       'create_date': '2004-02-23 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '169',
#       'source_type': 'database',
#       'source_name': 'The PLANTS Database',
#       'version': '5.1.1',
#       'acquisition_date': '2000-01-21 00:00:00',
#       'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#       'create_date': '2004-02-23 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '758',
#       'source_type': 'database',
#       'source_name': 'Rosaceae of North America Update',
#       'version': '2011',
#       'acquisition_date': '2011-09-23 00:00:00',
#       'source_comment': 'Updated for ITIS by the Flora of North America Expertise Network, in connection with an update for USDA PLANTS (2007-2010)',
#       'create_date': '2011-12-08 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Rosanae'},
#      {'rank': 'Order', 'name': 'Rosales'},
#      {'rank': 'Family', 'name': 'Rosaceae'},
#      {'rank': 'Genus', 'name': 'Cercocarpus'},
#      {'rank': 'Species', 'name': 'Cercocarpus ledifolius'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Rosanae',
#      'Rosales',
#      'Rosaceae',
#      'Cercocarpus',
#      'Cercocarpus ledifolius'],
#     'commonnames': [{'name': 'curlleaf cercocarpus', 'language': 'English'},
#      {'name': 'curl-leaf mountain-mahogany', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:06.875165',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:175165'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Melanitta\\%20deglandi'}]},
#   'parameters': {'Scientific Name': 'Melanitta deglandi'},
#   'itis_data': [{'tsn': '175165',
#     'nameWInd': 'Melanitta fusca deglandi',
#     'nameWOInd': 'Melanitta fusca deglandi',
#     'unit1': 'Melanitta',
#     'unit2': 'fusca',
#     'unit3': 'deglandi',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Bonaparte, 1850)',
#     'kingdom': 'Animalia',
#     'parentTSN': '175163',
#     'rankID': '230',
#     'rank': 'Subspecies',
#     'synonyms': ['175165:$Melanitta fusca dixoni$Melanitta deglandi$Melanitta deglandi deglandi$Melanitta deglandi dixoni$'],
#     'synonymTSNs': ['175165:$175166$175167$175168$175169$'],
#     '_version_': 1641159117034749954,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2007-01-23 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '2007-01-23 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Alaska',
#       'origin': 'Native',
#       'update_date': '2007-01-23 00:00:00'},
#      {'jurisdiction_value': 'Canada',
#       'origin': 'Native',
#       'update_date': '2007-01-23 00:00:00'},
#      {'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2007-01-23 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '390',
#       'source_type': 'website',
#       'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2006.12.10',
#       'version': '10-Dec-06',
#       'acquisition_date': '2006-12-20 00:00:00',
#       'source_comment': '"Zoonomen - Zoological Nomenclature Resource" maintained by Alan P. Peterson at http://www.zoonomen.net',
#       'create_date': '2007-01-23 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Anseriformes'},
#      {'rank': 'Family', 'name': 'Anatidae'},
#      {'rank': 'Subfamily', 'name': 'Anatinae'},
#      {'rank': 'Genus', 'name': 'Melanitta'},
#      {'rank': 'Species', 'name': 'Melanitta fusca'},
#      {'rank': 'Subspecies', 'name': 'Melanitta fusca deglandi'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Anseriformes',
#      'Anatidae',
#      'Anatinae',
#      'Melanitta',
#      'Melanitta fusca',
#      'Melanitta fusca deglandi']},
#    {'tsn': '175167',
#     'nameWInd': 'Melanitta deglandi',
#     'nameWOInd': 'Melanitta deglandi',
#     'unit1': 'Melanitta',
#     'unit2': 'deglandi',
#     'usage': 'invalid',
#     'unacceptReason': 'subsequent name/combination',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Bonaparte, 1850)',
#     'kingdom': 'Animalia',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['175165:$Melanitta fusca dixoni$Melanitta deglandi$Melanitta deglandi deglandi$Melanitta deglandi dixoni$'],
#     'synonymTSNs': ['175165:$175166$175167$175168$175169$'],
#     'acceptedTSN': ['175165'],
#     '_version_': 1641159117034749956,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2007-01-23 00:00:00',
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '2909',
#       'author': "American Ornithologists' Union",
#       'title': 'Check-list of North American Birds, 5th Edition',
#       'other_variable_0': '1957-01-01 00:00:00',
#       'other_variable_1': '1957-01-01 00:00:00',
#       'other_variable_2': "American Ornithologists' Union",
#       'other_variable_3': 'Baltimore, Maryland, USA',
#       'other_variable_6': 'xiii + 691',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-06-26 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '2916',
#       'author': "American Ornithologists' Union",
#       'title': 'Check-list of North American Birds, 6th Edition',
#       'other_variable_0': '1983-01-01 00:00:00',
#       'other_variable_1': '1983-01-01 00:00:00',
#       'other_variable_2': "American Ornithologists' Union",
#       'other_variable_3': 'Washington, DC, USA',
#       'other_variable_4': '0-943610-32-X',
#       'other_variable_6': 'xxix + 877',
#       'other_variable_8': 'N',
#       'other_variable_9': '2015-10-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '5351',
#       'author': 'Gill, Frank, and Minturn Wright',
#       'title': 'Birds of the World: Recommended English Names',
#       'other_variable_0': '2006-01-01 00:00:00',
#       'other_variable_1': '2006-01-01 00:00:00',
#       'other_variable_2': 'Princeton University Press',
#       'other_variable_3': 'Princeton, New Jersey, USA',
#       'other_variable_4': '0-691-12827-8',
#       'other_variable_6': 'ix + 259',
#       'other_variable_7': 'Includes a CD-ROM with the full dataset',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-06-26 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Anseriformes'},
#      {'rank': 'Family', 'name': 'Anatidae'},
#      {'rank': 'Subfamily', 'name': 'Anatinae'},
#      {'rank': 'Genus', 'name': 'Melanitta'},
#      {'rank': 'Species', 'name': 'Melanitta fusca'},
#      {'rank': 'Subspecies', 'name': 'Melanitta fusca deglandi'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Anseriformes',
#      'Anatidae',
#      'Anatinae',
#      'Melanitta',
#      'Melanitta fusca',
#      'Melanitta fusca deglandi'],
#     'commonnames': [{'name': 'White-winged Scoter', 'language': 'English'}]}]}]

# %% [markdown]
# In some cases more than one ITIS record was returned from the function. In every case, the “processing_metadata” structure indicates that the scientific species names used at the point of discovery were accepted. However, the "itis_data" structure indicates that potentially invalid names were provided from the WLCI literature database or xDD source information yet have a valid record in ITIS. The following code block lets us examine what is going on in these cases.
#
# The “processing_metadata” structure provides information about what the function does. It includes the URLs to the ITIS API that resulted in some action. Both the valid/accepted and invalid/unaccepted names from ITIS are recorded. We reach back to the itis_cahce to show that record.

# %%
#Select ITIS records with more than one record 
validate =[i for i in itis_cache if "itis_data" in i.keys() and len(i["itis_data"]) > 1]

# %%
validate
# Out:
# [{'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:02.362286',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:503283'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Bassia\\%20prostrata'}]},
#   'parameters': {'Scientific Name': 'Bassia prostrata'},
#   'itis_data': [{'tsn': '503283',
#     'nameWInd': 'Kochia prostrata',
#     'nameWOInd': 'Kochia prostrata',
#     'unit1': 'Kochia',
#     'unit2': 'prostrata',
#     'usage': 'accepted',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(L.) Schrad.',
#     'kingdom': 'Plantae',
#     'parentTSN': '20693',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['503283:$Bassia prostrata$Kochia prostrata villosissima$'],
#     'synonymTSNs': ['503283:$822851$822929$'],
#     '_version_': 1641159123757170695,
#     'date_created': '1996-11-04 17:57:08',
#     'date_modified': '2011-08-30 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '1996-11-05 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Continental US',
#       'origin': 'Introduced',
#       'update_date': '2000-03-15 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '168',
#       'source_type': 'database',
#       'source_name': 'The PLANTS Database',
#       'version': '4.0.4',
#       'acquisition_date': '1996-07-26 00:00:00',
#       'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#       'create_date': '2004-02-23 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '169',
#       'source_type': 'database',
#       'source_name': 'The PLANTS Database',
#       'version': '5.1.1',
#       'acquisition_date': '2000-01-21 00:00:00',
#       'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#       'create_date': '2004-02-23 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '558',
#       'source_type': 'database',
#       'source_name': 'Amaranthaceae and Phytolaccaceae of North America Update',
#       'version': '2011',
#       'acquisition_date': '2011-07-18 00:00:00',
#       'source_comment': 'Updated for ITIS by the Flora of North America Expertise Network, in connection with an update for USDA PLANTS (2007-2010)',
#       'create_date': '2011-08-30 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Caryophyllanae'},
#      {'rank': 'Order', 'name': 'Caryophyllales'},
#      {'rank': 'Family', 'name': 'Amaranthaceae'},
#      {'rank': 'Genus', 'name': 'Kochia'},
#      {'rank': 'Species', 'name': 'Kochia prostrata'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Caryophyllanae',
#      'Caryophyllales',
#      'Amaranthaceae',
#      'Kochia',
#      'Kochia prostrata'],
#     'commonnames': [{'name': 'prostrate summer-cypress',
#       'language': 'unspecified'},
#      {'name': 'prostrate kochia', 'language': 'unspecified'},
#      {'name': 'prostrate summercypress', 'language': 'English'},
#      {'name': 'forage kochia', 'language': 'English'}]},
#    {'tsn': '822851',
#     'nameWInd': 'Bassia prostrata',
#     'nameWOInd': 'Bassia prostrata',
#     'unit1': 'Bassia',
#     'unit2': 'prostrata',
#     'usage': 'not accepted',
#     'unacceptReason': 'synonym',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(L.) A.J. Scott',
#     'kingdom': 'Plantae',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['503283:$Bassia prostrata$Kochia prostrata villosissima$'],
#     'synonymTSNs': ['503283:$822851$822929$'],
#     'acceptedTSN': ['503283'],
#     '_version_': 1641159167245811713,
#     'date_created': '2011-08-30 12:42:34',
#     'date_modified': '2011-08-30 00:00:00',
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '558',
#       'source_type': 'database',
#       'source_name': 'Amaranthaceae and Phytolaccaceae of North America Update',
#       'version': '2011',
#       'acquisition_date': '2011-07-18 00:00:00',
#       'source_comment': 'Updated for ITIS by the Flora of North America Expertise Network, in connection with an update for USDA PLANTS (2007-2010)',
#       'create_date': '2011-08-30 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#      {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#      {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#      {'rank': 'Superdivision', 'name': 'Embryophyta'},
#      {'rank': 'Division', 'name': 'Tracheophyta'},
#      {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#      {'rank': 'Class', 'name': 'Magnoliopsida'},
#      {'rank': 'Superorder', 'name': 'Caryophyllanae'},
#      {'rank': 'Order', 'name': 'Caryophyllales'},
#      {'rank': 'Family', 'name': 'Amaranthaceae'},
#      {'rank': 'Genus', 'name': 'Kochia'},
#      {'rank': 'Species', 'name': 'Kochia prostrata'}],
#     'hierarchy': ['Plantae',
#      'Viridiplantae',
#      'Streptophyta',
#      'Embryophyta',
#      'Tracheophyta',
#      'Spermatophytina',
#      'Magnoliopsida',
#      'Caryophyllanae',
#      'Caryophyllales',
#      'Amaranthaceae',
#      'Kochia',
#      'Kochia prostrata'],
#     'commonnames': [{'name': 'forage kochia', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:02.886822',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:960160'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Brucella\\%20abortus'}]},
#   'parameters': {'Scientific Name': 'Brucella abortus'},
#   'itis_data': [{'tsn': '960160',
#     'nameWInd': 'Brucella melitensis',
#     'nameWOInd': 'Brucella melitensis',
#     'unit1': 'Brucella',
#     'unit2': 'melitensis',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Hughes, 1893) Meyer and Shaw, 1920 emend. Verger et al., 1985',
#     'kingdom': 'Bacteria',
#     'parentTSN': '956860',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['960160:$Brucella abortus$Brucella canis$Brucella neotomae$Brucella ovis$Brucella suis$'],
#     'synonymTSNs': ['960160:$968200$968201$968202$968203$968204$'],
#     '_version_': 1641159187725549569,
#     'date_created': '2015-03-02 13:47:03',
#     'date_modified': '2015-03-02 00:00:00',
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '1096',
#       'source_type': 'website',
#       'source_name': 'Bacterial Nomenclature up-to-date',
#       'version': 'Jun 2012',
#       'acquisition_date': '2012-07-02 00:00:00',
#       'source_comment': 'Bacterial Nomenclature up-to-date published by the Leibniz Institute DSMZ-German Collection of Microorganisms and Cell Cultures at http://www.dsmz.de/bacterial-diversity/bacterial-nomenclature-up-to-date.html',
#       'create_date': '2015-03-02 00:00:00',
#       'update_date': ''}],
#     'comment': [{'comment_id': '30314',
#       'commentator': 'DSMZ',
#       'comment_text': 'species (AL)',
#       'create_date': '2014-12-22 13:38:32',
#       'update_date': '2014-12-22 00:00:00'},
#      {'comment_id': '31480',
#       'commentator': 'DSMZ',
#       'comment_text': 'International Journal of Systematic and Evolutionary Microbiology (IJSEM), 1980 30:270: Approved List',
#       'create_date': '2015-03-02 14:57:15',
#       'update_date': '2015-03-02 00:00:00'},
#      {'comment_id': '35334',
#       'commentator': 'DSMZ',
#       'comment_text': 'emend. description: IJSB 35:294*',
#       'create_date': '2015-03-02 15:08:56',
#       'update_date': '2015-03-02 00:00:00'},
#      {'comment_id': '35335',
#       'commentator': 'DSMZ',
#       'comment_text': 'Risk group 3; Strains ATCC 23456',
#       'create_date': '2015-03-02 15:08:57',
#       'update_date': '2015-03-02 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Bacteria'},
#      {'rank': 'Subkingdom', 'name': 'Negibacteria'},
#      {'rank': 'Phylum', 'name': 'Proteobacteria'},
#      {'rank': 'Class', 'name': 'Alphaproteobacteria'},
#      {'rank': 'Order', 'name': 'Rhizobiales'},
#      {'rank': 'Family', 'name': 'Brucellaceae'},
#      {'rank': 'Genus', 'name': 'Brucella'},
#      {'rank': 'Species', 'name': 'Brucella melitensis'}],
#     'hierarchy': ['Bacteria',
#      'Negibacteria',
#      'Proteobacteria',
#      'Alphaproteobacteria',
#      'Rhizobiales',
#      'Brucellaceae',
#      'Brucella',
#      'Brucella melitensis']},
#    {'tsn': '968200',
#     'nameWInd': 'Brucella abortus',
#     'nameWOInd': 'Brucella abortus',
#     'unit1': 'Brucella',
#     'unit2': 'abortus',
#     'usage': 'invalid',
#     'unacceptReason': 'junior synonym',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Schmidt, 1901) Meyer and Shaw, 1920',
#     'kingdom': 'Bacteria',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['960160:$Brucella abortus$Brucella canis$Brucella neotomae$Brucella ovis$Brucella suis$'],
#     'synonymTSNs': ['960160:$968200$968201$968202$968203$968204$'],
#     'acceptedTSN': ['960160'],
#     '_version_': 1641159188682899464,
#     'date_created': '2015-03-02 14:41:31',
#     'date_modified': '2015-03-02 00:00:00',
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '1096',
#       'source_type': 'website',
#       'source_name': 'Bacterial Nomenclature up-to-date',
#       'version': 'Jun 2012',
#       'acquisition_date': '2012-07-02 00:00:00',
#       'source_comment': 'Bacterial Nomenclature up-to-date published by the Leibniz Institute DSMZ-German Collection of Microorganisms and Cell Cultures at http://www.dsmz.de/bacterial-diversity/bacterial-nomenclature-up-to-date.html',
#       'create_date': '2015-03-02 00:00:00',
#       'update_date': ''}],
#     'comment': [{'comment_id': '31480',
#       'commentator': 'DSMZ',
#       'comment_text': 'International Journal of Systematic and Evolutionary Microbiology (IJSEM), 1980 30:270: Approved List',
#       'create_date': '2015-03-02 14:57:15',
#       'update_date': '2015-03-02 00:00:00'},
#      {'comment_id': '33046',
#       'commentator': 'DSMZ',
#       'comment_text': 'species (AL), heterotypic syn.',
#       'create_date': '2015-03-02 15:02:02',
#       'update_date': '2015-03-02 00:00:00'},
#      {'comment_id': '47968',
#       'commentator': 'DSMZ',
#       'comment_text': 'Brucella melitensis biovar abortus IJSB 35:294*',
#       'create_date': '2015-03-02 15:49:20',
#       'update_date': '2015-03-02 00:00:00'},
#      {'comment_id': '47969',
#       'commentator': 'DSMZ',
#       'comment_text': 'Risk group 3; Strains ATCC 23448',
#       'create_date': '2015-03-02 15:49:20',
#       'update_date': '2015-03-02 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Bacteria'},
#      {'rank': 'Subkingdom', 'name': 'Negibacteria'},
#      {'rank': 'Phylum', 'name': 'Proteobacteria'},
#      {'rank': 'Class', 'name': 'Alphaproteobacteria'},
#      {'rank': 'Order', 'name': 'Rhizobiales'},
#      {'rank': 'Family', 'name': 'Brucellaceae'},
#      {'rank': 'Genus', 'name': 'Brucella'},
#      {'rank': 'Species', 'name': 'Brucella melitensis'}],
#     'hierarchy': ['Bacteria',
#      'Negibacteria',
#      'Proteobacteria',
#      'Alphaproteobacteria',
#      'Rhizobiales',
#      'Brucellaceae',
#      'Brucella',
#      'Brucella melitensis']}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:03.320874',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:677538'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Tetrao\\%20tetrix'}]},
#   'parameters': {'Scientific Name': 'Tetrao tetrix'},
#   'itis_data': [{'tsn': '677538',
#     'nameWInd': 'Lyrurus tetrix',
#     'nameWOInd': 'Lyrurus tetrix',
#     'unit1': 'Lyrurus',
#     'unit2': 'tetrix',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Linnaeus, 1758)',
#     'kingdom': 'Animalia',
#     'parentTSN': '677534',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['677538:$Tetrao tetrix$'],
#     'synonymTSNs': ['677538:$553891$'],
#     '_version_': 1641159148017025025,
#     'date_created': '2005-06-08 08:29:33',
#     'date_modified': '2005-06-08 00:00:00',
#     'geographicDivision': [{'geographic_value': 'Europe & Northern Asia (excluding China)',
#       'update_date': '2005-06-08 00:00:00'}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '5324',
#       'author': 'Dickinson, Edward C., ed.',
#       'title': 'The Howard and Moore Complete Checklist of the Birds of the World, 3rd edition',
#       'other_variable_0': '2003-01-01 00:00:00',
#       'other_variable_1': '2003-01-01 00:00:00',
#       'other_variable_2': 'Princeton University Press',
#       'other_variable_3': 'Princeton, New Jersey, USA',
#       'other_variable_4': '0-691-11701-2',
#       'other_variable_6': '1039',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-06-26 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '5351',
#       'author': 'Gill, Frank, and Minturn Wright',
#       'title': 'Birds of the World: Recommended English Names',
#       'other_variable_0': '2006-01-01 00:00:00',
#       'other_variable_1': '2006-01-01 00:00:00',
#       'other_variable_2': 'Princeton University Press',
#       'other_variable_3': 'Princeton, New Jersey, USA',
#       'other_variable_4': '0-691-12827-8',
#       'other_variable_6': 'ix + 259',
#       'other_variable_7': 'Includes a CD-ROM with the full dataset',
#       'other_variable_9': '2018-06-26 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '303',
#       'source_type': 'website',
#       'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2005.05.23',
#       'version': '23-May-05',
#       'acquisition_date': '2005-05-31 00:00:00',
#       'source_comment': '"Zoonomen Nomenclatural data" maintained by Alan P. Peterson at http://www.zoonomen.net',
#       'create_date': '2005-06-28 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Galliformes'},
#      {'rank': 'Family', 'name': 'Phasianidae'},
#      {'rank': 'Subfamily', 'name': 'Tetraoninae'},
#      {'rank': 'Genus', 'name': 'Lyrurus'},
#      {'rank': 'Species', 'name': 'Lyrurus tetrix'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Galliformes',
#      'Phasianidae',
#      'Tetraoninae',
#      'Lyrurus',
#      'Lyrurus tetrix'],
#     'commonnames': [{'name': 'Eurasian Black Grouse', 'language': 'English'},
#      {'name': 'Black Grouse', 'language': 'English'}]},
#    {'tsn': '553891',
#     'nameWInd': 'Tetrao tetrix',
#     'nameWOInd': 'Tetrao tetrix',
#     'unit1': 'Tetrao',
#     'unit2': 'tetrix',
#     'usage': 'invalid',
#     'unacceptReason': 'original name/combination',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': 'Linnaeus, 1758',
#     'kingdom': 'Animalia',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['677538:$Tetrao tetrix$'],
#     'synonymTSNs': ['677538:$553891$'],
#     'acceptedTSN': ['677538'],
#     '_version_': 1641159130645266433,
#     'date_created': '1998-09-16 14:57:03',
#     'date_modified': '2005-06-08 00:00:00',
#     'expert': [{'reference_type': 'EXP',
#       'expert_id': '11',
#       'expert_name': 'Alan P. Peterson, M.D.',
#       'expert_comment': 'PO Box 1999 Walla Walla, Washington 99362-0999',
#       'create_date': '2001-09-28 00:00:00',
#       'update_date': ''}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '2925',
#       'author': 'Peters, James Lee',
#       'title': 'Check-List of Birds of the World, vol. 2',
#       'other_variable_0': '1934-01-01 00:00:00',
#       'other_variable_1': '1934-01-01 00:00:00',
#       'other_variable_2': 'Oxford University Press',
#       'other_variable_3': 'London, England, UK',
#       'other_variable_6': 'xvii + 401',
#       'other_variable_8': 'N',
#       'other_variable_9': '2011-09-22 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '105',
#       'source_type': 'website',
#       'source_name': 'Zoonomen - Zoological Nomenclature Resource',
#       'version': '1998',
#       'acquisition_date': '1998-07-01 00:00:00',
#       'source_comment': 'Alan P. Peterson; http://www.zoonomen.net/',
#       'create_date': '2003-02-27 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Galliformes'},
#      {'rank': 'Family', 'name': 'Phasianidae'},
#      {'rank': 'Subfamily', 'name': 'Tetraoninae'},
#      {'rank': 'Genus', 'name': 'Lyrurus'},
#      {'rank': 'Species', 'name': 'Lyrurus tetrix'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Galliformes',
#      'Phasianidae',
#      'Tetraoninae',
#      'Lyrurus',
#      'Lyrurus tetrix']}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:04.476920',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:997724'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Amphispiza\\%20belli'}]},
#   'parameters': {'Scientific Name': 'Amphispiza belli'},
#   'itis_data': [{'tsn': '997724',
#     'nameWInd': 'Artemisiospiza belli',
#     'nameWOInd': 'Artemisiospiza belli',
#     'unit1': 'Artemisiospiza',
#     'unit2': 'belli',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Cassin, 1850)',
#     'kingdom': 'Animalia',
#     'parentTSN': '997695',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['997724:$Amphispiza belli$'],
#     'synonymTSNs': ['997724:$179402$'],
#     '_version_': 1641159193636372481,
#     'date_created': '2015-10-28 14:07:43',
#     'date_modified': '2015-10-28 00:00:00',
#     'geographicDivision': [{'geographic_value': 'Middle America',
#       'update_date': '2015-10-28 00:00:00'},
#      {'geographic_value': 'North America',
#       'update_date': '2015-10-28 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2015-10-28 00:00:00'},
#      {'jurisdiction_value': 'Mexico',
#       'origin': 'Native',
#       'update_date': '2015-10-28 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '1118',
#       'source_type': 'website',
#       'source_name': 'IOC World Bird List (v 5.3)',
#       'version': '5.3',
#       'acquisition_date': '2015-09-04 00:00:00',
#       'source_comment': 'Gill, F., and D. Donsker, eds. 2015. IOC World Bird List (v 5.3). Available at http://www.worldbirdnames.org [Accessed 04 September, 2015]',
#       'create_date': '2015-10-28 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '1119',
#       'source_type': 'website',
#       'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2015.02.01',
#       'version': '01-Feb-15',
#       'acquisition_date': '2015-01-02 00:00:00',
#       'source_comment': "'Zoonomen Nomenclatural data' maintained by Alan P. Peterson at http://www.zoonomen.net",
#       'create_date': '2015-10-28 00:00:00',
#       'update_date': ''}],
#     'comment': [{'comment_id': '58985',
#       'commentator': 'IOC List v5.3',
#       'comment_text': "Change English name of A. belli to Bell's Sparrow with transfer of 'Sage Sparrow' to A. nevadensis (IOC List v5.3)",
#       'create_date': '2015-10-28 14:23:40',
#       'update_date': '2015-10-28 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Emberizidae'},
#      {'rank': 'Genus', 'name': 'Artemisiospiza'},
#      {'rank': 'Species', 'name': 'Artemisiospiza belli'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Emberizidae',
#      'Artemisiospiza',
#      'Artemisiospiza belli'],
#     'commonnames': [{'name': "Bell's Sparrow", 'language': 'English'},
#      {'name': 'Zacatonero de artemisa', 'language': 'Spanish'},
#      {'name': 'Sage Sparrow', 'language': 'English'}]},
#    {'tsn': '179402',
#     'nameWInd': 'Amphispiza belli',
#     'nameWOInd': 'Amphispiza belli',
#     'unit1': 'Amphispiza',
#     'unit2': 'belli',
#     'usage': 'invalid',
#     'unacceptReason': 'subsequent name/combination',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Cassin, 1850)',
#     'kingdom': 'Animalia',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['997724:$Amphispiza belli$'],
#     'synonymTSNs': ['997724:$179402$'],
#     'acceptedTSN': ['997724'],
#     '_version_': 1641159117623001090,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2015-10-28 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '1998-09-16 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Canada',
#       'origin': 'Native',
#       'update_date': '2007-10-11 00:00:00'},
#      {'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2007-10-11 00:00:00'}],
#     'expert': [{'reference_type': 'EXP',
#       'expert_id': '11',
#       'expert_name': 'Alan P. Peterson, M.D.',
#       'expert_comment': 'PO Box 1999 Walla Walla, Washington 99362-0999',
#       'create_date': '2001-09-28 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'EXP',
#       'expert_id': '12',
#       'expert_name': 'Richard C. Banks',
#       'expert_comment': 'Chief, Bird Section, U.S.G.S. - B.R.D. - P.W.R.C.',
#       'create_date': '2001-09-28 00:00:00',
#       'update_date': ''}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '706',
#       'author': 'Banks, R. C., R. W. McDiarmid, and A. L. Gardner',
#       'title': 'Resource Publication, no. 166',
#       'other_variable_0': '1987-01-01 00:00:00',
#       'other_variable_1': '1987-01-01 00:00:00',
#       'other_variable_2': 'United States Department of the Interior Fish and Wildlife Service',
#       'other_variable_3': 'Washington, D.C., USA',
#       'other_variable_6': '79',
#       'other_variable_8': 'N',
#       'other_variable_9': '2019-04-27 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '5351',
#       'author': 'Gill, Frank, and Minturn Wright',
#       'title': 'Birds of the World: Recommended English Names',
#       'other_variable_0': '2006-01-01 00:00:00',
#       'other_variable_1': '2006-01-01 00:00:00',
#       'other_variable_2': 'Princeton University Press',
#       'other_variable_3': 'Princeton, New Jersey, USA',
#       'other_variable_4': '0-691-12827-8',
#       'other_variable_6': 'ix + 259',
#       'other_variable_7': 'Includes a CD-ROM with the full dataset',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-06-26 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '428',
#       'source_type': 'website',
#       'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2007.09.20',
#       'version': '20-Sep-07',
#       'acquisition_date': '2007-09-25 00:00:00',
#       'source_comment': '"Zoonomen - Zoological Nomenclature Resource" maintained by Alan P. Peterson at http://www.zoonomen.net',
#       'create_date': '2007-10-11 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '431',
#       'source_type': 'website',
#       'source_name': 'AOU Check-List (07-2007)',
#       'version': 'Jul-2007',
#       'acquisition_date': '2007-08-28 00:00:00',
#       'source_comment': 'American Ornithologists\' Union\'s "List of the 2,046 Bird Species (With Scientific and English Names) Known From the A.O.U. Check-list Area" (AOU Check-list, 7th edition, updated with Supplements 42-48), maintained at http://www.aou.org/',
#       'create_date': '2007-10-11 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '432',
#       'source_type': 'website',
#       'source_name': 'Gill & Wright (2006) corrigenda/updates - 21-Sep-2007',
#       'version': '1.1',
#       'acquisition_date': '2007-09-21 00:00:00',
#       'source_comment': 'Corrigenda & updates for "BIRDS OF THE WORLD Recommended English Names" available at http://www.worldbirdnames.org/',
#       'create_date': '2007-10-11 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Passeriformes'},
#      {'rank': 'Family', 'name': 'Emberizidae'},
#      {'rank': 'Genus', 'name': 'Artemisiospiza'},
#      {'rank': 'Species', 'name': 'Artemisiospiza belli'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Passeriformes',
#      'Emberizidae',
#      'Artemisiospiza',
#      'Artemisiospiza belli'],
#     'commonnames': [{'name': 'Sage Sparrow', 'language': 'English'},
#      {'name': 'Zacatonero de artemisa', 'language': 'Spanish'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:04.684279',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:551209'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Clupea\\%20pallasi'}]},
#   'parameters': {'Scientific Name': 'Clupea pallasi'},
#   'itis_data': [{'tsn': '551209',
#     'nameWInd': 'Clupea pallasii',
#     'nameWOInd': 'Clupea pallasii',
#     'unit1': 'Clupea',
#     'unit2': 'pallasii',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': 'Valenciennes in Cuvier and Valenciennes, 1847',
#     'kingdom': 'Animalia',
#     'parentTSN': '161721',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['551209:$Clupea harengus pallasii$Clupea harengus marisalbi$Clupea pallasii marisalbi$Clupea pallasi$'],
#     'synonymTSNs': ['551209:$161723$161725$572703$646471$'],
#     '_version_': 1641159130125172738,
#     'date_created': '1997-08-20 14:33:38',
#     'date_modified': '2005-06-20 00:00:00',
#     'geographicDivision': [{'geographic_value': 'East Pacific',
#       'update_date': '2002-12-18 00:00:00'},
#      {'geographic_value': 'Indo-West Pacific',
#       'update_date': '2002-12-18 00:00:00'},
#      {'geographic_value': 'Southern Asia',
#       'update_date': '2002-12-18 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Alaska',
#       'origin': 'Native',
#       'update_date': '2005-06-20 00:00:00'},
#      {'jurisdiction_value': 'Canada',
#       'origin': 'Native',
#       'update_date': '2005-06-20 00:00:00'},
#      {'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2005-06-20 00:00:00'},
#      {'jurisdiction_value': 'Mexico',
#       'origin': 'Native',
#       'update_date': '2005-06-20 00:00:00'}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '1398',
#       'author': 'Eschmeyer, William N., ed.',
#       'title': 'Special Publication of the Center for Biodiversity Research and Information, no. 1, vol 1-3',
#       'other_variable_0': '1998-01-01 00:00:00',
#       'other_variable_1': '1998-01-01 00:00:00',
#       'other_variable_2': 'California Academy of Sciences',
#       'other_variable_3': 'San Francisco, California, USA',
#       'other_variable_4': '0-940228-47-5',
#       'other_variable_6': '2905',
#       'other_variable_7': 'http://www.jstor.org/stable/25622932',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1481',
#       'author': 'Whitehead, Peter J. P.',
#       'title': 'FAO Fisheries Synopsis, no. 125, vol. 7, pt. 1',
#       'other_variable_0': '1985-01-01 00:00:00',
#       'other_variable_1': '1985-01-01 00:00:00',
#       'other_variable_2': 'Food and Agriculture Organization of the United Nations',
#       'other_variable_3': 'Rome, Italy',
#       'other_variable_4': '92-5-102340-9',
#       'other_variable_6': 'x + 303',
#       'other_variable_8': 'N',
#       'other_variable_9': '2003-02-13 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '1727',
#       'author': 'Robins, Richard C., Reeve M. Bailey, Carl E. Bond, James R. Brooker, Ernest A. Lachner, et al.',
#       'title': 'American Fisheries Society Special Publication, no. 20',
#       'other_variable_0': '1991-01-01 00:00:00',
#       'other_variable_1': '1991-01-01 00:00:00',
#       'other_variable_2': 'American Fisheries Society',
#       'other_variable_3': 'Bethesda, Maryland, USA',
#       'other_variable_4': '0-913235-70-9',
#       'other_variable_5': '0097-0638',
#       'other_variable_6': '183',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-08-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '2861',
#       'author': 'Nelson, Joseph S., Edwin J. Crossman, H. Espinosa-Pérez, L. T. Findley, C. R. Gilbert, et al., eds.',
#       'title': 'American Fisheries Society Special Publication, no. 29',
#       'other_variable_0': '2004-01-01 00:00:00',
#       'other_variable_1': '2004-07-01 00:00:00',
#       'other_variable_2': 'American Fisheries Society',
#       'other_variable_3': 'Bethesda, Maryland, USA',
#       'other_variable_4': '1-888569-61-1',
#       'other_variable_5': '0097-0638',
#       'other_variable_6': 'ix + 386',
#       'other_variable_7': 'Full author list: Nelson, Joseph S., Edwin J. Crossman, Héctor Espinosa-Pérez, Lloyd T. Findley, Carter R. Gilbert, Robert N. Lea, and James D. Williams',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-08-28 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '295',
#       'source_type': 'website',
#       'source_name': 'Catalog of Fishes, 27-Sept-2004',
#       'version': '16-Sep-04',
#       'acquisition_date': '2004-09-27 00:00:00',
#       'source_comment': 'http://www.calacademy.org/research/ichthyology/catalog/',
#       'create_date': '2005-05-03 00:00:00',
#       'update_date': ''}],
#     'comment': [{'comment_id': '13324',
#       'commentator': 'Andrew K. Townesmith, ITIS Data Development Technician',
#       'comment_text': 'Nelson et al. (2004) Occurrence values: P',
#       'create_date': '2005-05-03 08:03:11',
#       'update_date': '2014-02-28 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Actinopterygii'},
#      {'rank': 'Class', 'name': 'Teleostei'},
#      {'rank': 'Superorder', 'name': 'Clupeomorpha'},
#      {'rank': 'Order', 'name': 'Clupeiformes'},
#      {'rank': 'Suborder', 'name': 'Clupeoidei'},
#      {'rank': 'Family', 'name': 'Clupeidae'},
#      {'rank': 'Subfamily', 'name': 'Clupeinae'},
#      {'rank': 'Genus', 'name': 'Clupea'},
#      {'rank': 'Species', 'name': 'Clupea pallasii'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Actinopterygii',
#      'Teleostei',
#      'Clupeomorpha',
#      'Clupeiformes',
#      'Clupeoidei',
#      'Clupeidae',
#      'Clupeinae',
#      'Clupea',
#      'Clupea pallasii'],
#     'commonnames': [{'name': 'arenque del Pacífico', 'language': 'Spanish'},
#      {'name': 'Pacific herring', 'language': 'English'}]},
#    {'tsn': '646471',
#     'nameWInd': 'Clupea pallasi',
#     'nameWOInd': 'Clupea pallasi',
#     'unit1': 'Clupea',
#     'unit2': 'pallasi',
#     'usage': 'invalid',
#     'unacceptReason': 'unavailable, literature misspelling',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': 'Valenciennes in Cuvier and Valenciennes, 1847',
#     'kingdom': 'Animalia',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['551209:$Clupea harengus pallasii$Clupea harengus marisalbi$Clupea pallasii marisalbi$Clupea pallasi$'],
#     'synonymTSNs': ['551209:$161723$161725$572703$646471$'],
#     'acceptedTSN': ['551209'],
#     '_version_': 1641159144039776256,
#     'date_created': '2004-09-24 11:17:27',
#     'date_modified': '2005-06-20 00:00:00',
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '1727',
#       'author': 'Robins, Richard C., Reeve M. Bailey, Carl E. Bond, James R. Brooker, Ernest A. Lachner, et al.',
#       'title': 'American Fisheries Society Special Publication, no. 20',
#       'other_variable_0': '1991-01-01 00:00:00',
#       'other_variable_1': '1991-01-01 00:00:00',
#       'other_variable_2': 'American Fisheries Society',
#       'other_variable_3': 'Bethesda, Maryland, USA',
#       'other_variable_4': '0-913235-70-9',
#       'other_variable_5': '0097-0638',
#       'other_variable_6': '183',
#       'other_variable_8': 'N',
#       'other_variable_9': '2017-08-28 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '295',
#       'source_type': 'website',
#       'source_name': 'Catalog of Fishes, 27-Sept-2004',
#       'version': '16-Sep-04',
#       'acquisition_date': '2004-09-27 00:00:00',
#       'source_comment': 'http://www.calacademy.org/research/ichthyology/catalog/',
#       'create_date': '2005-05-03 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Actinopterygii'},
#      {'rank': 'Class', 'name': 'Teleostei'},
#      {'rank': 'Superorder', 'name': 'Clupeomorpha'},
#      {'rank': 'Order', 'name': 'Clupeiformes'},
#      {'rank': 'Suborder', 'name': 'Clupeoidei'},
#      {'rank': 'Family', 'name': 'Clupeidae'},
#      {'rank': 'Subfamily', 'name': 'Clupeinae'},
#      {'rank': 'Genus', 'name': 'Clupea'},
#      {'rank': 'Species', 'name': 'Clupea pallasii'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Actinopterygii',
#      'Teleostei',
#      'Clupeomorpha',
#      'Clupeiformes',
#      'Clupeoidei',
#      'Clupeidae',
#      'Clupeinae',
#      'Clupea',
#      'Clupea pallasii'],
#     'commonnames': [{'name': 'Pacific herring', 'language': 'English'}]}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:04.684140',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:825373'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Thrichomys\\%20fosteri'}]},
#   'parameters': {'Scientific Name': 'Thrichomys fosteri'},
#   'itis_data': [{'tsn': '825373',
#     'nameWInd': 'Thrichomys pachyurus',
#     'nameWOInd': 'Thrichomys pachyurus',
#     'unit1': 'Thrichomys',
#     'unit2': 'pachyurus',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Wagner, 1845)',
#     'kingdom': 'Animalia',
#     'parentTSN': '584649',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['825373:$Thrichomys fosteri$'],
#     'synonymTSNs': ['825373:$825422$'],
#     '_version_': 1641159167544655880,
#     'date_created': '2011-09-22 13:55:16',
#     'date_modified': '2011-09-22 00:00:00',
#     'geographicDivision': [{'geographic_value': 'South America',
#       'update_date': '2011-09-22 00:00:00'}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '8092',
#       'author': 'Woods, Charles A., and C. William Kilpatrick / Wilson, Don E., and DeeAnn M. Reeder, eds.',
#       'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 3rd ed., vol. 2',
#       'other_variable_0': '2005-10-01 00:00:00',
#       'other_variable_1': '2005-10-01 00:00:00',
#       'other_variable_2': 'Johns Hopkins University Press',
#       'other_variable_3': 'Baltimore, Maryland, USA',
#       'other_variable_4': '0-8018-8221-4',
#       'other_variable_6': '1538-1600',
#       'other_variable_8': 'N',
#       'other_variable_9': '2011-09-22 00:00:00'}],
#     'comment': [{'comment_id': '22797',
#       'commentator': 'Wilson & Reeder, eds. (2005)',
#       'comment_text': 'Comments: Originally described in the genus Isothrix by Wagner (1845) and included in Isothrix by Tate (1935) and Ellerman (1940). Included in Thrichomys apereoides by Cabrera (1961) but recognized as a distinct species based on chromosomal differentiation (Bonvicino et al., 2002) and sequence divergence (Braggio and Bonvicino, 2004). Karyotype has 2n=34; FN=64 (Bonvicino et al., 2002)',
#       'create_date': '2011-09-22 13:58:35',
#       'update_date': '2011-09-22 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Rodentia'},
#      {'rank': 'Suborder', 'name': 'Hystricomorpha'},
#      {'rank': 'Infraorder', 'name': 'Hystricognathi'},
#      {'rank': 'Family', 'name': 'Echimyidae'},
#      {'rank': 'Subfamily', 'name': 'Eumysopinae'},
#      {'rank': 'Genus', 'name': 'Thrichomys'},
#      {'rank': 'Species', 'name': 'Thrichomys pachyurus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Rodentia',
#      'Hystricomorpha',
#      'Hystricognathi',
#      'Echimyidae',
#      'Eumysopinae',
#      'Thrichomys',
#      'Thrichomys pachyurus'],
#     'commonnames': [{'name': 'Paraguayan Punaré', 'language': 'English'}]},
#    {'tsn': '825422',
#     'nameWInd': 'Thrichomys fosteri',
#     'nameWOInd': 'Thrichomys fosteri',
#     'unit1': 'Thrichomys',
#     'unit2': 'fosteri',
#     'usage': 'invalid',
#     'unacceptReason': 'junior synonym',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': 'Thomas, 1903',
#     'kingdom': 'Animalia',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['825373:$Thrichomys fosteri$'],
#     'synonymTSNs': ['825373:$825422$'],
#     'acceptedTSN': ['825373'],
#     '_version_': 1641159167550947331,
#     'date_created': '2011-09-22 13:55:58',
#     'date_modified': '2011-09-22 00:00:00',
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '8092',
#       'author': 'Woods, Charles A., and C. William Kilpatrick / Wilson, Don E., and DeeAnn M. Reeder, eds.',
#       'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 3rd ed., vol. 2',
#       'other_variable_0': '2005-10-01 00:00:00',
#       'other_variable_1': '2005-10-01 00:00:00',
#       'other_variable_2': 'Johns Hopkins University Press',
#       'other_variable_3': 'Baltimore, Maryland, USA',
#       'other_variable_4': '0-8018-8221-4',
#       'other_variable_6': '1538-1600',
#       'other_variable_8': 'N',
#       'other_variable_9': '2011-09-22 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Rodentia'},
#      {'rank': 'Suborder', 'name': 'Hystricomorpha'},
#      {'rank': 'Infraorder', 'name': 'Hystricognathi'},
#      {'rank': 'Family', 'name': 'Echimyidae'},
#      {'rank': 'Subfamily', 'name': 'Eumysopinae'},
#      {'rank': 'Genus', 'name': 'Thrichomys'},
#      {'rank': 'Species', 'name': 'Thrichomys pachyurus'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Rodentia',
#      'Hystricomorpha',
#      'Hystricognathi',
#      'Echimyidae',
#      'Eumysopinae',
#      'Thrichomys',
#      'Thrichomys pachyurus']}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:04.790429',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:926246'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Equus\\%20burchelli'}]},
#   'parameters': {'Scientific Name': 'Equus burchelli'},
#   'itis_data': [{'tsn': '926246',
#     'nameWInd': 'Equus quagga burchellii',
#     'nameWOInd': 'Equus quagga burchellii',
#     'unit1': 'Equus',
#     'unit2': 'quagga',
#     'unit3': 'burchellii',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Gray, 1824)',
#     'kingdom': 'Animalia',
#     'parentTSN': '624996',
#     'rankID': '230',
#     'rank': 'Subspecies',
#     'synonyms': ['926246:$Equus burchellii$Hippotigris campestris$Equus festivus$Equus zebroides$Hippotigris antiquorum$Equus wardi$Equus burchelli$Asinus burchellii$Hippotigris isabellinus$Equus burchellii burchellii$Equus burchellii antiquorum$Equus burchelli burchelli$Hippotigris chapmanni kaokensi$'],
#     'synonymTSNs': ['926246:$624992$926090$926091$926092$926093$926100$926145$926147$926159$926168$926240$926241$926243$'],
#     '_version_': 1641159180992643074,
#     'date_created': '2013-11-04 18:34:23',
#     'date_modified': '2013-11-04 00:00:00',
#     'geographicDivision': [{'geographic_value': 'Africa',
#       'update_date': '2013-11-04 00:00:00'}],
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '10543',
#       'author': 'Groves, C. P., and Catherine H. Bell',
#       'title': 'Mammalian Biology, vol. 69, no. 3',
#       'other_variable_0': '2004-03-01 00:00:00',
#       'other_variable_1': '2004-03-01 00:00:00',
#       'other_variable_5': '1616-5047',
#       'other_variable_6': '182-196',
#       'other_variable_7': 'doi:10.1078/1616-5047-00133',
#       'other_variable_8': 'N',
#       'other_variable_9': '2013-11-04 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '10544',
#       'author': 'Groves, Colin, and Peter Grubb',
#       'title': 'Ungulate Taxonomy',
#       'other_variable_0': '2011-01-01 00:00:00',
#       'other_variable_1': '2011-01-01 00:00:00',
#       'other_variable_2': 'Johns Hopkins University Press',
#       'other_variable_3': 'Baltimore, Maryland, USA',
#       'other_variable_4': '1-4214-0093-6',
#       'other_variable_6': 'ix + 317',
#       'other_variable_8': 'N',
#       'other_variable_9': '2013-12-23 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Perissodactyla'},
#      {'rank': 'Family', 'name': 'Equidae'},
#      {'rank': 'Genus', 'name': 'Equus'},
#      {'rank': 'Subgenus', 'name': 'Equus (Hippotigris)'},
#      {'rank': 'Species', 'name': 'Equus quagga'},
#      {'rank': 'Subspecies', 'name': 'Equus quagga burchellii'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Perissodactyla',
#      'Equidae',
#      'Equus',
#      'Equus (Hippotigris)',
#      'Equus quagga',
#      'Equus quagga burchellii'],
#     'commonnames': [{'name': 'Zululand zebra', 'language': 'English'},
#      {'name': 'Damara zebra', 'language': 'English'},
#      {'name': "Burchell's Zebra", 'language': 'English'},
#      {'name': 'Bontequagga', 'language': 'English'}]},
#    {'tsn': '926145',
#     'nameWInd': 'Equus burchelli',
#     'nameWOInd': 'Equus burchelli',
#     'unit1': 'Equus',
#     'unit2': 'burchelli',
#     'usage': 'invalid',
#     'unacceptReason': 'unavailable, literature misspelling',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Gray, 1824)',
#     'kingdom': 'Animalia',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['926246:$Equus burchellii$Hippotigris campestris$Equus festivus$Equus zebroides$Hippotigris antiquorum$Equus wardi$Equus burchelli$Asinus burchellii$Hippotigris isabellinus$Equus burchellii burchellii$Equus burchellii antiquorum$Equus burchelli burchelli$Hippotigris chapmanni kaokensi$'],
#     'synonymTSNs': ['926246:$624992$926090$926091$926092$926093$926100$926145$926147$926159$926168$926240$926241$926243$'],
#     'acceptedTSN': ['926246'],
#     '_version_': 1641159180977963009,
#     'date_created': '2013-11-04 18:34:01',
#     'date_modified': '2013-11-04 00:00:00',
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '10522',
#       'author': 'Wilson, Don E., and DeeAnn M. Reeder, eds.',
#       'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 3rd ed., vols. 1 & 2',
#       'other_variable_0': '2005-10-01 00:00:00',
#       'other_variable_1': '2005-10-01 00:00:00',
#       'other_variable_2': 'Johns Hopkins University Press',
#       'other_variable_3': 'Baltimore, Maryland',
#       'other_variable_4': '0-8018-8221-4',
#       'other_variable_6': '2000',
#       'other_variable_8': 'N',
#       'other_variable_9': '2013-12-23 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '10526',
#       'author': 'Grubb, Peter',
#       'title': 'Mammalian Species, no. 157',
#       'other_variable_0': '1981-12-03 00:00:00',
#       'other_variable_1': '1981-12-03 00:00:00',
#       'other_variable_6': '1-9',
#       'other_variable_7': 'Available online at http://www.science.smith.edu/departments/Biology/VHAYSSEN/msi/default.html',
#       'other_variable_8': 'N',
#       'other_variable_9': '2013-11-04 00:00:00'}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Mammalia'},
#      {'rank': 'Subclass', 'name': 'Theria'},
#      {'rank': 'Infraclass', 'name': 'Eutheria'},
#      {'rank': 'Order', 'name': 'Perissodactyla'},
#      {'rank': 'Family', 'name': 'Equidae'},
#      {'rank': 'Genus', 'name': 'Equus'},
#      {'rank': 'Subgenus', 'name': 'Equus (Hippotigris)'},
#      {'rank': 'Species', 'name': 'Equus quagga'},
#      {'rank': 'Subspecies', 'name': 'Equus quagga burchellii'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Mammalia',
#      'Theria',
#      'Eutheria',
#      'Perissodactyla',
#      'Equidae',
#      'Equus',
#      'Equus (Hippotigris)',
#      'Equus quagga',
#      'Equus quagga burchellii']}]},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-28T22:13:06.875165',
#    'status_message': 'Followed Accepted TSN',
#    'details': [{'TSN Search': 'https://services.itis.gov/?wt=json&rows=10&q=tsn:175165'},
#     {'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Melanitta\\%20deglandi'}]},
#   'parameters': {'Scientific Name': 'Melanitta deglandi'},
#   'itis_data': [{'tsn': '175165',
#     'nameWInd': 'Melanitta fusca deglandi',
#     'nameWOInd': 'Melanitta fusca deglandi',
#     'unit1': 'Melanitta',
#     'unit2': 'fusca',
#     'unit3': 'deglandi',
#     'usage': 'valid',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Bonaparte, 1850)',
#     'kingdom': 'Animalia',
#     'parentTSN': '175163',
#     'rankID': '230',
#     'rank': 'Subspecies',
#     'synonyms': ['175165:$Melanitta fusca dixoni$Melanitta deglandi$Melanitta deglandi deglandi$Melanitta deglandi dixoni$'],
#     'synonymTSNs': ['175165:$175166$175167$175168$175169$'],
#     '_version_': 1641159117034749954,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2007-01-23 00:00:00',
#     'geographicDivision': [{'geographic_value': 'North America',
#       'update_date': '2007-01-23 00:00:00'}],
#     'jurisdiction': [{'jurisdiction_value': 'Alaska',
#       'origin': 'Native',
#       'update_date': '2007-01-23 00:00:00'},
#      {'jurisdiction_value': 'Canada',
#       'origin': 'Native',
#       'update_date': '2007-01-23 00:00:00'},
#      {'jurisdiction_value': 'Continental US',
#       'origin': 'Native',
#       'update_date': '2007-01-23 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''},
#      {'reference_type': 'SRC',
#       'source_id': '390',
#       'source_type': 'website',
#       'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2006.12.10',
#       'version': '10-Dec-06',
#       'acquisition_date': '2006-12-20 00:00:00',
#       'source_comment': '"Zoonomen - Zoological Nomenclature Resource" maintained by Alan P. Peterson at http://www.zoonomen.net',
#       'create_date': '2007-01-23 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Anseriformes'},
#      {'rank': 'Family', 'name': 'Anatidae'},
#      {'rank': 'Subfamily', 'name': 'Anatinae'},
#      {'rank': 'Genus', 'name': 'Melanitta'},
#      {'rank': 'Species', 'name': 'Melanitta fusca'},
#      {'rank': 'Subspecies', 'name': 'Melanitta fusca deglandi'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Anseriformes',
#      'Anatidae',
#      'Anatinae',
#      'Melanitta',
#      'Melanitta fusca',
#      'Melanitta fusca deglandi']},
#    {'tsn': '175167',
#     'nameWInd': 'Melanitta deglandi',
#     'nameWOInd': 'Melanitta deglandi',
#     'unit1': 'Melanitta',
#     'unit2': 'deglandi',
#     'usage': 'invalid',
#     'unacceptReason': 'subsequent name/combination',
#     'credibilityRating': 'TWG standards met',
#     'taxonAuthor': '(Bonaparte, 1850)',
#     'kingdom': 'Animalia',
#     'rankID': '220',
#     'rank': 'Species',
#     'synonyms': ['175165:$Melanitta fusca dixoni$Melanitta deglandi$Melanitta deglandi deglandi$Melanitta deglandi dixoni$'],
#     'synonymTSNs': ['175165:$175166$175167$175168$175169$'],
#     'acceptedTSN': ['175165'],
#     '_version_': 1641159117034749956,
#     'date_created': '1996-06-13 14:51:08',
#     'date_modified': '2007-01-23 00:00:00',
#     'publication': [{'reference_type': 'PUB',
#       'reference_id': '2909',
#       'author': "American Ornithologists' Union",
#       'title': 'Check-list of North American Birds, 5th Edition',
#       'other_variable_0': '1957-01-01 00:00:00',
#       'other_variable_1': '1957-01-01 00:00:00',
#       'other_variable_2': "American Ornithologists' Union",
#       'other_variable_3': 'Baltimore, Maryland, USA',
#       'other_variable_6': 'xiii + 691',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-06-26 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '2916',
#       'author': "American Ornithologists' Union",
#       'title': 'Check-list of North American Birds, 6th Edition',
#       'other_variable_0': '1983-01-01 00:00:00',
#       'other_variable_1': '1983-01-01 00:00:00',
#       'other_variable_2': "American Ornithologists' Union",
#       'other_variable_3': 'Washington, DC, USA',
#       'other_variable_4': '0-943610-32-X',
#       'other_variable_6': 'xxix + 877',
#       'other_variable_8': 'N',
#       'other_variable_9': '2015-10-28 00:00:00'},
#      {'reference_type': 'PUB',
#       'reference_id': '5351',
#       'author': 'Gill, Frank, and Minturn Wright',
#       'title': 'Birds of the World: Recommended English Names',
#       'other_variable_0': '2006-01-01 00:00:00',
#       'other_variable_1': '2006-01-01 00:00:00',
#       'other_variable_2': 'Princeton University Press',
#       'other_variable_3': 'Princeton, New Jersey, USA',
#       'other_variable_4': '0-691-12827-8',
#       'other_variable_6': 'ix + 259',
#       'other_variable_7': 'Includes a CD-ROM with the full dataset',
#       'other_variable_8': 'N',
#       'other_variable_9': '2018-06-26 00:00:00'}],
#     'otherSource': [{'reference_type': 'SRC',
#       'source_id': '7',
#       'source_type': 'database',
#       'source_name': 'NODC Taxonomic Code',
#       'version': '8.0',
#       'acquisition_date': '1996-07-29 00:00:00',
#       'source_comment': '',
#       'create_date': '2010-01-14 00:00:00',
#       'update_date': ''}],
#     'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#      {'rank': 'Subkingdom', 'name': 'Bilateria'},
#      {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#      {'rank': 'Phylum', 'name': 'Chordata'},
#      {'rank': 'Subphylum', 'name': 'Vertebrata'},
#      {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#      {'rank': 'Superclass', 'name': 'Tetrapoda'},
#      {'rank': 'Class', 'name': 'Aves'},
#      {'rank': 'Order', 'name': 'Anseriformes'},
#      {'rank': 'Family', 'name': 'Anatidae'},
#      {'rank': 'Subfamily', 'name': 'Anatinae'},
#      {'rank': 'Genus', 'name': 'Melanitta'},
#      {'rank': 'Species', 'name': 'Melanitta fusca'},
#      {'rank': 'Subspecies', 'name': 'Melanitta fusca deglandi'}],
#     'hierarchy': ['Animalia',
#      'Bilateria',
#      'Deuterostomia',
#      'Chordata',
#      'Vertebrata',
#      'Gnathostomata',
#      'Tetrapoda',
#      'Aves',
#      'Anseriformes',
#      'Anatidae',
#      'Anatinae',
#      'Melanitta',
#      'Melanitta fusca',
#      'Melanitta fusca deglandi'],
#     'commonnames': [{'name': 'White-winged Scoter', 'language': 'English'}]}]}]

# %% [markdown]
# This list indicates a few things:
# 1. There is one case where a source name was misspelled, Equus burchelli should have been Equus quagga burchellii. In this case, the search used the TSN of the misspelled species name to correctly identify the species. ITIS considers the record containing the misspelled name to be invalid and the other record valid, even though they are for the same name.
# 2. In three cases, the names provided were considered invalid or not accepted because ITIS considered the names to be synonyms or junior synonyms of the correct species names.
# 3. In one case, ITIS considered the name provided to be invalid because it was an  “original name/combination”.
# 4. In one case, ITIS considered the name provided to be invalid because it was a “subsequent name/combination”.
#
# In the case of any disagreement between WLCI scientists and the taxonomic authority, both the invalid/not accepted and valid/accepted ITIS names from the WLCI species names list will be used for further consultations with additional systems. Two seperate lists, invalid_itis and valid_itis, will be used to distinguish the invalid/not accepted and valid/accepted ITIS names in these consultations. Any information that results from consultations using the invalid_itis list will be cached separately and evaluated for their utility.

# %%
#Create list containing sciencitific names and ITIS usage classifications
itis_explore = list()
for itis_doc_set in itis_cache:
    for itis_doc in itis_doc_set["itis_data"]:
        itis_explore.append({"scientific_name": itis_doc["nameWInd"],"itis_usage": itis_doc["usage"]})

# %%
#Display the ITIS list of species names and ITIS usage (valid/invalid and accepted/not accepted)
itis_explore
# Out:
# [{'scientific_name': 'Setophaga discolor', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pascopyrum smithii', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lasiurus cinereus semotus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pseudoroegneria spicata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Cronartium ribicola', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lepidochelys olivacea', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pterodroma sandwichensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Anoplopoma fimbria', 'itis_usage': 'valid'},
#  {'scientific_name': 'Gopherus agassizii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Microtus californicus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Tympanuchus pallidicinctus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pinus flexilis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Betula nana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Peromyscus maniculatus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Potorous tridactylus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Kochia prostrata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Bassia prostrata', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Passer domesticus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Tamiasciurus hudsonicus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Buteo jamaicensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Kochia prostrata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Aythya marila', 'itis_usage': 'valid'},
#  {'scientific_name': 'Sterna dougallii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Suaeda maritima', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Buteo regalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Bison bison', 'itis_usage': 'valid'},
#  {'scientific_name': 'Descurainia sophia', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Purshia tridentata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Mergus merganser', 'itis_usage': 'valid'},
#  {'scientific_name': 'Fringilla montifringilla', 'itis_usage': 'valid'},
#  {'scientific_name': 'Hesperostipa comata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Branta canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Artemisia tridentata ssp. wyomingensis',
#   'itis_usage': 'accepted'},
#  {'scientific_name': 'Circus cyaneus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Artemisia cana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Brucella melitensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Brucella abortus', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Puffinus newelli', 'itis_usage': 'valid'},
#  {'scientific_name': 'Shepherdia canadensis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Orgyia pseudotsugata', 'itis_usage': 'valid'},
#  {'scientific_name': 'Gavia stellata', 'itis_usage': 'valid'},
#  {'scientific_name': 'Tamias minimus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Vulpes velox', 'itis_usage': 'valid'},
#  {'scientific_name': 'Agave americana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Rhynchophanes mccownii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Colinus virginianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ursus americanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Eremophila alpestris', 'itis_usage': 'valid'},
#  {'scientific_name': 'Phleum pratense', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lyrurus tetrix', 'itis_usage': 'valid'},
#  {'scientific_name': 'Tetrao tetrix', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Capreolus capreolus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Puccinellia rupestris', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Achnatherum hymenoides', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Canis latrans', 'itis_usage': 'valid'},
#  {'scientific_name': 'Dendroctonus ponderosae', 'itis_usage': 'valid'},
#  {'scientific_name': 'Rangifer tarandus groenlandicus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ictidomys tridecemlineatus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oreoscoptes montanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Thinopyrum ponticum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Morus bassanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Vaccinium membranaceum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Aythya affinis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ursus arctos', 'itis_usage': 'valid'},
#  {'scientific_name': 'Podiceps grisegena', 'itis_usage': 'valid'},
#  {'scientific_name': 'Corvus corax', 'itis_usage': 'valid'},
#  {'scientific_name': 'Prunus virginiana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lanius ludovicianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Atriplex argentea', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Salvelinus namaycush', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ammodramus savannarum', 'itis_usage': 'valid'},
#  {'scientific_name': 'Mallotus villosus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ammodytes marinus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus mykiss', 'itis_usage': 'valid'},
#  {'scientific_name': 'Gavia immer', 'itis_usage': 'valid'},
#  {'scientific_name': 'Microtus agrestis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Cercocarpus montanus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Brachylagus idahoensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Juniperus communis var. depressa',
#   'itis_usage': 'accepted'},
#  {'scientific_name': 'Elymus elymoides', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Ovis canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Cervus elaphus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Antilocapra americana', 'itis_usage': 'valid'},
#  {'scientific_name': 'Medicago sativa', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lepus townsendii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus clarkii pleuriticus',
#   'itis_usage': 'valid'},
#  {'scientific_name': 'Arctostaphylos patula', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Krascheninnikovia lanata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Sphaeralcea coccinea', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Artemisiospiza belli', 'itis_usage': 'valid'},
#  {'scientific_name': 'Amphispiza belli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Pinus contorta', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Juniperus communis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Taxidea taxus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Clupea pallasii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Clupea pallasi', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Thrichomys pachyurus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Thrichomys fosteri', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Buteo swainsoni', 'itis_usage': 'valid'},
#  {'scientific_name': 'Clangula hyemalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Equus quagga burchellii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Equus burchelli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Bromus tectorum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Atriplex gardneri', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Atriplex canescens', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Pseudotsuga menziesii', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Vulpes vulpes', 'itis_usage': 'valid'},
#  {'scientific_name': 'Zea mays', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Falco mexicanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Sarcobatus vermiculatus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Clupea pallasii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Glaucomys volans', 'itis_usage': 'valid'},
#  {'scientific_name': 'Rangifer tarandus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Melanitta perspicillata', 'itis_usage': 'valid'},
#  {'scientific_name': 'Branta leucopsis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus gorbuscha', 'itis_usage': 'valid'},
#  {'scientific_name': 'Panicum virgatum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Myotis sodalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Lasiurus cinereus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Xerospermophilus mohavensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Peromyscus keeni', 'itis_usage': 'valid'},
#  {'scientific_name': 'Elymus lanceolatus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Populus tremuloides', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Festuca idahoensis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Macaca sylvanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Schoenoplectus acutus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Artemisia tridentata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Grus canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Odocoileus hemionus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Bombus griseocollis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Lasiurus borealis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Cottus bairdii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Canis lupus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Leymus cinereus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Centrocercus minimus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus nerka', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pelecanus occidentalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Aquila chrysaetos', 'itis_usage': 'valid'},
#  {'scientific_name': 'Myotis septentrionalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Halogeton glomeratus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Centrocercus urophasianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Urocitellus armatus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Grus americana', 'itis_usage': 'valid'},
#  {'scientific_name': 'Amelanchier alnifolia', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Pinus albicaulis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Procapra gutturosa', 'itis_usage': 'valid'},
#  {'scientific_name': 'Gymnogyps californianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Connochaetes taurinus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Abies lasiocarpa', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Procyon lotor', 'itis_usage': 'valid'},
#  {'scientific_name': 'Castor canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Alces alces', 'itis_usage': 'valid'},
#  {'scientific_name': 'Haliaeetus leucocephalus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ericameria nauseosa', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lullula arborea', 'itis_usage': 'valid'},
#  {'scientific_name': 'Dendroctonus pseudotsugae', 'itis_usage': 'valid'},
#  {'scientific_name': 'Artemisiospiza nevadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus tshawytscha', 'itis_usage': 'valid'},
#  {'scientific_name': 'Falco sparverius', 'itis_usage': 'valid'},
#  {'scientific_name': 'Picea engelmannii', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Reithrodontomys megalotis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Spizella breweri', 'itis_usage': 'valid'},
#  {'scientific_name': 'Catostomus platyrhynchus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus clarkii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Otis tarda', 'itis_usage': 'valid'},
#  {'scientific_name': 'Amorpha canescens', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Apis mellifera', 'itis_usage': 'valid'},
#  {'scientific_name': 'Cercocarpus ledifolius', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Melanitta fusca deglandi', 'itis_usage': 'valid'},
#  {'scientific_name': 'Melanitta deglandi', 'itis_usage': 'invalid'}]

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("cache/itis_explore.json", itis_explore))

# %%
#Create list of specie names considered invalid or not accepted by ITIS
invalid_itis=[i for i in itis_explore if i['itis_usage'] == 'invalid']
invalid_itis.extend([i for i in itis_explore if i['itis_usage'] == 'not accepted'])

# %%
#Display list of specie names considered invalid or not accepted by ITIS
invalid_itis
# Out:
# [{'scientific_name': 'Brucella abortus', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Tetrao tetrix', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Amphispiza belli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Clupea pallasi', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Thrichomys fosteri', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Equus burchelli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Melanitta deglandi', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Bassia prostrata', 'itis_usage': 'not accepted'}]

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("cache/invalid_itis.json", invalid_itis))
# Out:
# {'Doc Cache File': 'cache/invalid_itis.json',
#  'Number of Documents in Cache': 8,
#  'Document Number 7': {'scientific_name': 'Bassia prostrata',
#   'itis_usage': 'not accepted'}}

# %%
#Create an updated list of species names considered valid or accepted by ITIS
updated_itis=[e for e in itis_explore if e['scientific_name'] not in {'Amphispiza belli','Thrichomys fosteri','Tetrao tetrix','Brucella abortus','Equus burchelli','Bassia prostrata'}]
len(updated_itis)
# Out:
# 164

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("cache/valid_itis.json", updated_itis))
# Out:
# {'Doc Cache File': 'cache/valid_itis.json',
#  'Number of Documents in Cache': 164,
#  'Document Number 62': {'scientific_name': 'Corvus corax',
#   'itis_usage': 'valid'}}

# %% [markdown]
# Here we examine the geographic division and jurisdiction information provided by ITIS for each species record to better understand the geographical ranges and jurisdictions of the species included in the species name list created in the Build Species List notebook.
#
# First we create a set of lists, one that includes species whose designated geographic values are listed as "North America" and another that includes species with their jurisdictions listed "Coninental US". Both of these lists are intended to represent the species that might encompass the WLCI boundary.
#
# Then we create another set of lists, one that includes species whose designated geographic values are listed as places other than "North America" and another that includes species with their jurisdictions listed as areas other than the "Continental US". These lists are intended to indicate species that may not be appropriate to include in the WLCI species list.

# %%
#Create a list that includes only the tsn number, scientific name, geographic division information, and jurisdiction information. 
geo_info=[]
for item in itis_cache:
    for record in item['itis_data']:
        tsn=record['tsn']
        scientific_name=record['nameWInd']
        itis_usage=record['usage']
        if 'geographicDivision' in record:
            geo_division=record['geographicDivision']
        if 'jurisdiction' in record:
            jurisdiction=record['jurisdiction']
            geo_info.append({'tsn':tsn, 'scientific_name':scientific_name,'itis_usage':itis_usage, 'geo_division':geo_division,'jurisdiction':jurisdiction})

# %% [markdown]
# Here we look at the species records with geographic values listed as "North America"

# %%
#Create a list which only includes tsn number, scientific name, and geographic value information.
geographic_value=[]
for record in geo_info:
    tsn=record['tsn']
    scientific_name=record['scientific_name']
    for item in record['geo_division']:
        geo_value=item['geographic_value']
        geographic_value.append({'tsn':tsn, 'scientific_name':scientific_name, 'geo_value':geo_value})

# %%
#Select all records that list the geographic value as "North America"
north_america=[i for i in geographic_value if i['geo_value'] in 'North America']

# %%
north_america
# Out:
# [{'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'geo_value': 'North America'},
#  {'tsn': '504637',
#   'scientific_name': 'Pseudoroegneria spicata',
#   'geo_value': 'North America'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'North America'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'geo_value': 'North America'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'geo_value': 'North America'},
#  {'tsn': '175838',
#   'scientific_name': 'Tympanuchus pallidicinctus',
#   'geo_value': 'North America'},
#  {'tsn': '183343',
#   'scientific_name': 'Pinus flexilis',
#   'geo_value': 'North America'},
#  {'tsn': '19479',
#   'scientific_name': 'Betula nana',
#   'geo_value': 'North America'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'geo_value': 'North America'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'geo_value': 'North America'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'geo_value': 'North America'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'geo_value': 'North America'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'geo_value': 'North America'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'geo_value': 'North America'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'North America'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'geo_value': 'North America'},
#  {'tsn': '20662',
#   'scientific_name': 'Suaeda maritima',
#   'geo_value': 'North America'},
#  {'tsn': '175377',
#   'scientific_name': 'Buteo regalis',
#   'geo_value': 'North America'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'geo_value': 'North America'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'geo_value': 'North America'},
#  {'tsn': '25290',
#   'scientific_name': 'Purshia tridentata',
#   'geo_value': 'North America'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'geo_value': 'North America'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'geo_value': 'North America'},
#  {'tsn': '507974',
#   'scientific_name': 'Hesperostipa comata',
#   'geo_value': 'North America'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '183741',
#   'scientific_name': 'Artemisia tridentata ssp. wyomingensis',
#   'geo_value': 'North America'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'geo_value': 'North America'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'geo_value': 'North America'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'geo_value': 'North America'},
#  {'tsn': '180195',
#   'scientific_name': 'Tamias minimus',
#   'geo_value': 'North America'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'geo_value': 'North America'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'geo_value': 'North America'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'geo_value': 'North America'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'geo_value': 'North America'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'geo_value': 'North America'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'geo_value': 'North America'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'geo_value': 'North America'},
#  {'tsn': '41223',
#   'scientific_name': 'Puccinellia rupestris',
#   'geo_value': 'North America'},
#  {'tsn': '507943',
#   'scientific_name': 'Achnatherum hymenoides',
#   'geo_value': 'North America'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'geo_value': 'North America'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'geo_value': 'North America'},
#  {'tsn': '898935',
#   'scientific_name': 'Rangifer tarandus groenlandicus',
#   'geo_value': 'North America'},
#  {'tsn': '930308',
#   'scientific_name': 'Ictidomys tridecemlineatus',
#   'geo_value': 'North America'},
#  {'tsn': '178654',
#   'scientific_name': 'Oreoscoptes montanus',
#   'geo_value': 'North America'},
#  {'tsn': '174712',
#   'scientific_name': 'Morus bassanus',
#   'geo_value': 'North America'},
#  {'tsn': '23601',
#   'scientific_name': 'Vaccinium membranaceum',
#   'geo_value': 'North America'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'geo_value': 'North America'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'geo_value': 'North America'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'North America'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'North America'},
#  {'tsn': '24806',
#   'scientific_name': 'Prunus virginiana',
#   'geo_value': 'North America'},
#  {'tsn': '178515',
#   'scientific_name': 'Lanius ludovicianus',
#   'geo_value': 'North America'},
#  {'tsn': '20512',
#   'scientific_name': 'Atriplex argentea',
#   'geo_value': 'North America'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'geo_value': 'North America'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'North America'},
#  {'tsn': '162035',
#   'scientific_name': 'Mallotus villosus',
#   'geo_value': 'North America'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'North America'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'geo_value': 'North America'},
#  {'tsn': '25136',
#   'scientific_name': 'Cercocarpus montanus',
#   'geo_value': 'North America'},
#  {'tsn': '552521',
#   'scientific_name': 'Brachylagus idahoensis',
#   'geo_value': 'North America'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'geo_value': 'North America'},
#  {'tsn': '502264',
#   'scientific_name': 'Elymus elymoides',
#   'geo_value': 'North America'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'North America'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'geo_value': 'North America'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'geo_value': 'North America'},
#  {'tsn': '180118',
#   'scientific_name': 'Lepus townsendii',
#   'geo_value': 'North America'},
#  {'tsn': '553429',
#   'scientific_name': 'Oncorhynchus clarkii pleuriticus',
#   'geo_value': 'North America'},
#  {'tsn': '23512',
#   'scientific_name': 'Arctostaphylos patula',
#   'geo_value': 'North America'},
#  {'tsn': '503290',
#   'scientific_name': 'Krascheninnikovia lanata',
#   'geo_value': 'North America'},
#  {'tsn': '21920',
#   'scientific_name': 'Sphaeralcea coccinea',
#   'geo_value': 'North America'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'geo_value': 'North America'},
#  {'tsn': '179402',
#   'scientific_name': 'Amphispiza belli',
#   'geo_value': 'North America'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'geo_value': 'North America'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'geo_value': 'North America'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'geo_value': 'North America'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'geo_value': 'North America'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'North America'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'geo_value': 'North America'},
#  {'tsn': '20531',
#   'scientific_name': 'Atriplex gardneri',
#   'geo_value': 'North America'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'geo_value': 'North America'},
#  {'tsn': '183424',
#   'scientific_name': 'Pseudotsuga menziesii',
#   'geo_value': 'North America'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'North America'},
#  {'tsn': '42269', 'scientific_name': 'Zea mays', 'geo_value': 'North America'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'geo_value': 'North America'},
#  {'tsn': '20707',
#   'scientific_name': 'Sarcobatus vermiculatus',
#   'geo_value': 'North America'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'geo_value': 'North America'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'geo_value': 'North America'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'geo_value': 'North America'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'geo_value': 'North America'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'geo_value': 'North America'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'geo_value': 'North America'},
#  {'tsn': '180001',
#   'scientific_name': 'Myotis sodalis',
#   'geo_value': 'North America'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'North America'},
#  {'tsn': '930310',
#   'scientific_name': 'Xerospermophilus mohavensis',
#   'geo_value': 'North America'},
#  {'tsn': '552497',
#   'scientific_name': 'Peromyscus keeni',
#   'geo_value': 'North America'},
#  {'tsn': '502267',
#   'scientific_name': 'Elymus lanceolatus',
#   'geo_value': 'North America'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'geo_value': 'North America'},
#  {'tsn': '40816',
#   'scientific_name': 'Festuca idahoensis',
#   'geo_value': 'North America'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'geo_value': 'North America'},
#  {'tsn': '35498',
#   'scientific_name': 'Artemisia tridentata',
#   'geo_value': 'North America'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'North America'},
#  {'tsn': '714807',
#   'scientific_name': 'Bombus griseocollis',
#   'geo_value': 'North America'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'North America'},
#  {'tsn': '167237',
#   'scientific_name': 'Cottus bairdii',
#   'geo_value': 'North America'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'North America'},
#  {'tsn': '503433',
#   'scientific_name': 'Leymus cinereus',
#   'geo_value': 'North America'},
#  {'tsn': '677540',
#   'scientific_name': 'Centrocercus minimus',
#   'geo_value': 'North America'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'geo_value': 'North America'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'geo_value': 'North America'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'geo_value': 'North America'},
#  {'tsn': '180000',
#   'scientific_name': 'Myotis septentrionalis',
#   'geo_value': 'North America'},
#  {'tsn': '20692',
#   'scientific_name': 'Halogeton glomeratus',
#   'geo_value': 'North America'},
#  {'tsn': '175855',
#   'scientific_name': 'Centrocercus urophasianus',
#   'geo_value': 'North America'},
#  {'tsn': '930314',
#   'scientific_name': 'Urocitellus armatus',
#   'geo_value': 'North America'},
#  {'tsn': '176176',
#   'scientific_name': 'Grus americana',
#   'geo_value': 'North America'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'geo_value': 'North America'},
#  {'tsn': '183311',
#   'scientific_name': 'Pinus albicaulis',
#   'geo_value': 'North America'},
#  {'tsn': '175274',
#   'scientific_name': 'Gymnogyps californianus',
#   'geo_value': 'North America'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'geo_value': 'North America'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'North America'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'geo_value': 'North America'},
#  {'tsn': '507594',
#   'scientific_name': 'Ericameria nauseosa',
#   'geo_value': 'North America'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'geo_value': 'North America'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'geo_value': 'North America'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'geo_value': 'North America'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'North America'},
#  {'tsn': '183291',
#   'scientific_name': 'Picea engelmannii',
#   'geo_value': 'North America'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'geo_value': 'North America'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'geo_value': 'North America'},
#  {'tsn': '163909',
#   'scientific_name': 'Catostomus platyrhynchus',
#   'geo_value': 'North America'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'geo_value': 'North America'},
#  {'tsn': '25371',
#   'scientific_name': 'Amorpha canescens',
#   'geo_value': 'North America'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'North America'},
#  {'tsn': '25134',
#   'scientific_name': 'Cercocarpus ledifolius',
#   'geo_value': 'North America'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'geo_value': 'North America'}]

# %% [markdown]
# Here we look at the species records with jurisdiction information listed as "Continental US"

# %%
#Create list which only contains the tsn number, scientific name, jurisdiction information, and origin information
jurisdiction_info=[]
for record in geo_info:
    tsn=record['tsn']
    scientific_name=record['scientific_name']
    for item in record['jurisdiction']:
        jurisdiction=item['jurisdiction_value']
        origin=item['origin']
        jurisdiction_info.append({'tsn':tsn,'scientific_name':scientific_name,'jurisdiction':jurisdiction, 'origin':origin})

# %%
#Select all records that list the jurisdiction as "Continental US"
continental_us=[i for i in jurisdiction_info if i['jurisdiction'] == 'Continental US']

# %%
continental_us
# Out:
# [{'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '504637',
#   'scientific_name': 'Pseudoroegneria spicata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175838',
#   'scientific_name': 'Tympanuchus pallidicinctus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183343',
#   'scientific_name': 'Pinus flexilis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20662',
#   'scientific_name': 'Suaeda maritima',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175377',
#   'scientific_name': 'Buteo regalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '25290',
#   'scientific_name': 'Purshia tridentata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '507974',
#   'scientific_name': 'Hesperostipa comata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183741',
#   'scientific_name': 'Artemisia tridentata ssp. wyomingensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180195',
#   'scientific_name': 'Tamias minimus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '41223',
#   'scientific_name': 'Puccinellia rupestris',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '507943',
#   'scientific_name': 'Achnatherum hymenoides',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '930308',
#   'scientific_name': 'Ictidomys tridecemlineatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '178654',
#   'scientific_name': 'Oreoscoptes montanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174712',
#   'scientific_name': 'Morus bassanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '23601',
#   'scientific_name': 'Vaccinium membranaceum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '24806',
#   'scientific_name': 'Prunus virginiana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '178515',
#   'scientific_name': 'Lanius ludovicianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20512',
#   'scientific_name': 'Atriplex argentea',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '162035',
#   'scientific_name': 'Mallotus villosus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '25136',
#   'scientific_name': 'Cercocarpus montanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '552521',
#   'scientific_name': 'Brachylagus idahoensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '502264',
#   'scientific_name': 'Elymus elymoides',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '180118',
#   'scientific_name': 'Lepus townsendii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '553429',
#   'scientific_name': 'Oncorhynchus clarkii pleuriticus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '23512',
#   'scientific_name': 'Arctostaphylos patula',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503290',
#   'scientific_name': 'Krascheninnikovia lanata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '21920',
#   'scientific_name': 'Sphaeralcea coccinea',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179402',
#   'scientific_name': 'Amphispiza belli',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '20531',
#   'scientific_name': 'Atriplex gardneri',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183424',
#   'scientific_name': 'Pseudotsuga menziesii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '42269',
#   'scientific_name': 'Zea mays',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20707',
#   'scientific_name': 'Sarcobatus vermiculatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180001',
#   'scientific_name': 'Myotis sodalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '930310',
#   'scientific_name': 'Xerospermophilus mohavensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '502267',
#   'scientific_name': 'Elymus lanceolatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '40816',
#   'scientific_name': 'Festuca idahoensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '35498',
#   'scientific_name': 'Artemisia tridentata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '714807',
#   'scientific_name': 'Bombus griseocollis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '167237',
#   'scientific_name': 'Cottus bairdii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503433',
#   'scientific_name': 'Leymus cinereus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '677540',
#   'scientific_name': 'Centrocercus minimus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180000',
#   'scientific_name': 'Myotis septentrionalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20692',
#   'scientific_name': 'Halogeton glomeratus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '175855',
#   'scientific_name': 'Centrocercus urophasianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '930314',
#   'scientific_name': 'Urocitellus armatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '176176',
#   'scientific_name': 'Grus americana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183311',
#   'scientific_name': 'Pinus albicaulis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175274',
#   'scientific_name': 'Gymnogyps californianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '507594',
#   'scientific_name': 'Ericameria nauseosa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183291',
#   'scientific_name': 'Picea engelmannii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '163909',
#   'scientific_name': 'Catostomus platyrhynchus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '25371',
#   'scientific_name': 'Amorpha canescens',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '25134',
#   'scientific_name': 'Cercocarpus ledifolius',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'}]

# %% [markdown]
# Here we look at the species with geographic values listed as places other than "North America"

# %%
not_north_america=[e for e in geographic_value if e['geo_value'] not in 'North America']

# %%
not_north_america
# Out:
# [{'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'geo_value': 'Caribbean'},
#  {'tsn': '202344',
#   'scientific_name': 'Lasiurus cinereus semotus',
#   'geo_value': 'Oceania'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Middle America'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Oceania'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Africa'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Australia'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Caribbean'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'East Pacific'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Eastern Atlantic Ocean'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'South America'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Western Atlantic Ocean'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'geo_value': 'Middle America'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'geo_value': 'Middle America'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'geo_value': 'Oceania'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '175130', 'scientific_name': 'Aythya marila', 'geo_value': 'Oceania'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'geo_value': 'Caribbean'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'geo_value': 'Middle America'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'geo_value': 'Oceania'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'geo_value': 'Oceania'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'geo_value': 'Africa'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'geo_value': 'Oceania'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'geo_value': 'Oceania'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'geo_value': 'Middle America'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'geo_value': 'Caribbean'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'geo_value': 'Oceania'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'geo_value': 'Middle America'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'geo_value': 'Middle America'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'geo_value': 'Oceania'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'geo_value': 'South America'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'geo_value': 'Middle America'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'geo_value': 'Middle America'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'geo_value': 'Middle America'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Oceania'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Africa'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'Middle America'},
#  {'tsn': '179725', 'scientific_name': 'Corvus corax', 'geo_value': 'Africa'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'Middle America'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'Caribbean'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'South America'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Western Atlantic Ocean'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'East Pacific'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Oceania'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'South America'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '180695', 'scientific_name': 'Cervus elaphus', 'geo_value': 'Africa'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Australia'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'geo_value': 'Oceania'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'geo_value': 'Middle America'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'geo_value': 'Oceania'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'geo_value': 'Caribbean'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'geo_value': 'Middle America'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'geo_value': 'Middle America'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'East Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'Oceania'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'geo_value': 'Oceania'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'geo_value': 'South America'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'geo_value': 'Oceania'},
#  {'tsn': '180604', 'scientific_name': 'Vulpes vulpes', 'geo_value': 'Africa'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'Australia'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '42269', 'scientific_name': 'Zea mays', 'geo_value': 'Caribbean'},
#  {'tsn': '42269', 'scientific_name': 'Zea mays', 'geo_value': 'South America'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'geo_value': 'Middle America'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'East Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'geo_value': 'Middle America'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'geo_value': 'Middle America'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'geo_value': 'Oceania'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'geo_value': 'East Pacific'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'geo_value': 'Oceania'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'South America'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'Oceania'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'geo_value': 'Oceania'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'South America'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'Oceania'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'Middle America'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'South America'},
#  {'tsn': '180596', 'scientific_name': 'Canis lupus', 'geo_value': 'Australia'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'geo_value': 'Oceania'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'Middle America'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'South America'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'South America'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'geo_value': 'Middle America'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'geo_value': 'East Pacific'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'Middle America'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'South America'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'geo_value': 'Middle America'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'geo_value': 'Middle America'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'geo_value': 'East Pacific'},
#  {'tsn': '154396', 'scientific_name': 'Apis mellifera', 'geo_value': 'Africa'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Australia'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Caribbean'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Middle America'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Oceania'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'South America'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Southern Asia'}]

# %% [markdown]
# Here we look at species with jurisdiction information listed as areas other than the "Continental US"

# %%
not_continental_us=[e for e in jurisdiction_info if e['jurisdiction'] not in 'Continental US']

# %%
not_continental_us
# Out:
# [{'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '202344',
#   'scientific_name': 'Lasiurus cinereus semotus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '504637',
#   'scientific_name': 'Pseudoroegneria spicata',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '183343',
#   'scientific_name': 'Pinus flexilis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '19479',
#   'scientific_name': 'Betula nana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '19479',
#   'scientific_name': 'Betula nana',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Central Pacific Territories',
#   'origin': 'Incidental'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '20662',
#   'scientific_name': 'Suaeda maritima',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175377',
#   'scientific_name': 'Buteo regalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '25290',
#   'scientific_name': 'Purshia tridentata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180195',
#   'scientific_name': 'Tamias minimus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '898935',
#   'scientific_name': 'Rangifer tarandus groenlandicus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '930308',
#   'scientific_name': 'Ictidomys tridecemlineatus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '178654',
#   'scientific_name': 'Oreoscoptes montanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174712',
#   'scientific_name': 'Morus bassanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '23601',
#   'scientific_name': 'Vaccinium membranaceum',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '24806',
#   'scientific_name': 'Prunus virginiana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '178515',
#   'scientific_name': 'Lanius ludovicianus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '20512',
#   'scientific_name': 'Atriplex argentea',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '162035',
#   'scientific_name': 'Mallotus villosus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native & Introduced'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '180118',
#   'scientific_name': 'Lepus townsendii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '503290',
#   'scientific_name': 'Krascheninnikovia lanata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '21920',
#   'scientific_name': 'Sphaeralcea coccinea',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '179402',
#   'scientific_name': 'Amphispiza belli',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '20531',
#   'scientific_name': 'Atriplex gardneri',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '183424',
#   'scientific_name': 'Pseudotsuga menziesii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '42269',
#   'scientific_name': 'Zea mays',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '20707',
#   'scientific_name': 'Sarcobatus vermiculatus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Incidental'},
#  {'tsn': '552497',
#   'scientific_name': 'Peromyscus keeni',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '552497',
#   'scientific_name': 'Peromyscus keeni',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '502267',
#   'scientific_name': 'Elymus lanceolatus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '35498',
#   'scientific_name': 'Artemisia tridentata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '714807',
#   'scientific_name': 'Bombus griseocollis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '167237',
#   'scientific_name': 'Cottus bairdii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '180000',
#   'scientific_name': 'Myotis septentrionalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175855',
#   'scientific_name': 'Centrocercus urophasianus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176176',
#   'scientific_name': 'Grus americana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '183311',
#   'scientific_name': 'Pinus albicaulis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '507594',
#   'scientific_name': 'Ericameria nauseosa',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '183291',
#   'scientific_name': 'Picea engelmannii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '163909',
#   'scientific_name': 'Catostomus platyrhynchus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native & Introduced'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '25371',
#   'scientific_name': 'Amorpha canescens',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'}]
