# %%
import json

taxonomy_lookup = []

# %%
def get_wlci_xdd_cache():
    '''
    description: Import WLCI xdd species cached data 
    '''
    with open("../sources/WLCI_Species_List_from_Literature.json", "r") as f:
        wlci_sp_mentions = json.loads(f.read())
    return wlci_sp_mentions

def get_wlci_xdd_info(name):
    '''
    description: Extract summary information for a provided species from the WLCI_Species_List_from_Literature.json file.
    This information summarizes mentions of scientific names from WLCI literature included in the xDD database.
    '''
    wlci_sp_mentions = get_wlci_xdd_cache()
    unique_wlci_xdd_articles = list(set([spp["xdd_id"] for spp in wlci_sp_mentions]))
    
    wlci_xdd_info = dict()
    name_mentions = [i for i in wlci_sp_mentions if i['Scientific Name']==name]
    count_hits = sum(int(mention['n_hits']) for mention in name_mentions)
    doi_list = list(set([mention['doi'] for mention in name_mentions]))
    wlci_xdd_info['scientific_name'] = name
    #Percent of wlci_xdd articles that mention the specie "name"
    wlci_xdd_info['wlci_xdd_per'] = len(doi_list)/len(unique_wlci_xdd_articles)*100
    wlci_xdd_info['wlci_xdd_hits'] = count_hits
    wlci_xdd_info['wlci_xdd_doi_list'] = doi_list
    return wlci_xdd_info

def get_xdd_snippets(name, xdd_snippet_cache):
    '''
    description: Pull count and api to access xDD snippets for species of interest.
    '''
    xdd_snippets = dict()

    record = [i for i in xdd_snippet_cache if i['parameters']['Search Term']==name if i['data']] 
    if len(record) > 0:
        record = record[0] #tested for only 1 record per specie name, one duplicate existed but all data other than timestamp was same so ignored
        xdd_snippets['xdd_snippet_api'] = record['processing_metadata']['api']
        xdd_snippets['xdd_snippet_doc_ct'] = len(record['data'])
    
    return xdd_snippets

# %%
#Import ITIS Cache and grabs summary information for a species
def itis_summary(specie_name, itis_cache):
    '''
    description: Extract summary information for a provided species from the itis.json file.
    This information summarizes relevant ITIS information.
    '''

    record = [i for i in itis_cache if i['parameters']['Scientific Name']==specie_name][0]
    itis_data = dict()
    for itis_entry in record['data']:
        itis_related_tsn =[]
        if itis_entry['usage'] == 'valid' or itis_entry['usage'] == 'accepted':
            itis_data['itis_tsn'] = itis_entry['tsn']
            itis_data['itis_tsn_usage'] = itis_entry['usage']
            for level in itis_entry['biological_taxonomy']:
                l = level['rank']
                field = f'itis_{l}'
                bio_tax_value = level['name']
                itis_data[field]= bio_tax_value
            if 'commonnames' in itis_entry:
                itis_data['itis_common_names'] = list(set([nm['name'] for nm in itis_entry['commonnames'] if nm['language']=='English']))
        else:
            itis_related_tsn.append(itis_entry['tsn'])
        if len(itis_related_tsn)>0:
            itis_data['itis_related_tsn'] = itis_related_tsn
        if 'geographicDivision' in itis_entry:
            itis_data['itis_geographic_division']= list(set([i['geographic_value'] for i in itis_entry['geographicDivision']]))
        if 'jurisdiction' in itis_entry:
            itis_data['itis_native_to']=list(set([i['jurisdiction_value'] for i in itis_entry['jurisdiction'] if i['origin']=='Native']))

    else:
        itis_tsn = record['data'][0]['tsn']
        
    return itis_data

# %%
#Import SGCN Cache and grabs summary information for a species
def sgcn_summary(specie_name, sgcn_cache):
    '''
    description: Extract summary information for a provided species from the sgcn.json file.
    '''
    sgcn_data = dict()
    
    record = [i for i in sgcn_cache if i['parameters']['Scientific Name']==name if i['data']] 
    if len(record) > 0:
        record = record[0] #tested for only 1 record per specie name, one duplicate existed but all data other than timestamp was same so ignored
        sgcn_data['sgcn_statelist_2005']= record['data']['statelist_2005']
        sgcn_data['sgcn_statelist_2015']= record['data']['statelist_2015']
        sgcn_data['sgcn_reference']=record['processing_metadata']['api']
    return sgcn_data

# %%
#Read in the data
with open('../cache/xdd.json', 'r') as f:
    xdd_snippet_cache = json.loads(f.read())

with open('../cache/sgcn.json', 'r') as f:
        sgcn_cache = json.loads(f.read())

with open('../cache/itis.json', 'r') as f:
    itis_cache = json.loads(f.read())

# %%
wlci_sp_mentions = get_wlci_xdd_cache()
sci_name_list = list(set([spp["Scientific Name"] for spp in wlci_sp_mentions]))

for name in sci_name_list:
    specie_document = dict()
    
    wlci_xdd_info = get_wlci_xdd_info(name)
    specie_document.update(wlci_xdd_info)
    
    itis_data = itis_summary(name, itis_cache) 
    specie_document.update(itis_data)
    
    sgcn_data = sgcn_summary(name, sgcn_cache)
    specie_document.update(sgcn_data)
    
    xdd_snippets = get_xdd_snippets(name, xdd_snippet_cache)
    specie_document.update(xdd_snippets)
    
    taxonomy_lookup.append(specie_document)

# %%
taxonomy_lookup
# Out:
# [{'scientific_name': 'Reithrodontomys megalotis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 3,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12513'],
#   'itis_tsn': '180343',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Rodentia',
#   'itis_Suborder': 'Myomorpha',
#   'itis_Superfamily': 'Muroidea',
#   'itis_Family': 'Cricetidae',
#   'itis_Subfamily': 'Neotominae',
#   'itis_Genus': 'Reithrodontomys',
#   'itis_Subgenus': 'Reithrodontomys (Reithrodontomys)',
#   'itis_Species': 'Reithrodontomys megalotis',
#   'itis_common_names': ['Western Harvest Mouse'],
#   'itis_geographic_division': ['North America', 'Middle America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada'],
#   'sgcn_statelist_2005': 'Arkansas,California,Minnesota',
#   'sgcn_statelist_2015': 'Arkansas,California,Minnesota',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Reithrodontomys megalotis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Reithrodontomys megalotis',
#   'xdd_snippet_doc_ct': 320},
#  {'scientific_name': 'Schoenoplectus acutus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '507785',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Lilianae',
#   'itis_Order': 'Poales',
#   'itis_Family': 'Cyperaceae',
#   'itis_Genus': 'Schoenoplectus',
#   'itis_Species': 'Schoenoplectus acutus',
#   'itis_common_names': ['hardstem bulrush'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada', 'Alaska'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Schoenoplectus acutus',
#   'xdd_snippet_doc_ct': 138},
#  {'scientific_name': 'Buteo regalis',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1016/j.ecolind.2017.12.033',
#    '10.3133/ofr20161147'],
#   'itis_tsn': '175377',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Accipitriformes',
#   'itis_Family': 'Accipitridae',
#   'itis_Genus': 'Buteo',
#   'itis_Species': 'Buteo regalis',
#   'itis_common_names': ['Ferruginous Hawk'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'Arizona,California,Colorado,Idaho,Kansas,Montana,Nebraska,Nevada,New Mexico,North Dakota,Oklahoma,Oregon,South Dakota,Texas,Utah,Washington,Wyoming',
#   'sgcn_statelist_2015': 'Arizona,Colorado,Idaho,Kansas,Nebraska,Nevada,North Dakota,Oklahoma,Oregon,South Dakota,Texas,Utah,Washington,Wyoming',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Buteo regalis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Buteo regalis',
#   'xdd_snippet_doc_ct': 185},
#  {'scientific_name': 'Pterodroma sandwichensis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '562561',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Procellariiformes',
#   'itis_Family': 'Procellariidae',
#   'itis_Genus': 'Pterodroma',
#   'itis_Species': 'Pterodroma sandwichensis',
#   'itis_common_names': ['Hawaiian Petrel', 'Hawaiian Dark-rumped Petrel'],
#   'sgcn_statelist_2005': 'Hawaii',
#   'sgcn_statelist_2015': 'Hawaii',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Pterodroma sandwichensis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Pterodroma sandwichensis',
#   'xdd_snippet_doc_ct': 28},
#  {'scientific_name': 'Betula nana',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 3,
#   'wlci_xdd_doi_list': ['10.1111/gcb.12852'],
#   'itis_tsn': '19479',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Rosanae',
#   'itis_Order': 'Fagales',
#   'itis_Family': 'Betulaceae',
#   'itis_Genus': 'Betula',
#   'itis_Species': 'Betula nana',
#   'itis_common_names': ['bog birch', 'dwarf birch', 'shrub birch'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Canada', 'Alaska'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Betula nana',
#   'xdd_snippet_doc_ct': 2437},
#  {'scientific_name': 'Passer domesticus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1002/jwmg.155'],
#   'itis_tsn': '179628',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Passeriformes',
#   'itis_Family': 'Passeridae',
#   'itis_Genus': 'Passer',
#   'itis_Species': 'Passer domesticus',
#   'itis_common_names': ['House Sparrow'],
#   'itis_geographic_division': ['Oceania', 'North America', 'Caribbean'],
#   'itis_native_to': [],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Passer domesticus',
#   'xdd_snippet_doc_ct': 5363},
#  {'scientific_name': 'Puffinus newelli',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '202223',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Procellariiformes',
#   'itis_Family': 'Procellariidae',
#   'itis_Genus': 'Puffinus',
#   'itis_Species': 'Puffinus newelli',
#   'itis_common_names': ["Newell's Shearwater"],
#   'sgcn_statelist_2005': 'Hawaii',
#   'sgcn_statelist_2015': 'Hawaii',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Puffinus newelli',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Puffinus newelli',
#   'xdd_snippet_doc_ct': 7},
#  {'scientific_name': 'Sterna dougallii',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '176891',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Charadriiformes',
#   'itis_Family': 'Laridae',
#   'itis_Genus': 'Sterna',
#   'itis_Species': 'Sterna dougallii',
#   'itis_common_names': ['Roseate Tern'],
#   'itis_geographic_division': ['North America', 'Caribbean'],
#   'itis_native_to': ['Caribbean Territories', 'Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'Connecticut,Florida,Maine,Maryland,Massachusetts,New Hampshire,New Jersey,New York,Puerto Rico,Rhode Island,Virginia',
#   'sgcn_statelist_2015': 'Connecticut,Delaware,Florida,Maine,Maryland,Massachusetts,New Hampshire,New York,Rhode Island',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Sterna dougallii',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Sterna dougallii',
#   'xdd_snippet_doc_ct': 357},
#  {'scientific_name': 'Artemisiospiza nevadensis',
#   'wlci_xdd_per': 13.793103448275861,
#   'wlci_xdd_hits': 8,
#   'wlci_xdd_doi_list': ['10.1016/j.biocon.2018.10.020',
#    '10.1016/j.biocon.2015.02.009',
#    '10.1111/1365-2664.12513',
#    '10.3133/ofr20161147'],
#   'itis_tsn': '997723',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Passeriformes',
#   'itis_Family': 'Emberizidae',
#   'itis_Genus': 'Artemisiospiza',
#   'itis_Species': 'Artemisiospiza nevadensis',
#   'itis_common_names': ['Sagebrush Sparrow'],
#   'itis_geographic_division': ['Middle America', 'North America'],
#   'itis_native_to': ['Continental US', 'Mexico'],
#   'sgcn_statelist_2005': '',
#   'sgcn_statelist_2015': 'Idaho,New Mexico,Oregon,Washington',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Artemisiospiza nevadensis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Artemisiospiza nevadensis',
#   'xdd_snippet_doc_ct': 17},
#  {'scientific_name': 'Zea mays',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1002/ece3.3607'],
#   'itis_tsn': '42269',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Lilianae',
#   'itis_Order': 'Poales',
#   'itis_Family': 'Poaceae',
#   'itis_Genus': 'Zea',
#   'itis_Species': 'Zea mays',
#   'itis_common_names': [],
#   'itis_geographic_division': ['North America', 'South America', 'Caribbean'],
#   'itis_native_to': [],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Zea mays',
#   'xdd_snippet_doc_ct': 45882},
#  {'scientific_name': 'Castor canadensis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1002/jwmg.21386'],
#   'itis_tsn': '180212',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Rodentia',
#   'itis_Suborder': 'Castorimorpha',
#   'itis_Family': 'Castoridae',
#   'itis_Genus': 'Castor',
#   'itis_Species': 'Castor canadensis',
#   'itis_common_names': ['American Beaver'],
#   'itis_geographic_division': ['Europe & Northern Asia (excluding China)',
#    'North America',
#    'South America',
#    'Middle America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Alaska,Arizona,New Mexico,Ohio',
#   'sgcn_statelist_2015': 'Arizona,California,District of Columbia',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Castor canadensis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Castor canadensis',
#   'xdd_snippet_doc_ct': 1673},
#  {'scientific_name': 'Dendroctonus pseudotsugae',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 3,
#   'wlci_xdd_doi_list': ['10.1080/2150704X.2015.1072289',
#    '10.1016/j.foreco.2016.01.017'],
#   'itis_tsn': '114919',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Protostomia',
#   'itis_Superphylum': 'Ecdysozoa',
#   'itis_Phylum': 'Arthropoda',
#   'itis_Subphylum': 'Hexapoda',
#   'itis_Class': 'Insecta',
#   'itis_Subclass': 'Pterygota',
#   'itis_Infraclass': 'Neoptera',
#   'itis_Superorder': 'Holometabola',
#   'itis_Order': 'Coleoptera',
#   'itis_Suborder': 'Polyphaga',
#   'itis_Infraorder': 'Cucujiformia',
#   'itis_Superfamily': 'Curculionoidea',
#   'itis_Family': 'Curculionidae',
#   'itis_Subfamily': 'Scolytinae',
#   'itis_Genus': 'Dendroctonus',
#   'itis_Species': 'Dendroctonus pseudotsugae',
#   'itis_common_names': ['Douglas-fir beetle'],
#   'itis_geographic_division': ['Middle America', 'North America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Dendroctonus pseudotsugae',
#   'xdd_snippet_doc_ct': 393},
#  {'scientific_name': 'Myotis septentrionalis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '180000',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Chiroptera',
#   'itis_Suborder': 'Yangochiroptera',
#   'itis_Superfamily': 'Vespertilionoidea',
#   'itis_Family': 'Vespertilionidae',
#   'itis_Subfamily': 'Myotinae',
#   'itis_Genus': 'Myotis',
#   'itis_Species': 'Myotis septentrionalis',
#   'itis_common_names': ['northern myotis',
#    'northern long-eared bat',
#    'Northern Myotis'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'Alabama,Connecticut,Delaware,Indiana,Iowa,Louisiana,Michigan,Minnesota,Mississippi,Montana,Nebraska,New Hampshire,North Carolina,Ohio,Oklahoma,Pennsylvania,Rhode Island,South Dakota,Vermont,Wisconsin,Wyoming',
#   'sgcn_statelist_2015': 'Alabama,Arkansas,Connecticut,Delaware,District of Columbia,Georgia,Illinois,Indiana,Iowa,Kansas,Louisiana,Maine,Maryland,Massachusetts,Michigan,Minnesota,Mississippi,Missouri,Nebraska,New Hampshire,New Jersey,New York,North Carolina,North Dakota,Ohio,Oklahoma,Pennsylvania,Rhode Island,South Carolina,South Dakota,Tennessee,Vermont,Virginia,West Virginia,Wisconsin,Wyoming',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Myotis septentrionalis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Myotis septentrionalis',
#   'xdd_snippet_doc_ct': 251},
#  {'scientific_name': 'Atriplex canescens',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 5,
#   'wlci_xdd_doi_list': ['10.1002/ece3.3607'],
#   'itis_tsn': '20518',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Caryophyllanae',
#   'itis_Order': 'Caryophyllales',
#   'itis_Family': 'Amaranthaceae',
#   'itis_Genus': 'Atriplex',
#   'itis_Species': 'Atriplex canescens',
#   'itis_common_names': ['fourwing saltbush'],
#   'itis_geographic_division': ['Oceania', 'North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Atriplex canescens',
#   'xdd_snippet_doc_ct': 731},
#  {'scientific_name': 'Brachylagus idahoensis',
#   'wlci_xdd_per': 10.344827586206897,
#   'wlci_xdd_hits': 33,
#   'wlci_xdd_doi_list': ['10.1016/j.ecolind.2017.12.033',
#    '10.3133/ofr20181188',
#    '10.1002/ecs2.1817'],
#   'itis_tsn': '552521',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Lagomorpha',
#   'itis_Family': 'Leporidae',
#   'itis_Genus': 'Brachylagus',
#   'itis_Species': 'Brachylagus idahoensis',
#   'itis_common_names': ['Pygmy Rabbit'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US'],
#   'sgcn_statelist_2005': 'California,Idaho,Montana,Nevada,Oregon,Utah,Washington,Wyoming',
#   'sgcn_statelist_2015': 'California,Colorado,Idaho,Nevada,Oregon,Utah,Washington,Wyoming',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Brachylagus idahoensis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Brachylagus idahoensis',
#   'xdd_snippet_doc_ct': 172},
#  {'scientific_name': 'Halogeton glomeratus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 7,
#   'wlci_xdd_doi_list': ['10.1002/ece3.3607'],
#   'itis_tsn': '20692',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Caryophyllanae',
#   'itis_Order': 'Caryophyllales',
#   'itis_Family': 'Amaranthaceae',
#   'itis_Genus': 'Halogeton',
#   'itis_Species': 'Halogeton glomeratus',
#   'itis_common_names': ['barilla', 'saltlover'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': [],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Halogeton glomeratus',
#   'xdd_snippet_doc_ct': 158},
#  {'scientific_name': 'Arctostaphylos patula',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 6,
#   'wlci_xdd_doi_list': ['10.1080/2150704X.2015.1072289',
#    '10.1016/j.foreco.2016.01.017'],
#   'itis_tsn': '23512',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Asteranae',
#   'itis_Order': 'Ericales',
#   'itis_Family': 'Ericaceae',
#   'itis_Genus': 'Arctostaphylos',
#   'itis_Species': 'Arctostaphylos patula',
#   'itis_common_names': ['greenleaf manzanita'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US'],
#   'itis_related_tsn': ['23513'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Arctostaphylos patula',
#   'xdd_snippet_doc_ct': 212},
#  {'scientific_name': 'Spizella breweri',
#   'wlci_xdd_per': 17.24137931034483,
#   'wlci_xdd_hits': 20,
#   'wlci_xdd_doi_list': ['10.1016/j.biocon.2018.10.020',
#    '10.1111/1365-2664.12513',
#    '10.3133/ofr20181188',
#    '10.1016/j.biocon.2015.02.009',
#    '10.3133/ofr20161147'],
#   'itis_tsn': '179440',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Passeriformes',
#   'itis_Family': 'Emberizidae',
#   'itis_Genus': 'Spizella',
#   'itis_Species': 'Spizella breweri',
#   'itis_common_names': ["Brewer's Sparrow"],
#   'itis_geographic_division': ['North America', 'Middle America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'California,Colorado,Idaho,Montana,Nebraska,Nevada,North Dakota,Oregon,Texas,Utah,Wyoming',
#   'sgcn_statelist_2015': 'Arizona,Colorado,Nebraska,Nevada,North Dakota,Wyoming',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Spizella breweri',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Spizella breweri',
#   'xdd_snippet_doc_ct': 152},
#  {'scientific_name': 'Oncorhynchus nerka',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1111/ele.12772'],
#   'itis_tsn': '161979',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Actinopterygii',
#   'itis_Class': 'Teleostei',
#   'itis_Superorder': 'Protacanthopterygii',
#   'itis_Order': 'Salmoniformes',
#   'itis_Family': 'Salmonidae',
#   'itis_Subfamily': 'Salmoninae',
#   'itis_Genus': 'Oncorhynchus',
#   'itis_Species': 'Oncorhynchus nerka',
#   'itis_common_names': ['blueback salmon',
#    'sockeye salmon',
#    'kokanee',
#    'red salmon'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Alaska'],
#   'sgcn_statelist_2005': 'Idaho',
#   'sgcn_statelist_2015': 'Alaska,Idaho,Washington',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Oncorhynchus nerka',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Oncorhynchus nerka',
#   'xdd_snippet_doc_ct': 6246},
#  {'scientific_name': 'Vulpes vulpes',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12513'],
#   'itis_tsn': '180604',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Carnivora',
#   'itis_Suborder': 'Caniformia',
#   'itis_Family': 'Canidae',
#   'itis_Genus': 'Vulpes',
#   'itis_Species': 'Vulpes vulpes',
#   'itis_common_names': ['Red Fox'],
#   'itis_geographic_division': ['Southern Asia',
#    'Africa',
#    'North America',
#    'Australia',
#    'Europe & Northern Asia (excluding China)'],
#   'itis_native_to': ['Continental US', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Arizona,Ohio',
#   'sgcn_statelist_2015': 'Arizona',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Vulpes vulpes',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Vulpes vulpes',
#   'xdd_snippet_doc_ct': 6297},
#  {'scientific_name': 'Rhynchophanes mccownii',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '997873',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Passeriformes',
#   'itis_Family': 'Calcariidae',
#   'itis_Genus': 'Rhynchophanes',
#   'itis_Species': 'Rhynchophanes mccownii',
#   'itis_common_names': ["McCown's Longspur"],
#   'itis_geographic_division': ['Middle America', 'North America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada'],
#   'sgcn_statelist_2005': 'Arizona,Colorado,Kansas,Montana,Nebraska,North Dakota,Oklahoma,Texas,Wyoming',
#   'sgcn_statelist_2015': 'Arizona,Colorado,Kansas,Nebraska,New Mexico,North Dakota,Oklahoma,Texas,Wyoming',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Rhynchophanes mccownii',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Rhynchophanes mccownii',
#   'xdd_snippet_doc_ct': 21},
#  {'scientific_name': 'Picea engelmannii',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 3,
#   'wlci_xdd_doi_list': ['10.1016/j.foreco.2016.01.017', '10.1002/ecs2.2113'],
#   'itis_tsn': '183291',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Pinopsida',
#   'itis_Subclass': 'Pinidae',
#   'itis_Order': 'Pinales',
#   'itis_Family': 'Pinaceae',
#   'itis_Genus': 'Picea',
#   'itis_Species': 'Picea engelmannii',
#   'itis_common_names': ['mountain spruce',
#    'silver spruce',
#    'Engelmann spruce',
#    'white spruce',
#    "Engelmann's spruce",
#    'Columbian spruce'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Picea engelmannii',
#   'xdd_snippet_doc_ct': 2791},
#  {'scientific_name': 'Cercocarpus montanus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 9,
#   'wlci_xdd_doi_list': ['10.3133/ofr20181188'],
#   'itis_tsn': '25136',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Rosanae',
#   'itis_Order': 'Rosales',
#   'itis_Family': 'Rosaceae',
#   'itis_Genus': 'Cercocarpus',
#   'itis_Species': 'Cercocarpus montanus',
#   'itis_common_names': ['true mountain-mahogany',
#    'alderleaf cercocarpus',
#    'mountain-mahogany',
#    'birchleaf mountain-mahogany',
#    'alderleaf mountain-mahogany'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Cercocarpus montanus',
#   'xdd_snippet_doc_ct': 155},
#  {'scientific_name': 'Odocoileus hemionus',
#   'wlci_xdd_per': 31.03448275862069,
#   'wlci_xdd_hits': 31,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12013',
#    '10.1016/j.ecolind.2017.12.033',
#    '10.1002/wmon.1014',
#    '10.1111/ele.12772',
#    '10.2193/2008-478',
#    '10.1890/08-2034.1',
#    '10.3133/ofr20181188',
#    '10.1111/j.1365-2656.2011.01845.x',
#    '10.1002/ecs2.2113'],
#   'itis_tsn': '180698',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Artiodactyla',
#   'itis_Family': 'Cervidae',
#   'itis_Subfamily': 'Capreolinae',
#   'itis_Genus': 'Odocoileus',
#   'itis_Species': 'Odocoileus hemionus',
#   'itis_common_names': ['mule deer', 'Mule Deer'],
#   'itis_geographic_division': ['Oceania',
#    'Middle America',
#    'North America',
#    'South America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Nevada,New Mexico,Utah',
#   'sgcn_statelist_2015': 'Nevada',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Odocoileus hemionus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Odocoileus hemionus',
#   'xdd_snippet_doc_ct': 2509},
#  {'scientific_name': 'Catostomus platyrhynchus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 9,
#   'wlci_xdd_doi_list': ['10.3133/ofr20181188'],
#   'itis_tsn': '163909',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Actinopterygii',
#   'itis_Class': 'Teleostei',
#   'itis_Superorder': 'Ostariophysi',
#   'itis_Order': 'Cypriniformes',
#   'itis_Superfamily': 'Cobitoidea',
#   'itis_Family': 'Catostomidae',
#   'itis_Subfamily': 'Catostominae',
#   'itis_Tribe': 'Catostomini',
#   'itis_Genus': 'Catostomus',
#   'itis_Species': 'Catostomus platyrhynchus',
#   'itis_common_names': ['mountain sucker'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'California,Colorado,Nebraska,South Dakota,Washington,Wyoming',
#   'sgcn_statelist_2015': 'California,Colorado,South Dakota,Washington',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Catostomus platyrhynchus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Catostomus platyrhynchus',
#   'xdd_snippet_doc_ct': 58},
#  {'scientific_name': 'Aythya marila',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '175130',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Anseriformes',
#   'itis_Family': 'Anatidae',
#   'itis_Subfamily': 'Anatinae',
#   'itis_Genus': 'Aythya',
#   'itis_Species': 'Aythya marila',
#   'itis_common_names': ['Greater Scaup'],
#   'itis_geographic_division': ['Southern Asia',
#    'North America',
#    'Caribbean',
#    'Oceania',
#    'Europe & Northern Asia (excluding China)'],
#   'itis_native_to': ['Continental US', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Connecticut,Delaware,Kentucky,Maine,New Jersey,New York,South Carolina,Virginia,Washington',
#   'sgcn_statelist_2015': 'Connecticut,Delaware,Florida,Iowa,Kentucky,Maine,New Jersey,New York,Rhode Island,South Carolina,Virginia',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Aythya marila',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Aythya marila',
#   'xdd_snippet_doc_ct': 362},
#  {'scientific_name': 'Lanius ludovicianus',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12513', '10.3133/ofr20161147'],
#   'itis_tsn': '178515',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Passeriformes',
#   'itis_Family': 'Laniidae',
#   'itis_Genus': 'Lanius',
#   'itis_Species': 'Lanius ludovicianus',
#   'itis_common_names': ['Loggerhead Shrike'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'California,Colorado,Delaware,Florida,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Maine,Maryland,Minnesota,Mississippi,Missouri,Montana,Nevada,New Jersey,New Mexico,New York,North Carolina,North Dakota,Ohio,Oklahoma,Oregon,Pennsylvania,South Carolina,Tennessee,Texas,Virginia,Washington,Wisconsin',
#   'sgcn_statelist_2015': 'Alabama,Arkansas,California,Colorado,Delaware,Florida,Georgia,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Maryland,Minnesota,Mississippi,Missouri,Nebraska,Nevada,New Mexico,New York,North Carolina,North Dakota,Ohio,Oklahoma,Oregon,Pennsylvania,South Carolina,Tennessee,Texas,Virginia,Washington,West Virginia,Wisconsin',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Lanius ludovicianus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Lanius ludovicianus',
#   'xdd_snippet_doc_ct': 433},
#  {'scientific_name': 'Pascopyrum smithii',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1002/ecs2.1817'],
#   'itis_related_tsn': ['504124'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Alaska'],
#   'itis_tsn': '784287',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Lilianae',
#   'itis_Order': 'Poales',
#   'itis_Family': 'Poaceae',
#   'itis_Genus': 'Pascopyrum',
#   'itis_Species': 'Pascopyrum smithii',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Pascopyrum smithii',
#   'xdd_snippet_doc_ct': 484},
#  {'scientific_name': 'Tamias minimus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 3,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12513'],
#   'itis_tsn': '180195',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Rodentia',
#   'itis_Suborder': 'Sciuromorpha',
#   'itis_Family': 'Sciuridae',
#   'itis_Subfamily': 'Xerinae',
#   'itis_Tribe': 'Marmotini',
#   'itis_Genus': 'Tamias',
#   'itis_Subgenus': 'Tamias (Neotamias)',
#   'itis_Species': 'Tamias minimus',
#   'itis_common_names': ['Least Chipmunk'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'Arizona,Michigan,Nebraska',
#   'sgcn_statelist_2015': 'Arizona,Nebraska',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Tamias minimus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Tamias minimus',
#   'xdd_snippet_doc_ct': 142},
#  {'scientific_name': 'Buteo jamaicensis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '175350',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Accipitriformes',
#   'itis_Family': 'Accipitridae',
#   'itis_Genus': 'Buteo',
#   'itis_Species': 'Buteo jamaicensis',
#   'itis_common_names': ['Red-tailed Hawk'],
#   'itis_geographic_division': ['North America', 'Caribbean'],
#   'itis_native_to': ['Caribbean Territories',
#    'Continental US',
#    'Canada',
#    'Alaska'],
#   'sgcn_statelist_2005': 'Ohio,Virgin Islands',
#   'sgcn_statelist_2015': '',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Buteo jamaicensis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Buteo jamaicensis',
#   'xdd_snippet_doc_ct': 832},
#  {'scientific_name': 'Clupea pallasii',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1111/ele.12772'],
#   'itis_tsn': '551209',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Actinopterygii',
#   'itis_Class': 'Teleostei',
#   'itis_Superorder': 'Clupeomorpha',
#   'itis_Order': 'Clupeiformes',
#   'itis_Suborder': 'Clupeoidei',
#   'itis_Family': 'Clupeidae',
#   'itis_Subfamily': 'Clupeinae',
#   'itis_Genus': 'Clupea',
#   'itis_Species': 'Clupea pallasii',
#   'itis_common_names': ['Pacific herring'],
#   'itis_geographic_division': ['East Pacific',
#    'Southern Asia',
#    'Indo-West Pacific'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Washington',
#   'sgcn_statelist_2015': 'Alaska,Oregon,Washington',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Clupea pallasii',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Clupea pallasii',
#   'xdd_snippet_doc_ct': 664},
#  {'scientific_name': 'Mallotus villosus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '162035',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Actinopterygii',
#   'itis_Class': 'Teleostei',
#   'itis_Superorder': 'Protacanthopterygii',
#   'itis_Order': 'Osmeriformes',
#   'itis_Suborder': 'Osmeroidei',
#   'itis_Superfamily': 'Osmeroidea',
#   'itis_Family': 'Osmeridae',
#   'itis_Genus': 'Mallotus',
#   'itis_Species': 'Mallotus villosus',
#   'itis_common_names': ['capelin'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'Alaska',
#   'sgcn_statelist_2015': 'Alaska',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Mallotus villosus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Mallotus villosus',
#   'xdd_snippet_doc_ct': 2279},
#  {'scientific_name': 'Falco sparverius',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12513', '10.3133/ofr20161147'],
#   'itis_tsn': '175622',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Falconiformes',
#   'itis_Family': 'Falconidae',
#   'itis_Subfamily': 'Falconinae',
#   'itis_Genus': 'Falco',
#   'itis_Species': 'Falco sparverius',
#   'itis_common_names': ['American Kestrel'],
#   'itis_geographic_division': ['North America',
#    'Middle America',
#    'South America',
#    'Caribbean'],
#   'itis_native_to': ['Mexico',
#    'Caribbean Territories',
#    'Continental US',
#    'Canada',
#    'Alaska'],
#   'sgcn_statelist_2005': 'Alabama,Connecticut,Kentucky,Massachusetts,New Jersey,North Carolina,Ohio,Rhode Island,Texas,Vermont,Virgin Islands',
#   'sgcn_statelist_2015': 'Alaska,Arkansas,Connecticut,Delaware,District of Columbia,Iowa,Kentucky,Maine,Maryland,Massachusetts,Minnesota,New Hampshire,New Jersey,New York,North Carolina,North Dakota,Pennsylvania,Rhode Island,Texas,Vermont,West Virginia',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Falco sparverius',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Falco sparverius',
#   'xdd_snippet_doc_ct': 1399},
#  {'scientific_name': 'Clangula hyemalis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '175147',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Anseriformes',
#   'itis_Family': 'Anatidae',
#   'itis_Subfamily': 'Anatinae',
#   'itis_Genus': 'Clangula',
#   'itis_Species': 'Clangula hyemalis',
#   'itis_common_names': ['Oldsquaw', 'Long-tailed Duck'],
#   'itis_geographic_division': ['Oceania',
#    'Europe & Northern Asia (excluding China)',
#    'Southern Asia',
#    'North America'],
#   'itis_native_to': ['Continental US', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Alaska,Connecticut,Delaware,Massachusetts,New Jersey,New York,Washington',
#   'sgcn_statelist_2015': 'Alaska,Delaware,Maine,Maryland,Massachusetts,New Jersey,New York,North Carolina,Pennsylvania,Washington',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Clangula hyemalis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Clangula hyemalis',
#   'xdd_snippet_doc_ct': 426},
#  {'scientific_name': 'Falco mexicanus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '175603',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Falconiformes',
#   'itis_Family': 'Falconidae',
#   'itis_Subfamily': 'Falconinae',
#   'itis_Genus': 'Falco',
#   'itis_Species': 'Falco mexicanus',
#   'itis_common_names': ['Prairie Falcon'],
#   'itis_geographic_division': ['North America', 'Middle America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada'],
#   'sgcn_statelist_2005': 'California,Colorado,Nebraska,North Dakota,Oklahoma,Texas,Washington',
#   'sgcn_statelist_2015': 'Arizona,Colorado,Nebraska,Nevada,North Dakota,Oklahoma',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Falco mexicanus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Falco mexicanus',
#   'xdd_snippet_doc_ct': 210},
#  {'scientific_name': 'Circus cyaneus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '175430',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Accipitriformes',
#   'itis_Family': 'Accipitridae',
#   'itis_Genus': 'Circus',
#   'itis_Species': 'Circus cyaneus',
#   'itis_common_names': ['Northern Harrier'],
#   'itis_geographic_division': ['Oceania', 'North America', 'Caribbean'],
#   'itis_native_to': ['Caribbean Territories',
#    'Continental US',
#    'Canada',
#    'Alaska'],
#   'sgcn_statelist_2005': 'Alabama,Alaska,Arizona,Arkansas,California,Colorado,Connecticut,Delaware,Illinois,Indiana,Iowa,Kentucky,Louisiana,Maryland,Massachusetts,Michigan,Minnesota,Missouri,Nebraska,New Hampshire,New Jersey,New Mexico,New York,North Carolina,North Dakota,Ohio,Pennsylvania,Rhode Island,Tennessee,Texas,Vermont,Virginia,West Virginia,Wisconsin',
#   'sgcn_statelist_2015': 'Alaska,California,Colorado,Connecticut,Delaware,Illinois,Indiana,Iowa,Kentucky,Maine,Maryland,Massachusetts,Michigan,Minnesota,Missouri,New Hampshire,New Jersey,New York,North Carolina,North Dakota,Ohio,Pennsylvania,Rhode Island,Tennessee,Texas,Vermont,Virginia,West Virginia',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Circus cyaneus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Circus cyaneus',
#   'xdd_snippet_doc_ct': 1002},
#  {'scientific_name': 'Grus americana',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '176176',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Gruiformes',
#   'itis_Family': 'Gruidae',
#   'itis_Subfamily': 'Gruinae',
#   'itis_Genus': 'Grus',
#   'itis_Species': 'Grus americana',
#   'itis_common_names': ['Whooping Crane'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Canada'],
#   'sgcn_statelist_2005': 'Colorado,Florida,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Montana,Nebraska,North Dakota,Oklahoma,South Dakota,Tennessee,Texas,Utah,Wisconsin',
#   'sgcn_statelist_2015': 'Colorado,Florida,Georgia,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Montana,Nebraska,North Dakota,Oklahoma,South Dakota,Tennessee,Texas,Wisconsin',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Grus americana',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Grus americana',
#   'xdd_snippet_doc_ct': 466},
#  {'scientific_name': 'Procapra gutturosa',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12013'],
#   'itis_tsn': '625114',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Artiodactyla',
#   'itis_Family': 'Bovidae',
#   'itis_Subfamily': 'Antilopinae',
#   'itis_Genus': 'Procapra',
#   'itis_Species': 'Procapra gutturosa',
#   'itis_common_names': ['Mongolian gazelle', 'Mongolian Gazelle'],
#   'itis_geographic_division': ['Europe & Northern Asia (excluding China)',
#    'Southern Asia'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Procapra gutturosa',
#   'xdd_snippet_doc_ct': 197},
#  {'scientific_name': 'Sarcobatus vermiculatus',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12013', '10.1002/ecs2.2113'],
#   'itis_tsn': '20707',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Caryophyllanae',
#   'itis_Order': 'Caryophyllales',
#   'itis_Family': 'Sarcobataceae',
#   'itis_Genus': 'Sarcobatus',
#   'itis_Species': 'Sarcobatus vermiculatus',
#   'itis_common_names': ['greasewood'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Sarcobatus vermiculatus',
#   'xdd_snippet_doc_ct': 460},
#  {'scientific_name': 'Cottus bairdii',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 9,
#   'wlci_xdd_doi_list': ['10.3133/ofr20181188'],
#   'itis_tsn': '167237',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Actinopterygii',
#   'itis_Class': 'Teleostei',
#   'itis_Superorder': 'Acanthopterygii',
#   'itis_Order': 'Scorpaeniformes',
#   'itis_Suborder': 'Cottoidei',
#   'itis_Superfamily': 'Cottoidea',
#   'itis_Family': 'Cottidae',
#   'itis_Genus': 'Cottus',
#   'itis_Species': 'Cottus bairdii',
#   'itis_common_names': ['mottled sculpin'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Canada'],
# ...
#  {'scientific_name': 'Corvus corax',
#   'wlci_xdd_per': 13.793103448275861,
#   'wlci_xdd_hits': 4,
#   'wlci_xdd_doi_list': ['10.1016/j.biocon.2018.10.020',
#    '10.1111/1365-2664.12513',
#    '10.3133/ofr20161147',
#    '10.1002/ecs2.1817'],
#   'itis_tsn': '179725',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Passeriformes',
#   'itis_Family': 'Corvidae',
#   'itis_Genus': 'Corvus',
#   'itis_Species': 'Corvus corax',
#   'itis_common_names': ['Northern Raven', 'Common Raven'],
#   'itis_geographic_division': ['Southern Asia',
#    'North America',
#    'Africa',
#    'Middle America',
#    'Europe & Northern Asia (excluding China)'],
#   'itis_native_to': ['Continental US', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Alabama,Connecticut,Kentucky,Maryland,Missouri,Ohio,South Carolina,Tennessee',
#   'sgcn_statelist_2015': 'Alabama,Kentucky,North Carolina,South Carolina',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Corvus corax',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Corvus corax',
#   'xdd_snippet_doc_ct': 1875},
#  {'scientific_name': 'Hesperostipa comata',
#   'wlci_xdd_per': 6.896551724137931,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1016/j.ecolind.2017.12.033', '10.1002/ecs2.1817'],
#   'itis_tsn': '507974',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Magnoliopsida',
#   'itis_Superorder': 'Lilianae',
#   'itis_Order': 'Poales',
#   'itis_Family': 'Poaceae',
#   'itis_Genus': 'Hesperostipa',
#   'itis_Species': 'Hesperostipa comata',
#   'itis_common_names': [],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Hesperostipa comata',
#   'xdd_snippet_doc_ct': 242},
#  {'scientific_name': 'Otis tarda',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1002/jwmg.155'],
#   'itis_tsn': '176419',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Otidiformes',
#   'itis_Family': 'Otididae',
#   'itis_Genus': 'Otis',
#   'itis_Species': 'Otis tarda',
#   'itis_common_names': ['Great Bustard'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Otis tarda',
#   'xdd_snippet_doc_ct': 624},
#  {'scientific_name': 'Dendroctonus ponderosae',
#   'wlci_xdd_per': 10.344827586206897,
#   'wlci_xdd_hits': 4,
#   'wlci_xdd_doi_list': ['10.1016/j.jag.2014.01.008',
#    '10.1002/jwmg.21179',
#    '10.1016/j.foreco.2016.01.017'],
#   'itis_tsn': '114918',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Protostomia',
#   'itis_Superphylum': 'Ecdysozoa',
#   'itis_Phylum': 'Arthropoda',
#   'itis_Subphylum': 'Hexapoda',
#   'itis_Class': 'Insecta',
#   'itis_Subclass': 'Pterygota',
#   'itis_Infraclass': 'Neoptera',
#   'itis_Superorder': 'Holometabola',
#   'itis_Order': 'Coleoptera',
#   'itis_Suborder': 'Polyphaga',
#   'itis_Infraorder': 'Cucujiformia',
#   'itis_Superfamily': 'Curculionoidea',
#   'itis_Family': 'Curculionidae',
#   'itis_Subfamily': 'Scolytinae',
#   'itis_Genus': 'Dendroctonus',
#   'itis_Species': 'Dendroctonus ponderosae',
#   'itis_common_names': ['mountain pine beetle'],
#   'itis_geographic_division': ['Middle America', 'North America'],
#   'itis_native_to': ['Continental US', 'Mexico', 'Canada'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Dendroctonus ponderosae',
#   'xdd_snippet_doc_ct': 1686},
#  {'scientific_name': 'Lasiurus borealis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '180016',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Chiroptera',
#   'itis_Suborder': 'Yangochiroptera',
#   'itis_Superfamily': 'Vespertilionoidea',
#   'itis_Family': 'Vespertilionidae',
#   'itis_Subfamily': 'Vespertilioninae',
#   'itis_Tribe': 'Lasiurini',
#   'itis_Genus': 'Lasiurus',
#   'itis_Subgenus': 'Lasiurus (Lasiurus)',
#   'itis_Species': 'Lasiurus borealis',
#   'itis_common_names': ['Eastern Red Bat', 'red bat', 'eastern red bat'],
#   'itis_geographic_division': ['North America',
#    'Caribbean',
#    'South America',
#    'Middle America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'Connecticut,Delaware,District of Columbia,Florida,Indiana,Maryland,Massachusetts,Michigan,Montana,New Hampshire,New Jersey,New York,Ohio,Puerto Rico,Rhode Island,Vermont,West Virginia,Wisconsin',
#   'sgcn_statelist_2015': 'Connecticut,Delaware,District of Columbia,Indiana,Maine,Maryland,Massachusetts,Minnesota,New Hampshire,New Jersey,New York,Ohio,Rhode Island,South Carolina,Vermont,Virginia,West Virginia,Wyoming',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Lasiurus borealis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Lasiurus borealis',
#   'xdd_snippet_doc_ct': 393},
#  {'scientific_name': 'Gavia immer',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '174469',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Gaviiformes',
#   'itis_Family': 'Gaviidae',
#   'itis_Genus': 'Gavia',
#   'itis_Species': 'Gavia immer',
#   'itis_common_names': ['Common Loon',
#    'Great Northern Loon',
#    'Great Northern Diver'],
#   'itis_geographic_division': ['Europe & Northern Asia (excluding China)',
#    'North America'],
#   'itis_native_to': ['Continental US', 'Canada', 'Alaska'],
#   'sgcn_statelist_2005': 'Alaska,California,Connecticut,Florida,Idaho,Maine,Maryland,Massachusetts,Michigan,Minnesota,Montana,Nevada,New Hampshire,New York,South Carolina,Vermont,Washington,Wyoming',
#   'sgcn_statelist_2015': 'California,Connecticut,Delaware,Florida,Idaho,Iowa,Maine,Maryland,Massachusetts,Michigan,Minnesota,Nevada,New Hampshire,New Jersey,New York,Rhode Island,South Carolina,Vermont,Washington,Wyoming',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Gavia immer',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Gavia immer',
#   'xdd_snippet_doc_ct': 666},
#  {'scientific_name': 'Gymnogyps californianus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 3,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '175274',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Accipitriformes',
#   'itis_Family': 'Cathartidae',
#   'itis_Genus': 'Gymnogyps',
#   'itis_Species': 'Gymnogyps californianus',
#   'itis_common_names': ['California Condor'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US'],
#   'sgcn_statelist_2005': 'Arizona,California,Utah',
#   'sgcn_statelist_2015': 'Arizona,California,Utah',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Gymnogyps californianus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Gymnogyps californianus',
#   'xdd_snippet_doc_ct': 436},
#  {'scientific_name': 'Pinus albicaulis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1002/jwmg.21179'],
#   'itis_tsn': '183311',
#   'itis_tsn_usage': 'accepted',
#   'itis_Kingdom': 'Plantae',
#   'itis_Subkingdom': 'Viridiplantae',
#   'itis_Infrakingdom': 'Streptophyta',
#   'itis_Superdivision': 'Embryophyta',
#   'itis_Division': 'Tracheophyta',
#   'itis_Subdivision': 'Spermatophytina',
#   'itis_Class': 'Pinopsida',
#   'itis_Subclass': 'Pinidae',
#   'itis_Order': 'Pinales',
#   'itis_Family': 'Pinaceae',
#   'itis_Genus': 'Pinus',
#   'itis_Species': 'Pinus albicaulis',
#   'itis_common_names': ['white pine', 'whitebark pine', 'scrub pine'],
#   'itis_geographic_division': ['North America'],
#   'itis_native_to': ['Continental US', 'Canada'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Pinus albicaulis',
#   'xdd_snippet_doc_ct': 1012},
#  {'scientific_name': 'Equus burchelli',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12013'],
#   'itis_tsn': '926246',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Perissodactyla',
#   'itis_Family': 'Equidae',
#   'itis_Genus': 'Equus',
#   'itis_Subgenus': 'Equus (Hippotigris)',
#   'itis_Species': 'Equus quagga',
#   'itis_Subspecies': 'Equus quagga burchellii',
#   'itis_common_names': ['Zululand zebra',
#    'Damara zebra',
#    'Bontequagga',
#    "Burchell's Zebra"],
#   'itis_geographic_division': ['Africa'],
#   'itis_related_tsn': ['926145'],
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Equus burchelli',
#   'xdd_snippet_doc_ct': 1040},
#  {'scientific_name': 'Microtus californicus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.1016/j.biocon.2015.02.009'],
#   'itis_tsn': '180305',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Rodentia',
#   'itis_Suborder': 'Myomorpha',
#   'itis_Superfamily': 'Muroidea',
#   'itis_Family': 'Cricetidae',
#   'itis_Subfamily': 'Arvicolinae',
#   'itis_Genus': 'Microtus',
#   'itis_Species': 'Microtus californicus',
#   'itis_common_names': ['California Vole', 'Amargosa Vole'],
#   'itis_geographic_division': ['North America', 'Middle America'],
#   'itis_native_to': ['Continental US', 'Mexico'],
#   'sgcn_statelist_2005': 'California',
#   'sgcn_statelist_2015': 'California',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Microtus californicus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Microtus californicus',
#   'xdd_snippet_doc_ct': 590},
#  {'scientific_name': 'Taxidea taxus',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 2,
#   'wlci_xdd_doi_list': ['10.1111/1365-2664.12513'],
#   'itis_tsn': '180565',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Carnivora',
#   'itis_Suborder': 'Caniformia',
#   'itis_Family': 'Mustelidae',
#   'itis_Subfamily': 'Taxidiinae',
#   'itis_Genus': 'Taxidea',
#   'itis_Species': 'Taxidea taxus',
#   'itis_common_names': ['American Badger', 'badger'],
#   'itis_geographic_division': ['Middle America', 'North America'],
#   'itis_native_to': ['Mexico', 'Canada'],
#   'sgcn_statelist_2005': 'Arkansas,California,Illinois,Indiana,Minnesota,Missouri,Ohio,Texas,Washington',
#   'sgcn_statelist_2015': 'Arkansas,California,Indiana,Minnesota,Missouri,Ohio,Texas,Washington',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Taxidea taxus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Taxidea taxus',
#   'xdd_snippet_doc_ct': 647},
#  {'scientific_name': 'Pelecanus occidentalis',
#   'wlci_xdd_per': 3.4482758620689653,
#   'wlci_xdd_hits': 1,
#   'wlci_xdd_doi_list': ['10.3133/ofr20161147'],
#   'itis_tsn': '174685',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Aves',
#   'itis_Order': 'Pelecaniformes',
#   'itis_Family': 'Pelecanidae',
#   'itis_Genus': 'Pelecanus',
#   'itis_Species': 'Pelecanus occidentalis',
#   'itis_common_names': ['Brown Pelican'],
#   'itis_geographic_division': ['North America', 'Caribbean'],
#   'itis_native_to': ['Caribbean Territories', 'Continental US', 'Canada'],
#   'sgcn_statelist_2005': 'Delaware,Florida,Louisiana,Maryland,Mississippi,North Carolina,Puerto Rico,Texas,Virgin Islands',
#   'sgcn_statelist_2015': 'Delaware,Florida,Louisiana,Maryland,Mississippi,North Carolina,South Carolina,Texas,Washington',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Pelecanus occidentalis',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Pelecanus occidentalis',
#   'xdd_snippet_doc_ct': 482},
#  {'scientific_name': 'Cervus elaphus',
#   'wlci_xdd_per': 24.137931034482758,
#   'wlci_xdd_hits': 19,
#   'wlci_xdd_doi_list': ['10.1002/jwmg.21179',
#    '10.1002/wmon.1014',
#    '10.1111/ele.12772',
#    '10.1890/08-2034.1',
#    '10.3133/ofr20181188',
#    '10.1111/j.1365-2656.2011.01845.x',
#    '10.1002/ecs2.2113'],
#   'itis_tsn': '180695',
#   'itis_tsn_usage': 'valid',
#   'itis_Kingdom': 'Animalia',
#   'itis_Subkingdom': 'Bilateria',
#   'itis_Infrakingdom': 'Deuterostomia',
#   'itis_Phylum': 'Chordata',
#   'itis_Subphylum': 'Vertebrata',
#   'itis_Infraphylum': 'Gnathostomata',
#   'itis_Superclass': 'Tetrapoda',
#   'itis_Class': 'Mammalia',
#   'itis_Subclass': 'Theria',
#   'itis_Infraclass': 'Eutheria',
#   'itis_Order': 'Artiodactyla',
#   'itis_Family': 'Cervidae',
#   'itis_Subfamily': 'Cervinae',
#   'itis_Genus': 'Cervus',
#   'itis_Species': 'Cervus elaphus',
#   'itis_common_names': ['elk',
#    'wapiti',
#    'Red Deer (see comments)',
#    'wapiti or elk'],
#   'itis_geographic_division': ['Europe & Northern Asia (excluding China)',
#    'Southern Asia',
#    'Africa',
#    'North America',
#    'Australia',
#    'Middle America',
#    'South America'],
#   'itis_native_to': [],
#   'sgcn_statelist_2005': 'Alabama,Minnesota,Nebraska,Ohio',
#   'sgcn_statelist_2015': 'Alabama,North Carolina',
#   'sgcn_reference': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Cervus elaphus',
#   'xdd_snippet_api': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Cervus elaphus',
#   'xdd_snippet_doc_ct': 9308}]
