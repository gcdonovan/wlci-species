# %% [markdown]
# This notebook explores the records retrieved from the consultation between the WLCI scientific species name list and the ITIS API. The cached ITIS results are examined and next steps are determined.
#
# __Source(s)__
#
# _'cache/itis.json'_ : Information from ITIS on WLCI referenced species.  This file is created in _'workflow/Consult-with-ITIS.ipynb'_
#
# __Output(s)__
#
# '/cache/valid_itis.json' : Specie names classified as valid or accepted in ITIS
#
# 'cache/invalid_itis.json' : Specie names classified as invalid or not accepted in ITIS

# %%
#Import needed packages
import json
import bispy
import requests
from IPython.display import display
from joblib import Parallel, delayed

bis_utils = bispy.bis.Utils()

# %%
#Open cache ITIS list created from WLCI-Species-List-from-Literature.ipynb
with open("../cache/itis.json", "r") as f:
    itis_cache = json.loads(f.read())

# %%
#Print first record in ITIS list as an example
itis_cache[0]
# Out:
# {'processing_metadata': {'status': 'success',
#   'date_processed': '2019-09-25T16:45:51.362570',
#   'status_message': 'Exact Match',
#   'details': [{'Exact Match': 'https://services.itis.gov/?wt=json&rows=10&q=nameWOInd:Otis\\%20tarda'}]},
#  'parameters': {'Scientific Name': 'Otis tarda'},
#  'data': [{'tsn': '176419',
#    'nameWInd': 'Otis tarda',
#    'nameWOInd': 'Otis tarda',
#    'unit1': 'Otis',
#    'unit2': 'tarda',
#    'usage': 'valid',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'parentTSN': '176418',
#    'rankID': '220',
#    'rank': 'Species',
#    '_version_': 1643585546269753353,
#    'date_created': '1996-06-13 14:51:08',
#    'date_modified': '2006-11-28 00:00:00',
#    'expert': [{'reference_type': 'EXP',
#      'expert_id': '11',
#      'expert_name': 'Alan P. Peterson, M.D.',
#      'expert_comment': 'PO Box 1999 Walla Walla, Washington 99362-0999',
#      'create_date': '2001-09-28 00:00:00',
#      'update_date': ''}],
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '5351',
#      'author': 'Gill, Frank, and Minturn Wright',
#      'title': 'Birds of the World: Recommended English Names',
#      'other_variable_0': '2006-01-01 00:00:00',
#      'other_variable_1': '2006-01-01 00:00:00',
#      'other_variable_2': 'Princeton University Press',
#      'other_variable_3': 'Princeton, New Jersey, USA',
#      'other_variable_4': '0-691-12827-8',
#      'other_variable_6': 'ix + 259',
#      'other_variable_7': 'Includes a CD-ROM with the full dataset',
#      'other_variable_9': '2018-06-26 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '7',
#      'source_type': 'database',
#      'source_name': 'NODC Taxonomic Code',
#      'version': '8.0',
#      'acquisition_date': '1996-07-29 00:00:00',
#      'source_comment': '',
#      'create_date': '2010-01-14 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '385',
#      'source_type': 'website',
#      'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2006.07.04',
#      'version': '04-Jul-06',
#      'acquisition_date': '2006-08-21 00:00:00',
#      'source_comment': 'Zoonomen - Zoological Nomenclature Resource" maintained by Alan P. Peterson at http://www.zoonomen.net',
#      'create_date': '2006-11-28 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Aves'},
#     {'rank': 'Order', 'name': 'Otidiformes'},
#     {'rank': 'Family', 'name': 'Otididae'},
#     {'rank': 'Genus', 'name': 'Otis'},
#     {'rank': 'Species', 'name': 'Otis tarda'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Aves',
#     'Otidiformes',
#     'Otididae',
#     'Otis',
#     'Otis tarda'],
#    'commonnames': [{'name': 'Great Bustard', 'language': 'English'}]}]}

# %% [markdown]
# In some cases more than one ITIS record was returned from the function. In every case, the “processing_metadata” structure indicates that the scientific species names used at the point of discovery were accepted. However, the "itis_data" structure indicates that potentially invalid names were provided from the WLCI literature database or xDD source information yet have a valid record in ITIS. The following code block lets us examine what is going on in these cases.
#
# The “processing_metadata” structure provides information about what the function does. It includes the URLs to the ITIS API that resulted in some action. Both the valid/accepted and invalid/unaccepted names from ITIS are recorded. We reach back to the itis_cache to show that record.

# %%
#Select ITIS records with more than one record 
validate =[i["data"] for i in itis_cache if "data" in i.keys() and len(i["data"]) > 1]

# %%
validate
# Out:
# [[{'tsn': '997724',
#    'nameWInd': 'Artemisiospiza belli',
#    'nameWOInd': 'Artemisiospiza belli',
#    'unit1': 'Artemisiospiza',
#    'unit2': 'belli',
#    'usage': 'valid',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Cassin, 1850)',
#    'kingdom': 'Animalia',
#    'parentTSN': '997695',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['997724:$Amphispiza belli$'],
#    'synonymTSNs': ['997724:$179402$'],
#    '_version_': 1643585615848013824,
#    'date_created': '2015-10-28 14:07:43',
#    'date_modified': '2015-10-28 00:00:00',
#    'geographicDivision': [{'geographic_value': 'Middle America',
#      'update_date': '2015-10-28 00:00:00'},
#     {'geographic_value': 'North America',
#      'update_date': '2015-10-28 00:00:00'}],
#    'jurisdiction': [{'jurisdiction_value': 'Continental US',
#      'origin': 'Native',
#      'update_date': '2015-10-28 00:00:00'},
#     {'jurisdiction_value': 'Mexico',
#      'origin': 'Native',
#      'update_date': '2015-10-28 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '1118',
#      'source_type': 'website',
#      'source_name': 'IOC World Bird List (v 5.3)',
#      'version': '5.3',
#      'acquisition_date': '2015-09-04 00:00:00',
#      'source_comment': 'Gill, F., and D. Donsker, eds. 2015. IOC World Bird List (v 5.3). Available at http://www.worldbirdnames.org [Accessed 04 September, 2015]',
#      'create_date': '2015-10-28 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '1119',
#      'source_type': 'website',
#      'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2015.02.01',
#      'version': '01-Feb-15',
#      'acquisition_date': '2015-01-02 00:00:00',
#      'source_comment': "'Zoonomen Nomenclatural data' maintained by Alan P. Peterson at http://www.zoonomen.net",
#      'create_date': '2015-10-28 00:00:00',
#      'update_date': ''}],
#    'comment': [{'comment_id': '58985',
#      'commentator': 'IOC List v5.3',
#      'comment_text': "Change English name of A. belli to Bell's Sparrow with transfer of 'Sage Sparrow' to A. nevadensis (IOC List v5.3)",
#      'create_date': '2015-10-28 14:23:40',
#      'update_date': '2015-10-28 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Aves'},
#     {'rank': 'Order', 'name': 'Passeriformes'},
#     {'rank': 'Family', 'name': 'Emberizidae'},
#     {'rank': 'Genus', 'name': 'Artemisiospiza'},
#     {'rank': 'Species', 'name': 'Artemisiospiza belli'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Aves',
#     'Passeriformes',
#     'Emberizidae',
#     'Artemisiospiza',
#     'Artemisiospiza belli'],
#    'commonnames': [{'name': "Bell's Sparrow", 'language': 'English'},
#     {'name': 'Zacatonero de artemisa', 'language': 'Spanish'},
#     {'name': 'Sage Sparrow', 'language': 'English'}]},
#   {'tsn': '179402',
#    'nameWInd': 'Amphispiza belli',
#    'nameWOInd': 'Amphispiza belli',
#    'unit1': 'Amphispiza',
#    'unit2': 'belli',
#    'usage': 'invalid',
#    'unacceptReason': 'subsequent name/combination',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Cassin, 1850)',
#    'kingdom': 'Animalia',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['997724:$Amphispiza belli$'],
#    'synonymTSNs': ['997724:$179402$'],
#    'acceptedTSN': ['997724'],
#    '_version_': 1643585546660872193,
#    'date_created': '1996-06-13 14:51:08',
#    'date_modified': '2015-10-28 00:00:00',
#    'geographicDivision': [{'geographic_value': 'North America',
#      'update_date': '1998-09-16 00:00:00'}],
#    'jurisdiction': [{'jurisdiction_value': 'Canada',
#      'origin': 'Native',
#      'update_date': '2007-10-11 00:00:00'},
#     {'jurisdiction_value': 'Continental US',
#      'origin': 'Native',
#      'update_date': '2007-10-11 00:00:00'}],
#    'expert': [{'reference_type': 'EXP',
#      'expert_id': '11',
#      'expert_name': 'Alan P. Peterson, M.D.',
#      'expert_comment': 'PO Box 1999 Walla Walla, Washington 99362-0999',
#      'create_date': '2001-09-28 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'EXP',
#      'expert_id': '12',
#      'expert_name': 'Richard C. Banks',
#      'expert_comment': 'Chief, Bird Section, U.S.G.S. - B.R.D. - P.W.R.C.',
#      'create_date': '2001-09-28 00:00:00',
#      'update_date': ''}],
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '706',
#      'author': 'Banks, R. C., R. W. McDiarmid, and A. L. Gardner',
#      'title': 'Resource Publication, no. 166',
#      'other_variable_0': '1987-01-01 00:00:00',
#      'other_variable_1': '1987-01-01 00:00:00',
#      'other_variable_2': 'United States Department of the Interior Fish and Wildlife Service',
#      'other_variable_3': 'Washington, D.C., USA',
#      'other_variable_6': '79',
#      'other_variable_8': 'N',
#      'other_variable_9': '2019-04-27 00:00:00'},
#     {'reference_type': 'PUB',
#      'reference_id': '5351',
#      'author': 'Gill, Frank, and Minturn Wright',
#      'title': 'Birds of the World: Recommended English Names',
#      'other_variable_0': '2006-01-01 00:00:00',
#      'other_variable_1': '2006-01-01 00:00:00',
#      'other_variable_2': 'Princeton University Press',
#      'other_variable_3': 'Princeton, New Jersey, USA',
#      'other_variable_4': '0-691-12827-8',
#      'other_variable_6': 'ix + 259',
#      'other_variable_7': 'Includes a CD-ROM with the full dataset',
#      'other_variable_8': 'N',
#      'other_variable_9': '2018-06-26 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '7',
#      'source_type': 'database',
#      'source_name': 'NODC Taxonomic Code',
#      'version': '8.0',
#      'acquisition_date': '1996-07-29 00:00:00',
#      'source_comment': '',
#      'create_date': '2010-01-14 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '428',
#      'source_type': 'website',
#      'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2007.09.20',
#      'version': '20-Sep-07',
#      'acquisition_date': '2007-09-25 00:00:00',
#      'source_comment': '"Zoonomen - Zoological Nomenclature Resource" maintained by Alan P. Peterson at http://www.zoonomen.net',
#      'create_date': '2007-10-11 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '431',
#      'source_type': 'website',
#      'source_name': 'AOU Check-List (07-2007)',
#      'version': 'Jul-2007',
#      'acquisition_date': '2007-08-28 00:00:00',
#      'source_comment': 'American Ornithologists\' Union\'s "List of the 2,046 Bird Species (With Scientific and English Names) Known From the A.O.U. Check-list Area" (AOU Check-list, 7th edition, updated with Supplements 42-48), maintained at http://www.aou.org/',
#      'create_date': '2007-10-11 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '432',
#      'source_type': 'website',
#      'source_name': 'Gill & Wright (2006) corrigenda/updates - 21-Sep-2007',
#      'version': '1.1',
#      'acquisition_date': '2007-09-21 00:00:00',
#      'source_comment': 'Corrigenda & updates for "BIRDS OF THE WORLD Recommended English Names" available at http://www.worldbirdnames.org/',
#      'create_date': '2007-10-11 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Aves'},
#     {'rank': 'Order', 'name': 'Passeriformes'},
#     {'rank': 'Family', 'name': 'Emberizidae'},
#     {'rank': 'Genus', 'name': 'Artemisiospiza'},
#     {'rank': 'Species', 'name': 'Artemisiospiza belli'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Aves',
#     'Passeriformes',
#     'Emberizidae',
#     'Artemisiospiza',
#     'Artemisiospiza belli'],
#    'commonnames': [{'name': 'Sage Sparrow', 'language': 'English'},
#     {'name': 'Zacatonero de artemisa', 'language': 'Spanish'}]}],
#  [{'tsn': '960160',
#    'nameWInd': 'Brucella melitensis',
#    'nameWOInd': 'Brucella melitensis',
#    'unit1': 'Brucella',
#    'unit2': 'melitensis',
#    'usage': 'valid',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Hughes, 1893) Meyer and Shaw, 1920 emend. Verger et al., 1985',
#    'kingdom': 'Bacteria',
#    'parentTSN': '956860',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['960160:$Brucella abortus$Brucella canis$Brucella neotomae$Brucella ovis$Brucella suis$'],
#    'synonymTSNs': ['960160:$968200$968201$968202$968203$968204$'],
#    '_version_': 1643585609141321732,
#    'date_created': '2015-03-02 13:47:03',
#    'date_modified': '2015-03-02 00:00:00',
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '1096',
#      'source_type': 'website',
#      'source_name': 'Bacterial Nomenclature up-to-date',
#      'version': 'Jun 2012',
#      'acquisition_date': '2012-07-02 00:00:00',
#      'source_comment': 'Bacterial Nomenclature up-to-date published by the Leibniz Institute DSMZ-German Collection of Microorganisms and Cell Cultures at http://www.dsmz.de/bacterial-diversity/bacterial-nomenclature-up-to-date.html',
#      'create_date': '2015-03-02 00:00:00',
#      'update_date': ''}],
#    'comment': [{'comment_id': '30314',
#      'commentator': 'DSMZ',
#      'comment_text': 'species (AL)',
#      'create_date': '2014-12-22 13:38:32',
#      'update_date': '2014-12-22 00:00:00'},
#     {'comment_id': '31480',
#      'commentator': 'DSMZ',
#      'comment_text': 'International Journal of Systematic and Evolutionary Microbiology (IJSEM), 1980 30:270: Approved List',
#      'create_date': '2015-03-02 14:57:15',
#      'update_date': '2015-03-02 00:00:00'},
#     {'comment_id': '35334',
#      'commentator': 'DSMZ',
#      'comment_text': 'emend. description: IJSB 35:294*',
#      'create_date': '2015-03-02 15:08:56',
#      'update_date': '2015-03-02 00:00:00'},
#     {'comment_id': '35335',
#      'commentator': 'DSMZ',
#      'comment_text': 'Risk group 3; Strains ATCC 23456',
#      'create_date': '2015-03-02 15:08:57',
#      'update_date': '2015-03-02 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Bacteria'},
#     {'rank': 'Subkingdom', 'name': 'Negibacteria'},
#     {'rank': 'Phylum', 'name': 'Proteobacteria'},
#     {'rank': 'Class', 'name': 'Alphaproteobacteria'},
#     {'rank': 'Order', 'name': 'Rhizobiales'},
#     {'rank': 'Family', 'name': 'Brucellaceae'},
#     {'rank': 'Genus', 'name': 'Brucella'},
#     {'rank': 'Species', 'name': 'Brucella melitensis'}],
#    'hierarchy': ['Bacteria',
#     'Negibacteria',
#     'Proteobacteria',
#     'Alphaproteobacteria',
#     'Rhizobiales',
#     'Brucellaceae',
#     'Brucella',
#     'Brucella melitensis']},
#   {'tsn': '968200',
#    'nameWInd': 'Brucella abortus',
#    'nameWOInd': 'Brucella abortus',
#    'unit1': 'Brucella',
#    'unit2': 'abortus',
#    'usage': 'invalid',
#    'unacceptReason': 'junior synonym',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Schmidt, 1901) Meyer and Shaw, 1920',
#    'kingdom': 'Bacteria',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['960160:$Brucella abortus$Brucella canis$Brucella neotomae$Brucella ovis$Brucella suis$'],
#    'synonymTSNs': ['960160:$968200$968201$968202$968203$968204$'],
#    'acceptedTSN': ['960160'],
#    '_version_': 1643585610053582855,
#    'date_created': '2015-03-02 14:41:31',
#    'date_modified': '2015-03-02 00:00:00',
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '1096',
#      'source_type': 'website',
#      'source_name': 'Bacterial Nomenclature up-to-date',
#      'version': 'Jun 2012',
#      'acquisition_date': '2012-07-02 00:00:00',
#      'source_comment': 'Bacterial Nomenclature up-to-date published by the Leibniz Institute DSMZ-German Collection of Microorganisms and Cell Cultures at http://www.dsmz.de/bacterial-diversity/bacterial-nomenclature-up-to-date.html',
#      'create_date': '2015-03-02 00:00:00',
#      'update_date': ''}],
#    'comment': [{'comment_id': '31480',
#      'commentator': 'DSMZ',
#      'comment_text': 'International Journal of Systematic and Evolutionary Microbiology (IJSEM), 1980 30:270: Approved List',
#      'create_date': '2015-03-02 14:57:15',
#      'update_date': '2015-03-02 00:00:00'},
#     {'comment_id': '33046',
#      'commentator': 'DSMZ',
#      'comment_text': 'species (AL), heterotypic syn.',
#      'create_date': '2015-03-02 15:02:02',
#      'update_date': '2015-03-02 00:00:00'},
#     {'comment_id': '47968',
#      'commentator': 'DSMZ',
#      'comment_text': 'Brucella melitensis biovar abortus IJSB 35:294*',
#      'create_date': '2015-03-02 15:49:20',
#      'update_date': '2015-03-02 00:00:00'},
#     {'comment_id': '47969',
#      'commentator': 'DSMZ',
#      'comment_text': 'Risk group 3; Strains ATCC 23448',
#      'create_date': '2015-03-02 15:49:20',
#      'update_date': '2015-03-02 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Bacteria'},
#     {'rank': 'Subkingdom', 'name': 'Negibacteria'},
#     {'rank': 'Phylum', 'name': 'Proteobacteria'},
#     {'rank': 'Class', 'name': 'Alphaproteobacteria'},
#     {'rank': 'Order', 'name': 'Rhizobiales'},
#     {'rank': 'Family', 'name': 'Brucellaceae'},
#     {'rank': 'Genus', 'name': 'Brucella'},
#     {'rank': 'Species', 'name': 'Brucella melitensis'}],
#    'hierarchy': ['Bacteria',
#     'Negibacteria',
#     'Proteobacteria',
#     'Alphaproteobacteria',
#     'Rhizobiales',
#     'Brucellaceae',
#     'Brucella',
#     'Brucella melitensis']}],
#  [{'tsn': '23512',
#    'nameWInd': 'Arctostaphylos patula',
#    'nameWOInd': 'Arctostaphylos patula',
#    'unit1': 'Arctostaphylos',
#    'unit2': 'patula',
#    'usage': 'accepted',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'Greene',
#    'kingdom': 'Plantae',
#    'parentTSN': '23467',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['23512:$Arctostaphylos acutifolia$Arctostaphylos patula$Arctostaphylos patula platyphy$Arctostaphylos acutifolia$Arctostaphylos parryana pineto$Arctostaphylos patula coalesce$'],
#    'synonymTSNs': ['23512:$23471$23513$23514$184524$184525$184526$'],
#    '_version_': 1643585526601613318,
#    'date_created': '1996-06-13 14:51:08',
#    'date_modified': '2012-05-31 00:00:00',
#    'geographicDivision': [{'geographic_value': 'North America',
#      'update_date': '2012-05-31 00:00:00'}],
#    'jurisdiction': [{'jurisdiction_value': 'Continental US',
#      'origin': 'Native',
#      'update_date': '2012-05-31 00:00:00'}],
#    'expert': [{'reference_type': 'EXP',
#      'expert_id': '204',
#      'expert_name': 'Walter S. Judd',
#      'expert_comment': 'Professor, Department of Biology, University of Florida, Gainesville, Florida, 32611-7800, USA',
#      'create_date': '2012-05-31 00:00:00',
#      'update_date': ''}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '7',
#      'source_type': 'database',
#      'source_name': 'NODC Taxonomic Code',
#      'version': '8.0',
#      'acquisition_date': '1996-07-29 00:00:00',
#      'source_comment': '',
#      'create_date': '2010-01-14 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '794',
#      'source_type': 'database',
#      'source_name': 'Ericaceae of North America Update',
#      'version': '2010',
#      'acquisition_date': '2010-12-06 00:00:00',
#      'source_comment': 'Updated by the Flora of North America Expertise Network, in connection with an update for USDA PLANTS (2007-2010)',
#      'create_date': '2012-05-31 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '795',
#      'source_type': 'website',
#      'source_name': 'Jepson Manual',
#      'version': '2',
#      'acquisition_date': '2010-11-01 00:00:00',
#      'source_comment': 'Wallace, Gary D. 2011 (in press). Ericaceae. In B. G. Baldwin et al. (eds.), The Jepson Manual: Vascular Plants of California. Univ. of California Press, Berkeley. Retrieved from ucjeps.berkeley.edu/jepsonmanual/review/',
#      'create_date': '2012-05-31 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#     {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#     {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#     {'rank': 'Superdivision', 'name': 'Embryophyta'},
#     {'rank': 'Division', 'name': 'Tracheophyta'},
#     {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#     {'rank': 'Class', 'name': 'Magnoliopsida'},
#     {'rank': 'Superorder', 'name': 'Asteranae'},
#     {'rank': 'Order', 'name': 'Ericales'},
#     {'rank': 'Family', 'name': 'Ericaceae'},
#     {'rank': 'Genus', 'name': 'Arctostaphylos'},
#     {'rank': 'Species', 'name': 'Arctostaphylos patula'}],
#    'hierarchy': ['Plantae',
#     'Viridiplantae',
#     'Streptophyta',
#     'Embryophyta',
#     'Tracheophyta',
#     'Spermatophytina',
#     'Magnoliopsida',
#     'Asteranae',
#     'Ericales',
#     'Ericaceae',
#     'Arctostaphylos',
#     'Arctostaphylos patula'],
#    'commonnames': [{'name': 'greenleaf manzanita', 'language': 'English'}]},
#   {'tsn': '23513',
#    'nameWInd': 'Arctostaphylos patula',
#    'nameWOInd': 'Arctostaphylos patula',
#    'unit1': 'Arctostaphylos',
#    'unit2': 'patula',
#    'usage': 'not accepted',
#    'unacceptReason': 'database artifact',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'Greene',
#    'kingdom': 'Plantae',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['23512:$Arctostaphylos acutifolia$Arctostaphylos patula$Arctostaphylos patula platyphy$Arctostaphylos acutifolia$Arctostaphylos parryana pineto$Arctostaphylos patula coalesce$'],
#    'synonymTSNs': ['23512:$23471$23513$23514$184524$184525$184526$'],
#    'acceptedTSN': ['23512'],
#    '_version_': 1643585526602661888,
#    'date_created': '1996-06-13 14:51:08',
#    'date_modified': '2012-05-31 00:00:00',
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '7',
#      'source_type': 'database',
#      'source_name': 'NODC Taxonomic Code',
#      'version': '8.0',
#      'acquisition_date': '1996-07-29 00:00:00',
#      'source_comment': '',
#      'create_date': '2010-01-14 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '168',
#      'source_type': 'database',
#      'source_name': 'The PLANTS Database',
#      'version': '4.0.4',
#      'acquisition_date': '1996-07-26 00:00:00',
#      'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#      'create_date': '2004-02-23 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '169',
#      'source_type': 'database',
#      'source_name': 'The PLANTS Database',
#      'version': '5.1.1',
#      'acquisition_date': '2000-01-21 00:00:00',
#      'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#      'create_date': '2004-02-23 00:00:00',
#      'update_date': ''}],
#    'comment': [{'comment_id': '24221',
#      'commentator': 'S.N. Alexander, ITIS Data Development Specialist',
#      'comment_text': "Delete: database artifact. This record was originally 'Arctostaphylos patula patula' (TSN 23513), and was later mistakenly turned into 'Arctostaphylos patula,' a name that was already present in ITIS (with its own TSN, 23512). These kinds of changes (rank and name string changes, and new duplications) are in violation of ITIS' data management requirements. Refer instead to either Arctostaphylos patula Greene (TSN 23512), or to Arctostaphylos patula ssp. patula Greene",
#      'create_date': '2012-05-31 11:10:16',
#      'update_date': '2012-05-31 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#     {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#     {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#     {'rank': 'Superdivision', 'name': 'Embryophyta'},
#     {'rank': 'Division', 'name': 'Tracheophyta'},
#     {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#     {'rank': 'Class', 'name': 'Magnoliopsida'},
#     {'rank': 'Superorder', 'name': 'Asteranae'},
#     {'rank': 'Order', 'name': 'Ericales'},
#     {'rank': 'Family', 'name': 'Ericaceae'},
#     {'rank': 'Genus', 'name': 'Arctostaphylos'},
#     {'rank': 'Species', 'name': 'Arctostaphylos patula'}],
#    'hierarchy': ['Plantae',
#     'Viridiplantae',
#     'Streptophyta',
#     'Embryophyta',
#     'Tracheophyta',
#     'Spermatophytina',
#     'Magnoliopsida',
#     'Asteranae',
#     'Ericales',
#     'Ericaceae',
#     'Arctostaphylos',
#     'Arctostaphylos patula']}],
#  [{'tsn': '825373',
#    'nameWInd': 'Thrichomys pachyurus',
#    'nameWOInd': 'Thrichomys pachyurus',
#    'unit1': 'Thrichomys',
#    'unit2': 'pachyurus',
#    'usage': 'valid',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Wagner, 1845)',
#    'kingdom': 'Animalia',
#    'parentTSN': '584649',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['825373:$Thrichomys fosteri$'],
#    'synonymTSNs': ['825373:$825422$'],
#    '_version_': 1643585592895733768,
#    'date_created': '2011-09-22 13:55:16',
#    'date_modified': '2011-09-22 00:00:00',
#    'geographicDivision': [{'geographic_value': 'South America',
#      'update_date': '2011-09-22 00:00:00'}],
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '8092',
#      'author': 'Woods, Charles A., and C. William Kilpatrick / Wilson, Don E., and DeeAnn M. Reeder, eds.',
#      'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 3rd ed., vol. 2',
#      'other_variable_0': '2005-10-01 00:00:00',
#      'other_variable_1': '2005-10-01 00:00:00',
#      'other_variable_2': 'Johns Hopkins University Press',
#      'other_variable_3': 'Baltimore, Maryland, USA',
#      'other_variable_4': '0-8018-8221-4',
#      'other_variable_6': '1538-1600',
#      'other_variable_8': 'N',
#      'other_variable_9': '2011-09-22 00:00:00'}],
#    'comment': [{'comment_id': '22797',
#      'commentator': 'Wilson & Reeder, eds. (2005)',
#      'comment_text': 'Comments: Originally described in the genus Isothrix by Wagner (1845) and included in Isothrix by Tate (1935) and Ellerman (1940). Included in Thrichomys apereoides by Cabrera (1961) but recognized as a distinct species based on chromosomal differentiation (Bonvicino et al., 2002) and sequence divergence (Braggio and Bonvicino, 2004). Karyotype has 2n=34; FN=64 (Bonvicino et al., 2002)',
#      'create_date': '2011-09-22 13:58:35',
#      'update_date': '2011-09-22 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Mammalia'},
#     {'rank': 'Subclass', 'name': 'Theria'},
#     {'rank': 'Infraclass', 'name': 'Eutheria'},
#     {'rank': 'Order', 'name': 'Rodentia'},
#     {'rank': 'Suborder', 'name': 'Hystricomorpha'},
#     {'rank': 'Infraorder', 'name': 'Hystricognathi'},
#     {'rank': 'Family', 'name': 'Echimyidae'},
#     {'rank': 'Subfamily', 'name': 'Eumysopinae'},
#     {'rank': 'Genus', 'name': 'Thrichomys'},
#     {'rank': 'Species', 'name': 'Thrichomys pachyurus'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Mammalia',
#     'Theria',
#     'Eutheria',
#     'Rodentia',
#     'Hystricomorpha',
#     'Hystricognathi',
#     'Echimyidae',
#     'Eumysopinae',
#     'Thrichomys',
#     'Thrichomys pachyurus'],
#    'commonnames': [{'name': 'Paraguayan Punaré', 'language': 'English'}]},
#   {'tsn': '825422',
#    'nameWInd': 'Thrichomys fosteri',
#    'nameWOInd': 'Thrichomys fosteri',
#    'unit1': 'Thrichomys',
#    'unit2': 'fosteri',
#    'usage': 'invalid',
#    'unacceptReason': 'junior synonym',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'Thomas, 1903',
#    'kingdom': 'Animalia',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['825373:$Thrichomys fosteri$'],
#    'synonymTSNs': ['825373:$825422$'],
#    'acceptedTSN': ['825373'],
#    '_version_': 1643585592902025216,
#    'date_created': '2011-09-22 13:55:58',
#    'date_modified': '2011-09-22 00:00:00',
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '8092',
#      'author': 'Woods, Charles A., and C. William Kilpatrick / Wilson, Don E., and DeeAnn M. Reeder, eds.',
#      'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 3rd ed., vol. 2',
#      'other_variable_0': '2005-10-01 00:00:00',
#      'other_variable_1': '2005-10-01 00:00:00',
#      'other_variable_2': 'Johns Hopkins University Press',
#      'other_variable_3': 'Baltimore, Maryland, USA',
#      'other_variable_4': '0-8018-8221-4',
#      'other_variable_6': '1538-1600',
#      'other_variable_8': 'N',
#      'other_variable_9': '2011-09-22 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Mammalia'},
#     {'rank': 'Subclass', 'name': 'Theria'},
#     {'rank': 'Infraclass', 'name': 'Eutheria'},
#     {'rank': 'Order', 'name': 'Rodentia'},
#     {'rank': 'Suborder', 'name': 'Hystricomorpha'},
#     {'rank': 'Infraorder', 'name': 'Hystricognathi'},
#     {'rank': 'Family', 'name': 'Echimyidae'},
#     {'rank': 'Subfamily', 'name': 'Eumysopinae'},
#     {'rank': 'Genus', 'name': 'Thrichomys'},
#     {'rank': 'Species', 'name': 'Thrichomys pachyurus'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Mammalia',
#     'Theria',
#     'Eutheria',
#     'Rodentia',
#     'Hystricomorpha',
#     'Hystricognathi',
#     'Echimyidae',
#     'Eumysopinae',
#     'Thrichomys',
#     'Thrichomys pachyurus']}],
#  [{'tsn': '522542',
#    'nameWInd': 'Thinopyrum ponticum',
#    'nameWOInd': 'Thinopyrum ponticum',
#    'unit1': 'Thinopyrum',
#    'unit2': 'ponticum',
#    'usage': 'not accepted',
#    'unacceptReason': 'other, see comments',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Podp.) Z.-W. Liu & R.R.-C. Wang',
#    'kingdom': 'Plantae',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['785041:$Elytrigia pontica$Agropyron varnense$Elymus varnensis$Thinopyrum ponticum$Elymus elongatus ponticus$Lophopyrum ponticum$Thinopyrum ponticum$Triticum ponticum$Elymus elongatus ponticus$Elytrigia elongata pontica$Elytrigia pontica pontica$'],
#    'synonymTSNs': ['785041:$502290$508476$512849$522542$534861$790996$795814$796242$797784$797802$797804$'],
#    'acceptedTSN': ['785041'],
#    '_version_': 1643585554766364673,
#    'date_created': '1996-11-04 17:57:08',
#    'date_modified': '2010-11-30 00:00:00',
#    'geographicDivision': [{'geographic_value': 'North America',
#      'update_date': '2000-03-15 00:00:00'}],
#    'jurisdiction': [{'jurisdiction_value': 'Continental US',
#      'origin': 'Introduced',
#      'update_date': '2000-03-15 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '168',
#      'source_type': 'database',
#      'source_name': 'The PLANTS Database',
#      'version': '4.0.4',
#      'acquisition_date': '1996-07-26 00:00:00',
#      'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#      'create_date': '2004-02-23 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '169',
#      'source_type': 'database',
#      'source_name': 'The PLANTS Database',
#      'version': '5.1.1',
#      'acquisition_date': '2000-01-21 00:00:00',
#      'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#      'create_date': '2004-02-23 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '483',
#      'source_type': 'database',
#      'source_name': 'Catalogue of New World Grasses (Poaceae) - 11/2009',
#      'version': '24/11/2009',
#      'acquisition_date': '2009-11-24 00:00:00',
#      'source_comment': 'Maintained by R. J. Soreng et al., at http://www.tropicos.org/Project/CNWG and formerly at http://mobot.mobot.org/W3T/Search/nwgc.html',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '485',
#      'source_type': 'database',
#      'source_name': 'Poaceae update',
#      'version': 'Sept. 2010',
#      'acquisition_date': '2010-09-01 00:00:00',
#      'source_comment': 'Poaceae update for ITIS, in cooperation with NatureServe, and based on the Catalogue of New World Grasses database and other sources',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''}],
#    'comment': [{'comment_id': '20946',
#      'commentator': 'David Nicolson - ITIS Data Development Coordinator',
#      'comment_text': 'No "unacceptability reason" was explicitly supplied in Catalogue of New World Grasses data export',
#      'create_date': '2010-12-01 00:38:46',
#      'update_date': '2016-01-05 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#     {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#     {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#     {'rank': 'Superdivision', 'name': 'Embryophyta'},
#     {'rank': 'Division', 'name': 'Tracheophyta'},
#     {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#     {'rank': 'Class', 'name': 'Magnoliopsida'},
#     {'rank': 'Superorder', 'name': 'Lilianae'},
#     {'rank': 'Order', 'name': 'Poales'},
#     {'rank': 'Family', 'name': 'Poaceae'},
#     {'rank': 'Genus', 'name': 'Thinopyrum'},
#     {'rank': 'Species', 'name': 'Thinopyrum ponticum'}],
#    'hierarchy': ['Plantae',
#     'Viridiplantae',
#     'Streptophyta',
#     'Embryophyta',
#     'Tracheophyta',
#     'Spermatophytina',
#     'Magnoliopsida',
#     'Lilianae',
#     'Poales',
#     'Poaceae',
#     'Thinopyrum',
#     'Thinopyrum ponticum'],
#    'commonnames': [{'name': 'rush wheatgrass', 'language': 'unspecified'},
#     {'name': 'tall wheatgrass', 'language': 'unspecified'}]},
#   {'tsn': '785041',
#    'nameWInd': 'Thinopyrum ponticum',
#    'nameWOInd': 'Thinopyrum ponticum',
#    'unit1': 'Thinopyrum',
#    'unit2': 'ponticum',
#    'usage': 'accepted',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Podp.) Barkworth & D.R. Dewey',
#    'kingdom': 'Plantae',
#    'parentTSN': '564908',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['785041:$Elytrigia pontica$Agropyron varnense$Elymus varnensis$Thinopyrum ponticum$Elymus elongatus ponticus$Lophopyrum ponticum$Thinopyrum ponticum$Triticum ponticum$Elymus elongatus ponticus$Elytrigia elongata pontica$Elytrigia pontica pontica$'],
#    'synonymTSNs': ['785041:$502290$508476$512849$522542$534861$790996$795814$796242$797784$797802$797804$'],
#    '_version_': 1643585588144635908,
#    'date_created': '2010-11-30 18:55:40',
#    'date_modified': '2010-11-30 00:00:00',
#    'geographicDivision': [{'geographic_value': 'North America',
#      'update_date': '2010-12-01 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '483',
#      'source_type': 'database',
#      'source_name': 'Catalogue of New World Grasses (Poaceae) - 11/2009',
#      'version': '24/11/2009',
#      'acquisition_date': '2009-11-24 00:00:00',
#      'source_comment': 'Maintained by R. J. Soreng et al., at http://www.tropicos.org/Project/CNWG and formerly at http://mobot.mobot.org/W3T/Search/nwgc.html',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '485',
#      'source_type': 'database',
#      'source_name': 'Poaceae update',
#      'version': 'Sept. 2010',
#      'acquisition_date': '2010-09-01 00:00:00',
#      'source_comment': 'Poaceae update for ITIS, in cooperation with NatureServe, and based on the Catalogue of New World Grasses database and other sources',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#     {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#     {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#     {'rank': 'Superdivision', 'name': 'Embryophyta'},
#     {'rank': 'Division', 'name': 'Tracheophyta'},
#     {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#     {'rank': 'Class', 'name': 'Magnoliopsida'},
#     {'rank': 'Superorder', 'name': 'Lilianae'},
#     {'rank': 'Order', 'name': 'Poales'},
#     {'rank': 'Family', 'name': 'Poaceae'},
#     {'rank': 'Genus', 'name': 'Thinopyrum'},
#     {'rank': 'Species', 'name': 'Thinopyrum ponticum'}],
#    'hierarchy': ['Plantae',
#     'Viridiplantae',
#     'Streptophyta',
#     'Embryophyta',
#     'Tracheophyta',
#     'Spermatophytina',
#     'Magnoliopsida',
#     'Lilianae',
#     'Poales',
#     'Poaceae',
#     'Thinopyrum',
#     'Thinopyrum ponticum']},
#   {'tsn': '795814',
#    'nameWInd': 'Thinopyrum ponticum',
#    'nameWOInd': 'Thinopyrum ponticum',
#    'unit1': 'Thinopyrum',
#    'unit2': 'ponticum',
#    'usage': 'not accepted',
#    'unacceptReason': 'other, see comments',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'Barkworth & D.R. Dewey',
#    'kingdom': 'Plantae',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['785041:$Elytrigia pontica$Agropyron varnense$Elymus varnensis$Thinopyrum ponticum$Elymus elongatus ponticus$Lophopyrum ponticum$Thinopyrum ponticum$Triticum ponticum$Elymus elongatus ponticus$Elytrigia elongata pontica$Elytrigia pontica pontica$'],
#    'synonymTSNs': ['785041:$502290$508476$512849$522542$534861$790996$795814$796242$797784$797802$797804$'],
#    'acceptedTSN': ['785041'],
#    '_version_': 1643585589473181698,
#    'date_created': '2010-11-30 21:32:22',
#    'date_modified': '2010-11-30 00:00:00',
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '483',
#      'source_type': 'database',
#      'source_name': 'Catalogue of New World Grasses (Poaceae) - 11/2009',
#      'version': '24/11/2009',
#      'acquisition_date': '2009-11-24 00:00:00',
#      'source_comment': 'Maintained by R. J. Soreng et al., at http://www.tropicos.org/Project/CNWG and formerly at http://mobot.mobot.org/W3T/Search/nwgc.html',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '485',
#      'source_type': 'database',
#      'source_name': 'Poaceae update',
#      'version': 'Sept. 2010',
#      'acquisition_date': '2010-09-01 00:00:00',
#      'source_comment': 'Poaceae update for ITIS, in cooperation with NatureServe, and based on the Catalogue of New World Grasses database and other sources',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''}],
#    'comment': [{'comment_id': '20946',
#      'commentator': 'David Nicolson - ITIS Data Development Coordinator',
#      'comment_text': 'No "unacceptability reason" was explicitly supplied in Catalogue of New World Grasses data export',
#      'create_date': '2010-12-01 00:38:46',
#      'update_date': '2016-01-05 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#     {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#     {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#     {'rank': 'Superdivision', 'name': 'Embryophyta'},
#     {'rank': 'Division', 'name': 'Tracheophyta'},
#     {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#     {'rank': 'Class', 'name': 'Magnoliopsida'},
#     {'rank': 'Superorder', 'name': 'Lilianae'},
#     {'rank': 'Order', 'name': 'Poales'},
#     {'rank': 'Family', 'name': 'Poaceae'},
#     {'rank': 'Genus', 'name': 'Thinopyrum'},
#     {'rank': 'Species', 'name': 'Thinopyrum ponticum'}],
#    'hierarchy': ['Plantae',
#     'Viridiplantae',
#     'Streptophyta',
#     'Embryophyta',
#     'Tracheophyta',
#     'Spermatophytina',
#     'Magnoliopsida',
#     'Lilianae',
#     'Poales',
#     'Poaceae',
#     'Thinopyrum',
#     'Thinopyrum ponticum']}],
#  [{'tsn': '677538',
#    'nameWInd': 'Lyrurus tetrix',
#    'nameWOInd': 'Lyrurus tetrix',
#    'unit1': 'Lyrurus',
#    'unit2': 'tetrix',
#    'usage': 'valid',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Linnaeus, 1758)',
#    'kingdom': 'Animalia',
#    'parentTSN': '677534',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['677538:$Tetrao tetrix$'],
#    'synonymTSNs': ['677538:$553891$'],
#    '_version_': 1643585574377881600,
#    'date_created': '2005-06-08 08:29:33',
#    'date_modified': '2005-06-08 00:00:00',
#    'geographicDivision': [{'geographic_value': 'Europe & Northern Asia (excluding China)',
#      'update_date': '2005-06-08 00:00:00'}],
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '5324',
#      'author': 'Dickinson, Edward C., ed.',
#      'title': 'The Howard and Moore Complete Checklist of the Birds of the World, 3rd edition',
#      'other_variable_0': '2003-01-01 00:00:00',
#      'other_variable_1': '2003-01-01 00:00:00',
#      'other_variable_2': 'Princeton University Press',
#      'other_variable_3': 'Princeton, New Jersey, USA',
#      'other_variable_4': '0-691-11701-2',
#      'other_variable_6': '1039',
#      'other_variable_8': 'N',
#      'other_variable_9': '2018-06-26 00:00:00'},
#     {'reference_type': 'PUB',
#      'reference_id': '5351',
#      'author': 'Gill, Frank, and Minturn Wright',
#      'title': 'Birds of the World: Recommended English Names',
#      'other_variable_0': '2006-01-01 00:00:00',
#      'other_variable_1': '2006-01-01 00:00:00',
#      'other_variable_2': 'Princeton University Press',
#      'other_variable_3': 'Princeton, New Jersey, USA',
#      'other_variable_4': '0-691-12827-8',
#      'other_variable_6': 'ix + 259',
#      'other_variable_7': 'Includes a CD-ROM with the full dataset',
#      'other_variable_9': '2018-06-26 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '303',
#      'source_type': 'website',
#      'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2005.05.23',
#      'version': '23-May-05',
#      'acquisition_date': '2005-05-31 00:00:00',
#      'source_comment': '"Zoonomen Nomenclatural data" maintained by Alan P. Peterson at http://www.zoonomen.net',
#      'create_date': '2005-06-28 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Aves'},
#     {'rank': 'Order', 'name': 'Galliformes'},
#     {'rank': 'Family', 'name': 'Phasianidae'},
#     {'rank': 'Subfamily', 'name': 'Tetraoninae'},
#     {'rank': 'Genus', 'name': 'Lyrurus'},
#     {'rank': 'Species', 'name': 'Lyrurus tetrix'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Aves',
#     'Galliformes',
#     'Phasianidae',
#     'Tetraoninae',
#     'Lyrurus',
#     'Lyrurus tetrix'],
#    'commonnames': [{'name': 'Eurasian Black Grouse', 'language': 'English'},
#     {'name': 'Black Grouse', 'language': 'English'}]},
#   {'tsn': '553891',
#    'nameWInd': 'Tetrao tetrix',
#    'nameWOInd': 'Tetrao tetrix',
#    'unit1': 'Tetrao',
#    'unit2': 'tetrix',
#    'usage': 'invalid',
#    'unacceptReason': 'original name/combination',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['677538:$Tetrao tetrix$'],
#    'synonymTSNs': ['677538:$553891$'],
#    'acceptedTSN': ['677538'],
#    '_version_': 1643585558774022144,
#    'date_created': '1998-09-16 14:57:03',
#    'date_modified': '2005-06-08 00:00:00',
#    'expert': [{'reference_type': 'EXP',
#      'expert_id': '11',
#      'expert_name': 'Alan P. Peterson, M.D.',
#      'expert_comment': 'PO Box 1999 Walla Walla, Washington 99362-0999',
#      'create_date': '2001-09-28 00:00:00',
#      'update_date': ''}],
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '2925',
#      'author': 'Peters, James Lee',
#      'title': 'Check-List of Birds of the World, vol. 2',
#      'other_variable_0': '1934-01-01 00:00:00',
#      'other_variable_1': '1934-01-01 00:00:00',
#      'other_variable_2': 'Oxford University Press',
#      'other_variable_3': 'London, England, UK',
#      'other_variable_6': 'xvii + 401',
#      'other_variable_8': 'N',
#      'other_variable_9': '2011-09-22 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '105',
#      'source_type': 'website',
#      'source_name': 'Zoonomen - Zoological Nomenclature Resource',
#      'version': '1998',
#      'acquisition_date': '1998-07-01 00:00:00',
#      'source_comment': 'Alan P. Peterson; http://www.zoonomen.net/',
#      'create_date': '2003-02-27 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Aves'},
#     {'rank': 'Order', 'name': 'Galliformes'},
#     {'rank': 'Family', 'name': 'Phasianidae'},
#     {'rank': 'Subfamily', 'name': 'Tetraoninae'},
#     {'rank': 'Genus', 'name': 'Lyrurus'},
#     {'rank': 'Species', 'name': 'Lyrurus tetrix'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Aves',
#     'Galliformes',
#     'Phasianidae',
#     'Tetraoninae',
#     'Lyrurus',
#     'Lyrurus tetrix']}],
#  [{'tsn': '41103',
#    'nameWInd': 'Poa secunda',
#    'nameWOInd': 'Poa secunda',
#    'unit1': 'Poa',
#    'unit2': 'secunda',
#    'usage': 'accepted',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'J. Presl',
#    'kingdom': 'Plantae',
#    'parentTSN': '41074',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['41103:$Poa fulvescens$Poa tenuifolia$'],
#    'synonymTSNs': ['41103:$794141$794396$'],
#    '_version_': 1643585529033261057,
#    'date_created': '1996-06-13 14:51:08',
#    'date_modified': '2010-11-30 00:00:00',
#    'geographicDivision': [{'geographic_value': 'North America',
#      'update_date': '1996-11-05 00:00:00'},
#     {'geographic_value': 'South America',
#      'update_date': '2010-12-01 00:00:00'}],
#    'jurisdiction': [{'jurisdiction_value': 'Continental US',
#      'origin': 'Native',
#      'update_date': '2000-03-15 00:00:00'},
#     {'jurisdiction_value': 'Alaska',
#      'origin': 'Native',
#      'update_date': '2000-03-15 00:00:00'},
#     {'jurisdiction_value': 'Canada',
#      'origin': 'Native',
#      'update_date': '2010-12-01 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '7',
#      'source_type': 'database',
#      'source_name': 'NODC Taxonomic Code',
#      'version': '8.0',
#      'acquisition_date': '1996-07-29 00:00:00',
#      'source_comment': '',
#      'create_date': '2010-01-14 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '168',
#      'source_type': 'database',
#      'source_name': 'The PLANTS Database',
#      'version': '4.0.4',
#      'acquisition_date': '1996-07-26 00:00:00',
#      'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#      'create_date': '2004-02-23 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '169',
#      'source_type': 'database',
#      'source_name': 'The PLANTS Database',
#      'version': '5.1.1',
#      'acquisition_date': '2000-01-21 00:00:00',
#      'source_comment': 'National Plant Data Center, NRCS, USDA. Baton Rouge, LA 70874-4490 USA. http://plants.usda.gov',
#      'create_date': '2004-02-23 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '483',
#      'source_type': 'database',
#      'source_name': 'Catalogue of New World Grasses (Poaceae) - 11/2009',
#      'version': '24/11/2009',
#      'acquisition_date': '2009-11-24 00:00:00',
#      'source_comment': 'Maintained by R. J. Soreng et al., at http://www.tropicos.org/Project/CNWG and formerly at http://mobot.mobot.org/W3T/Search/nwgc.html',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '485',
#      'source_type': 'database',
#      'source_name': 'Poaceae update',
#      'version': 'Sept. 2010',
#      'acquisition_date': '2010-09-01 00:00:00',
#      'source_comment': 'Poaceae update for ITIS, in cooperation with NatureServe, and based on the Catalogue of New World Grasses database and other sources',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Plantae'},
#     {'rank': 'Subkingdom', 'name': 'Viridiplantae'},
#     {'rank': 'Infrakingdom', 'name': 'Streptophyta'},
#     {'rank': 'Superdivision', 'name': 'Embryophyta'},
#     {'rank': 'Division', 'name': 'Tracheophyta'},
#     {'rank': 'Subdivision', 'name': 'Spermatophytina'},
#     {'rank': 'Class', 'name': 'Magnoliopsida'},
#     {'rank': 'Superorder', 'name': 'Lilianae'},
#     {'rank': 'Order', 'name': 'Poales'},
#     {'rank': 'Family', 'name': 'Poaceae'},
#     {'rank': 'Genus', 'name': 'Poa'},
#     {'rank': 'Species', 'name': 'Poa secunda'}],
#    'hierarchy': ['Plantae',
#     'Viridiplantae',
#     'Streptophyta',
#     'Embryophyta',
#     'Tracheophyta',
#     'Spermatophytina',
#     'Magnoliopsida',
#     'Lilianae',
#     'Poales',
#     'Poaceae',
#     'Poa',
#     'Poa secunda'],
#    'commonnames': [{'name': 'big bluegrass', 'language': 'unspecified'},
#     {'name': 'Sandberg bluegrass', 'language': 'unspecified'},
#     {'name': "Sandberg's bluegrass", 'language': 'unspecified'}]},
#   {'tsn': '794344',
#    'nameWInd': 'Poa secunda',
#    'nameWOInd': 'Poa secunda',
#    'unit1': 'Poa',
#    'unit2': 'secunda',
#    'usage': 'not accepted',
#    'unacceptReason': 'other, see comments',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': 'Zea ex Roem. & Schult.',
#    'kingdom': 'Plantae',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['41223:$Glyceria rupestris$Atropis procumbens$Festuca procumbens$Glyceria procumbens$Panicularia procumbens$Poa procumbens$Poa rupestris$Poa secunda$Pseudosclerochloa rupestris$Sclerochloa procumbens$Scleropoa procumbens$'],
#    'synonymTSNs': ['41223:$514093$786977$790096$790238$791815$794305$794335$794344$794571$794908$794912$'],
#    'acceptedTSN': ['41223'],
#    '_version_': 1643585589289680903,
#    'date_created': '2010-11-30 21:09:56',
#    'date_modified': '2010-11-30 00:00:00',
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '483',
#      'source_type': 'database',
#      'source_name': 'Catalogue of New World Grasses (Poaceae) - 11/2009',
#      'version': '24/11/2009',
#      'acquisition_date': '2009-11-24 00:00:00',
#      'source_comment': 'Maintained by R. J. Soreng et al., at http://www.tropicos.org/Project/CNWG and formerly at http://mobot.mobot.org/W3T/Search/nwgc.html',
#      'create_date': '2010-12-01 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '485',
#      'source_type': 'database',
#      'source_name': 'Poaceae update',
#      'version': 'Sept. 2010',
#      'acquisition_date': '2010-09-01 00:00:00',
# ...
#    'acceptedTSN': ['551209'],
#    '_version_': 1643585570996224004,
#    'date_created': '2004-09-24 11:17:27',
#    'date_modified': '2005-06-20 00:00:00',
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '1727',
#      'author': 'Robins, Richard C., Reeve M. Bailey, Carl E. Bond, James R. Brooker, Ernest A. Lachner, et al.',
#      'title': 'American Fisheries Society Special Publication, no. 20',
#      'other_variable_0': '1991-01-01 00:00:00',
#      'other_variable_1': '1991-01-01 00:00:00',
#      'other_variable_2': 'American Fisheries Society',
#      'other_variable_3': 'Bethesda, Maryland, USA',
#      'other_variable_4': '0-913235-70-9',
#      'other_variable_5': '0097-0638',
#      'other_variable_6': '183',
#      'other_variable_8': 'N',
#      'other_variable_9': '2017-08-28 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '295',
#      'source_type': 'website',
#      'source_name': 'Catalog of Fishes, 27-Sept-2004',
#      'version': '16-Sep-04',
#      'acquisition_date': '2004-09-27 00:00:00',
#      'source_comment': 'http://www.calacademy.org/research/ichthyology/catalog/',
#      'create_date': '2005-05-03 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Actinopterygii'},
#     {'rank': 'Class', 'name': 'Teleostei'},
#     {'rank': 'Superorder', 'name': 'Clupeomorpha'},
#     {'rank': 'Order', 'name': 'Clupeiformes'},
#     {'rank': 'Suborder', 'name': 'Clupeoidei'},
#     {'rank': 'Family', 'name': 'Clupeidae'},
#     {'rank': 'Subfamily', 'name': 'Clupeinae'},
#     {'rank': 'Genus', 'name': 'Clupea'},
#     {'rank': 'Species', 'name': 'Clupea pallasii'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Actinopterygii',
#     'Teleostei',
#     'Clupeomorpha',
#     'Clupeiformes',
#     'Clupeoidei',
#     'Clupeidae',
#     'Clupeinae',
#     'Clupea',
#     'Clupea pallasii'],
#    'commonnames': [{'name': 'Pacific herring', 'language': 'English'}]}],
#  [{'tsn': '175165',
#    'nameWInd': 'Melanitta fusca deglandi',
#    'nameWOInd': 'Melanitta fusca deglandi',
#    'unit1': 'Melanitta',
#    'unit2': 'fusca',
#    'unit3': 'deglandi',
#    'usage': 'valid',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Bonaparte, 1850)',
#    'kingdom': 'Animalia',
#    'parentTSN': '175163',
#    'rankID': '230',
#    'rank': 'Subspecies',
#    'synonyms': ['175165:$Melanitta fusca dixoni$Melanitta deglandi$Melanitta deglandi deglandi$Melanitta deglandi dixoni$'],
#    'synonymTSNs': ['175165:$175166$175167$175168$175169$'],
#    '_version_': 1643585546113515526,
#    'date_created': '1996-06-13 14:51:08',
#    'date_modified': '2007-01-23 00:00:00',
#    'geographicDivision': [{'geographic_value': 'North America',
#      'update_date': '2007-01-23 00:00:00'}],
#    'jurisdiction': [{'jurisdiction_value': 'Alaska',
#      'origin': 'Native',
#      'update_date': '2007-01-23 00:00:00'},
#     {'jurisdiction_value': 'Canada',
#      'origin': 'Native',
#      'update_date': '2007-01-23 00:00:00'},
#     {'jurisdiction_value': 'Continental US',
#      'origin': 'Native',
#      'update_date': '2007-01-23 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '7',
#      'source_type': 'database',
#      'source_name': 'NODC Taxonomic Code',
#      'version': '8.0',
#      'acquisition_date': '1996-07-29 00:00:00',
#      'source_comment': '',
#      'create_date': '2010-01-14 00:00:00',
#      'update_date': ''},
#     {'reference_type': 'SRC',
#      'source_id': '390',
#      'source_type': 'website',
#      'source_name': 'Zoonomen - Zoological Nomenclature Resource, 2006.12.10',
#      'version': '10-Dec-06',
#      'acquisition_date': '2006-12-20 00:00:00',
#      'source_comment': '"Zoonomen - Zoological Nomenclature Resource" maintained by Alan P. Peterson at http://www.zoonomen.net',
#      'create_date': '2007-01-23 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Aves'},
#     {'rank': 'Order', 'name': 'Anseriformes'},
#     {'rank': 'Family', 'name': 'Anatidae'},
#     {'rank': 'Subfamily', 'name': 'Anatinae'},
#     {'rank': 'Genus', 'name': 'Melanitta'},
#     {'rank': 'Species', 'name': 'Melanitta fusca'},
#     {'rank': 'Subspecies', 'name': 'Melanitta fusca deglandi'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Aves',
#     'Anseriformes',
#     'Anatidae',
#     'Anatinae',
#     'Melanitta',
#     'Melanitta fusca',
#     'Melanitta fusca deglandi']},
#   {'tsn': '175167',
#    'nameWInd': 'Melanitta deglandi',
#    'nameWOInd': 'Melanitta deglandi',
#    'unit1': 'Melanitta',
#    'unit2': 'deglandi',
#    'usage': 'invalid',
#    'unacceptReason': 'subsequent name/combination',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Bonaparte, 1850)',
#    'kingdom': 'Animalia',
#    'rankID': '220',
#    'rank': 'Species',
#    'synonyms': ['175165:$Melanitta fusca dixoni$Melanitta deglandi$Melanitta deglandi deglandi$Melanitta deglandi dixoni$'],
#    'synonymTSNs': ['175165:$175166$175167$175168$175169$'],
#    'acceptedTSN': ['175165'],
#    '_version_': 1643585546114564097,
#    'date_created': '1996-06-13 14:51:08',
#    'date_modified': '2007-01-23 00:00:00',
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '2909',
#      'author': "American Ornithologists' Union",
#      'title': 'Check-list of North American Birds, 5th Edition',
#      'other_variable_0': '1957-01-01 00:00:00',
#      'other_variable_1': '1957-01-01 00:00:00',
#      'other_variable_2': "American Ornithologists' Union",
#      'other_variable_3': 'Baltimore, Maryland, USA',
#      'other_variable_6': 'xiii + 691',
#      'other_variable_8': 'N',
#      'other_variable_9': '2018-06-26 00:00:00'},
#     {'reference_type': 'PUB',
#      'reference_id': '2916',
#      'author': "American Ornithologists' Union",
#      'title': 'Check-list of North American Birds, 6th Edition',
#      'other_variable_0': '1983-01-01 00:00:00',
#      'other_variable_1': '1983-01-01 00:00:00',
#      'other_variable_2': "American Ornithologists' Union",
#      'other_variable_3': 'Washington, DC, USA',
#      'other_variable_4': '0-943610-32-X',
#      'other_variable_6': 'xxix + 877',
#      'other_variable_8': 'N',
#      'other_variable_9': '2015-10-28 00:00:00'},
#     {'reference_type': 'PUB',
#      'reference_id': '5351',
#      'author': 'Gill, Frank, and Minturn Wright',
#      'title': 'Birds of the World: Recommended English Names',
#      'other_variable_0': '2006-01-01 00:00:00',
#      'other_variable_1': '2006-01-01 00:00:00',
#      'other_variable_2': 'Princeton University Press',
#      'other_variable_3': 'Princeton, New Jersey, USA',
#      'other_variable_4': '0-691-12827-8',
#      'other_variable_6': 'ix + 259',
#      'other_variable_7': 'Includes a CD-ROM with the full dataset',
#      'other_variable_8': 'N',
#      'other_variable_9': '2018-06-26 00:00:00'}],
#    'otherSource': [{'reference_type': 'SRC',
#      'source_id': '7',
#      'source_type': 'database',
#      'source_name': 'NODC Taxonomic Code',
#      'version': '8.0',
#      'acquisition_date': '1996-07-29 00:00:00',
#      'source_comment': '',
#      'create_date': '2010-01-14 00:00:00',
#      'update_date': ''}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Aves'},
#     {'rank': 'Order', 'name': 'Anseriformes'},
#     {'rank': 'Family', 'name': 'Anatidae'},
#     {'rank': 'Subfamily', 'name': 'Anatinae'},
#     {'rank': 'Genus', 'name': 'Melanitta'},
#     {'rank': 'Species', 'name': 'Melanitta fusca'},
#     {'rank': 'Subspecies', 'name': 'Melanitta fusca deglandi'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Aves',
#     'Anseriformes',
#     'Anatidae',
#     'Anatinae',
#     'Melanitta',
#     'Melanitta fusca',
#     'Melanitta fusca deglandi'],
#    'commonnames': [{'name': 'White-winged Scoter', 'language': 'English'}]}],
#  [{'tsn': '666753',
#    'nameWInd': 'Rangifer tarandus groenlandicus',
#    'nameWOInd': 'Rangifer tarandus groenlandicus',
#    'unit1': 'Rangifer',
#    'unit2': 'tarandus',
#    'unit3': 'groenlandicus',
#    'usage': 'invalid',
#    'unacceptReason': 'other, see comments',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Linnaeus, 1767)',
#    'kingdom': 'Animalia',
#    'rankID': '230',
#    'rank': 'Subspecies',
#    'synonyms': ['898935:$Rangifer tarandus granti$Rangifer tarandus groenlandicu$Rangifer tarandus arcticus$Rangifer tarandus excelsifrons$Rangifer tarandus grewensis$Rangifer tarandus ramosus$'],
#    'synonymTSNs': ['898935:$666752$666753$898920$898921$898922$898923$'],
#    'acceptedTSN': ['898935'],
#    '_version_': 1643585573221302278,
#    'date_created': '2005-03-09 14:22:57',
#    'date_modified': '2012-12-21 00:00:00',
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '1191',
#      'author': 'Hall, E. Raymond',
#      'title': 'The Mammals of North America, vols. I and II, 2nd ed.',
#      'other_variable_0': '1981-04-03 00:00:00',
#      'other_variable_1': '1981-04-03 00:00:00',
#      'other_variable_2': 'John Wiley and Sons, Inc.',
#      'other_variable_3': 'New York, New York, USA',
#      'other_variable_6': '1181',
#      'other_variable_8': 'N',
#      'other_variable_9': '2019-04-27 00:00:00'},
#     {'reference_type': 'PUB',
#      'reference_id': '1423',
#      'author': 'Wilson, Don E., and Sue Ruff, eds.',
#      'title': 'The Smithsonian Book of North American Mammals',
#      'other_variable_0': '1999-01-01 00:00:00',
#      'other_variable_1': '1999-01-01 00:00:00',
#      'other_variable_2': 'Smithsonian Institution Press',
#      'other_variable_3': 'Washington, DC, USA',
#      'other_variable_4': '1-56098-845-2',
#      'other_variable_6': 'xxv + 750',
#      'other_variable_8': 'N',
#      'other_variable_9': '2019-04-27 00:00:00'}],
#    'comment': [{'comment_id': '25103',
#      'commentator': 'Donna J. Reynolds, NatureServe',
#      'comment_text': 'See Kellogg (1932), New names for mammals proposed by Borowski in 1780 and 1781, Proceedings of the Biological Society of Washington 45:147',
#      'create_date': '2012-12-21 08:37:15',
#      'update_date': '2012-12-21 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Mammalia'},
#     {'rank': 'Subclass', 'name': 'Theria'},
#     {'rank': 'Infraclass', 'name': 'Eutheria'},
#     {'rank': 'Order', 'name': 'Artiodactyla'},
#     {'rank': 'Family', 'name': 'Cervidae'},
#     {'rank': 'Subfamily', 'name': 'Capreolinae'},
#     {'rank': 'Genus', 'name': 'Rangifer'},
#     {'rank': 'Species', 'name': 'Rangifer tarandus'},
#     {'rank': 'Subspecies', 'name': 'Rangifer tarandus groenlandicus'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Mammalia',
#     'Theria',
#     'Eutheria',
#     'Artiodactyla',
#     'Cervidae',
#     'Capreolinae',
#     'Rangifer',
#     'Rangifer tarandus',
#     'Rangifer tarandus groenlandicus']},
#   {'tsn': '898935',
#    'nameWInd': 'Rangifer tarandus groenlandicus',
#    'nameWOInd': 'Rangifer tarandus groenlandicus',
#    'unit1': 'Rangifer',
#    'unit2': 'tarandus',
#    'unit3': 'groenlandicus',
#    'usage': 'valid',
#    'credibilityRating': 'TWG standards met',
#    'taxonAuthor': '(Borowski, 1780)',
#    'kingdom': 'Animalia',
#    'parentTSN': '180701',
#    'rankID': '230',
#    'rank': 'Subspecies',
#    'synonyms': ['898935:$Rangifer tarandus granti$Rangifer tarandus groenlandicu$Rangifer tarandus arcticus$Rangifer tarandus excelsifrons$Rangifer tarandus grewensis$Rangifer tarandus ramosus$'],
#    'synonymTSNs': ['898935:$666752$666753$898920$898921$898922$898923$'],
#    '_version_': 1643585602053996549,
#    'date_created': '2012-12-21 08:36:26',
#    'date_modified': '2012-12-21 00:00:00',
#    'geographicDivision': [{'geographic_value': 'North America',
#      'update_date': '2012-12-21 00:00:00'}],
#    'jurisdiction': [{'jurisdiction_value': 'Canada',
#      'origin': 'Native',
#      'update_date': '2012-12-21 00:00:00'}],
#    'publication': [{'reference_type': 'PUB',
#      'reference_id': '5099',
#      'author': 'Wilson, Don E., and DeeAnn M. Reeder, eds.',
#      'title': 'Mammal Species of the World: A Taxonomic and Geographic Reference, 3rd ed., vols. 1 & 2',
#      'other_variable_0': '2005-10-01 00:00:00',
#      'other_variable_1': '2005-10-01 00:00:00',
#      'other_variable_2': 'Johns Hopkins University Press',
#      'other_variable_3': 'Baltimore, Maryland, USA',
#      'other_variable_4': '0-8018-8221-4',
#      'other_variable_6': '2142',
#      'other_variable_8': 'N',
#      'other_variable_9': '2019-04-27 00:00:00'},
#     {'reference_type': 'PUB',
#      'reference_id': '9109',
#      'author': 'U. S. Fish and Wildlife Service',
#      'title': 'Federal Register, vol. 76, no. 65',
#      'other_variable_0': '2011-04-05 00:00:00',
#      'other_variable_1': '2011-04-05 00:00:00',
#      'other_variable_6': '18701-18706',
#      'other_variable_8': 'N',
#      'other_variable_9': '2012-12-21 00:00:00'}],
#    'comment': [{'comment_id': '25171',
#      'commentator': 'David F. Mitchell, ITIS Data Development Specialist',
#      'comment_text': 'US ESA: Petition to list as threatened or endangered the Dolphin and Union population substantial and initiating status review according to 90-day petition finding, as published in Federal Register Volume 76, Number 65, Pages 18701 - 18706, April 05, 2011',
#      'create_date': '2012-12-21 08:37:19',
#      'update_date': '2012-12-21 00:00:00'}],
#    'biological_taxonomy': [{'rank': 'Kingdom', 'name': 'Animalia'},
#     {'rank': 'Subkingdom', 'name': 'Bilateria'},
#     {'rank': 'Infrakingdom', 'name': 'Deuterostomia'},
#     {'rank': 'Phylum', 'name': 'Chordata'},
#     {'rank': 'Subphylum', 'name': 'Vertebrata'},
#     {'rank': 'Infraphylum', 'name': 'Gnathostomata'},
#     {'rank': 'Superclass', 'name': 'Tetrapoda'},
#     {'rank': 'Class', 'name': 'Mammalia'},
#     {'rank': 'Subclass', 'name': 'Theria'},
#     {'rank': 'Infraclass', 'name': 'Eutheria'},
#     {'rank': 'Order', 'name': 'Artiodactyla'},
#     {'rank': 'Family', 'name': 'Cervidae'},
#     {'rank': 'Subfamily', 'name': 'Capreolinae'},
#     {'rank': 'Genus', 'name': 'Rangifer'},
#     {'rank': 'Species', 'name': 'Rangifer tarandus'},
#     {'rank': 'Subspecies', 'name': 'Rangifer tarandus groenlandicus'}],
#    'hierarchy': ['Animalia',
#     'Bilateria',
#     'Deuterostomia',
#     'Chordata',
#     'Vertebrata',
#     'Gnathostomata',
#     'Tetrapoda',
#     'Mammalia',
#     'Theria',
#     'Eutheria',
#     'Artiodactyla',
#     'Cervidae',
#     'Capreolinae',
#     'Rangifer',
#     'Rangifer tarandus',
#     'Rangifer tarandus groenlandicus'],
#    'commonnames': [{'name': 'barren-ground caribou', 'language': 'English'}]}]]

# %% [markdown]
# This list indicates a few things:
# 1. There is one case where a source name was misspelled, Equus burchelli should have been Equus quagga burchellii. In this case, the search used the TSN of the misspelled species name to correctly identify the species. ITIS considers the record containing the misspelled name to be invalid and the other record valid, even though they are for the same name.
# 2. In three cases, the names provided were considered invalid or not accepted because ITIS considered the names to be synonyms or junior synonyms of the correct species names.
# 3. In one case, ITIS considered the name provided to be invalid because it was an  “original name/combination”.
# 4. In one case, ITIS considered the name provided to be invalid because it was a “subsequent name/combination”.
#
# In the case of any disagreement between WLCI scientists and the taxonomic authority, both the invalid/not accepted and valid/accepted ITIS names from the WLCI species names list will be used for further consultations with additional systems. Two seperate lists, invalid_itis and valid_itis, will be used to distinguish the invalid/not accepted and valid/accepted ITIS names in these consultations. Any information that results from consultations using the invalid_itis list will be cached separately and evaluated for their utility.

# %%
#Create list containing sciencitific names and ITIS usage classifications
itis_explore = list()
for itis_doc_set in itis_cache:
    for itis_doc in itis_doc_set["data"]:
        itis_explore.append({"scientific_name": itis_doc["nameWInd"],"itis_usage": itis_doc["usage"]})

# %%
#Display the ITIS list of species names and ITIS usage (valid/invalid and accepted/not accepted)
itis_explore
# Out:
# [{'scientific_name': 'Otis tarda', 'itis_usage': 'valid'},
#  {'scientific_name': 'Clangula hyemalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Artemisiospiza belli', 'itis_usage': 'valid'},
#  {'scientific_name': 'Amphispiza belli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Taxidea taxus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Schoenoplectus acutus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Shepherdia canadensis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Ericameria nauseosa', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Festuca idahoensis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Elymus lanceolatus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Brucella melitensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Brucella abortus', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Buteo regalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Bombus griseocollis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus nerka', 'itis_usage': 'valid'},
#  {'scientific_name': 'Atriplex gardneri', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Peromyscus keeni', 'itis_usage': 'valid'},
#  {'scientific_name': 'Vulpes velox', 'itis_usage': 'valid'},
#  {'scientific_name': 'Artemisia cana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Arctostaphylos patula', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Arctostaphylos patula', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Pinus contorta', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Anoplopoma fimbria', 'itis_usage': 'valid'},
#  {'scientific_name': 'Colinus virginianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Passer domesticus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Bison bison', 'itis_usage': 'valid'},
#  {'scientific_name': 'Gopherus agassizii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus mykiss', 'itis_usage': 'valid'},
#  {'scientific_name': 'Antilocapra americana', 'itis_usage': 'valid'},
#  {'scientific_name': 'Dendroctonus ponderosae', 'itis_usage': 'valid'},
#  {'scientific_name': 'Juniperus communis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Thrichomys pachyurus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Thrichomys fosteri', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Ursus americanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Macaca sylvanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oreoscoptes montanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Zea mays', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Buteo swainsoni', 'itis_usage': 'valid'},
#  {'scientific_name': 'Aythya marila', 'itis_usage': 'valid'},
#  {'scientific_name': 'Cervus elaphus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Microtus agrestis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Circus cyaneus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Spizella breweri', 'itis_usage': 'valid'},
#  {'scientific_name': 'Grus americana', 'itis_usage': 'valid'},
#  {'scientific_name': 'Vulpes vulpes', 'itis_usage': 'valid'},
#  {'scientific_name': 'Fringilla montifringilla', 'itis_usage': 'valid'},
#  {'scientific_name': 'Atriplex argentea', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Mallotus villosus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Panicum virgatum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Aythya affinis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Tympanuchus pallidicinctus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Lepus townsendii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Falco mexicanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Hesperostipa comata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Buteo jamaicensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Artemisia tridentata ssp. wyomingensis',
#   'itis_usage': 'accepted'},
#  {'scientific_name': 'Vaccinium membranaceum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Xerospermophilus mohavensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Branta leucopsis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pseudoroegneria spicata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Descurainia sophia', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Corvus corax', 'itis_usage': 'valid'},
#  {'scientific_name': 'Setophaga discolor', 'itis_usage': 'valid'},
#  {'scientific_name': 'Myotis sodalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Thinopyrum ponticum', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Thinopyrum ponticum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Thinopyrum ponticum', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Tamiasciurus hudsonicus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Lanius ludovicianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ictidomys tridecemlineatus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Purshia tridentata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Potorous tridactylus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Grus canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Lyrurus tetrix', 'itis_usage': 'valid'},
#  {'scientific_name': 'Tetrao tetrix', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Lasiurus borealis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Catostomus platyrhynchus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Krascheninnikovia lanata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lasiurus cinereus semotus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Betula nana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Juniperus communis var. depressa',
#   'itis_usage': 'accepted'},
#  {'scientific_name': 'Capreolus capreolus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Centrocercus urophasianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ammodytes marinus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Agave americana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Artemisiospiza nevadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Poa secunda', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Poa secunda', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Mergus merganser', 'itis_usage': 'valid'},
#  {'scientific_name': 'Glaucomys volans', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pinus flexilis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Pseudotsuga menziesii', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Gavia immer', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pinus albicaulis', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Connochaetes taurinus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Kochia prostrata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Prunus virginiana', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Clupea pallasii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Apis mellifera', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pelecanus occidentalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Kochia prostrata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Bassia prostrata', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Pascopyrum smithii', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Pascopyrum smithii', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Urocitellus armatus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Peromyscus maniculatus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Myotis septentrionalis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Canis latrans', 'itis_usage': 'valid'},
#  {'scientific_name': 'Amelanchier alnifolia', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Falco sparverius', 'itis_usage': 'valid'},
#  {'scientific_name': 'Rangifer tarandus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Aquila chrysaetos', 'itis_usage': 'valid'},
#  {'scientific_name': 'Procyon lotor', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus tshawytscha', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ursus arctos', 'itis_usage': 'valid'},
#  {'scientific_name': 'Cottus bairdii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Sterna dougallii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Sphaeralcea coccinea', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Odocoileus hemionus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Haliaeetus leucocephalus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Populus tremuloides', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Equus quagga burchellii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Equus burchelli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Ammodramus savannarum', 'itis_usage': 'valid'},
#  {'scientific_name': 'Atriplex canescens', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Oncorhynchus clarkii pleuriticus',
#   'itis_usage': 'valid'},
#  {'scientific_name': 'Clupea pallasii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Clupea pallasi', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Puffinus newelli', 'itis_usage': 'valid'},
#  {'scientific_name': 'Gavia stellata', 'itis_usage': 'valid'},
#  {'scientific_name': 'Alces alces', 'itis_usage': 'valid'},
#  {'scientific_name': 'Ovis canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Rhynchophanes mccownii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Salvelinus namaycush', 'itis_usage': 'valid'},
#  {'scientific_name': 'Lullula arborea', 'itis_usage': 'valid'},
#  {'scientific_name': 'Abies lasiocarpa', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Elymus elymoides', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Podiceps grisegena', 'itis_usage': 'valid'},
#  {'scientific_name': 'Amorpha canescens', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Tamias minimus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Cercocarpus ledifolius', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Artemisia tridentata', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Oncorhynchus clarkii', 'itis_usage': 'valid'},
#  {'scientific_name': 'Melanitta fusca deglandi', 'itis_usage': 'valid'},
#  {'scientific_name': 'Melanitta deglandi', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Melanitta perspicillata', 'itis_usage': 'valid'},
#  {'scientific_name': 'Leymus cinereus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Centrocercus minimus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Morus bassanus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Pterodroma sandwichensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Branta canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Lepidochelys olivacea', 'itis_usage': 'valid'},
#  {'scientific_name': 'Brachylagus idahoensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Medicago sativa', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Microtus californicus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Phleum pratense', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Lasiurus cinereus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Halogeton glomeratus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Suaeda maritima', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Orgyia pseudotsugata', 'itis_usage': 'valid'},
#  {'scientific_name': 'Dendroctonus pseudotsugae', 'itis_usage': 'valid'},
#  {'scientific_name': 'Bromus tectorum', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Cercocarpus montanus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Castor canadensis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Canis lupus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Picea engelmannii', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Cronartium ribicola', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Eremophila alpestris', 'itis_usage': 'valid'},
#  {'scientific_name': 'Sarcobatus vermiculatus', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Procapra gutturosa', 'itis_usage': 'valid'},
#  {'scientific_name': 'Rangifer tarandus groenlandicus',
#   'itis_usage': 'invalid'},
#  {'scientific_name': 'Rangifer tarandus groenlandicus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Gymnogyps californianus', 'itis_usage': 'valid'},
#  {'scientific_name': 'Achnatherum hymenoides', 'itis_usage': 'accepted'},
#  {'scientific_name': 'Reithrodontomys megalotis', 'itis_usage': 'valid'},
#  {'scientific_name': 'Oncorhynchus gorbuscha', 'itis_usage': 'valid'}]

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("../cache/itis_explore.json", itis_explore))
# Out:
# {'Doc Cache File': '../cache/itis_explore.json',
#  'Number of Documents in Cache': 176,
#  'Document Number 144': {'scientific_name': 'Melanitta deglandi',
#   'itis_usage': 'invalid'}}

# %%
#Create list of specie names considered invalid or not accepted by ITIS
invalid_itis=[i for i in itis_explore if i['itis_usage'] == 'invalid']
invalid_itis.extend([i for i in itis_explore if i['itis_usage'] == 'not accepted'])

# %%
#Display list of specie names considered invalid or not accepted by ITIS
invalid_itis
# Out:
# [{'scientific_name': 'Amphispiza belli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Brucella abortus', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Thrichomys fosteri', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Tetrao tetrix', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Equus burchelli', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Clupea pallasi', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Melanitta deglandi', 'itis_usage': 'invalid'},
#  {'scientific_name': 'Rangifer tarandus groenlandicus',
#   'itis_usage': 'invalid'},
#  {'scientific_name': 'Arctostaphylos patula', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Thinopyrum ponticum', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Thinopyrum ponticum', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Poa secunda', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Bassia prostrata', 'itis_usage': 'not accepted'},
#  {'scientific_name': 'Pascopyrum smithii', 'itis_usage': 'not accepted'}]

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("../cache/invalid_itis.json", invalid_itis))
# Out:
# {'Doc Cache File': '../cache/invalid_itis.json',
#  'Number of Documents in Cache': 14,
#  'Document Number 9': {'scientific_name': 'Thinopyrum ponticum',
#   'itis_usage': 'not accepted'}}

# %%
#Create an updated list of species names considered valid or accepted by ITIS
updated_itis=[e for e in itis_explore if e['scientific_name'] not in {'Amphispiza belli','Thrichomys fosteri','Tetrao tetrix','Brucella abortus','Equus burchelli','Bassia prostrata'}]
len(updated_itis)
# Out:
# 170

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("../cache/valid_itis.json", updated_itis))
# Out:
# {'Doc Cache File': '../cache/valid_itis.json',
#  'Number of Documents in Cache': 170,
#  'Document Number 58': {'scientific_name': 'Corvus corax',
#   'itis_usage': 'valid'}}

# %% [markdown]
# Here we examine the geographic division and jurisdiction information provided by ITIS for each species record to better understand the geographical ranges and jurisdictions of the species included in the species name list created in the Build Species List notebook.
#
# First we create a set of lists, one that includes species whose designated geographic values are listed as "North America" and another that includes species with their jurisdictions listed "Coninental US". Both of these lists are intended to represent the species that might encompass the WLCI boundary.
#
# Then we create another set of lists, one that includes species whose designated geographic values are listed as places other than "North America" and another that includes species with their jurisdictions listed as areas other than the "Continental US". These lists are intended to indicate species that may not be appropriate to include in the WLCI species list.

# %%
#Create a list that includes only the tsn number, scientific name, geographic division information, and jurisdiction information. 
geo_info=[]
for item in itis_cache:
    for record in item['data']:
        tsn=record['tsn']
        scientific_name=record['nameWInd']
        itis_usage=record['usage']
        if 'geographicDivision' in record:
            geo_division=record['geographicDivision']
        if 'jurisdiction' in record:
            jurisdiction=record['jurisdiction']
            geo_info.append({'tsn':tsn, 'scientific_name':scientific_name,'itis_usage':itis_usage, 'geo_division':geo_division,'jurisdiction':jurisdiction})

# %% [markdown]
# Here we look at the species records with geographic values listed as "North America"

# %%
#Create a list which only includes tsn number, scientific name, and geographic value information.
geographic_value=[]
for record in geo_info:
    tsn=record['tsn']
    scientific_name=record['scientific_name']
    for item in record['geo_division']:
        geo_value=item['geographic_value']
        geographic_value.append({'tsn':tsn, 'scientific_name':scientific_name, 'geo_value':geo_value})

# %%
#Select all records that list the geographic value as "North America"
north_america=[i for i in geographic_value if i['geo_value'] in 'North America']

# %%
north_america
# Out:
# [{'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'North America'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'geo_value': 'North America'},
#  {'tsn': '179402',
#   'scientific_name': 'Amphispiza belli',
#   'geo_value': 'North America'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'geo_value': 'North America'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'geo_value': 'North America'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '507594',
#   'scientific_name': 'Ericameria nauseosa',
#   'geo_value': 'North America'},
#  {'tsn': '40816',
#   'scientific_name': 'Festuca idahoensis',
#   'geo_value': 'North America'},
#  {'tsn': '502267',
#   'scientific_name': 'Elymus lanceolatus',
#   'geo_value': 'North America'},
#  {'tsn': '175377',
#   'scientific_name': 'Buteo regalis',
#   'geo_value': 'North America'},
#  {'tsn': '714807',
#   'scientific_name': 'Bombus griseocollis',
#   'geo_value': 'North America'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'geo_value': 'North America'},
#  {'tsn': '20531',
#   'scientific_name': 'Atriplex gardneri',
#   'geo_value': 'North America'},
#  {'tsn': '552497',
#   'scientific_name': 'Peromyscus keeni',
#   'geo_value': 'North America'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'geo_value': 'North America'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'geo_value': 'North America'},
#  {'tsn': '23512',
#   'scientific_name': 'Arctostaphylos patula',
#   'geo_value': 'North America'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'geo_value': 'North America'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'geo_value': 'North America'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'geo_value': 'North America'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'geo_value': 'North America'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'geo_value': 'North America'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'North America'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'geo_value': 'North America'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'geo_value': 'North America'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'geo_value': 'North America'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'geo_value': 'North America'},
#  {'tsn': '178654',
#   'scientific_name': 'Oreoscoptes montanus',
#   'geo_value': 'North America'},
#  {'tsn': '42269', 'scientific_name': 'Zea mays', 'geo_value': 'North America'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'geo_value': 'North America'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'North America'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'North America'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'geo_value': 'North America'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'geo_value': 'North America'},
#  {'tsn': '176176',
#   'scientific_name': 'Grus americana',
#   'geo_value': 'North America'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'North America'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'geo_value': 'North America'},
#  {'tsn': '20512',
#   'scientific_name': 'Atriplex argentea',
#   'geo_value': 'North America'},
#  {'tsn': '162035',
#   'scientific_name': 'Mallotus villosus',
#   'geo_value': 'North America'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'geo_value': 'North America'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'geo_value': 'North America'},
#  {'tsn': '175838',
#   'scientific_name': 'Tympanuchus pallidicinctus',
#   'geo_value': 'North America'},
#  {'tsn': '180118',
#   'scientific_name': 'Lepus townsendii',
#   'geo_value': 'North America'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'geo_value': 'North America'},
#  {'tsn': '507974',
#   'scientific_name': 'Hesperostipa comata',
#   'geo_value': 'North America'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'geo_value': 'North America'},
#  {'tsn': '183741',
#   'scientific_name': 'Artemisia tridentata ssp. wyomingensis',
#   'geo_value': 'North America'},
#  {'tsn': '23601',
#   'scientific_name': 'Vaccinium membranaceum',
#   'geo_value': 'North America'},
#  {'tsn': '930310',
#   'scientific_name': 'Xerospermophilus mohavensis',
#   'geo_value': 'North America'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'geo_value': 'North America'},
#  {'tsn': '504637',
#   'scientific_name': 'Pseudoroegneria spicata',
#   'geo_value': 'North America'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'geo_value': 'North America'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'North America'},
#  {'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'geo_value': 'North America'},
#  {'tsn': '180001',
#   'scientific_name': 'Myotis sodalis',
#   'geo_value': 'North America'},
#  {'tsn': '522542',
#   'scientific_name': 'Thinopyrum ponticum',
#   'geo_value': 'North America'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'geo_value': 'North America'},
#  {'tsn': '178515',
#   'scientific_name': 'Lanius ludovicianus',
#   'geo_value': 'North America'},
#  {'tsn': '930308',
#   'scientific_name': 'Ictidomys tridecemlineatus',
#   'geo_value': 'North America'},
#  {'tsn': '25290',
#   'scientific_name': 'Purshia tridentata',
#   'geo_value': 'North America'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'North America'},
#  {'tsn': '163909',
#   'scientific_name': 'Catostomus platyrhynchus',
#   'geo_value': 'North America'},
#  {'tsn': '503290',
#   'scientific_name': 'Krascheninnikovia lanata',
#   'geo_value': 'North America'},
#  {'tsn': '19479',
#   'scientific_name': 'Betula nana',
#   'geo_value': 'North America'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'geo_value': 'North America'},
#  {'tsn': '175855',
#   'scientific_name': 'Centrocercus urophasianus',
#   'geo_value': 'North America'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'geo_value': 'North America'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'geo_value': 'North America'},
#  {'tsn': '41103',
#   'scientific_name': 'Poa secunda',
#   'geo_value': 'North America'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'geo_value': 'North America'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'geo_value': 'North America'},
#  {'tsn': '183343',
#   'scientific_name': 'Pinus flexilis',
#   'geo_value': 'North America'},
#  {'tsn': '183424',
#   'scientific_name': 'Pseudotsuga menziesii',
#   'geo_value': 'North America'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'geo_value': 'North America'},
#  {'tsn': '183311',
#   'scientific_name': 'Pinus albicaulis',
#   'geo_value': 'North America'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'geo_value': 'North America'},
#  {'tsn': '24806',
#   'scientific_name': 'Prunus virginiana',
#   'geo_value': 'North America'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'North America'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'geo_value': 'North America'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'geo_value': 'North America'},
#  {'tsn': '504124',
#   'scientific_name': 'Pascopyrum smithii',
#   'geo_value': 'North America'},
#  {'tsn': '930314',
#   'scientific_name': 'Urocitellus armatus',
#   'geo_value': 'North America'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'geo_value': 'North America'},
#  {'tsn': '180000',
#   'scientific_name': 'Myotis septentrionalis',
#   'geo_value': 'North America'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'geo_value': 'North America'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'geo_value': 'North America'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'North America'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'geo_value': 'North America'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'geo_value': 'North America'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'North America'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'geo_value': 'North America'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'geo_value': 'North America'},
#  {'tsn': '167237',
#   'scientific_name': 'Cottus bairdii',
#   'geo_value': 'North America'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'geo_value': 'North America'},
#  {'tsn': '21920',
#   'scientific_name': 'Sphaeralcea coccinea',
#   'geo_value': 'North America'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'North America'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'geo_value': 'North America'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'geo_value': 'North America'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'North America'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'geo_value': 'North America'},
#  {'tsn': '553429',
#   'scientific_name': 'Oncorhynchus clarkii pleuriticus',
#   'geo_value': 'North America'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'geo_value': 'North America'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'geo_value': 'North America'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'geo_value': 'North America'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'geo_value': 'North America'},
#  {'tsn': '502264',
#   'scientific_name': 'Elymus elymoides',
#   'geo_value': 'North America'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'North America'},
#  {'tsn': '25371',
#   'scientific_name': 'Amorpha canescens',
#   'geo_value': 'North America'},
#  {'tsn': '180195',
#   'scientific_name': 'Tamias minimus',
#   'geo_value': 'North America'},
#  {'tsn': '25134',
#   'scientific_name': 'Cercocarpus ledifolius',
#   'geo_value': 'North America'},
#  {'tsn': '35498',
#   'scientific_name': 'Artemisia tridentata',
#   'geo_value': 'North America'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'geo_value': 'North America'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'geo_value': 'North America'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'geo_value': 'North America'},
#  {'tsn': '503433',
#   'scientific_name': 'Leymus cinereus',
#   'geo_value': 'North America'},
#  {'tsn': '677540',
#   'scientific_name': 'Centrocercus minimus',
#   'geo_value': 'North America'},
#  {'tsn': '174712',
#   'scientific_name': 'Morus bassanus',
#   'geo_value': 'North America'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'North America'},
#  {'tsn': '552521',
#   'scientific_name': 'Brachylagus idahoensis',
#   'geo_value': 'North America'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'geo_value': 'North America'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'geo_value': 'North America'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'geo_value': 'North America'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'North America'},
#  {'tsn': '20692',
#   'scientific_name': 'Halogeton glomeratus',
#   'geo_value': 'North America'},
#  {'tsn': '20662',
#   'scientific_name': 'Suaeda maritima',
#   'geo_value': 'North America'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'geo_value': 'North America'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'geo_value': 'North America'},
#  {'tsn': '25136',
#   'scientific_name': 'Cercocarpus montanus',
#   'geo_value': 'North America'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'North America'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'North America'},
#  {'tsn': '183291',
#   'scientific_name': 'Picea engelmannii',
#   'geo_value': 'North America'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'geo_value': 'North America'},
#  {'tsn': '20707',
#   'scientific_name': 'Sarcobatus vermiculatus',
#   'geo_value': 'North America'},
#  {'tsn': '898935',
#   'scientific_name': 'Rangifer tarandus groenlandicus',
#   'geo_value': 'North America'},
#  {'tsn': '175274',
#   'scientific_name': 'Gymnogyps californianus',
#   'geo_value': 'North America'},
#  {'tsn': '507943',
#   'scientific_name': 'Achnatherum hymenoides',
#   'geo_value': 'North America'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'geo_value': 'North America'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'geo_value': 'North America'}]

# %% [markdown]
# Here we look at the species records with jurisdiction information listed as "Continental US"

# %%
#Create list which only contains the tsn number, scientific name, jurisdiction information, and origin information
jurisdiction_info=[]
for record in geo_info:
    tsn=record['tsn']
    scientific_name=record['scientific_name']
    for item in record['jurisdiction']:
        jurisdiction=item['jurisdiction_value']
        origin=item['origin']
        jurisdiction_info.append({'tsn':tsn,'scientific_name':scientific_name,'jurisdiction':jurisdiction, 'origin':origin})

# %%
#Select all records that list the jurisdiction as "Continental US"
continental_us=[i for i in jurisdiction_info if i['jurisdiction'] == 'Continental US']

# %%
continental_us
# Out:
# [{'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179402',
#   'scientific_name': 'Amphispiza belli',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '507594',
#   'scientific_name': 'Ericameria nauseosa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '40816',
#   'scientific_name': 'Festuca idahoensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '502267',
#   'scientific_name': 'Elymus lanceolatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175377',
#   'scientific_name': 'Buteo regalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '714807',
#   'scientific_name': 'Bombus griseocollis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '20531',
#   'scientific_name': 'Atriplex gardneri',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '23512',
#   'scientific_name': 'Arctostaphylos patula',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '178654',
#   'scientific_name': 'Oreoscoptes montanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '42269',
#   'scientific_name': 'Zea mays',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '176176',
#   'scientific_name': 'Grus americana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20512',
#   'scientific_name': 'Atriplex argentea',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '162035',
#   'scientific_name': 'Mallotus villosus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175838',
#   'scientific_name': 'Tympanuchus pallidicinctus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180118',
#   'scientific_name': 'Lepus townsendii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '507974',
#   'scientific_name': 'Hesperostipa comata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183741',
#   'scientific_name': 'Artemisia tridentata ssp. wyomingensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '23601',
#   'scientific_name': 'Vaccinium membranaceum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '930310',
#   'scientific_name': 'Xerospermophilus mohavensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '504637',
#   'scientific_name': 'Pseudoroegneria spicata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180001',
#   'scientific_name': 'Myotis sodalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '522542',
#   'scientific_name': 'Thinopyrum ponticum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '178515',
#   'scientific_name': 'Lanius ludovicianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '930308',
#   'scientific_name': 'Ictidomys tridecemlineatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '25290',
#   'scientific_name': 'Purshia tridentata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '163909',
#   'scientific_name': 'Catostomus platyrhynchus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503290',
#   'scientific_name': 'Krascheninnikovia lanata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175855',
#   'scientific_name': 'Centrocercus urophasianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '41103',
#   'scientific_name': 'Poa secunda',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183343',
#   'scientific_name': 'Pinus flexilis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183424',
#   'scientific_name': 'Pseudotsuga menziesii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183311',
#   'scientific_name': 'Pinus albicaulis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '24806',
#   'scientific_name': 'Prunus virginiana',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503283',
#   'scientific_name': 'Kochia prostrata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '504124',
#   'scientific_name': 'Pascopyrum smithii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '930314',
#   'scientific_name': 'Urocitellus armatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180000',
#   'scientific_name': 'Myotis septentrionalis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '167237',
#   'scientific_name': 'Cottus bairdii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '21920',
#   'scientific_name': 'Sphaeralcea coccinea',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '553429',
#   'scientific_name': 'Oncorhynchus clarkii pleuriticus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '502264',
#   'scientific_name': 'Elymus elymoides',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '25371',
#   'scientific_name': 'Amorpha canescens',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180195',
#   'scientific_name': 'Tamias minimus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '25134',
#   'scientific_name': 'Cercocarpus ledifolius',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '35498',
#   'scientific_name': 'Artemisia tridentata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '503433',
#   'scientific_name': 'Leymus cinereus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '677540',
#   'scientific_name': 'Centrocercus minimus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174712',
#   'scientific_name': 'Morus bassanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '552521',
#   'scientific_name': 'Brachylagus idahoensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20692',
#   'scientific_name': 'Halogeton glomeratus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '20662',
#   'scientific_name': 'Suaeda maritima',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'jurisdiction': 'Continental US',
#   'origin': 'Introduced'},
#  {'tsn': '25136',
#   'scientific_name': 'Cercocarpus montanus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '183291',
#   'scientific_name': 'Picea engelmannii',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '20707',
#   'scientific_name': 'Sarcobatus vermiculatus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '175274',
#   'scientific_name': 'Gymnogyps californianus',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '507943',
#   'scientific_name': 'Achnatherum hymenoides',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'jurisdiction': 'Continental US',
#   'origin': 'Native & Introduced'}]

# %% [markdown]
# Here we look at the species with geographic values listed as places other than "North America"

# %%
not_north_america=[e for e in geographic_value if e['geo_value'] not in 'North America']

# %%
not_north_america
# Out:
# [{'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'geo_value': 'Oceania'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'geo_value': 'Middle America'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'geo_value': 'Middle America'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'geo_value': 'Middle America'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'geo_value': 'Oceania'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'geo_value': 'Middle America'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'geo_value': 'Middle America'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Western Atlantic Ocean'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'East Pacific'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'geo_value': 'Oceania'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'geo_value': 'Oceania'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'geo_value': 'Middle America'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'geo_value': 'Middle America'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'geo_value': 'Middle America'},
#  {'tsn': '42269', 'scientific_name': 'Zea mays', 'geo_value': 'Caribbean'},
#  {'tsn': '42269', 'scientific_name': 'Zea mays', 'geo_value': 'South America'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '175130', 'scientific_name': 'Aythya marila', 'geo_value': 'Oceania'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'South America'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '180695', 'scientific_name': 'Cervus elaphus', 'geo_value': 'Africa'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Australia'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'geo_value': 'Oceania'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'geo_value': 'Middle America'},
#  {'tsn': '180604', 'scientific_name': 'Vulpes vulpes', 'geo_value': 'Africa'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'Australia'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'geo_value': 'Africa'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'geo_value': 'Oceania'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'geo_value': 'Middle America'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'geo_value': 'Middle America'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'geo_value': 'Oceania'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'geo_value': 'Middle America'},
#  {'tsn': '179725', 'scientific_name': 'Corvus corax', 'geo_value': 'Africa'},
#  {'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'geo_value': 'Caribbean'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'geo_value': 'Oceania'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'Middle America'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'geo_value': 'South America'},
#  {'tsn': '202344',
#   'scientific_name': 'Lasiurus cinereus semotus',
#   'geo_value': 'Oceania'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'geo_value': 'Caribbean'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'geo_value': 'Oceania'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '41103',
#   'scientific_name': 'Poa secunda',
#   'geo_value': 'South America'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'geo_value': 'Oceania'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'geo_value': 'Middle America'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'East Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '154396', 'scientific_name': 'Apis mellifera', 'geo_value': 'Africa'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Australia'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Caribbean'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Middle America'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Oceania'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'South America'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'geo_value': 'Caribbean'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'geo_value': 'Middle America'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'Caribbean'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'Middle America'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'geo_value': 'South America'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'geo_value': 'Oceania'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'Middle America'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'geo_value': 'South America'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'geo_value': 'East Pacific'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'geo_value': 'Caribbean'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'South America'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'geo_value': 'Oceania'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'Middle America'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'Caribbean'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'geo_value': 'South America'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'geo_value': 'Oceania'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'East Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'geo_value': 'Middle America'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Oceania'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'geo_value': 'Africa'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'geo_value': 'East Pacific'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'geo_value': 'Middle America'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'geo_value': 'Oceania'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'geo_value': 'Oceania'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Middle America'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Oceania'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Africa'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Australia'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Caribbean'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'East Pacific'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Eastern Atlantic Ocean'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Indo-West Pacific'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'South America'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'geo_value': 'Western Atlantic Ocean'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'geo_value': 'Oceania'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'geo_value': 'Caribbean'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'geo_value': 'Middle America'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'geo_value': 'Oceania'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'geo_value': 'South America'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'South America'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'Oceania'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'geo_value': 'Caribbean'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'geo_value': 'Middle America'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'geo_value': 'Oceania'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'geo_value': 'South America'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'Middle America'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'geo_value': 'South America'},
#  {'tsn': '180596', 'scientific_name': 'Canis lupus', 'geo_value': 'Australia'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'Europe & Northern Asia (excluding China)'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'Middle America'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'geo_value': 'Southern Asia'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'geo_value': 'Middle America'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'geo_value': 'East Pacific'}]

# %% [markdown]
# Here we look at species with jurisdiction information listed as areas other than the "Continental US"

# %%
not_continental_us=[e for e in jurisdiction_info if e['jurisdiction'] not in 'Continental US']

# %%
not_continental_us
# Out:
# [{'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175147',
#   'scientific_name': 'Clangula hyemalis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '997724',
#   'scientific_name': 'Artemisiospiza belli',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '179402',
#   'scientific_name': 'Amphispiza belli',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180565',
#   'scientific_name': 'Taxidea taxus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '507785',
#   'scientific_name': 'Schoenoplectus acutus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '27779',
#   'scientific_name': 'Shepherdia canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '507594',
#   'scientific_name': 'Ericameria nauseosa',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '502267',
#   'scientific_name': 'Elymus lanceolatus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175377',
#   'scientific_name': 'Buteo regalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '714807',
#   'scientific_name': 'Bombus griseocollis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '161979',
#   'scientific_name': 'Oncorhynchus nerka',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '20531',
#   'scientific_name': 'Atriplex gardneri',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '552497',
#   'scientific_name': 'Peromyscus keeni',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '552497',
#   'scientific_name': 'Peromyscus keeni',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180607',
#   'scientific_name': 'Vulpes velox',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '35454',
#   'scientific_name': 'Artemisia cana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '183327',
#   'scientific_name': 'Pinus contorta',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '175863',
#   'scientific_name': 'Colinus virginianus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '179628',
#   'scientific_name': 'Passer domesticus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180706',
#   'scientific_name': 'Bison bison',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '173856',
#   'scientific_name': 'Gopherus agassizii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native & Introduced'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '161989',
#   'scientific_name': 'Oncorhynchus mykiss',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180717',
#   'scientific_name': 'Antilocapra americana',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '114918',
#   'scientific_name': 'Dendroctonus ponderosae',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '194820',
#   'scientific_name': 'Juniperus communis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180544',
#   'scientific_name': 'Ursus americanus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '178654',
#   'scientific_name': 'Oreoscoptes montanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '42269',
#   'scientific_name': 'Zea mays',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175367',
#   'scientific_name': 'Buteo swainsoni',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Central Pacific Territories',
#   'origin': 'Incidental'},
#  {'tsn': '175130',
#   'scientific_name': 'Aythya marila',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '180695',
#   'scientific_name': 'Cervus elaphus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175430',
#   'scientific_name': 'Circus cyaneus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '179440',
#   'scientific_name': 'Spizella breweri',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '176176',
#   'scientific_name': 'Grus americana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180604',
#   'scientific_name': 'Vulpes vulpes',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179167',
#   'scientific_name': 'Fringilla montifringilla',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '20512',
#   'scientific_name': 'Atriplex argentea',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '162035',
#   'scientific_name': 'Mallotus villosus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '40913',
#   'scientific_name': 'Panicum virgatum',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '175134',
#   'scientific_name': 'Aythya affinis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180118',
#   'scientific_name': 'Lepus townsendii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175603',
#   'scientific_name': 'Falco mexicanus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175350',
#   'scientific_name': 'Buteo jamaicensis',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '23601',
#   'scientific_name': 'Vaccinium membranaceum',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175014',
#   'scientific_name': 'Branta leucopsis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '504637',
#   'scientific_name': 'Pseudoroegneria spicata',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '22843',
#   'scientific_name': 'Descurainia sophia',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179725',
#   'scientific_name': 'Corvus corax',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '950052',
#   'scientific_name': 'Setophaga discolor',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180166',
#   'scientific_name': 'Tamiasciurus hudsonicus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '178515',
#   'scientific_name': 'Lanius ludovicianus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '930308',
#   'scientific_name': 'Ictidomys tridecemlineatus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '25290',
#   'scientific_name': 'Purshia tridentata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '176177',
#   'scientific_name': 'Grus canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180016',
#   'scientific_name': 'Lasiurus borealis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '163909',
#   'scientific_name': 'Catostomus platyrhynchus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '503290',
#   'scientific_name': 'Krascheninnikovia lanata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '202344',
#   'scientific_name': 'Lasiurus cinereus semotus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '19479',
#   'scientific_name': 'Betula nana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '19479',
#   'scientific_name': 'Betula nana',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '528646',
#   'scientific_name': 'Juniperus communis var. depressa',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175855',
#   'scientific_name': 'Centrocercus urophasianus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '182660',
#   'scientific_name': 'Agave americana',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '997723',
#   'scientific_name': 'Artemisiospiza nevadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '41103',
#   'scientific_name': 'Poa secunda',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '41103',
#   'scientific_name': 'Poa secunda',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175185',
#   'scientific_name': 'Mergus merganser',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180170',
#   'scientific_name': 'Glaucomys volans',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '183343',
#   'scientific_name': 'Pinus flexilis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '183424',
#   'scientific_name': 'Pseudotsuga menziesii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174469',
#   'scientific_name': 'Gavia immer',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '183311',
#   'scientific_name': 'Pinus albicaulis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '24806',
#   'scientific_name': 'Prunus virginiana',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '154396',
#   'scientific_name': 'Apis mellifera',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174685',
#   'scientific_name': 'Pelecanus occidentalis',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '504124',
#   'scientific_name': 'Pascopyrum smithii',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180276',
#   'scientific_name': 'Peromyscus maniculatus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180000',
#   'scientific_name': 'Myotis septentrionalis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180599',
#   'scientific_name': 'Canis latrans',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '25109',
#   'scientific_name': 'Amelanchier alnifolia',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '175622',
#   'scientific_name': 'Falco sparverius',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180701',
#   'scientific_name': 'Rangifer tarandus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175407',
#   'scientific_name': 'Aquila chrysaetos',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180575',
#   'scientific_name': 'Procyon lotor',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '161980',
#   'scientific_name': 'Oncorhynchus tshawytscha',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180543',
#   'scientific_name': 'Ursus arctos',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '167237',
#   'scientific_name': 'Cottus bairdii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '176891',
#   'scientific_name': 'Sterna dougallii',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '21920',
#   'scientific_name': 'Sphaeralcea coccinea',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '180698',
#   'scientific_name': 'Odocoileus hemionus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175420',
#   'scientific_name': 'Haliaeetus leucocephalus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '195773',
#   'scientific_name': 'Populus tremuloides',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '179333',
#   'scientific_name': 'Ammodramus savannarum',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Native'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '20518',
#   'scientific_name': 'Atriplex canescens',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '551209',
#   'scientific_name': 'Clupea pallasii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174474',
#   'scientific_name': 'Gavia stellata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180711',
#   'scientific_name': 'Ovis canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '997873',
#   'scientific_name': 'Rhynchophanes mccownii',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '162002',
#   'scientific_name': 'Salvelinus namaycush',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '181830',
#   'scientific_name': 'Abies lasiocarpa',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174479',
#   'scientific_name': 'Podiceps grisegena',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '25371',
#   'scientific_name': 'Amorpha canescens',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180195',
#   'scientific_name': 'Tamias minimus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '35498',
#   'scientific_name': 'Artemisia tridentata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native & Introduced'},
#  {'tsn': '161983',
#   'scientific_name': 'Oncorhynchus clarkii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175165',
#   'scientific_name': 'Melanitta fusca deglandi',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Incidental'},
#  {'tsn': '175170',
#   'scientific_name': 'Melanitta perspicillata',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '174712',
#   'scientific_name': 'Morus bassanus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '174999',
#   'scientific_name': 'Branta canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '173840',
#   'scientific_name': 'Lepidochelys olivacea',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Introduced'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '183623',
#   'scientific_name': 'Medicago sativa',
#   'jurisdiction': 'Canada',
#   'origin': 'Introduced'},
#  {'tsn': '180305',
#   'scientific_name': 'Microtus californicus',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '41062',
#   'scientific_name': 'Phleum pratense',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Native'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180017',
#   'scientific_name': 'Lasiurus cinereus',
#   'jurisdiction': 'Caribbean Territories',
#   'origin': 'Incidental'},
#  {'tsn': '20662',
#   'scientific_name': 'Suaeda maritima',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '114919',
#   'scientific_name': 'Dendroctonus pseudotsugae',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'jurisdiction': 'Hawaii',
#   'origin': 'Introduced'},
#  {'tsn': '40524',
#   'scientific_name': 'Bromus tectorum',
#   'jurisdiction': 'Alaska',
#   'origin': 'Introduced'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '180212',
#   'scientific_name': 'Castor canadensis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180596',
#   'scientific_name': 'Canis lupus',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '183291',
#   'scientific_name': 'Picea engelmannii',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '554256',
#   'scientific_name': 'Eremophila alpestris',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '20707',
#   'scientific_name': 'Sarcobatus vermiculatus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '898935',
#   'scientific_name': 'Rangifer tarandus groenlandicus',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'jurisdiction': 'Canada',
#   'origin': 'Native'},
#  {'tsn': '180343',
#   'scientific_name': 'Reithrodontomys megalotis',
#   'jurisdiction': 'Mexico',
#   'origin': 'Native'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'jurisdiction': 'Alaska',
#   'origin': 'Native'},
#  {'tsn': '161975',
#   'scientific_name': 'Oncorhynchus gorbuscha',
#   'jurisdiction': 'Canada',
#   'origin': 'Native & Introduced'}]
