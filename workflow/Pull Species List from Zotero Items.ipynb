# %% [markdown]
# Now that we have the "haul" of ITIS dictionary scientific name matches for a subset of the articles in our Zotero library, we can go grab up the names (and the more detailed return if needed) and run that through our species name processing in this workflow. From this point, it's relatively easy to read specific information out of the Zotero repository that we want to be able to use.

# %%
from pyzotero import zotero
import os
import json
from IPython.display import display

# %%
wlci_library_group_id = "2341914"
wlci_lib = zotero.Zotero(wlci_library_group_id, "group", os.environ["ZOTERO_API_KEY"])

# %%
scientific_name_list = list()
for tags in [i["data"]["tags"] for i in wlci_lib.items(itemType="attachment", q="xDD terms from document for the ITIS dictionary")]:
    scientific_name_list.extend([i["tag"] for i in tags])
scientific_name_list = list(set(scientific_name_list))
scientific_name_list.sort()

# %%
scientific_name_list
# Out:
# ['Abies lasiocarpa',
#  'Achnatherum hymenoides',
#  'Agave americana',
#  'Alces alces',
#  'Amelanchier alnifolia',
#  'Ammodramus savannarum',
#  'Ammodytes marinus',
#  'Amorpha canescens',
#  'Amphispiza belli',
#  'Anoplopoma fimbria',
#  'Antilocapra americana',
#  'Apis mellifera',
#  'Aquila chrysaetos',
#  'Arctostaphylos patula',
#  'Artemisia cana',
#  'Artemisia tridentata',
#  'Artemisia tridentata ssp. wyomingensis',
#  'Artemisiospiza nevadensis',
#  'Atriplex argentea',
#  'Atriplex canescens',
#  'Atriplex gardneri',
#  'Aythya affinis',
#  'Aythya marila',
#  'Bassia prostrata',
#  'Betula nana',
#  'Bison bison',
#  'Bombus griseocollis',
#  'Brachylagus idahoensis',
#  'Branta canadensis',
#  'Branta leucopsis',
#  'Bromus tectorum',
#  'Brucella abortus',
#  'Buteo jamaicensis',
#  'Buteo regalis',
#  'Buteo swainsoni',
#  'Canis latrans',
#  'Canis lupus',
#  'Capreolus capreolus',
#  'Castor canadensis',
#  'Catostomus platyrhynchus',
#  'Centrocercus minimus',
#  'Centrocercus urophasianus',
#  'Cercocarpus ledifolius',
#  'Cercocarpus montanus',
#  'Cervus elaphus',
#  'Circus cyaneus',
#  'Clangula hyemalis',
#  'Clupea pallasi',
#  'Clupea pallasii',
#  'Colinus virginianus',
#  'Connochaetes taurinus',
#  'Corvus corax',
#  'Cottus bairdii',
#  'Cronartium ribicola',
#  'Dendroctonus ponderosae',
#  'Dendroctonus pseudotsugae',
#  'Descurainia sophia',
#  'Elymus elymoides',
#  'Elymus lanceolatus',
#  'Equus burchelli',
#  'Eremophila alpestris',
#  'Ericameria nauseosa',
#  'Falco mexicanus',
#  'Falco sparverius',
#  'Festuca idahoensis',
#  'Fringilla montifringilla',
#  'Gavia immer',
#  'Gavia stellata',
#  'Glaucomys volans',
#  'Gopherus agassizii',
#  'Grus americana',
#  'Grus canadensis',
#  'Gymnogyps californianus',
#  'Haliaeetus leucocephalus',
#  'Halogeton glomeratus',
#  'Hesperostipa comata',
#  'Ictidomys tridecemlineatus',
#  'Juniperus communis',
#  'Juniperus communis var. depressa',
#  'Kochia prostrata',
#  'Krascheninnikovia lanata',
#  'Lanius ludovicianus',
#  'Lasiurus borealis',
#  'Lasiurus cinereus',
#  'Lasiurus cinereus semotus',
#  'Lepidochelys olivacea',
#  'Lepus townsendii',
#  'Leymus cinereus',
#  'Lullula arborea',
#  'Macaca sylvanus',
#  'Mallotus villosus',
#  'Medicago sativa',
#  'Melanitta deglandi',
#  'Melanitta perspicillata',
#  'Mergus merganser',
#  'Microtus agrestis',
#  'Microtus californicus',
#  'Morus bassanus',
#  'Myotis septentrionalis',
#  'Myotis sodalis',
#  'Odocoileus hemionus',
#  'Oncorhynchus clarkii',
#  'Oncorhynchus clarkii pleuriticus',
#  'Oncorhynchus gorbuscha',
#  'Oncorhynchus mykiss',
#  'Oncorhynchus nerka',
#  'Oncorhynchus tshawytscha',
#  'Oreoscoptes montanus',
#  'Orgyia pseudotsugata',
#  'Otis tarda',
#  'Ovis canadensis',
#  'Panicum virgatum',
#  'Pascopyrum smithii',
#  'Passer domesticus',
#  'Pelecanus occidentalis',
#  'Peromyscus keeni',
#  'Peromyscus maniculatus',
#  'Phleum pratense',
#  'Picea engelmannii',
#  'Pinus albicaulis',
#  'Pinus contorta',
#  'Pinus flexilis',
#  'Poa secunda',
#  'Podiceps grisegena',
#  'Populus tremuloides',
#  'Potorous tridactylus',
#  'Procapra gutturosa',
#  'Procyon lotor',
#  'Prunus virginiana',
#  'Pseudoroegneria spicata',
#  'Pseudotsuga menziesii',
#  'Pterodroma sandwichensis',
#  'Puffinus newelli',
#  'Purshia tridentata',
#  'Rangifer tarandus',
#  'Rangifer tarandus groenlandicus',
#  'Reithrodontomys megalotis',
#  'Rhynchophanes mccownii',
#  'Salvelinus namaycush',
#  'Sarcobatus vermiculatus',
#  'Schoenoplectus acutus',
#  'Setophaga discolor',
#  'Shepherdia canadensis',
#  'Sphaeralcea coccinea',
#  'Spizella breweri',
#  'Sterna dougallii',
#  'Suaeda maritima',
#  'Tamias minimus',
#  'Tamiasciurus hudsonicus',
#  'Taxidea taxus',
#  'Tetrao tetrix',
#  'Thinopyrum ponticum',
#  'Thrichomys fosteri',
#  'Tympanuchus pallidicinctus',
#  'Urocitellus armatus',
#  'Ursus americanus',
#  'Ursus arctos',
#  'Vaccinium membranaceum',
#  'Vulpes velox',
#  'Vulpes vulpes',
#  'Xerospermophilus mohavensis',
#  'Zea mays']

# %% [markdown]
# If we wanted to pull out additional details like the hit counts to work with, we can load up the json dump that we stuffed into the note. The recordset I build here also adds in the API and web page reference to the attachment item in Zotero so that we could possibly provide that linkage back into the Zotero library for a user application

# %%
itis_items = list()
for item in [i for i in wlci_lib.items(itemType="attachment", q="xDD terms from document for the ITIS dictionary")]:
    itis_items.append({
        "Zotero Web Link": item["links"]["alternate"]["href"],
        "Zotero Web Link": item["links"]["self"]["href"],
        "xDD API Link": item["data"]["url"],
        "ITIS Dictionary Hits": json.loads(item["data"]["note"])
    })

# %%
itis_items
# Out:
# [{'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/E6IXQ92A',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5c2c30a41faed655488b299b&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Branta canadensis',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Castor canadensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Haliaeetus leucocephalus', 'hit_count': 6},
#    {'dictionary': 'ITIS', 'term': 'Macaca sylvanus', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/5DC7XE9E',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5897848bcf58f1ac5aa42563&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Artemisiospiza nevadensis',
#     'hit_count': 4},
#    {'dictionary': 'ITIS', 'term': 'Canis latrans', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus urophasianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Corvus corax', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Falco sparverius', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Glaucomys volans', 'hit_count': 1},
#    {'dictionary': 'ITIS',
#     'term': 'Ictidomys tridecemlineatus',
#     'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Lanius ludovicianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Oreoscoptes montanus', 'hit_count': 5},
#    {'dictionary': 'ITIS', 'term': 'Peromyscus keeni', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Peromyscus maniculatus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Procyon lotor', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Reithrodontomys megalotis', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Spizella breweri', 'hit_count': 6},
#    {'dictionary': 'ITIS', 'term': 'Tamias minimus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Taxidea taxus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Urocitellus armatus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Vulpes vulpes', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/IG8QFBEM',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=57a84443cf58f17046db1a8a&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Amphispiza belli',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Artemisia tridentata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Artemisiospiza nevadensis', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Microtus californicus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Oreoscoptes montanus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Spizella breweri', 'hit_count': 3}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/IU7F3662',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5acfde1ecf58f17c7517b27d&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Centrocercus urophasianus',
#     'hit_count': 5}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/KQX78STI',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5c2c22901faed655488b289b&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Bison bison',
#     'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Brucella abortus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Canis lupus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Cervus elaphus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Cronartium ribicola', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Dendroctonus ponderosae', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Oncorhynchus clarkii', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pinus albicaulis', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Potorous tridactylus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Salvelinus namaycush', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Shepherdia canadensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Tamiasciurus hudsonicus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Ursus americanus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Ursus arctos', 'hit_count': 4},
#    {'dictionary': 'ITIS', 'term': 'Vaccinium membranaceum', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/CSITKBHZ',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5d1ed9d20b45c76caf912f8f&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Artemisia tridentata',
#     'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Atriplex argentea', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Brachylagus idahoensis', 'hit_count': 20},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus urophasianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Corvus corax', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Hesperostipa comata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Lepus townsendii', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Pascopyrum smithii', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pascopyrum smithii', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Poa secunda', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Poa secunda', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Sphaeralcea coccinea', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/V5D3NN5E',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5c4e3f571faed655489408c3&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Artemisia cana',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Artemisia tridentata', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus minimus', 'hit_count': 1},
#    {'dictionary': 'ITIS',
#     'term': 'Centrocercus urophasianus',
#     'hit_count': 10},
#    {'dictionary': 'ITIS', 'term': 'Cervus elaphus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Medicago sativa', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Salvelinus namaycush', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/7492838K',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5c2c30a41faed655488b29a1&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Centrocercus urophasianus',
#     'hit_count': 8}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/2ND2EUNF',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5c2c1b8a1faed655488b27d9&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Centrocercus urophasianus',
#     'hit_count': 6},
#    {'dictionary': 'ITIS', 'term': 'Colinus virginianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Lepidochelys olivacea', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Lullula arborea', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Microtus agrestis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Otis tarda', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Passer domesticus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Tetrao tetrix', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/6KRJ9SBS',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=577bdf78cf58f1585217325f&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Abies lasiocarpa',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Arctostaphylos patula', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Arctostaphylos patula', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Artemisia tridentata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Dendroctonus ponderosae', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Dendroctonus pseudotsugae', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Juniperus communis', 'hit_count': 1},
#    {'dictionary': 'ITIS',
#     'term': 'Juniperus communis var. depressa',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Orgyia pseudotsugata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Picea engelmannii', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pinus contorta', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Populus tremuloides', 'hit_count': 7},
#    {'dictionary': 'ITIS', 'term': 'Pseudotsuga menziesii', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/48ZCR2JG',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=594407d1cf58f1b3059ba5a4&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Abies lasiocarpa',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Arctostaphylos patula', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Arctostaphylos patula', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Dendroctonus pseudotsugae', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Juniperus communis', 'hit_count': 1},
#    {'dictionary': 'ITIS',
#     'term': 'Juniperus communis var. depressa',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pinus contorta', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pinus flexilis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Populus tremuloides', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pseudotsuga menziesii', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/Q6MHCJZR',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5900f56ccf58f172049f469a&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Branta leucopsis',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Cervus elaphus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Clupea pallasii', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Connochaetes taurinus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Melanitta perspicillata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Oncorhynchus nerka', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Populus tremuloides', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Ursus arctos', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/QHURXX23',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5904c6c6cf58f152d18be8bf&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Artemisia tridentata',
#     'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/SPMC6CK9',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5c4977e21faed6554893aeb0&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Abies lasiocarpa',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Alces alces', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Atriplex gardneri', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Bison bison', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Capreolus capreolus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Cervus elaphus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Picea engelmannii', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pinus contorta', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Rangifer tarandus', 'hit_count': 3},
#    {'dictionary': 'ITIS',
#     'term': 'Rangifer tarandus groenlandicus',
#     'hit_count': 1},
#    {'dictionary': 'ITIS',
#     'term': 'Rangifer tarandus groenlandicus',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Sarcobatus vermiculatus', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/BSGI73AF',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5839f904cf58f149de664120&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Alces alces',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Amelanchier alnifolia', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Antilocapra americana', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Cervus elaphus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Fringilla montifringilla', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 4},
#    {'dictionary': 'ITIS', 'term': 'Ovis canadensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Prunus virginiana', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Purshia tridentata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Rangifer tarandus', 'hit_count': 2}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/9EGAH48M',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=572c8f7ccf58f1127a9809f7&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Antilocapra americana',
#     'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Artemisia tridentata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus urophasianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 3}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/5VMNPQE7',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=58976134cf58f1a1de231c7a&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Connochaetes taurinus',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Equus burchelli', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Procapra gutturosa', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Purshia tridentata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Sarcobatus vermiculatus', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/BECJ7BWK',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=583da612cf58f107cb09840d&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Antilocapra americana',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Cervus elaphus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Connochaetes taurinus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Fringilla montifringilla', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Rangifer tarandus', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/DQMFWMZB',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5c1cc81f1faed65548897433&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Achnatherum hymenoides',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Artemisia tridentata', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Artemisiospiza nevadensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus urophasianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Corvus corax', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Descurainia sophia', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Elymus elymoides', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Leymus cinereus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Oreoscoptes montanus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Peromyscus maniculatus', 'hit_count': 9},
#    {'dictionary': 'ITIS', 'term': 'Phleum pratense', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Spizella breweri', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Thrichomys fosteri', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/TMFTWTW3',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5a49f8becf58f132c3775c3a&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Atriplex canescens',
#     'hit_count': 5},
#    {'dictionary': 'ITIS', 'term': 'Atriplex gardneri', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Bassia prostrata', 'hit_count': 4},
#    {'dictionary': 'ITIS', 'term': 'Halogeton glomeratus', 'hit_count': 7},
#    {'dictionary': 'ITIS', 'term': 'Kochia prostrata', 'hit_count': 5},
#    {'dictionary': 'ITIS', 'term': 'Medicago sativa', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Suaeda maritima', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Thinopyrum ponticum', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Thinopyrum ponticum', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Zea mays', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/F2G859VP',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=551d04b9e138236e51a9956a&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Dendroctonus ponderosae',
#     'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/XX9XWJ6B',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=58e2c641cf58f1697d39b86b&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Centrocercus urophasianus',
#     'hit_count': 6}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/VR3EDPBR',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5ad055c3cf58f1a9152a8fd5&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Aquila chrysaetos',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Artemisia tridentata', 'hit_count': 4},
#    {'dictionary': 'ITIS',
#     'term': 'Artemisia tridentata ssp. wyomingensis',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Atriplex gardneri', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Brachylagus idahoensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Branta leucopsis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Bromus tectorum', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Buteo regalis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus urophasianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Elymus elymoides', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Elymus lanceolatus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Ericameria nauseosa', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Festuca idahoensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Hesperostipa comata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Krascheninnikovia lanata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pseudoroegneria spicata', 'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/VSVG54AZ',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=579f4458cf58f123c56623f8&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Artemisia tridentata',
#     'hit_count': 1},
#    {'dictionary': 'ITIS',
#     'term': 'Centrocercus urophasianus',
#     'hit_count': 5}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/I4VFTDAM',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=551d6881e138236e51a9970e&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Artemisia tridentata',
#     'hit_count': 4}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/QB5WP8ZP',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=585b52f3cf58f1a722da9ab5&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Betula nana',
#     'hit_count': 1}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/SRSHSAGF',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=57c28175cf58f1aa5dd91edd&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Centrocercus urophasianus',
#     'hit_count': 5}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/X3G7I48W',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=5d23b0bf0b45c76caf91e0b3&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Alces alces',
#     'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Amelanchier alnifolia', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Brachylagus idahoensis', 'hit_count': 4},
#    {'dictionary': 'ITIS', 'term': 'Bromus tectorum', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Catostomus platyrhynchus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus urophasianus', 'hit_count': 5},
#    {'dictionary': 'ITIS', 'term': 'Cercocarpus ledifolius', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Cercocarpus montanus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Cervus elaphus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Cottus bairdii', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Odocoileus hemionus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Oncorhynchus clarkii', 'hit_count': 2},
#    {'dictionary': 'ITIS',
#     'term': 'Oncorhynchus clarkii pleuriticus',
#     'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Oreoscoptes montanus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Peromyscus maniculatus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Populus tremuloides', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Prunus virginiana', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Purshia tridentata', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Spizella breweri', 'hit_count': 3}]},
#  {'Zotero Web Link': 'https://api.zotero.org/groups/2341914/items/4FFERF7B',
#   'xDD API Link': 'https://geodeepdive.org/api/terms?docid=57d99162cf58f191c21a5823&dictionary=ITIS',
#   'ITIS Dictionary Hits': [{'dictionary': 'ITIS',
#     'term': 'Agave americana',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Ammodramus savannarum', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Ammodytes marinus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Amorpha canescens', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Anoplopoma fimbria', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Apis mellifera', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Aquila chrysaetos', 'hit_count': 8},
#    {'dictionary': 'ITIS', 'term': 'Artemisiospiza nevadensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Aythya affinis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Aythya marila', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Bombus griseocollis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Buteo jamaicensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Buteo regalis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Buteo swainsoni', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Centrocercus urophasianus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Circus cyaneus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Clangula hyemalis', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Clupea pallasi', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Corvus corax', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Eremophila alpestris', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Falco mexicanus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Falco sparverius', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Gavia immer', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Gavia stellata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Gopherus agassizii', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Grus americana', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Grus canadensis', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Gymnogyps californianus', 'hit_count': 3},
#    {'dictionary': 'ITIS', 'term': 'Haliaeetus leucocephalus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Lanius ludovicianus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Lasiurus borealis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Lasiurus cinereus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Lasiurus cinereus semotus', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Mallotus villosus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Melanitta deglandi', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Melanitta perspicillata', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Mergus merganser', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Morus bassanus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Myotis septentrionalis', 'hit_count': 2},
#    {'dictionary': 'ITIS', 'term': 'Myotis sodalis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Oncorhynchus gorbuscha', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Oncorhynchus mykiss', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Oncorhynchus tshawytscha', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Oreoscoptes montanus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Panicum virgatum', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pelecanus occidentalis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Podiceps grisegena', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Pterodroma sandwichensis', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Puffinus newelli', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Rhynchophanes mccownii', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Schoenoplectus acutus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Setophaga discolor', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Spizella breweri', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Sterna dougallii', 'hit_count': 2},
#    {'dictionary': 'ITIS',
#     'term': 'Tympanuchus pallidicinctus',
#     'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Ursus americanus', 'hit_count': 1},
#    {'dictionary': 'ITIS', 'term': 'Vulpes velox', 'hit_count': 1},
#    {'dictionary': 'ITIS',
#     'term': 'Xerospermophilus mohavensis',
#     'hit_count': 3}]}]

# %% [markdown]
# My recommendation is to replace the previously developed process that works against an export of references from the Zotero library with this process that runs directly against the online library via the API. But to check things out at this point, if we did everything right, we should be able to pull up the stashed file from the process that generated the WLCI species list from literature and have the same number of scientific names and the two lists should exactly match when sorted. Sure enough...

# %%
with open("../sources/WLCI_Species_List_from_Literature.json", "r") as f:
    sp_list = json.loads(f.read())
sci_name_list = list(set([spp["Scientific Name"] for spp in sp_list]))
sci_name_list.sort()

print(len(scientific_name_list))
print(len(sci_name_list))
print(sci_name_list == scientific_name_list)
# Out:
# 162
# 162
# True
