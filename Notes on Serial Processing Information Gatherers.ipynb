# %% [markdown]
# After fixing my dumb mistake in the bispy package, the code here will work now. This notebook uses a similar process to what we worked out to build the name list to work with from the ITIS data. I've provided a few notes on what's going on for your reference.

# %%
import json
import bispy
from IPython.display import display
from collections import Counter

sgcn = bispy.sgcn.Search()

# %%
with open('cache/itis.json', 'r') as f:
    itis_cache = json.loads(f.read())
    f.close()

# %% [markdown]
# I also fixed the problem where those two scientific names were not getting routed to the appropriate ITIS search. I re-ran the ITIS cache process and dumped out a new file. The following show the number of records in the raw cache and then the number of records if we select for only successful records. They show the same number now.

# %%
len(itis_cache)
# Out:
# 116

# %%
len([i for i in itis_cache if i["processing_metadata"]["status"] == "success"])
# Out:
# 116

# %% [markdown]
# Because we know every record is usable, we can make the process of building our list simpler. We don't need the conditional piece.

# %%
lookup_name_list = list()
for itis_doc_set in itis_cache:
    for itis_doc in itis_doc_set["itis_data"]:
        lookup_name_list.append({
            "scientific_name": itis_doc["nameWInd"],
            "itis_usage": itis_doc["usage"]
        })

# %% [markdown]
# We see here now that we have more names to look up because we are using both valid and invalid/accepted and not accepted names from ITIS.

# %%
len(lookup_name_list)
# Out:
# 122

# %% [markdown]
# We can now run the loop over the names the way we were going to and produce a set of information from one of the sources like the SGCN case we started with. In this case, I pass in the "itis_usage" property as an optional variable called name_source to this function where it comes back with the data. This lets us look to see what all cases were found with the invalid vs. valid ITIS names below. I go ahead and put the data from SGCN into their own list of documents so that we can look at the results again. This will take a few seconds to run because we are working through each record sequentially.

# %%
# %%time
sgcn_info = []
for name in lookup_name_list:
    sgcn_info.append(sgcn.search(name["scientific_name"], name_source=name["itis_usage"]))
# Out:
# CPU times: user 2.47 s, sys: 205 ms, total: 2.67 s
# Wall time: 1min 5s

# %%
sgcn_info
# Out:
# [{'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:12.923217',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Procapra gutturosa'},
#   'parameters': {'Scientific Name': 'Procapra gutturosa',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:13.566322',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Salvelinus namaycush'},
#   'parameters': {'Scientific Name': 'Salvelinus namaycush',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Illinois,Maine,Montana,New Hampshire,Ohio,Vermont',
#    'statelist_2015': 'Alaska,Illinois,Maine,Montana,New Hampshire,New York,Vermont',
#    'scientificname': 'Salvelinus namaycush',
#    'commonname': 'lake trout',
#    'taxonomicgroup': 'Fish',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=162002'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:14.180235',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Pinus flexilis'},
#   'parameters': {'Scientific Name': 'Pinus flexilis',
#    'Name Source': 'accepted'},
#   'sgcn_species': {'statelist_2005': 'Nebraska',
#    'statelist_2015': 'Nebraska',
#    'scientificname': 'Pinus flexilis',
#    'commonname': 'limber pine',
#    'taxonomicgroup': 'Plants',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=183343'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:14.766010',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Ovis canadensis'},
#   'parameters': {'Scientific Name': 'Ovis canadensis', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Colorado,Idaho,Utah,Wyoming',
#    'statelist_2015': 'Colorado,Idaho,Nevada,Utah,Washington,Wyoming',
#    'scientificname': 'Ovis canadensis',
#    'commonname': 'bighorn sheep',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180711'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:15.416613',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Amelanchier alnifolia'},
#   'parameters': {'Scientific Name': 'Amelanchier alnifolia',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:16.023805',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Peromyscus keeni'},
#   'parameters': {'Scientific Name': 'Peromyscus keeni',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alaska',
#    'statelist_2015': 'Alaska',
#    'scientificname': 'Peromyscus keeni',
#    'commonname': "Keen's Mouse",
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=552497'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:16.637997',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Tamiasciurus hudsonicus'},
#   'parameters': {'Scientific Name': 'Tamiasciurus hudsonicus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Georgia,Illinois,Iowa,Ohio,Tennessee',
#    'statelist_2015': 'Alaska,Georgia,Illinois,Tennessee',
#    'scientificname': 'Tamiasciurus hudsonicus',
#    'commonname': 'Red Squirrel',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180166'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:17.258175',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Oncorhynchus clarkii'},
#   'parameters': {'Scientific Name': 'Oncorhynchus clarkii',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Oregon,Wyoming',
#    'statelist_2015': 'Wyoming',
#    'scientificname': 'Oncorhynchus clarkii',
#    'commonname': 'cutthroat trout',
#    'taxonomicgroup': 'Fish',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=161983'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:17.736402',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Canis latrans'},
#   'parameters': {'Scientific Name': 'Canis latrans', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Delaware,Ohio',
#    'statelist_2015': '',
#    'scientificname': 'Canis latrans',
#    'commonname': 'Coyote',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180599'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:18.277729',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Orgyia pseudotsugata'},
#   'parameters': {'Scientific Name': 'Orgyia pseudotsugata',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:18.748985',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Urocitellus armatus'},
#   'parameters': {'Scientific Name': 'Urocitellus armatus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Wyoming',
#    'statelist_2015': '',
#    'scientificname': 'Urocitellus armatus',
#    'commonname': 'Uinta Ground Squirrel',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=930314'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:19.305318',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Antilocapra americana'},
#   'parameters': {'Scientific Name': 'Antilocapra americana',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Texas,Washington',
#    'statelist_2015': 'California,Texas',
#    'scientificname': 'Antilocapra americana',
#    'commonname': 'pronghorn',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180717'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:19.766988',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Oreoscoptes montanus'},
#   'parameters': {'Scientific Name': 'Oreoscoptes montanus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arizona,Montana,Nebraska,New Mexico,Utah,Washington,Wyoming',
#    'statelist_2015': 'Arizona,Idaho,Nevada,Washington,Wyoming',
#    'scientificname': 'Oreoscoptes montanus',
#    'commonname': 'Sage Thrasher',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=178654'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:20.328957',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Branta canadensis'},
#   'parameters': {'Scientific Name': 'Branta canadensis',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arizona,Delaware,Ohio',
#    'statelist_2015': 'Delaware,New Jersey,Rhode Island',
#    'scientificname': 'Branta canadensis',
#    'commonname': 'Canada Goose',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=174999'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:20.782072',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Picea engelmannii'},
#   'parameters': {'Scientific Name': 'Picea engelmannii',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:21.349744',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Canis lupus'},
#   'parameters': {'Scientific Name': 'Canis lupus', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Colorado,Idaho,Illinois,Maine,Michigan,Minnesota,Missouri,Montana,New York,North Carolina,North Dakota,Ohio,Utah,Washington,Wisconsin',
#    'statelist_2015': 'California,Colorado,Illinois,New Hampshire,Oregon,Utah,Washington',
#    'scientificname': 'Canis lupus',
#    'commonname': 'Wolf',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Fuzzy Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180596'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:21.760418',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Artemisia cana'},
#   'parameters': {'Scientific Name': 'Artemisia cana',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:22.171249',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Potorous tridactylus'},
#   'parameters': {'Scientific Name': 'Potorous tridactylus',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:22.579609',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Arctostaphylos patula'},
#   'parameters': {'Scientific Name': 'Arctostaphylos patula',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:22.992496',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Betula nana'},
#   'parameters': {'Scientific Name': 'Betula nana', 'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:23.608219',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Pseudoroegneria spicata'},
#   'parameters': {'Scientific Name': 'Pseudoroegneria spicata',
#    'Name Source': 'accepted'},
#   'sgcn_species': {'statelist_2005': 'Nebraska',
#    'statelist_2015': 'Nebraska',
#    'scientificname': 'Pseudoroegneria spicata',
#    'commonname': 'Bluebunch Wheatgrass',
#    'taxonomicgroup': 'Plants',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=504637'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:24.215612',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Connochaetes taurinus'},
#   'parameters': {'Scientific Name': 'Connochaetes taurinus',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:24.829352',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Artemisiospiza belli'},
#   'parameters': {'Scientific Name': 'Artemisiospiza belli',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Colorado,Montana,Nevada,New Mexico,Oregon,Utah,Washington,Wyoming',
#    'statelist_2015': 'Arizona,Colorado,Nevada,Wyoming',
#    'scientificname': 'Artemisiospiza belli',
#    'commonname': "Bell's Sparrow",
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=997724'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:25.449611',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Amphispiza belli'},
#   'parameters': {'Scientific Name': 'Amphispiza belli',
#    'Name Source': 'invalid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:26.679757',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Descurainia sophia'},
#   'parameters': {'Scientific Name': 'Descurainia sophia',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:27.289137',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Phleum pratense'},
#   'parameters': {'Scientific Name': 'Phleum pratense',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:27.872977',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Reithrodontomys megalotis'},
#   'parameters': {'Scientific Name': 'Reithrodontomys megalotis',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arkansas,California,Minnesota',
#    'statelist_2015': 'Arkansas,California,Minnesota',
#    'scientificname': 'Reithrodontomys megalotis',
#    'commonname': 'Western Harvest Mouse',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180343'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:28.316975',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Cercocarpus ledifolius'},
#   'parameters': {'Scientific Name': 'Cercocarpus ledifolius',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:28.886480',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Microtus agrestis'},
#   'parameters': {'Scientific Name': 'Microtus agrestis',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:29.310751',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Lepus townsendii'},
#   'parameters': {'Scientific Name': 'Lepus townsendii',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California,Colorado,Iowa,Kansas,Missouri,Nebraska,Oregon,Washington,Wisconsin',
#    'statelist_2015': 'Colorado,Iowa,Minnesota,Nebraska,Oregon,Washington',
#    'scientificname': 'Lepus townsendii',
#    'commonname': 'white-tailed jack rabbit',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180118'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:29.753724',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Dendroctonus ponderosae'},
#   'parameters': {'Scientific Name': 'Dendroctonus ponderosae',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:30.358942',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Corvus corax'},
#   'parameters': {'Scientific Name': 'Corvus corax', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alabama,Connecticut,Kentucky,Maryland,Missouri,Ohio,South Carolina,Tennessee',
#    'statelist_2015': 'Alabama,Kentucky,North Carolina,South Carolina',
#    'scientificname': 'Corvus corax',
#    'commonname': 'Common Raven',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=179725'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:30.775386',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Sphaeralcea coccinea'},
#   'parameters': {'Scientific Name': 'Sphaeralcea coccinea',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:31.163389',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Elymus elymoides'},
#   'parameters': {'Scientific Name': 'Elymus elymoides',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:31.593004',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Cottus bairdii'},
#   'parameters': {'Scientific Name': 'Cottus bairdii', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Illinois,Iowa,Maryland,New Mexico,South Carolina,Vermont,Wyoming',
#    'statelist_2015': 'Delaware,Iowa,Maryland,Ohio,Vermont',
#    'scientificname': 'Cottus bairdii',
#    'commonname': 'mottled sculpin',
#    'taxonomicgroup': 'Fish',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=167237'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:32.205707',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Colinus virginianus'},
#   'parameters': {'Scientific Name': 'Colinus virginianus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arkansas,Connecticut,Delaware,District of Columbia,Florida,Georgia,Illinois,Iowa,Kansas,Kentucky,Louisiana,Maryland,Massachusetts,Michigan,Mississippi,Nebraska,New Jersey,New York,North Carolina,Ohio,Oklahoma,Pennsylvania,Rhode Island,South Carolina,Texas,Virginia,West Virginia,Wisconsin',
#    'statelist_2015': 'Arkansas,Colorado,Delaware,District of Columbia,Florida,Georgia,Illinois,Iowa,Kansas,Kentucky,Louisiana,Maryland,Massachusetts,Mississippi,Missouri,New Jersey,New York,North Carolina,Ohio,Oklahoma,South Carolina,Tennessee,Texas,Virginia,West Virginia,Wisconsin',
#    'scientificname': 'Colinus virginianus',
#    'commonname': 'Northern Bobwhite',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=175863'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:32.818103',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Pascopyrum smithii'},
#   'parameters': {'Scientific Name': 'Pascopyrum smithii',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:33.232551',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Tamias minimus'},
#   'parameters': {'Scientific Name': 'Tamias minimus', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arizona,Michigan,Nebraska',
#    'statelist_2015': 'Arizona,Nebraska',
#    'scientificname': 'Tamias minimus',
#    'commonname': 'Least Chipmunk',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180195'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:33.847570',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Shepherdia canadensis'},
#   'parameters': {'Scientific Name': 'Shepherdia canadensis',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:34.461944',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Ursus arctos'},
#   'parameters': {'Scientific Name': 'Ursus arctos', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Colorado,Idaho,Montana,Utah,Washington,Wyoming',
#    'statelist_2015': 'California,Colorado,Idaho,Montana,Washington',
#    'scientificname': 'Ursus arctos',
#    'commonname': 'Brown Bear',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180543'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:35.076383',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Centrocercus minimus'},
#   'parameters': {'Scientific Name': 'Centrocercus minimus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Colorado,Utah',
#    'statelist_2015': 'Colorado,Utah',
#    'scientificname': 'Centrocercus minimus',
#    'commonname': 'Gunnison Sage Grouse',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=677540'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:35.492406',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Haliaeetus leucocephalus'},
#   'parameters': {'Scientific Name': 'Haliaeetus leucocephalus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alaska,Arizona,Arkansas,California,Colorado,Connecticut,Delaware,District of Columbia,Florida,Georgia,Idaho,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Maine,Maryland,Massachusetts,Michigan,Minnesota,Mississippi,Missouri,Montana,Nebraska,Nevada,New Hampshire,New Jersey,New Mexico,New York,North Carolina,North Dakota,Ohio,Oklahoma,Oregon,Pennsylvania,Rhode Island,South Carolina,South Dakota,Tennessee,Texas,Utah,Vermont,Virginia,Washington,West Virginia,Wisconsin,Wyoming',
#    'statelist_2015': 'Alaska,Arizona,California,Colorado,Connecticut,Delaware,District of Columbia,Florida,Georgia,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Maryland,Massachusetts,Michigan,Mississippi,Missouri,Nebraska,Nevada,New Hampshire,New Jersey,New Mexico,New York,North Carolina,North Dakota,Oklahoma,Pennsylvania,Rhode Island,South Carolina,South Dakota,Tennessee,Texas,Utah,Vermont,Washington,West Virginia,Wyoming',
#    'scientificname': 'Haliaeetus leucocephalus',
#    'commonname': 'Bald Eagle',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=175420'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:35.995642',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Zea mays'},
#   'parameters': {'Scientific Name': 'Zea mays', 'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:36.509259',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Alces alces'},
#   'parameters': {'Scientific Name': 'Alces alces', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Massachusetts,Michigan,Wisconsin,Wyoming',
#    'statelist_2015': 'Vermont,Wyoming',
#    'scientificname': 'Alces alces',
#    'commonname': 'moose',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180703'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:37.015057',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Artemisiospiza nevadensis'},
#   'parameters': {'Scientific Name': 'Artemisiospiza nevadensis',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': '',
#    'statelist_2015': 'Idaho,New Mexico,Oregon,Washington',
#    'scientificname': 'Artemisiospiza nevadensis',
#    'commonname': 'Sagebrush Sparrow',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=997723'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:37.531640',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Cronartium ribicola'},
#   'parameters': {'Scientific Name': 'Cronartium ribicola',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:38.028265',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Clupea pallasii'},
#   'parameters': {'Scientific Name': 'Clupea pallasii', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Washington',
#    'statelist_2015': 'Alaska,Oregon,Washington',
#    'scientificname': 'Clupea pallasii',
#    'commonname': 'Pacific herring',
#    'taxonomicgroup': 'Fish',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=551209'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:38.555071',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Spizella breweri'},
#   'parameters': {'Scientific Name': 'Spizella breweri',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California,Colorado,Idaho,Montana,Nebraska,Nevada,North Dakota,Oregon,Texas,Utah,Wyoming',
#    'statelist_2015': 'Arizona,Colorado,Nebraska,Nevada,North Dakota,Wyoming',
#    'scientificname': 'Spizella breweri',
#    'commonname': "Brewer's Sparrow",
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=179440'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:39.046604',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Capreolus capreolus'},
#   'parameters': {'Scientific Name': 'Capreolus capreolus',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:39.576777',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Kochia prostrata'},
#   'parameters': {'Scientific Name': 'Kochia prostrata',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:39.977760',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Bassia prostrata'},
#   'parameters': {'Scientific Name': 'Bassia prostrata',
#    'Name Source': 'not accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:40.601956',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Microtus californicus'},
#   'parameters': {'Scientific Name': 'Microtus californicus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California',
#    'statelist_2015': 'California',
#    'scientificname': 'Microtus californicus',
#    'commonname': 'Amargosa Vole',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180305'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:41.213328',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Atriplex canescens'},
#   'parameters': {'Scientific Name': 'Atriplex canescens',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:41.832349',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Lepidochelys olivacea'},
#   'parameters': {'Scientific Name': 'Lepidochelys olivacea',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alaska,Hawaii',
#    'statelist_2015': 'California,Hawaii',
#    'scientificname': 'Lepidochelys olivacea',
#    'commonname': 'Pacific ridley',
#    'taxonomicgroup': 'Reptiles',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=173840'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:42.443631',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Buteo regalis'},
#   'parameters': {'Scientific Name': 'Buteo regalis', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arizona,California,Colorado,Idaho,Kansas,Montana,Nebraska,Nevada,New Mexico,North Dakota,Oklahoma,Oregon,South Dakota,Texas,Utah,Washington,Wyoming',
#    'statelist_2015': 'Arizona,Colorado,Idaho,Kansas,Nebraska,Nevada,North Dakota,Oklahoma,Oregon,South Dakota,Texas,Utah,Washington,Wyoming',
#    'scientificname': 'Buteo regalis',
#    'commonname': 'Ferruginous Hawk',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=175377'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:43.063516',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Bromus tectorum'},
#   'parameters': {'Scientific Name': 'Bromus tectorum',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:43.674059',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Equus quagga burchellii'},
#   'parameters': {'Scientific Name': 'Equus quagga burchellii',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:44.286697',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Equus burchelli'},
#   'parameters': {'Scientific Name': 'Equus burchelli',
#    'Name Source': 'invalid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:44.905206',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Pinus contorta'},
#   'parameters': {'Scientific Name': 'Pinus contorta',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:45.522957',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Achnatherum hymenoides'},
#   'parameters': {'Scientific Name': 'Achnatherum hymenoides',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:46.140203',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Atriplex argentea'},
#   'parameters': {'Scientific Name': 'Atriplex argentea',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:46.746317',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Cercocarpus montanus'},
#   'parameters': {'Scientific Name': 'Cercocarpus montanus',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:47.164430',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Abies lasiocarpa'},
#   'parameters': {'Scientific Name': 'Abies lasiocarpa',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:47.767175',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Prunus virginiana'},
#   'parameters': {'Scientific Name': 'Prunus virginiana',
#    'Name Source': 'accepted'},
#   'sgcn_species': {'statelist_2005': '',
#    'statelist_2015': 'Tennessee',
#    'scientificname': 'Prunus virginiana',
#    'commonname': 'chokecherry',
#    'taxonomicgroup': 'Plants',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=24806'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:48.238080',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Brachylagus idahoensis'},
#   'parameters': {'Scientific Name': 'Brachylagus idahoensis',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California,Idaho,Montana,Nevada,Oregon,Utah,Washington,Wyoming',
#    'statelist_2015': 'California,Colorado,Idaho,Nevada,Oregon,Utah,Washington,Wyoming',
#    'scientificname': 'Brachylagus idahoensis',
#    'commonname': 'Pygmy Rabbit',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=552521'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:48.791993',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Suaeda maritima'},
#   'parameters': {'Scientific Name': 'Suaeda maritima',
#    'Name Source': 'accepted'},
#   'sgcn_species': {'statelist_2005': '',
#    'statelist_2015': 'Massachusetts',
#    'scientificname': 'Suaeda maritima',
#    'commonname': 'herbaceous seepweed',
#    'taxonomicgroup': 'Plants',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=20662'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:49.214783',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Fringilla montifringilla'},
#   'parameters': {'Scientific Name': 'Fringilla montifringilla',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alaska',
#    'statelist_2015': '',
#    'scientificname': 'Fringilla montifringilla',
#    'commonname': 'Brambling',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=179167'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:49.819692',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Passer domesticus'},
#   'parameters': {'Scientific Name': 'Passer domesticus',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:50.233048',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Rangifer tarandus groenlandicus'},
#   'parameters': {'Scientific Name': 'Rangifer tarandus groenlandicus',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:50.842458',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Hesperostipa comata'},
#   'parameters': {'Scientific Name': 'Hesperostipa comata',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:51.350741',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Lanius ludovicianus'},
#   'parameters': {'Scientific Name': 'Lanius ludovicianus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California,Colorado,Delaware,Florida,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Maine,Maryland,Minnesota,Mississippi,Missouri,Montana,Nevada,New Jersey,New Mexico,New York,North Carolina,North Dakota,Ohio,Oklahoma,Oregon,Pennsylvania,South Carolina,Tennessee,Texas,Virginia,Washington,Wisconsin',
#    'statelist_2015': 'Alabama,Arkansas,California,Colorado,Delaware,Florida,Georgia,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Maryland,Minnesota,Mississippi,Missouri,Nebraska,Nevada,New Mexico,New York,North Carolina,North Dakota,Ohio,Oklahoma,Oregon,Pennsylvania,South Carolina,Tennessee,Texas,Virginia,Washington,West Virginia,Wisconsin',
#    'scientificname': 'Lanius ludovicianus',
#    'commonname': 'Loggerhead Shrike',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=178515'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:51.868895',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Macaca sylvanus'},
#   'parameters': {'Scientific Name': 'Macaca sylvanus',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:52.480256',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Halogeton glomeratus'},
#   'parameters': {'Scientific Name': 'Halogeton glomeratus',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:53.097041',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Oncorhynchus nerka'},
#   'parameters': {'Scientific Name': 'Oncorhynchus nerka',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Idaho',
#    'statelist_2015': 'Alaska,Idaho,Washington',
#    'scientificname': 'Oncorhynchus nerka',
#    'commonname': 'blueback salmon',
#    'taxonomicgroup': 'Fish',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=161979'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:53.555617',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Vulpes vulpes'},
#   'parameters': {'Scientific Name': 'Vulpes vulpes', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arizona,Ohio',
#    'statelist_2015': 'Arizona',
#    'scientificname': 'Vulpes vulpes',
#    'commonname': 'Red Fox',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180604'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:54.122382',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Peromyscus maniculatus'},
#   'parameters': {'Scientific Name': 'Peromyscus maniculatus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California,Connecticut,Ohio',
#    'statelist_2015': 'Connecticut',
#    'scientificname': 'Peromyscus maniculatus',
#    'commonname': 'Deer Mouse',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180276'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:54.736927',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Dendroctonus pseudotsugae'},
#   'parameters': {'Scientific Name': 'Dendroctonus pseudotsugae',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:55.095471',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Populus tremuloides'},
#   'parameters': {'Scientific Name': 'Populus tremuloides',
#    'Name Source': 'accepted'},
#   'sgcn_species': {'statelist_2005': 'Missouri,Nebraska',
#    'statelist_2015': 'Nebraska',
#    'scientificname': 'Populus tremuloides',
#    'commonname': 'quaking aspen',
#    'taxonomicgroup': 'Plants',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=195773'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:55.553657',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Puccinellia rupestris'},
#   'parameters': {'Scientific Name': 'Puccinellia rupestris',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:55.963089',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Catostomus platyrhynchus'},
#   'parameters': {'Scientific Name': 'Catostomus platyrhynchus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California,Colorado,Nebraska,South Dakota,Washington,Wyoming',
#    'statelist_2015': 'California,Colorado,South Dakota,Washington',
#    'scientificname': 'Catostomus platyrhynchus',
#    'commonname': 'mountain sucker',
#    'taxonomicgroup': 'Fish',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=163909'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:56.372766',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Purshia tridentata'},
#   'parameters': {'Scientific Name': 'Purshia tridentata',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:56.987014',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Brucella melitensis'},
#   'parameters': {'Scientific Name': 'Brucella melitensis',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:57.604885',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Brucella abortus'},
#   'parameters': {'Scientific Name': 'Brucella abortus',
#    'Name Source': 'invalid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:58.010549',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Elymus lanceolatus'},
#   'parameters': {'Scientific Name': 'Elymus lanceolatus',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:17:58.627683',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Artemisia tridentata ssp. wyomingensis'},
#   'parameters': {'Scientific Name': 'Artemisia tridentata ssp. wyomingensis',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:59.243340',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Leymus cinereus'},
#   'parameters': {'Scientific Name': 'Leymus cinereus',
#    'Name Source': 'accepted'},
#   'sgcn_species': {'statelist_2005': '',
#    'statelist_2015': 'Nebraska',
#    'scientificname': 'Leymus cinereus',
#    'commonname': 'Great Basin Wild-rye',
#    'taxonomicgroup': 'Plants',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=503433'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:17:59.856105',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Castor canadensis'},
#   'parameters': {'Scientific Name': 'Castor canadensis',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alaska,Arizona,New Mexico,Ohio',
#    'statelist_2015': 'Arizona,California,District of Columbia',
# ...
#    'statelist_2015': 'Alabama,Kentucky,Massachusetts,Mississippi,Missouri,Ohio,Rhode Island,South Carolina,Texas',
#    'scientificname': 'Ursus americanus',
#    'commonname': 'American Black Bear',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180544'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:03.742500',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Procyon lotor'},
#   'parameters': {'Scientific Name': 'Procyon lotor', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Ohio',
#    'statelist_2015': '',
#    'scientificname': 'Procyon lotor',
#    'commonname': 'Raccoon',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180575'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:04.359192',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Thrichomys pachyurus'},
#   'parameters': {'Scientific Name': 'Thrichomys pachyurus',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:04.972409',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Thrichomys fosteri'},
#   'parameters': {'Scientific Name': 'Thrichomys fosteri',
#    'Name Source': 'invalid'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:05.405080',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Odocoileus hemionus'},
#   'parameters': {'Scientific Name': 'Odocoileus hemionus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Nevada,New Mexico,Utah',
#    'statelist_2015': 'Nevada',
#    'scientificname': 'Odocoileus hemionus',
#    'commonname': 'mule deer',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180698'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:06.000646',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Juniperus communis var. depressa'},
#   'parameters': {'Scientific Name': 'Juniperus communis var. depressa',
#    'Name Source': 'accepted'},
#   'sgcn_species': {'statelist_2005': 'Georgia',
#    'statelist_2015': 'Georgia,South Carolina',
#    'scientificname': 'Juniperus communis var. depressa',
#    'commonname': 'common juniper',
#    'taxonomicgroup': 'Plants',
#    'taxonomicrank': 'Variety',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=528646'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:06.445094',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Festuca idahoensis'},
#   'parameters': {'Scientific Name': 'Festuca idahoensis',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:07.018978',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Centrocercus urophasianus'},
#   'parameters': {'Scientific Name': 'Centrocercus urophasianus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'California,Colorado,Idaho,Montana,Nebraska,Nevada,North Dakota,Oregon,South Dakota,Utah,Washington,Wyoming',
#    'statelist_2015': 'California,Colorado,Idaho,Montana,Nevada,North Dakota,Oregon,South Dakota,Utah,Washington,Wyoming',
#    'scientificname': 'Centrocercus urophasianus',
#    'commonname': 'Greater Sage Grouse',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=175855'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:07.452286',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Rangifer tarandus'},
#   'parameters': {'Scientific Name': 'Rangifer tarandus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Idaho,Washington',
#    'statelist_2015': 'Idaho,Washington',
#    'scientificname': 'Rangifer tarandus',
#    'commonname': 'reindeer',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180701'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:08.047247',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Kochia prostrata'},
#   'parameters': {'Scientific Name': 'Kochia prostrata',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:08.467865',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Falco sparverius'},
#   'parameters': {'Scientific Name': 'Falco sparverius',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alabama,Connecticut,Kentucky,Massachusetts,New Jersey,North Carolina,Ohio,Rhode Island,Texas,Vermont,Virgin Islands',
#    'statelist_2015': 'Alaska,Arkansas,Connecticut,Delaware,District of Columbia,Iowa,Kentucky,Maine,Maryland,Massachusetts,Minnesota,New Hampshire,New Jersey,New York,North Carolina,North Dakota,Pennsylvania,Rhode Island,Texas,Vermont,West Virginia',
#    'scientificname': 'Falco sparverius',
#    'commonname': 'American Kestrel',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=175622'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:09.069755',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Otis tarda'},
#   'parameters': {'Scientific Name': 'Otis tarda', 'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:09.539741',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Pseudotsuga menziesii'},
#   'parameters': {'Scientific Name': 'Pseudotsuga menziesii',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:10.025661',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Atriplex gardneri'},
#   'parameters': {'Scientific Name': 'Atriplex gardneri',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:10.444704',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Lullula arborea'},
#   'parameters': {'Scientific Name': 'Lullula arborea',
#    'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:10.918171',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Juniperus communis'},
#   'parameters': {'Scientific Name': 'Juniperus communis',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:11.324229',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Lyrurus tetrix'},
#   'parameters': {'Scientific Name': 'Lyrurus tetrix', 'Name Source': 'valid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:11.730527',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Tetrao tetrix'},
#   'parameters': {'Scientific Name': 'Tetrao tetrix',
#    'Name Source': 'invalid'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:12.142628',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Ericameria nauseosa'},
#   'parameters': {'Scientific Name': 'Ericameria nauseosa',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:12.762346',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Cervus elaphus'},
#   'parameters': {'Scientific Name': 'Cervus elaphus', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alabama,Minnesota,Nebraska,Ohio',
#    'statelist_2015': 'Alabama,North Carolina',
#    'scientificname': 'Cervus elaphus',
#    'commonname': 'elk',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180695'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:13.371073',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Bison bison'},
#   'parameters': {'Scientific Name': 'Bison bison', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alabama,Alaska,Colorado,Missouri,Montana,North Carolina,Ohio',
#    'statelist_2015': 'Alabama,Colorado,Montana,Texas,Utah',
#    'scientificname': 'Bison bison',
#    'commonname': 'American bison',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180706'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:13.764112',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Artemisia tridentata'},
#   'parameters': {'Scientific Name': 'Artemisia tridentata',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:14.190352',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Taxidea taxus'},
#   'parameters': {'Scientific Name': 'Taxidea taxus', 'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arkansas,California,Illinois,Indiana,Minnesota,Missouri,Ohio,Texas,Washington',
#    'statelist_2015': 'Arkansas,California,Indiana,Minnesota,Missouri,Ohio,Texas,Washington',
#    'scientificname': 'Taxidea taxus',
#    'commonname': 'American Badger',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180565'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:14.804292',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Sarcobatus vermiculatus'},
#   'parameters': {'Scientific Name': 'Sarcobatus vermiculatus',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:15.421678',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Aquila chrysaetos'},
#   'parameters': {'Scientific Name': 'Aquila chrysaetos',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Alaska,California,Colorado,Kansas,Maine,Maryland,Montana,Nebraska,New Hampshire,New Mexico,New York,North Dakota,Pennsylvania,Tennessee,Texas,Washington',
#    'statelist_2015': 'Alabama,Arizona,Colorado,Delaware,Idaho,Kansas,Maine,Maryland,Mississippi,Nebraska,Nevada,New Hampshire,New Jersey,New York,North Dakota,Oklahoma,Pennsylvania,Tennessee,Texas,Utah,Virginia,Washington,West Virginia',
#    'scientificname': 'Aquila chrysaetos',
#    'commonname': 'Golden Eagle',
#    'taxonomicgroup': 'Birds',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=175407'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:15.837630',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Ictidomys tridecemlineatus'},
#   'parameters': {'Scientific Name': 'Ictidomys tridecemlineatus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Arizona,Missouri,Ohio,Utah',
#    'statelist_2015': 'Arizona,Missouri,Ohio',
#    'scientificname': 'Ictidomys tridecemlineatus',
#    'commonname': 'Thirteen-lined Ground Squirrel',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=930308'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:17.258769',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Oncorhynchus clarkii pleuriticus'},
#   'parameters': {'Scientific Name': 'Oncorhynchus clarkii pleuriticus',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'Colorado,Utah,Wyoming',
#    'statelist_2015': 'Colorado,Utah,Wyoming',
#    'scientificname': 'Oncorhynchus clarkii pleuriticus',
#    'commonname': 'Colorado River cutthroat trout',
#    'taxonomicgroup': 'Fish',
#    'taxonomicrank': 'Subspecies',
#    'matchmethod': 'Followed Accepted TSN',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=553429'}},
#  {'processing_metadata': {'status': 'failure',
#    'date_processed': '2019-08-02T20:18:17.667496',
#    'status_message': 'Not Matched',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Krascheninnikovia lanata'},
#   'parameters': {'Scientific Name': 'Krascheninnikovia lanata',
#    'Name Source': 'accepted'}},
#  {'processing_metadata': {'status': 'success',
#    'date_processed': '2019-08-02T20:18:18.091925',
#    'status_message': 'Name Match',
#    'api': 'https://api.sciencebase.gov/bis-api/api/v1/swap/nationallist?scientificname=Glaucomys volans'},
#   'parameters': {'Scientific Name': 'Glaucomys volans',
#    'Name Source': 'valid'},
#   'sgcn_species': {'statelist_2005': 'District of Columbia,Iowa,Kansas,Nebraska,Ohio,Vermont',
#    'statelist_2015': 'District of Columbia,Iowa,Kansas,Nebraska,Ohio,Vermont',
#    'scientificname': 'Glaucomys volans',
#    'commonname': 'Southern Flying Squirrel',
#    'taxonomicgroup': 'Mammals',
#    'taxonomicrank': 'Species',
#    'matchmethod': 'Exact Match',
#    'acceptedauthorityurl': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180170'}}]

# %% [markdown]
# This is another utility function that can be used to quickly count how many records in a list like this fit into different categories. The following checks for how many total species we found in the SGCN list vs. not by looking at the processing_metadata/success property.

# %%
Counter(spp["processing_metadata"]["status"] for spp in sgcn_info)
# Out:
# Counter({'failure': 65, 'success': 57})

# %% [markdown]
# This counter looks at the values that we passed in from itis_usage to see how those are distributed across the successful results. It shows us that all 57 we matched to SGCN were done using the valid or accepted names.

# %%
Counter(spp["parameters"]["Name Source"] for spp in [r for r in sgcn_info if r["processing_metadata"]["status"] == "success"])
# Out:
# Counter({'valid': 50, 'accepted': 7})

# %% [markdown]
# Now we can look to see which WLCI species have been studied (or at least showed up in literature) that are on the Wyoming SGCN list. This is kind of a clunky way to do this query, but it works for our purposes. This doesn't tell us a whole lot, but it does show that USGS funding has been contributed to some of the species that the state of Wyoming considers to be a priority for conservation research and management.

# %%
sgcn_wy_names = []
for spp in [r["sgcn_species"] for r in sgcn_info if r["processing_metadata"]["status"] == "success"]:
    if "Wyoming" in spp["statelist_2005"] or "Wyoming" in spp["statelist_2015"]:
        print(spp["commonname"], '======', spp["scientificname"])
        sgcn_wy_names.append(spp["scientificname"])
# Out:
# bighorn sheep ====== Ovis canadensis
# cutthroat trout ====== Oncorhynchus clarkii
# Uinta Ground Squirrel ====== Urocitellus armatus
# Sage Thrasher ====== Oreoscoptes montanus
# Bell's Sparrow ====== Artemisiospiza belli
# mottled sculpin ====== Cottus bairdii
# Brown Bear ====== Ursus arctos
# Bald Eagle ====== Haliaeetus leucocephalus
# moose ====== Alces alces
# Brewer's Sparrow ====== Spizella breweri
# Ferruginous Hawk ====== Buteo regalis
# Pygmy Rabbit ====== Brachylagus idahoensis
# mountain sucker ====== Catostomus platyrhynchus
# Greater Sage Grouse ====== Centrocercus urophasianus
# Colorado River cutthroat trout ====== Oncorhynchus clarkii pleuriticus

# %% [markdown]
# Just to take this one step further (and because this is all "our" data), we can also look to see what Wyoming SGCN species from the latest 2015 data are not in the WLCI list. Of course, we don't know that these species actually occur in the WLCI geographic area, so we'd need to do some more work on making this at all meaningful. Our API for SGCN species is really clunky right now, so don't get too deep into this one.

# %%
import requests

r_sgcn_api = requests.get("https://api.sciencebase.gov/bis-api/api/v1/swap/state?state=Wyoming").json()

for hit in r_sgcn_api["hits"]["hits"]:
    if hit["_source"]["properties"]["sgcn2015"] == 1 and hit["_source"]["properties"]["sgcn2015"] not in sgcn_wy_names:
        print(hit["_source"]["properties"]["commonname"], "=====", hit["_source"]["properties"]["scientificname"])
# Out:
# Bobolink ===== Dolichonyx oryzivorus
# Trumpeter Swan ===== Cygnus buccinator
# Midget Faded Rattlesnake ===== Crotalus oreganus concolor
# mule-eared bat ===== Corynorhinus townsendii
# moose ===== Alces alces
# Yellow-billed Cuckoo ===== Coccyzus americanus
# Western Painted Turtle ===== Chrysemys picta bellii
# finescale dace ===== Chrosomus neogaeus
# Black Tern ===== Chlidonias niger
# Rubber Boa ===== Charina bottae
# Mountain Plover ===== Charadrius montanus
# Hispid Pocket Mouse ===== Chaetodipus hispidus
# Greater Sage Grouse ===== Centrocercus urophasianus
# flannelmouth sucker ===== Catostomus latipinnis
# bluehead sucker ===== Catostomus discobolus
# central stoneroller ===== Campostoma anomalum
# devil crayfish ===== Cambarus diogenes
# Chestnut-collared Longspur ===== Calcarius ornatus
# Lark Bunting ===== Calamospiza melanocorys
# Swainson's Hawk ===== Buteo swainsoni
# Ferruginous Hawk ===== Buteo regalis
# Boreal Owl ===== Aegolius funereus
# Barrow's Goldeneye ===== Bucephala islandica
# Pygmy Rabbit ===== Brachylagus idahoensis
# American Bittern ===== Botaurus lentiginosus
# Clark's Grebe ===== Aechmophorus clarkii
# Upland Sandpiper ===== Bartramia longicauda
# Meadow Jumping Mouse ===== Zapus hudsonius
# Spotted Ground Squirrel ===== Xerospermophilus spilosoma
# Juniper Titmouse ===== Baeolophus ridgwayi
# Swift Fox ===== Vulpes velox
# Canvasback ===== Aythya valisineria
# Redhead ===== Aythya americana
# Northern Tree Lizard ===== Urosaurus ornatus wrighti
# Lesser Scaup ===== Aythya affinis
# Columbian sharp-tailed grouse ===== Tympanuchus phasianellus columbianus
# Idaho Pocket Gopher ===== Thomomys idahoensis
# Wyoming Pocket Gopher ===== Thomomys clusius
# Red-sided Garter Snake ===== Thamnophis sirtalis parietalis
# Valley Garter Snake ===== Thamnophis sirtalis fitchi
# Plains Garter Snake ===== Thamnophis radix
# Ornate Box Turtle ===== Terrapene ornata ornata
# Plains Black-headed Snake ===== Tantilla nigriceps
# Burrowing Owl ===== Athene cunicularia
# Great Gray Owl ===== Strix nebulosa
# Black Hills Redbelly Snake ===== Storeria occipitomaculata pahasapae
# Forster's Tern ===== Sterna forsteri
# Brewer's Sparrow ===== Spizella breweri
# Dickcissel ===== Spiza americana
# Great Basin Spadefoot ===== Spea intermontana
# Plains Spadefoot ===== Spea bombifrons
# wandering shrew ===== Sorex vagrans
# malheur shrew ===== Sorex preblei
# Rocky Mountain dwarf shrew ===== Sorex nanus
# Pygmy Shrew ===== Sorex hoyi
# Hayden's shrew ===== Sorex haydeni
# Pygmy Nuthatch ===== Sitta pygmaea
# Prairie Racerunner ===== Aspidoscelis sexlineatus viridis
# Short-eared Owl ===== Asio flammeus
# Prairie Lizard ===== Sceloporus consobrinus
# shovelnose sturgeon ===== Scaphirhynchus platorynchus
# sauger ===== Sander canadensis
# Bell's Sparrow ===== Artemisiospiza belli
# McCown's Longspur ===== Rhynchophanes mccownii
# Kendall Warm Springs dace ===== Rhinichthys osculus thermalis
# Plains Harvest Mouse ===== Reithrodontomys montanus
# Columbia Spotted Frog ===== Rana luteiventris
# Virginia Rail ===== Rallus limicola
# Jackson Lake springsnail ===== Pyrgulopsis robusta
# giant floater ===== Pyganodon grandis
# Bushtit ===== Psaltriparus minimus
# mountain whitefish ===== Prosopium williamsoni
# Great Basin Skink ===== Plestiodon skiltonianus utahensis
# Northern Many-lined Skink ===== Plestiodon multivirgatus multivirgatus
# White-faced Ibis ===== Plegadis chihi
# flathead chub ===== Platygobio gracilis
# Great Basin Gopher Snake ===== Pituophis catenifer deserticola
# American Three-toed Woodpecker ===== Picoides dorsalis
# Black-backed Woodpecker ===== Picoides arcticus
# cave physa ===== Physella spelunca
# Greater Short-horned Lizard ===== Phrynosoma hernandesi
# suckermouth minnow ===== Phenacobius mirabilis
# piñon mouse ===== Peromyscus truei
# Canyon Mouse ===== Peromyscus crinitus
# Great Basin Pocket Mouse ===== Perognathus parvus
# Silky Pocket Mouse ===== Perognathus flavus
# Plains Pocket Mouse ===== Perognathus flavescens
# Olive-backed Pocket Mouse ===== Perognathus fasciatus
# Western Scrub-Jay ===== Aphelocoma californica
# Pilose Crayfish ===== Pacifastacus gambelii
# bighorn sheep ===== Ovis canadensis
# Sage Thrasher ===== Oreoscoptes montanus
# Northern Spiny Softshell Turtle ===== Apalone spinifera spinifera
# ringed crayfish ===== Orconectes neglectus
# calico crayfish ===== Orconectes immunis
# Smooth Greensnake ===== Opheodrys vernalis
# pallid bat ===== Antrozous pallidus
# Bonneville cutthroat trout ===== Oncorhynchus clarkii utah
# Colorado River cutthroat trout ===== Oncorhynchus clarkii pleuriticus
# Yellowstone cutthroat trout ===== Oncorhynchus clarkii bouvieri
# cutthroat trout ===== Oncorhynchus clarkii
# pika ===== Ochotona princeps
# Black-crowned Night Heron ===== Nycticorax nycticorax
# Long-billed Curlew ===== Numenius americanus
# hornyhead chub ===== Nocomis biguttatus
# Uinta Chipmunk ===== Neotamias umbrinus
# Cliff Chipmunk ===== Neotamias dorsalis
# Yellow-pine Chipmunk ===== Neotamias amoenus
# long-legged myotis ===== Myotis volans
# fringed myotis ===== Myotis thysanodes
# northern myotis ===== Myotis septentrionalis
# little brown bat ===== Myotis lucifugus
# cylindrical papershell ===== Anodontoides ferussacianus
# long-eared myotis ===== Myotis evotis
# western small-footed bat ===== Myotis ciliolabrum
# Ash-throated Flycatcher ===== Myiarchus cinerascens
# Least Weasel ===== Mustela nivalis
# California floater ===== Anodonta californiensis
# Black-footed Ferret ===== Mustela nigripes
# Water Vole ===== Microtus richardsoni
# Lewis's Woodpecker ===== Melanerpes lewis
# Fisher ===== Martes pennanti
# American Marten ===== Martes americana
# western pearlshell ===== Margaritifera falcata
# pearl dace ===== Margariscus margarita
# sturgeon chub ===== Macrhybopsis gelida
# Canadian Lynx ===== Lynx canadensis
# common shiner ===== Luxilus cornutus
# burbot ===== Lota lota
# North American River Otter ===== Lontra canadensis
# Wood Frog ===== Lithobates sylvaticus
# Northern Leopard Frog ===== Lithobates pipiens
# Great Plains Toad ===== Anaxyrus cognatus
# Boreal Toad ===== Anaxyrus boreas boreas
# Wyoming Toad ===== Anaxyrus baxteri
# Brown-capped Rosy Finch ===== Leucosticte australis
# Black Rosy Finch ===== Leucosticte atrata
# Franklin's Gull ===== Leucophaeus pipixcan
# leatherside chub ===== Lepidomeda copei
# white heelsplitter ===== Lasmigona complanata
# red bat ===== Lasiurus borealis
# Northern Pintail ===== Anas acuta
# fatmucket ===== Lampsilis siliquoidea
# plain pocketbook ===== Lampsilis cardium
# Pale Milk Snake ===== Lampropeltis triangulum multistriata
# Caspian Tern ===== Hydroprogne caspia
# bigmouth shiner ===== Hybopsis dorsalis
# plains minnow ===== Hybognathus placitus
# brassy minnow ===== Hybognathus hankinsoni
# western silvery minnow ===== Hybognathus argyritis
# Northern Earless Lizard ===== Holbrookia maculata maculata
# Harlequin Duck ===== Histrionicus histrionicus
# goldeye ===== Hiodon alosoides
# Western Hog-nosed Snake ===== Heterodon nasicus
# Grasshopper Sparrow ===== Ammodramus savannarum
# Bald Eagle ===== Haliaeetus leucocephalus
# Wolverine ===== Gulo gulo
# Sandhill Crane (Greater) ===== Grus canadensis tabida
# Northern Flying Squirrel ===== Glaucomys sabrinus
# Northern Pygmy-Owl ===== Glaucidium gnoma
# roundtail chub ===== Gila robusta
# Plains Pocket Gopher ===== Geomys bursarius
# Common Loon ===== Gavia immer
# plains topminnow ===== Fundulus sciadicus
# northern plains killifish ===== Fundulus kansae
# Peregrine Falcon ===== Falco peregrinus
# Merlin ===== Falco columbarius
# spotted bat ===== Euderma maculatum
# orangethroat darter ===== Etheostoma spectabile
# Iowa darter ===== Etheostoma exile
# big brown bat ===== Eptesicus fuscus
# Northern Goshawk ===== Accipiter gentilis
# Willow Flycatcher ===== Empidonax traillii
# Snowy Egret ===== Egretta thula
